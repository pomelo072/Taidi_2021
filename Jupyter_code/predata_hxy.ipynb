# %% [markdown]
# # 因子特征选取 第一版
#
# 本文档主要完成特征因子筛选, 主要是学习一下
#
# 参考论文:
#
# - [A股上市公司财务造假预测模型研究_陶能发](C:\Users\Pomelo\Desktop\Taidi_2021\论文\A股上市公司财务造假预测模型研究_陶能发.caj)
# - [中国上市公司财务造假预测模型](C:\Users\Pomelo\Desktop\Taidi_2021\论文\中国上市公司财务造假预测模型.pdf)
# - etc. 看一个写一个吧
#
#
# ## 导入库
# - pandas, numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 导入数据
#
# - 附件一

# %%
raw_data1 = pd.read_excel("../附件1.xlsx")
raw_data1
# Out:
#            股票代码              所属行业
# 0        4019.0               制造业
# 1        4213.0               制造业
# 2        8166.0               制造业
# 3        9063.0            批发和零售业
# 4       10083.0   信息传输、软件和信息技术服务业
# ...         ...               ...
# 4158  4993201.0               制造业
# 4159  4993297.0  电力、热力、燃气及水生产和供应业
# 4160  4997833.0        科学研究和技术服务业
# 4161  4998808.0               制造业
# 4162  4999709.0               制造业
#
# [4163 rows x 2 columns]

# %% [markdown]
# - 附件二

# %%
raw_data2 = pd.read_csv("../附件2.csv")
raw_data2
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 0               4019            3             3             2         1
# 1               8166            3             3             2         1
# 2               9063            3             3             2         1
# 3              10083            4             4             4         1
# 4              11737            3             3             2         1
# ...              ...          ...           ...           ...       ...
# 22208        4993201            7             7             7         6
# 22209        4993297            7             7             7         6
# 22210        4997833            7             7             7         6
# 22211        4998808            7             7             7         6
# 22212        4999709            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# 0               A             12            1           CHAS_2007         CNY
# 1               A             12            1           CHAS_2007         CNY
# 2               A             12            1           CHAS_2007         CNY
# 3               A             12            1           CHAS_2007         CNY
# 4               A             12            1           CHAS_2007         CNY
# ...           ...            ...          ...                 ...         ...
# 22208           A             12            1           CHAS_2007         CNY
# 22209           A             12            1           CHAS_2007         CNY
# 22210           A             12            1           CHAS_2007         CNY
# 22211           A             12            1           CHAS_2007         CNY
# 22212           A             12            1           CHAS_2007         CNY
#
#        ...  CA_TURNOVER  OPER_CYCLE  INVEN_TURNOVER  FA_TURNOVER  \
# 0      ...          NaN         NaN             NaN          NaN
# 1      ...          NaN         NaN             NaN          NaN
# 2      ...       1.3751    148.8938          7.4240      20.9362
# 3      ...          NaN         NaN             NaN          NaN
# 4      ...          NaN         NaN             NaN          NaN
# ...    ...          ...         ...             ...          ...
# 22208  ...          NaN         NaN             NaN          NaN
# 22209  ...          NaN         NaN             NaN          NaN
# 22210  ...          NaN         NaN             NaN          NaN
# 22211  ...          NaN         NaN             NaN          NaN
# 22212  ...       2.6656     23.0840         21.9179       0.6571
#
#        TFA_TURNOVER  DAYS_AP  DAYS_INVEN  TA_TURNOVER  AR_TURNOVER  FLAG
# 0               NaN      NaN         NaN          NaN          NaN   0.0
# 1               NaN      NaN         NaN          NaN          NaN   0.0
# 2           15.2980  75.4337     48.4911       1.2774       3.5856   0.0
# 3               NaN      NaN         NaN          NaN          NaN   0.0
# 4               NaN      NaN         NaN          NaN          NaN   0.0
# ...             ...      ...         ...          ...          ...   ...
# 22208           NaN      NaN         NaN          NaN          NaN   NaN
# 22209           NaN      NaN         NaN          NaN          NaN   NaN
# 22210           NaN      NaN         NaN          NaN          NaN   NaN
# 22211           NaN      NaN         NaN          NaN          NaN   NaN
# 22212        0.6256  33.6589     16.4249       0.3692      54.0618   NaN
#
# [22213 rows x 363 columns]

# %% [markdown]
# - 附件三

# %%
raw_data3 = pd.read_excel("../附件3.xlsx")
raw_data3

# %% [markdown]
# ---
#
# ## 原始数据展示 and 操作部分

# %%
raw_data1.groupby(by="所属行业").count()

# %%
raw_data2
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 0               4019            3             3             2         1
# 1               8166            3             3             2         1
# 2               9063            3             3             2         1
# 3              10083            4             4             4         1
# 4              11737            3             3             2         1
# ...              ...          ...           ...           ...       ...
# 22208        4993201            7             7             7         6
# 22209        4993297            7             7             7         6
# 22210        4997833            7             7             7         6
# 22211        4998808            7             7             7         6
# 22212        4999709            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# 0               A             12            1           CHAS_2007         CNY
# 1               A             12            1           CHAS_2007         CNY
# 2               A             12            1           CHAS_2007         CNY
# 3               A             12            1           CHAS_2007         CNY
# 4               A             12            1           CHAS_2007         CNY
# ...           ...            ...          ...                 ...         ...
# 22208           A             12            1           CHAS_2007         CNY
# 22209           A             12            1           CHAS_2007         CNY
# 22210           A             12            1           CHAS_2007         CNY
# 22211           A             12            1           CHAS_2007         CNY
# 22212           A             12            1           CHAS_2007         CNY
#
#        ...  CA_TURNOVER  OPER_CYCLE  INVEN_TURNOVER  FA_TURNOVER  \
# 0      ...          NaN         NaN             NaN          NaN
# 1      ...          NaN         NaN             NaN          NaN
# 2      ...       1.3751    148.8938          7.4240      20.9362
# 3      ...          NaN         NaN             NaN          NaN
# 4      ...          NaN         NaN             NaN          NaN
# ...    ...          ...         ...             ...          ...
# 22208  ...          NaN         NaN             NaN          NaN
# 22209  ...          NaN         NaN             NaN          NaN
# 22210  ...          NaN         NaN             NaN          NaN
# 22211  ...          NaN         NaN             NaN          NaN
# 22212  ...       2.6656     23.0840         21.9179       0.6571
#
#        TFA_TURNOVER  DAYS_AP  DAYS_INVEN  TA_TURNOVER  AR_TURNOVER  FLAG
# 0               NaN      NaN         NaN          NaN          NaN   0.0
# 1               NaN      NaN         NaN          NaN          NaN   0.0
# 2           15.2980  75.4337     48.4911       1.2774       3.5856   0.0
# 3               NaN      NaN         NaN          NaN          NaN   0.0
# 4               NaN      NaN         NaN          NaN          NaN   0.0
# ...             ...      ...         ...          ...          ...   ...
# 22208           NaN      NaN         NaN          NaN          NaN   NaN
# 22209           NaN      NaN         NaN          NaN          NaN   NaN
# 22210           NaN      NaN         NaN          NaN          NaN   NaN
# 22211           NaN      NaN         NaN          NaN          NaN   NaN
# 22212        0.6256  33.6589     16.4249       0.3692      54.0618   NaN
#
# [22213 rows x 363 columns]

# %%
# raw_data3
lst = raw_data3["含义"].tolist()
lst
# Out:
# ['股票代码',
#  '实际披露时间',
#  '发布时间',
#  '报告截止日期',
#  '截止日期',
#  '报告类型',
#  '会计区间',
#  '合并标志：1-合并，2-母公司',
#  '会计准则',
#  '货币代码',
#  '货币资金',
#  '结算备付金',
#  '拆出资金',
#  '交易性金融资产',
#  '应收票据',
#  '应收账款',
#  '预付款项',
#  '应收保费',
#  '应收分保账款',
#  '应收分保合同准备金',
#  '应收利息',
#  '应收股利',
#  '其他应收款',
#  '买入返售金融资产',
#  '存货',
#  '一年内到期的非流动资产',
#  '其他流动资产',
#  '流动资产合计',
#  '发放委托贷款及垫款',
#  '可供出售金融资产',
#  '持有至到期投资',
#  '长期应收款',
#  '长期股权投资',
#  '投资性房地产',
#  '固定资产',
#  '在建工程',
#  '工程物资',
#  '固定资产清理',
#  '生产性生物资产',
#  '油气资产',
#  '无形资产',
#  '研发支出',
#  '商誉',
#  '长期待摊费用',
#  '递延所得税资产',
#  '其他非流动资产',
#  '非流动资产合计',
#  '资产总计',
#  '短期借款',
#  '向中央银行借款',
#  '吸收存款',
#  '拆入资金',
#  '交易性金融负债',
#  '应付票据',
#  '应付账款',
#  '预收款项',
#  '卖出回购金融资产款',
#  '应付手续费及佣金',
#  '应付职工薪酬',
#  '应交税费',
#  '应付利息',
#  '应付股利',
#  '其他应付款',
#  '应付分保账款',
#  '保险合同准备金',
#  '代理买卖证券款',
#  '代理承销证券款',
#  '一年内到期的非流动负债',
#  '预提费用',
#  '其他流动负债',
#  '流动负债合计',
#  '长期借款',
#  '应付债券',
#  '长期应付款',
#  '专项应付款',
#  '预计负债',
#  '递延收益',
#  '递延所得税负债',
#  '其他非流动负债',
#  '非流动负债合计',
#  '负债合计',
#  '实收资本(或股本)',
#  '资本公积',
#  '减:库存股',
#  '专项储备',
#  '盈余公积',
#  '一般风险准备',
#  '未分配利润',
#  '外币报表折算差额',
#  '归属于母公司所有者权益合计',
#  '少数股东权益',
#  '所有者权益(或股东权益)合计',
#  '负债和所有者权益(或股东权益)总计',
#  '其他综合收益',
#  '其他权益工具',
#  '优先股',
#  '永续债',
#  '其中：优先股',
#  '永续债',
#  '支付其他与筹资活动有关的现金',
#  '向中央银行借款净增加额',
#  '存放中央银行和同业款项净增加额',
#  '投资活动产生的现金流量净额',
#  '取得借款收到的现金',
#  '客户贷款及垫款净增加额',
#  '经营活动产生的现金流量净额',
#  '回购业务资金净增加额',
#  '吸收投资收到的现金',
#  '投资支付的现金',
#  '收到其他与筹资活动有关的现金',
#  '质押贷款净增加额',
#  '支付保单红利的现金',
#  '支付其他与投资活动有关的现金',
#  '投资活动现金流入小计',
#  '购买商品、接受劳务支付的现金',
#  '支付其他与经营活动有关的现金',
#  '收回投资收到的现金',
#  '销售商品、提供劳务收到的现金',
#  '收到的税费返还',
#  '经营活动现金流入小计',
#  '向其他金融机构拆入资金净增加额',
#  '取得投资收益收到的现金',
#  '取得子公司及其他营业单位支付的现金净额',
#  '现金及现金等价物净增加额',
#  '其中:子公司吸收少数股东投资收到的现金',
#  '汇率变动对现金及现金等价物的影响',
#  '支付的各项税费',
#  '支付利息、手续费及佣金的现金',
#  '收到再保险业务现金净额',
#  '分配股利、利润或偿付利息支付的现金',
#  '收到其他与投资活动有关的现金',
#  '拆入资金净增加额',
#  '经营活动现金流出小计',
#  '收到其他与经营活动有关的现金',
#  '投资活动现金流出小计',
#  '客户存款和同业存放款项净增加额',
#  '发行债券收到的现金',
#  '保户储金及投资款净增加额',
#  '支付原保险合同赔付款项的现金',
#  '偿还债务支付的现金',
#  '处置固定资产、无形资产和其他长期资产收回的现金净额',
#  '筹资活动产生的现金流量净额',
#  '加:期初现金及现金等价物余额',
#  '期末现金及现金等价物余额',
#  '其中:子公司支付给少数股东的股利、利润',
#  '购建固定资产、无形资产和其他长期资产支付的现金',
#  '筹资活动现金流入小计',
#  '收取利息、手续费及佣金的现金',
#  '支付给职工以及为职工支付的现金',
#  '筹资活动现金流出小计',
#  '处置交易性金融资产净增加额',
#  '处置子公司及其他营业单位收到的现金净额',
#  '收到原保险合同保费取得的现金',
#  '管理费用',
#  '稀释每股收益',
#  '其中:对联营企业和合营企业的投资收益',
#  '营业收入',
#  '赔付支出净额',
#  '终止经营净利润',
#  '营业总收入',
#  '利润总额(亏损总额以“－”号填列)',
#  '非流动资产处置损失',
#  '基本每股收益',
#  '营业利润(亏损以“－”号填列)',
#  '资产减值损失',
#  '归属于母公司所有者(或股东)的综合收益总额',
#  '其他综合收益',
#  '保单红利支出',
#  '综合收益总额',
#  '利息收入',
#  '归属于母公司所有者(或股东)的净利润',
#  '退保金',
#  '其他收益',
#  '已赚保费',
#  '投资收益(损失以“－”号填列)',
#  '资产处置收益',
#  '手续费及佣金支出',
#  '财务费用',
#  '公允价值变动收益(损失以“－”号填列)',
#  '利息支出',
#  '销售费用',
#  '营业成本',
#  '净利润(净亏损以“－”号填列)',
#  '分保费用',
#  '营业税金及附加',
#  '营业外支出',
#  '提取保险合同准备金净额',
#  '持续经营净利润',
#  '归属于少数股东的综合收益总额',
#  '汇兑收益(损失以“-”号填列)',
#  '所得税费用',
#  '营业外收入',
#  '少数股东损益',
#  '手续费及佣金收入',
#  '营业总成本',
#  '息税前利润',
#  '企业自由现金流量',
#  '息前税后利润',
#  '无息流动负债',
#  '无息非流动负债',
#  '营运资本',
#  '净营运资本',
#  '经营活动净收益',
#  '带息流动负债',
#  '扣除非经常性损益后的归属于上市公司股东的净利润',
#  '息税折旧摊销前利润',
#  '有形净资产',
#  '净债务',
#  '留存收益',
#  '折旧与摊销',
#  '价值变动净收益',
#  '带息债务',
#  '净利息费用',
#  '投入资本',
#  '股权自由现金流量',
#  '固定资产合计',
#  '非经常性损益',
#  '毛利',
#  '投资支出/折旧和摊销',
#  '经营活动产生的现金流量净额/营业收入',
#  '投资活动产生的现金流量净额占比',
#  '销售商品提供劳务收到的现金/营业收入',
#  '经营活动产生的现金流量净额/经营活动净收益',
#  '经营活动产生的现金流量净额/营业总收入',
#  '经营活动产生的现金流量净额/营业利润',
#  '筹资活动产生的现金流量净额占比',
#  '全部资产现金回收率',
#  '应收账款/营业收入',
#  '预收款项/营业收入',
#  '经营活动产生的现金流量净额占比',
#  '营业收入同比增长',
#  '每股净资产相对年初增长',
#  '总资产相对年初增长',
#  '归属于母公司净利润同比增长',
#  '稀释每股收益同比增长',
#  '营业总额同比增长',
#  '净利润同比增长',
#  '营业总收入同比增长',
#  '基本每股收益同比增长',
#  '经营活动产生的现金流量净额同比增长',
#  '归属于母公司净利润（扣除）同比增长',
#  '净资产收益率（摊薄）同比增长',
#  '归属于母公司的股东权益相对年初增长',
#  '营业利润同比增长',
#  '净资产相对年初增长',
#  '每股经营活动产生的现金流量净额同比增长',
#  '息税折旧摊销前利润/带息债务',
#  '货币资金/流动负债',
#  '现金流量利息保障倍数',
#  '资产负债率',
#  '经营活动现金流量净额/负债合计',
#  '非筹资性现金流量净额/流动负债',
#  '归属于母公司的股东权益/负债合计',
#  '息税折旧摊销前利润/负债合计',
#  'ebitda利息保障倍数',
#  '保守速动比率',
#  '产权比率',
#  '经营活动现金流量净额/净债务',
#  '非筹资性现金流量净额/负债总额',
#  '负债合计/归属于母公司的股东权益',
#  '有形净资产/带息债务',
#  '货币资金/带息流动负债',
#  '经营活动现金流量净额/带息债务',
#  '速动比率',
#  '非流动负债与营运资金比率',
#  'ebit利息保障倍数',
#  '营业利润/负债合计',
#  '经营活动现金流量净额/流动负债',
#  '有形净资产/净债务',
#  '流动比率',
#  '有形净资产/负债合计',
#  '经营活动现金流量净额/非流动负债',
#  '归属于母公司的股东权益/带息债务',
#  '营业利润/流动负债',
#  '每股收益(期末摊薄)',
#  '每股股东自由现金流量',
#  '每股留存收益',
#  '每股经营活动产生的现金流量净额',
#  '每股公积金',
#  '每股息税前利润',
#  '每股净资产',
#  '每股未分配利润',
#  '每股营业利润',
#  '每股营业收入',
#  '每股现金流量净额',
#  '每股盈余公积',
#  '每股营业总收入',
#  '每股企业自由现金流量',
#  '每股资本公积',
#  '总资产净利率',
#  '销售净利润率',
#  '净资产收益率',
#  '净资产收益率(加权平均)',
#  '总资产报酬率',
#  '净资产收益率(扣除摊薄)',
#  '净资产收益率(摊薄)',
#  '销售毛利率',
#  '投入资本回报率',
#  '净资产收益率(平均)',
#  '所有者权益/总资产',
#  '货币资金/总资产',
#  '应付债券/总资产',
#  '归属于母公司的股东权益/投入资本',
#  '长期待摊费用/总资产',
#  '非流动资产/总资产',
#  '短期借款/总资产',
#  '非流动负债/负债合计',
#  '权益乘数',
#  '资本固定化比率',
#  '有形净资产/总资产',
#  '长期借款/总资产',
#  '预付账款/总资产',
#  '带息债务/投入资本',
#  '应付账款/总资产',
#  '存货/总资产',
#  '流动负债/负债合计',
#  '预收款项/总资产',
#  '应收账款/总资产',
#  '归属于母公司的股东权益/总资产',
#  '固定资产合计/总资产',
#  '固定资产/总资产',
#  '留存收益/总资产',
#  '流动资产/总资产',
#  '无形资产/总资产',
#  '资产减值损失 /营业总收入',
#  '价值变动净收益/营业总收入',
#  '营业成本/营业总收入',
#  '销售费用/营业总收入',
#  '期间费用/营业总收入',
#  '投资收益/营业总收入',
#  '所得税/利润总额',
#  '经营活动净收益/利润总额',
#  '营业利润/营业总收入',
#  '财务费用/营业总收入',
#  '价值变动净收益/利润总额',
#  '扣除非经常损益后的归母净利润/归母净利润',
#  '经营活动净收益/营业总收入',
#  '营业外收支净额/利润总额',
#  '营业收入/营业总收入',
#  '营业外收入/营业总收入',
#  '净利润/营业总收入',
#  '营业总成本/营业总收入',
#  '公允价值变动收益/营业总收入',
#  '利润总额/营业总收入',
#  '营业外支出/营业总收入',
#  '管理费用/营业总收入',
#  'ebitda/营业总收入',
#  '营业税金及附加/营业总收入',
#  '所得税/营业总收入',
#  'ebit/营业总收入',
#  '营业利润/利润总额',
#  '应收账款周转天数',
#  '应付账款周转率',
#  '流动资产周转率',
#  '营业周期',
#  '存货周转率',
#  '固定资产周转率',
#  '固定资产合计周转率',
#  '应付账款周转天数',
#  '存货周转天数',
#  '总资产周转率',
#  '应收账款周转率',
#  '是否在当年造假']

# %% [markdown]
# ---
#
# ## 特征因子寻找
#
# ### Mscore模型中所使用的因子
#
# 1. 应收账款指数
#
# - 计算方式: 本期应收账款占营业收入的百分比 / 上期应收账款占营业收入的百分比
# - 因子:
#     - `ADV_R_R` 预收账款/营业收入
#     - `AR_R` 应收账款/营业收入

# %%
def showCount(data, name):
    temp = data[name]
    print("{} 非空数值数:{}".format(name, temp.count()))
    return temp

# %%
adv_r_r = raw_data2["ADV_R_R"]
print("ADV_R_R非空数值数:",adv_r_r.count())
ar_r = raw_data2["AR_R"]
print("AR_R非空数值数:",ar_r.count())
# Out:
# ADV_R_R非空数值数: 6724
# AR_R非空数值数: 6451

# %% [markdown]
# 2. 毛利率指数
# - 计算方式: 上期毛利率/本期毛利率
# - 因子:
#     - `GROSS_MARGIN` 销售毛利率

# %%
gross_margin = raw_data2["GROSS_MARGIN"]
print("GROSS_MARGIN非空数值数:",gross_margin.count())
# Out:
# GROSS_MARGIN非空数值数: 7191

# %% [markdown]
# 3. 资产质量指数
# - 计算方式: 本期非实物资产比例/上期非实物资产比例
# - 因子:
#     - `INTAN_A_TA` 无形资产/总资产
#     - ...不只是包含无形资产, 集中在表B300-B325区域

# %%
intan_a_ta = raw_data2["INTAN_A_TA"]
print("INTAN_A_TA非空数值数:", intan_a_ta.count())
# Out:
# INTAN_A_TA非空数值数: 6933

# %% [markdown]
# 4. 营业收入指数
#
# - 计算方式: 本期营业收入/上期营业收入
# - 因子:
#     - `REVENUE` 营业收入
#     - `REVENUE_YOY` 营业收入同比增长

# %%
revenue = raw_data2["REVENUE"]
revenue_yoy = raw_data2["REVENUE_YOY"]
print("REVENUE非空数值数:",revenue.count())
print("REVENUE_YOY非空数值数:",revenue_yoy.count())
# Out:
# REVENUE非空数值数: 22209
# REVENUE_YOY非空数值数: 7122

# %% [markdown]
# 5. 折旧率指数
# - 计算方式: 上期折旧率/本期折旧率. 折旧率 = 折旧费用/固定资产原值
# - 因子:
#     - `DA` 折旧与摊销
#     - `FIXED_ASSETS` 固定资产

# %%
da = raw_data2["DA"]
fixed_assets = raw_data2["FIXED_ASSETS"]
print("DA非空数值数:",da.count())
print("FIXED_ASSETS非空数值数:",fixed_assets.count())
# Out:
# DA非空数值数: 6305
# FIXED_ASSETS非空数值数: 22208

# %% [markdown]
# 6. 销售管理费用指数
# - 计算方式: 本期销售管理费用占营业收入比例/上期销售管理费用占营业收入比例
# - 因子:
#     - `C_FR_SALE_G_S` 销售商品、提供劳务收到的现金
#     - `CFSGS_R` 销售商品提供劳务收到的现金/营业收入
#     - `SELL_EXP` 销售费用
#     - 营业收入见`4`

# %%
c_fr_sale_g_s = raw_data2["C_FR_SALE_G_S"]
cfsgs_r = raw_data2["CFSGS_R"]
sell_exp = raw_data2["SELL_EXP"]
print("C_FR_SALE_G_S非空数值数:",c_fr_sale_g_s.count())
print("CFSGS_R非空数值数:",cfsgs_r.count())
print("SELL_EXP非空数值数:",sell_exp.count())
# Out:
# C_FR_SALE_G_S非空数值数: 21720
# CFSGS_R非空数值数: 6891
# SELL_EXP非空数值数: 21294

# %% [markdown]
# 7. 财务杠杆指数
# - 计算方式: 本期资产负债率/上期资产负债率
# - 因子:
#     - `ASSET_LIAB_RATIO` 资产负债率

# %%
asset_liab_ratio = raw_data2["ASSET_LIAB_RATIO"]
print("ASSET_LIAB_RATIO非空数值数:",asset_liab_ratio.count())
# Out:
# ASSET_LIAB_RATIO非空数值数: 7238

# %% [markdown]
# 8. 总应计项
# - 计算方式: 应计项/总资产
# - 应计项 = (本期上期流动资产的差 - 本期上期货币资金的差) - (本期上期流动负债的差 - 本期上期一年内到期长期负债的茶 - 本期上期应交税费的差) - 折旧费用
# - 因子:
#     - `T_CL` 流动负债合计
#     - `T_CA` 流动资产合计
#     - `CASH_C_EQUIV` 货币资金
#     - `NCL_WITHIN_1Y` 一年内到期的非流动负债
#     - `TAXES_PAYABLE` 应交税费
#     - 折旧与摊销见`4`

# %%
t_cl = raw_data2["T_CL"]
t_ca = raw_data2["T_CA"]
cash_c_equiv = raw_data2["CASH_C_EQUIV"]
ncl_within_1y = raw_data2["NCL_WITHIN_1Y"]
taxes_payable = raw_data2["TAXES_PAYABLE"]
print("T_CL非空数值数:",t_cl.count())
print("T_CA非空数值数:",t_ca.count())
print("CASH_C_EQUIV非空数值数:",cash_c_equiv.count())
print("NCL_WITHIN_1Y非空数值数:",ncl_within_1y.count())
print("ASSET_LIAB_RATIO非空数值数:",taxes_payable.count())
# Out:
# T_CL非空数值数: 21753
# T_CA非空数值数: 21753
# CASH_C_EQUIV非空数值数: 22212
# NCL_WITHIN_1Y非空数值数: 10996
# ASSET_LIAB_RATIO非空数值数: 22210

# %% [markdown]
# ---
#
# ### Fscore模型中使用的因子
#
# 1. RSST应计项
# - 计算方法: (经营资本变动值 + 非现金净营运资产变动值 + 金融资产变动值) / 平均总资产
# - 因子:
#     - ...

# %% [markdown]
# 2. 应收账款变动率
# - 计算方法: 应收账款变动值/平均总资产
# - 因子:
#     - `AR_TA` 应收账款/总资产

# %%
ar_ta = showCount(raw_data2, "AR_TA")
# Out:
# AR_TA 非空数值数:6558

# %% [markdown]
# 3. 存货变动率
# - 计算方法: 存货变动值/平均总资产
# - 因子:
#     - `INVEN_TA` 存货/总资产

# %%
inven_ta = showCount(raw_data2, "INVEN_TA")
# Out:
# INVEN_TA 非空数值数:6891

# %% [markdown]
# 4. 软资产比例
# - 计算方法: (总资产 - 固定资产 - 在建工程 - 工程物资 - 货币资金) / 总资产
# - 因子:
#     - `CIP` 在建工程
#     - `CONST_MATERIALS` 工程物资
#     - 货币基金见`Mscore 8`
#     - 固定资产见`Mscore 5`

# %%
cip = showCount(raw_data2, "CIP")
const_materials = showCount(raw_data2, "CONST_MATERIALS")
# Out:
# CIP 非空数值数:18579
# CONST_MATERIALS 非空数值数:3336

# %% [markdown]
# 5. 现金销售率
# - 计算方法: (营业收入 - 应收账款变动值) / 营业收入
# - 因子:
#     - 营业收入见`Mscore 4`
#     - `AR` 应收账款

# %%
ar = showCount(raw_data2, "AR")
# Out:
# AR 非空数值数:21471

# %% [markdown]
# 6. ROA增长率
# - 计算方法: 第t年(净利润 / 平均总资产) -  第t-1年(净利润 / 平均总资产)
# - 因子:
#     - `ROA` 总资产净利率

# %%
roa = showCount(raw_data2, "ROA")
# Out:
# ROA 非空数值数:7182

# %% [markdown]
# 7. 是否再融资
# - 有股权或债券融资
# - 因子:
#     - `LT_EQUITY_INVEST` 长期股权投资

# %%
lt_equity_invest = showCount(raw_data2, "LT_EQUITY_INVEST")
# Out:
# LT_EQUITY_INVEST 非空数值数:13027

# %% [markdown]
# ### 某个模型1
#
# 1. 其他应收款比例
# - 计算方法: 其他应收款/总资产
# - 因子: `OTH_RECEIV` 其他应收款
#
# 2. 是否亏损
# - 计算方法: 扣除非经常性损益后ROE小于0为1, 否则为0
# - 因子: ROE系列(见243.293.294.296.297.300)
#     - `ROE_CUT` 净资产收益率(扣除摊薄) (我认为是这个)

# %%
oth_reveiv = showCount(raw_data2, "OTH_RECEIV")
roe_cut = showCount(raw_data2, "ROE_CUT")
# Out:
# OTH_RECEIV 非空数值数:20857
# ROE_CUT 非空数值数:6566

# %% [markdown]
# ---

# %% [markdown]
# ## 数据预处理

# %%
raw_data_factory = pd.read_csv("./Data/房地产业.csv", encoding="utf8")

# %% [markdown]
# - 删除空值＞50%的因子

# %%
[m, n] = raw_data_factory.shape
nan_col = raw_data_factory.isnull().sum()
nan_col_lst = nan_col[nan_col > m * 0.5].index.to_list()   #判断空值率大于50%
clean_data_half = raw_data_factory.drop(columns=nan_col_lst, axis=1)
clean_data_half
# Out:
#      Unnamed: 0  TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  \
# 0            30          57559            3             3             2
# 1            37          70490            3             3             2
# 2           146         223571            3             3             2
# 3           148         230260            2             2             1
# 4           150         240886            3             3             2
# ..          ...            ...          ...           ...           ...
# 698       22103        4882971            7             7             7
# 699       22123        4901757            7             7             7
# 700       22130        4913094            7             7             7
# 701       22146        4926154            7             7             7
# 702       22193        4978437            7             7             7
#
#      END_DATE REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS  \
# 0           1           A             12            1           CHAS_2007
# 1           1           A             12            1           CHAS_2007
# 2           1           A             12            1           CHAS_2007
# 3           1           A             12            1           CHAS_2007
# 4           1           A             12            1           CHAS_2007
# ..        ...         ...            ...          ...                 ...
# 698         6           A             12            1           CHAS_2007
# 699         6           A             12            1           CHAS_2007
# 700         6           A             12            1           CHAS_2007
# 701         6           A             12            1           CHAS_2007
# 702         6           A             12            1           CHAS_2007
#
#      ... OPER_CYCLE  INVEN_TURNOVER  FA_TURNOVER  TFA_TURNOVER   DAYS_AP  \
# 0    ...        NaN             NaN          NaN           NaN       NaN
# 1    ...    95.2036          9.0785       9.0338        8.0687   42.4521
# 2    ...   146.2453          2.8019       8.1759       11.1429   45.7221
# 3    ...  1527.3109          0.2380      14.6845        6.6975  123.2082
# 4    ...   183.3116          4.1520       1.1357        1.1537   43.9136
# ..   ...        ...             ...          ...           ...       ...
# 698  ...        NaN             NaN          NaN           NaN       NaN
# 699  ...    91.9862          4.1342       2.1007        1.9118   37.4759
# 700  ...        NaN             NaN          NaN           NaN       NaN
# 701  ...   298.4432          2.1336       1.0865        1.0189  248.5765
# 702  ...   124.2385          4.3301       2.0689        2.0049   54.6944
#
#      DAYS_INVEN  TA_TURNOVER  AR_TURNOVER  FLAG  industry
# 0           NaN          NaN          NaN   0.0      房地产业
# 1       39.6543       0.4062       6.4807   0.0      房地产业
# 2      128.4841       1.0168      20.2690   0.0      房地产业
# 3     1512.7960       0.2216      24.8021   0.0      房地产业
# 4       86.7057       0.5396       3.7265   0.0      房地产业
# ..          ...          ...          ...   ...       ...
# 698         NaN          NaN          NaN   NaN      房地产业
# 699     87.0789       0.8184      73.3610   NaN      房地产业
# 700         NaN          NaN          NaN   NaN      房地产业
# 701    168.7272       0.1895       2.7753   NaN      房地产业
# 702     83.1399       0.2444       8.7594   NaN      房地产业
#
# [703 rows x 263 columns]

# %% [markdown]
# - 去除无用因子

# %%
clean_data_usefull = clean_data_half.drop(columns=["Unnamed: 0", "ACT_PUBTIME", "PUBLISH_DATE","END_DATE_REP",
                                                     "END_DATE","REPORT_TYPE","FISCAL_PERIOD","MERGED_FLAG",
                                                     "ACCOUTING_STANDARDS","CURRENCY_CD",'industry','TICKER_SYMBOL'])
clean_data_usefull
# Out:
#      TICKER_SYMBOL  CASH_C_EQUIV            AR    PREPAYMENT    OTH_RECEIV  \
# 0            57559  7.559464e+08  7.739169e+08  4.008068e+07  2.949474e+07
# 1            70490  5.965647e+08  8.313504e+07  3.532243e+06  2.366590e+07
# 2           223571  2.403818e+09  1.459319e+09  3.903112e+08  4.489071e+07
# 3           230260  9.493919e+07  6.351702e+07  4.427156e+06  6.474726e+07
# 4           240886  7.743822e+08  7.862877e+05  5.249390e+08  1.199600e+08
# ..             ...           ...           ...           ...           ...
# 698        4882971  4.861112e+09  1.166760e+07  3.141854e+08  2.527097e+08
# 699        4901757  2.846735e+09  2.337788e+08  4.578199e+08  9.312049e+07
# 700        4913094  2.728152e+09  2.309654e+08  6.691757e+06  1.895763e+08
# 701        4926154  9.260865e+08  1.225000e+05  3.353708e+05  9.033968e+07
# 702        4978437  2.215645e+09  1.092098e+07  1.477560e+09  4.297964e+08
#
#       INVENTORIES        OTH_CA          T_CA  AVAIL_FOR_SALE_FA  \
# 0    3.393538e+08  2.657979e+07  2.055454e+09       3.660000e+06
# 1    1.295028e+07  1.542759e+06  7.298122e+08                NaN
# 2    6.646567e+09  2.703635e+09  1.373691e+10       2.348458e+08
# 3    1.510956e+09           NaN  1.738587e+09                NaN
# 4    3.526219e+09           NaN  4.946287e+09                NaN
# ..            ...           ...           ...                ...
# 698  6.007771e+10  2.161713e+09  6.767911e+10       1.729748e+07
# 699  1.105261e+10  1.648181e+09  1.636234e+10       2.139620e+07
# 700  4.341056e+09  6.216832e+08  8.257380e+09       1.813890e+09
# 701  1.246639e+09  3.230788e+07  2.295831e+09                NaN
# 702  1.625508e+10  4.073073e+08  2.079631e+10                NaN
#
#      LT_EQUITY_INVEST  ...  CA_TURNOVER  OPER_CYCLE  INVEN_TURNOVER  \
# 0        1.011051e+08  ...          NaN         NaN             NaN
# 1        1.128189e+08  ...       0.7495     95.2036          9.0785
# 2        8.059522e+06  ...       1.5295    146.2453          2.8019
# 3        7.863232e+07  ...       0.2351   1527.3109          0.2380
# 4        3.151179e+07  ...       1.5182    183.3116          4.1520
# ..                ...  ...          ...         ...             ...
# 698      1.715000e+08  ...          NaN         NaN             NaN
# 699      8.508518e+08  ...       1.4651     91.9862          4.1342
# 700      3.471176e+09  ...          NaN         NaN             NaN
# 701               NaN  ...       0.5221    298.4432          2.1336
# 702      2.296607e+08  ...       0.9875    124.2385          4.3301
#
#      FA_TURNOVER  TFA_TURNOVER   DAYS_AP  DAYS_INVEN  TA_TURNOVER  \
# 0            NaN           NaN       NaN         NaN          NaN
# 1         9.0338        8.0687   42.4521     39.6543       0.4062
# 2         8.1759       11.1429   45.7221    128.4841       1.0168
# 3        14.6845        6.6975  123.2082   1512.7960       0.2216
# 4         1.1357        1.1537   43.9136     86.7057       0.5396
# ..           ...           ...       ...         ...          ...
# 698          NaN           NaN       NaN         NaN          NaN
# 699       2.1007        1.9118   37.4759     87.0789       0.8184
# 700          NaN           NaN       NaN         NaN          NaN
# 701       1.0865        1.0189  248.5765    168.7272       0.1895
# 702       2.0689        2.0049   54.6944     83.1399       0.2444
#
#      AR_TURNOVER  FLAG
# 0            NaN   0.0
# 1         6.4807   0.0
# 2        20.2690   0.0
# 3        24.8021   0.0
# 4         3.7265   0.0
# ..           ...   ...
# 698          NaN   NaN
# 699      73.3610   NaN
# 700          NaN   NaN
# 701       2.7753   NaN
# 702       8.7594   NaN
#
# [703 rows x 252 columns]

# %% [markdown]
# - 删除Flag为空的行数据

# %%
flag_nan = clean_data_usefull['FLAG'].isna()
flag_nan_list = flag_nan[flag_nan == True].index.to_list()
clean_data_flag=clean_data_usefull.drop(index=flag_nan_list, axis=0)
clean_data_flag['FLAG'].isna().sum()
# Out:
# 0

# %% [markdown]
# - 空值率20%到50%的数据用均值填充

# %%
[m, n] = clean_data_flag.shape
nan_col = clean_data_flag.isnull().sum()
nan_col_lst2 = nan_col[nan_col > m*0.2].index.to_list()
print("列数:",len(nan_col_lst2))
print(nan_col_lst2)

for na in nan_col_lst2:
    mean_val = clean_data_flag[na].mean()
    clean_data_flag[na].fillna(mean_val, inplace=True)
    
clean_data_mean = clean_data_flag
# Out:
# 列数: 135
# ['AVAIL_FOR_SALE_FA', 'OTH_NCA', 'ST_BORR', 'DIV_PAYABLE', 'DEFER_TAX_LIAB', 'OTH_COMPRE_INCOME', 'C_PAID_OTH_FINAN_A', 'C_FR_CAP_CONTR', 'C_PAID_INVEST', 'C_FR_OTH_FINAN_A', 'PROC_SELL_INVEST', 'GAIN_INVEST', 'FOREX_EFFECTS', 'A_J_INVEST_INCOME', 'OTH_COMPR_INCOME', 'EBIT', 'FCFF', 'EBIAT', 'INT_FREE_CL', 'INT_FREE_NCL', 'WORK_CAPITAL', 'N_WORK_CAPITAL', 'INT_CL', 'NI_ATTR_P_CUT', 'EBITDA', 'N_TAN_ASSETS', 'N_DEBT', 'T_RE', 'DA', 'INT_DEBT', 'N_INT_EXP', 'IC', 'FCFE', 'T_FIXED_ASSETS', 'NR_PROFIT_LOSS', 'GROSS_PROFIT', 'P_FIXA_O_DA', 'N_CF_OPA_R', 'CFSGS_R', 'N_CF_OPA_TR', 'N_CF_FA_PROPT', 'AR_R', 'ADV_R_R', 'REVENUE_YOY', 'NA_PS_YTD', 'DILUTED_EPS_YOY', 'T_REVENUE_YOY', 'BASIC_EPS_YOY', 'NI_ATTR_P_CUT_YOY', 'ROE_YOY', 'TE_ATTR_P_YTD', 'NA_YTD', 'N_CF_OPA_PS_YOY', 'CASH_CL', 'N_CF_OPA_LIAB', 'N_CF_NFA_CL', 'TEAP_TL', 'SQUICK_RATIO', 'EQUITY_RATIO', 'N_CF_OPA_ND', 'N_CF_NFA_LIAB', 'TL_TEAP', 'QUICK_RATIO', 'NCL_WC', 'OP_TL', 'N_CF_OPA_CL', 'N_TAN_A_ND', 'CURRENT_RATIO', 'N_TAN_A_TL', 'N_CF_OPA_NCL', 'OP_CL', 'FCFE_PS', 'T_RE_PS', 'N_CF_OPER_A_PS', 'RESER_PS', 'EBIT_PS', 'N_ASSET_PS', 'RE_PS', 'REV_PS', 'N_C_IN_CASH_PS', 'S_RESER_PS', 'T_REV_PS', 'FCFF_PS', 'C_RESER_PS', 'ROE_W', 'ROA_EBIT', 'ROE_CUT', 'ROE', 'ROIC', 'ROE_A', 'TSE_TA', 'TEAP_IC', 'LT_AMOR_EXP_TA', 'NCA_TA', 'ST_BORR_TA', 'NCL_TA', 'EQU_MULTIPLIER', 'CAP_FIX_RATIO', 'N_TAN_A_TA', 'LT_BORR_TA', 'REPAY_TA', 'ID_IC', 'AP_TA', 'INVEN_TA', 'CL_TA', 'ADV_R_TA', 'AR_TA', 'TEAP_TA', 'T_FIXED_A_TA', 'FIXED_A_TA', 'TRE_TA', 'CA_TA', 'INTAN_A_TA', 'SELL_EXP_TR', 'PERIOD_EXP_TR', 'INV_INC_TR', 'IT_TP', 'FINAN_EXP_TR', 'NI_CUT_NI', 'NOPL_TR', 'EBITDA_TR', 'BTAX_SURCHG_TR', 'IT_TR', 'EBIT_TR', 'DAYS_AR', 'AP_TURNOVER', 'CA_TURNOVER', 'OPER_CYCLE', 'INVEN_TURNOVER', 'FA_TURNOVER', 'TFA_TURNOVER', 'DAYS_AP', 'DAYS_INVEN', 'TA_TURNOVER', 'AR_TURNOVER']

# %% [markdown]
# ---
# ## 随机森林填补缺失值

# %%
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer  #填补缺失值

# %% [markdown]
# - 去除空值率<20%的数据按升序排序

# %%
sortindex = np.argsort(clean_data_mean.isnull().sum(axis = 0)).values
#np.argsort用来排序，返回从小到大的顺序对对应的索引，然后取出其中的values
nan_coll= clean_data_mean.isnull().sum()
a = nan_coll[nan_coll ==0 ].count()
print(a)
index = sortindex[a+1:]
print(index)
# Out:
# 175
# [ 93  82  92  90  21  19  20  25  48  64   5  77  49  33   4  86  70   3
#   58   2  34  79  14  72  84  30  94  68  91  37  62  12  43  63  10  28
#   26  13  23   6   9 148 191 111 221 239 224 123 227 130 127 103 215 181
#  133 216 234 231 232 222 226 125 230 228 121 182 214 187 229 166 134 136
#  144 137 140 174]

# %%
for i in index:
    #构造新特征矩阵和新标签
    df = clean_data_mean.drop(columns = 'FLAG')
    fillc = df.iloc[:,i]
   # df = pd.concat([df.iloc[:,df.columns!=i],pd.DataFrame(y_full)],axis = 1)
    
    #在新特征矩阵中，对含有缺失值的列，进行0的填补
    df_0 = SimpleImputer(missing_values = np.nan,strategy = 'constant',fill_value = 0).fit_transform(df)
    
    #划分训练集以及测试集
    y_train = fillc[fillc.notnull()]   #不为空值的
    y_test = fillc[fillc.isnull()]     #为空值的
    x_train = df_0[y_train.index,:]
    x_test = df_0[y_test.index,:]
    
    #a
    print(y_test)
    
    #用随机森林填补缺失值
    rfc = RandomForestRegressor()
    rfc.fit(x_train,y_train)
    y_predict = rfc.predict(x_test)
    
    clean_data_mean.iloc[y_test.index,i] = y_predict   #第六列全为空值的
# Out:
# 293   NaN
# Name: NOPERATE_INCOME, dtype: float64
# 212   NaN
# Name: T_COMPR_INCOME, dtype: float64
# 424   NaN
# Name: INCOME_TAX, dtype: float64
# 9     NaN
# 432   NaN
# Name: NOPERATE_EXP, dtype: float64
# 226   NaN
# 342   NaN
# Name: PAYROLL_PAYABLE, dtype: float64
# 532   NaN
# 568   NaN
# Name: AP, dtype: float64
# 306   NaN
# 424   NaN
# 543   NaN
# Name: ADVANCE_RECEIPTS, dtype: float64
# 418   NaN
# 464   NaN
# 497   NaN
# 537   NaN
# Name: OTH_PAYABLE, dtype: float64
# 11    NaN
# 47    NaN
# 124   NaN
# 381   NaN
# Name: C_INF_FR_INVEST_A, dtype: float64
# 12    NaN
# 119   NaN
# 536   NaN
# 556   NaN
# Name: N_CF_FR_FINAN_A, dtype: float64
# 98    NaN
# 214   NaN
# 330   NaN
# 448   NaN
# 491   NaN
# Name: INVENTORIES, dtype: float64
# 55    NaN
# 119   NaN
# 170   NaN
# 188   NaN
# 464   NaN
# Name: BASIC_EPS, dtype: float64
# 98    NaN
# 214   NaN
# 330   NaN
# 424   NaN
# 448   NaN
# Name: C_PAID_G_S, dtype: float64
# 110   NaN
# 119   NaN
# 179   NaN
# 226   NaN
# 280   NaN
# 433   NaN
# Name: CAPITAL_RESER, dtype: float64
# 382   NaN
# 464   NaN
# 492   NaN
# 497   NaN
# 501   NaN
# 532   NaN
# Name: OTH_RECEIV, dtype: float64
# 98    NaN
# 214   NaN
# 330   NaN
# 417   NaN
# 448   NaN
# 536   NaN
# 567   NaN
# Name: SELL_EXP, dtype: float64
# 12    NaN
# 75    NaN
# 119   NaN
# 190   NaN
# 243   NaN
# 359   NaN
# 424   NaN
# 536   NaN
# 543   NaN
# 556   NaN
# Name: C_OUTF_FR_FINAN_A, dtype: float64
# 47    NaN
# 64    NaN
# 75    NaN
# 119   NaN
# 190   NaN
# 235   NaN
# 279   NaN
# 306   NaN
# 351   NaN
# 396   NaN
# 491   NaN
# 515   NaN
# Name: PREPAYMENT, dtype: float64
# 12    NaN
# 75    NaN
# 87    NaN
# 119   NaN
# 190   NaN
# 225   NaN
# 243   NaN
# 306   NaN
# 359   NaN
# 424   NaN
# 536   NaN
# 543   NaN
# 556   NaN
# Name: C_PAID_DIV_PROF_INT, dtype: float64
# 75    NaN
# 128   NaN
# 190   NaN
# 234   NaN
# 257   NaN
# 306   NaN
# 350   NaN
# 360   NaN
# 372   NaN
# 424   NaN
# 479   NaN
# 491   NaN
# 536   NaN
# 543   NaN
# Name: AR, dtype: float64
# 10    NaN
# 15    NaN
# 41    NaN
# 110   NaN
# 125   NaN
# 130   NaN
# 156   NaN
# 226   NaN
# 241   NaN
# 272   NaN
# 342   NaN
# 357   NaN
# 362   NaN
# 389   NaN
# 481   NaN
# 508   NaN
# Name: SURPLUS_RESER, dtype: float64
# 60    NaN
# 146   NaN
# 175   NaN
# 257   NaN
# 262   NaN
# 291   NaN
# 306   NaN
# 378   NaN
# 382   NaN
# 403   NaN
# 408   NaN
# 418   NaN
# 464   NaN
# 497   NaN
# 501   NaN
# 518   NaN
# 525   NaN
# 537   NaN
# Name: ASSETS_IMPAIR_LOSS, dtype: float64
# 12    NaN
# 75    NaN
# 80    NaN
# 127   NaN
# 190   NaN
# 195   NaN
# 243   NaN
# 256   NaN
# 306   NaN
# 311   NaN
# 359   NaN
# 372   NaN
# 424   NaN
# 429   NaN
# 478   NaN
# 491   NaN
# 520   NaN
# 543   NaN
# 548   NaN
# Name: DEFER_TAX_ASSETS, dtype: float64
# 55    NaN
# 82    NaN
# 83    NaN
# 89    NaN
# 102   NaN
# 119   NaN
# 170   NaN
# 188   NaN
# 198   NaN
# 245   NaN
# 260   NaN
# 314   NaN
# 361   NaN
# 410   NaN
# 432   NaN
# 438   NaN
# 464   NaN
# 480   NaN
# 529   NaN
# 533   NaN
# Name: DILUTED_EPS, dtype: float64
# 9     NaN
# 15    NaN
# 18    NaN
# 34    NaN
# 47    NaN
# 69    NaN
# 122   NaN
# 124   NaN
# 130   NaN
# 149   NaN
# 167   NaN
# 184   NaN
# 283   NaN
# 340   NaN
# 350   NaN
# 381   NaN
# 435   NaN
# 469   NaN
# 470   NaN
# 500   NaN
# 554   NaN
# Name: INVEST_INCOME, dtype: float64
# 12    NaN
# 69    NaN
# 75    NaN
# 98    NaN
# 119   NaN
# 127   NaN
# 190   NaN
# 201   NaN
# 235   NaN
# 243   NaN
# 264   NaN
# 300   NaN
# 306   NaN
# 317   NaN
# 351   NaN
# 359   NaN
# 382   NaN
# 424   NaN
# 435   NaN
# 464   NaN
# 470   NaN
# 478   NaN
# 501   NaN
# 543   NaN
# 567   NaN
# Name: T_NCL, dtype: float64
# 1     NaN
# 9     NaN
# 11    NaN
# 27    NaN
# 47    NaN
# 57    NaN
# 94    NaN
# 102   NaN
# 115   NaN
# 126   NaN
# 134   NaN
# 142   NaN
# 148   NaN
# 172   NaN
# 242   NaN
# 250   NaN
# 258   NaN
# 278   NaN
# 288   NaN
# 314   NaN
# 351   NaN
# 358   NaN
# 366   NaN
# 374   NaN
# 395   NaN
# 477   NaN
# 514   NaN
# 542   NaN
# Name: MINORITY_GAIN, dtype: float64
# 12    NaN
# 75    NaN
# 87    NaN
# 88    NaN
# 109   NaN
# 119   NaN
# 177   NaN
# 265   NaN
# 300   NaN
# 306   NaN
# 317   NaN
# 319   NaN
# 381   NaN
# 417   NaN
# 424   NaN
# 437   NaN
# 470   NaN
# 479   NaN
# 480   NaN
# 493   NaN
# 500   NaN
# 524   NaN
# 536   NaN
# 542   NaN
# 543   NaN
# 549   NaN
# 556   NaN
# 581   NaN
# Name: C_INF_FR_FINAN_A, dtype: float64
# 1     NaN
# 9     NaN
# 11    NaN
# 27    NaN
# 47    NaN
# 57    NaN
# 94    NaN
# 96    NaN
# 102   NaN
# 115   NaN
# 126   NaN
# 134   NaN
# 142   NaN
# 148   NaN
# 172   NaN
# 212   NaN
# 242   NaN
# 250   NaN
# 258   NaN
# 278   NaN
# 288   NaN
# 314   NaN
# 351   NaN
# 358   NaN
# 366   NaN
# 374   NaN
# 395   NaN
# 477   NaN
# 493   NaN
# 514   NaN
# 542   NaN
# Name: COMPR_INC_ATTR_M_S, dtype: float64
# 1     NaN
# 9     NaN
# 11    NaN
# 19    NaN
# 33    NaN
# 47    NaN
# 57    NaN
# 84    NaN
# 102   NaN
# 115   NaN
# 126   NaN
# 134   NaN
# 148   NaN
# 162   NaN
# 172   NaN
# 199   NaN
# 218   NaN
# 226   NaN
# 235   NaN
# 242   NaN
# 250   NaN
# 278   NaN
# 288   NaN
# 314   NaN
# 351   NaN
# 358   NaN
# 366   NaN
# 372   NaN
# 395   NaN
# 423   NaN
# 477   NaN
# 514   NaN
# 542   NaN
# 578   NaN
# Name: MINORITY_INT, dtype: float64
# 12    NaN
# 37    NaN
# 75    NaN
# 87    NaN
# 88    NaN
# 119   NaN
# 152   NaN
# 190   NaN
# 203   NaN
# 225   NaN
# 235   NaN
# 243   NaN
# 256   NaN
# 306   NaN
# 317   NaN
# 319   NaN
# 351   NaN
# 359   NaN
# 372   NaN
# 382   NaN
# 385   NaN
# 417   NaN
# 424   NaN
# 435   NaN
# 437   NaN
# 470   NaN
# 478   NaN
# 491   NaN
# 493   NaN
# 501   NaN
# 536   NaN
# 542   NaN
# 543   NaN
# 554   NaN
# 556   NaN
# Name: C_PAID_FOR_DEBTS, dtype: float64
# 10    NaN
# 12    NaN
# 25    NaN
# 30    NaN
# 33    NaN
# 40    NaN
# 64    NaN
# 75    NaN
# 77    NaN
# 92    NaN
# 103   NaN
# 105   NaN
# 106   NaN
# 125   NaN
# 127   NaN
# 140   NaN
# 145   NaN
# 148   NaN
# 155   NaN
# 190   NaN
# 192   NaN
# 201   NaN
# 219   NaN
# 221   NaN
# 222   NaN
# 241   NaN
# 261   NaN
# 271   NaN
# 306   NaN
# 317   NaN
# 335   NaN
# 337   NaN
# 338   NaN
# 341   NaN
# 350   NaN
# 399   NaN
# 424   NaN
# 435   NaN
# 453   NaN
# 455   NaN
# 456   NaN
# 464   NaN
# 491   NaN
# 493   NaN
# 518   NaN
# 543   NaN
# 554   NaN
# 574   NaN
# Name: INTAN_ASSETS, dtype: float64
# 12    NaN
# 25    NaN
# 31    NaN
# 37    NaN
# 75    NaN
# 87    NaN
# 88    NaN
# 109   NaN
# 119   NaN
# 127   NaN
# 140   NaN
# 146   NaN
# 148   NaN
# 152   NaN
# 162   NaN
# 177   NaN
# 190   NaN
# 201   NaN
# 203   NaN
# 225   NaN
# 235   NaN
# 243   NaN
# 256   NaN
# 265   NaN
# 300   NaN
# 306   NaN
# 317   NaN
# 319   NaN
# 351   NaN
# 359   NaN
# 372   NaN
# 377   NaN
# 381   NaN
# 382   NaN
# 395   NaN
# 417   NaN
# 423   NaN
# 424   NaN
# 435   NaN
# 437   NaN
# 470   NaN
# 478   NaN
# 479   NaN
# 480   NaN
# 491   NaN
# 493   NaN
# 500   NaN
# 501   NaN
# 524   NaN
# 536   NaN
# 542   NaN
# 543   NaN
# 549   NaN
# 556   NaN
# 581   NaN
# Name: C_FR_BORR, dtype: float64
# 4     NaN
# 10    NaN
# 11    NaN
# 19    NaN
# 28    NaN
# 29    NaN
# 37    NaN
# 47    NaN
# 62    NaN
# 64    NaN
# 77    NaN
# 84    NaN
# 106   NaN
# 118   NaN
# 124   NaN
# 125   NaN
# 134   NaN
# 143   NaN
# 145   NaN
# 177   NaN
# 192   NaN
# 222   NaN
# 223   NaN
# 241   NaN
# 242   NaN
# 244   NaN
# 259   NaN
# 265   NaN
# 278   NaN
# 284   NaN
# 293   NaN
# 308   NaN
# 334   NaN
# 338   NaN
# 350   NaN
# 358   NaN
# 365   NaN
# 381   NaN
# 382   NaN
# 395   NaN
# 401   NaN
# 408   NaN
# 417   NaN
# 426   NaN
# 442   NaN
# 456   NaN
# 475   NaN
# 479   NaN
# 491   NaN
# 514   NaN
# 536   NaN
# 561   NaN
# 568   NaN
# 575   NaN
# 580   NaN
# 581   NaN
# Name: DISP_FIX_ASSETS_OTH, dtype: float64
# 0     NaN
# 9     NaN
# 12    NaN
# 22    NaN
# 24    NaN
#        ..
# 520   NaN
# 561   NaN
# 575   NaN
# 576   NaN
# 582   NaN
# Name: INVEST_REAL_ESTATE, Length: 67, dtype: float64
# 0     NaN
# 25    NaN
# 37    NaN
# 49    NaN
# 69    NaN
#        ..
# 544   NaN
# 556   NaN
# 561   NaN
# 567   NaN
# 581   NaN
# Name: LT_BORR, Length: 71, dtype: float64
# 4     NaN
# 31    NaN
# 33    NaN
# 47    NaN
# 49    NaN
#        ..
# 543   NaN
# 554   NaN
# 556   NaN
# 561   NaN
# 581   NaN
# Name: NCL_WITHIN_1Y, Length: 79, dtype: float64
# 4     NaN
# 9     NaN
# 11    NaN
# 13    NaN
# 16    NaN
#        ..
# 543   NaN
# 548   NaN
# 549   NaN
# 554   NaN
# 581   NaN
# Name: LT_AMOR_EXP, Length: 82, dtype: float64
# 3     NaN
# 11    NaN
# 13    NaN
# 16    NaN
# 17    NaN
#        ..
# 543   NaN
# 554   NaN
# 561   NaN
# 573   NaN
# 581   NaN
# Name: INT_PAYABLE, Length: 95, dtype: float64
# 3     NaN
# 4     NaN
# 5     NaN
# 7     NaN
# 8     NaN
#        ..
# 338   NaN
# 341   NaN
# 359   NaN
# 477   NaN
# 501   NaN
# Name: OTH_CA, Length: 98, dtype: float64
# 7     NaN
# 9     NaN
# 11    NaN
# 12    NaN
# 15    NaN
#        ..
# 549   NaN
# 554   NaN
# 561   NaN
# 578   NaN
# 581   NaN
# Name: LT_EQUITY_INVEST, Length: 103, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: ASSET_LIAB_RATIO, Length: 112, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: C_TA, Length: 112, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: VAL_CHG_PROFIT, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OPA_P_TP, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OP_TP, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: VAL_CHG_P_TP, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_CF_OPA_OPAP, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_NOPI_TP, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_CF_OPA_PROPT, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: C_RCVRY_A, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OPA_PROFIT, Length: 113, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: VAL_CHG_P_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: ROA, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: TA_YTD, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: COGS_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: ADMIN_EXP_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: TCOGS_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: TP_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OP_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OPA_P_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_CF_OPA_OP, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: NI_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: R_TR, Length: 114, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_CF_IA_PROPT, Length: 115, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 26    NaN
# 29    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: NP_MARGIN, Length: 115, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: AIL_TR, Length: 115, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 26    NaN
# 29    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: GROSS_MARGIN, Length: 115, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: NOPG_TR, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: EPS, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: NI_ATTR_P_YOY, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: T_PROFIT_YOY, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OPER_PROFIT_YOY, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: NI_YOY, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: N_CF_OPA_YOY, Length: 116, dtype: float64
# 0     NaN
# 10    NaN
# 15    NaN
# 29    NaN
# 31    NaN
#        ..
# 571   NaN
# 574   NaN
# 575   NaN
# 578   NaN
# 580   NaN
# Name: OP_PS, Length: 116, dtype: float64

# %%
y_train.groupby(y_train).count()
# Out:
# FLAG
# 0.0    397
# 1.0    397
# Name: FLAG, dtype: int64

# %%
clean_data_mean
# Out:
#      TICKER_SYMBOL  CASH_C_EQUIV            AR    PREPAYMENT    OTH_RECEIV  \
# 0            57559  7.559464e+08  7.739169e+08  4.008068e+07  2.949474e+07
# 1            70490  5.965647e+08  8.313504e+07  3.532243e+06  2.366590e+07
# 2           223571  2.403818e+09  1.459319e+09  3.903112e+08  4.489071e+07
# 3           230260  9.493919e+07  6.351702e+07  4.427156e+06  6.474726e+07
# 4           240886  7.743822e+08  7.862877e+05  5.249390e+08  1.199600e+08
# ..             ...           ...           ...           ...           ...
# 578        4882971  8.982526e+09  6.715511e+06  1.733837e+08  3.633976e+08
# 579        4901757  2.690191e+09  5.684386e+08  7.762174e+08  1.325584e+08
# 580        4913094  2.022218e+09  2.532097e+08  7.745800e+06  7.533849e+07
# 581        4926154  1.600999e+08  1.985817e+08  5.351682e+06  1.520744e+07
# 582        4978437  2.935241e+09  1.826116e+07  1.969008e+09  9.807161e+08
#
#       INVENTORIES        OTH_CA          T_CA  AVAIL_FOR_SALE_FA  \
# 0    3.393538e+08  2.657979e+07  2.055454e+09       3.660000e+06
# 1    1.295028e+07  1.542759e+06  7.298122e+08       7.902283e+08
# 2    6.646567e+09  2.703635e+09  1.373691e+10       2.348458e+08
# 3    1.510956e+09  1.583430e+05  1.738587e+09       7.902283e+08
# 4    3.526219e+09  1.103441e+05  4.946287e+09       7.902283e+08
# ..            ...           ...           ...                ...
# 578  6.423245e+10  1.639573e+09  7.539804e+10       1.729748e+07
# 579  1.213541e+10  1.362943e+09  1.768285e+10       1.429054e+08
# 580  5.111881e+09  5.858345e+08  8.123324e+09       2.082450e+09
# 581  1.732576e+09  4.043119e+07  2.152248e+09       7.902283e+08
# 582  1.465633e+10  3.220038e+08  2.088156e+10       7.902283e+08
#
#      LT_EQUITY_INVEST  ...  TFA_TURNOVER    DAYS_AP   DAYS_INVEN  TA_TURNOVER  \
# 0        1.011051e+08  ...     95.186434  111.16513   443.264534     0.630903
# 1        1.128189e+08  ...      8.068700   42.45210    39.654300     0.406200
# 2        8.059522e+06  ...     11.142900   45.72210   128.484100     1.016800
# 3        7.863232e+07  ...      6.697500  123.20820  1512.796000     0.221600
# 4        3.151179e+07  ...      1.153700   43.91360    86.705700     0.539600
# ..                ...  ...           ...        ...          ...          ...
# 578      6.078989e+05  ...     95.186434  111.16513   443.264534     0.630903
# 579      8.730648e+08  ...      1.505500   48.32180   105.907700     0.691300
# 580      3.397459e+09  ...     95.186434  111.16513   443.264534     0.630903
# 581      5.084497e+05  ...      0.848700  251.61690   185.399500     0.170800
# 582      5.945682e+07  ...      1.463300   65.18130    83.324500     0.170900
#
#      AR_TURNOVER  FLAG     AP_TC     OR_TC     IN_TC     NI_NI
# 0      29.270053   0.0  0.168825  0.014350  0.165099  1.479739
# 1       6.480700   0.0  0.294751  0.032427  0.017745  0.553507
# 2      20.269000   0.0  0.056067  0.003268  0.483847  0.019870
# 3      24.802100   0.0  0.083534  0.037241  0.869071  0.021491
# 4       3.726500   0.0  0.090641  0.024253  0.712902  0.028086
# ..           ...   ...       ...       ...       ...       ...
# 578    29.270053   0.0  0.079229  0.004820  0.851911  0.007779
# 579    59.902300   0.0  0.175777  0.007496  0.686281  0.017769
# 580    29.270053   0.0  0.057436  0.009274  0.629284  0.001624
# 581     2.122500   0.0  0.126404  0.007066  0.805008  0.004202
# 582     9.808200   0.0  0.082214  0.046966  0.701879  0.002546
#
# [583 rows x 256 columns]

# %% [markdown]
# ---
# ## 插入因子数据

# %%
#去除异常值
train_inf = np.isfinite(clean_data_mean)
clean_data_mean[train_inf==False] = 0

# %%
ramdonForest_end_Data = clean_data_mean
ramdonForest_end_Data["AP_TC"] = ramdonForest_end_Data["AP"] / ramdonForest_end_Data["T_CA"]
ramdonForest_end_Data["OR_TC"] = ramdonForest_end_Data["OTH_RECEIV"] / ramdonForest_end_Data["T_CA"]
ramdonForest_end_Data["IN_TC"] = ramdonForest_end_Data["INVENTORIES"] / ramdonForest_end_Data["T_CA"]
ramdonForest_end_Data["NI_NI"] = ramdonForest_end_Data["NOPERATE_INCOME"] / ramdonForest_end_Data["N_INCOME"]

# %%
ramdonForest_end_Data['FLAG'].groupby(ramdonForest_end_Data['FLAG']).count()
# Out:
# FLAG
# 0.0    571
# 1.0     12
# Name: FLAG, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split,cross_val_score
from imblearn.over_sampling import SMOTE
#定义SMOTE模型，random_state相当于随机数种子的作用
smo = SMOTE(sampling_strategy={1: 40,0:571 },random_state=42)

#ros = RandomOverSampler(random_state=100,sampling_strategy=0.8)
X_smo,y_smo = smo.fit_resample(ramdonForest_end_Data.drop(columns = 'FLAG'),ramdonForest_end_Data['FLAG'])
#拆分专家样本集
X_train, X_test, y_train, y_test = train_test_split(X_smo,y_smo,test_size=0.3)
y_test.groupby(y_test).count()
# Out:
# FLAG
# 0.0    169
# 1.0     15
# Name: FLAG, dtype: int64

# %%
# 贝叶斯优化调参
import xgboost as xgb
from sklearn import metrics
def modelfit(learning_rate, n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree,
             Reg_lambda, Reg_alpha):
    xgb1 =cross_val_score(xgb.XGBClassifier(objective='binary:logistic', nthread=2,
                             n_estimators=int(n_estimators),
                             learning_rate=float(learning_rate),
                             max_depth=int(max_depth), min_child_weight=int(min_child_weight),
                             gamma=float(gamma), subsample=float(subsample),
                             colsample_bytree=float(colsample_bytree),
                             Reg_lambda=float(Reg_lambda), Reg_alpha=float(Reg_alpha),
                             scale_pos_weight=1, seed=10, ),X_train, pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return xgb1


# 参数因子池
pool = {
    'learning_rate': (0.0001, 0.9999),
    'n_estimators': (400, 800),
    'max_depth': (1, 20),  # 树模型深度
    'min_child_weight': (1, 5),
    'gamma': (0.1, 0.7),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.6, 0.9),
    'Reg_lambda': (0.001, 3),
    'Reg_alpha': (0.001, 2)

}
# 定义贝叶斯调参模型
from bayes_opt import BayesianOptimization as bayes

optimizer = bayes(f=modelfit,
                  pbounds=pool,
                  verbose=2,
                  random_state=1,
                  )

# %%
# 调参并输出最优因子
optimizer.maximize(
    init_points=5,
    n_iter=25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | Reg_alpha | Reg_la... | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [19:20:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  1        |  1.0      |  0.8346   |  2.161    |  0.6      |  0.2814   |  0.1468   |  2.754    |  1.745    |  538.2    |  0.719    |
# [19:20:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:20:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [19:25:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  30       |  1.0      |  0.0739   |  1.483    |  0.61     |  0.1296   |  0.4776   |  18.62    |  4.524    |  667.9    |  0.8848   |
# =====================================================================================================================================
# {'target': 1.0, 'params': {'Reg_alpha': 0.8346269874004455, 'Reg_lambda': 2.161253155833032, 'colsample_bytree': 0.6000343124452034, 'gamma': 0.28139954357910385, 'learning_rate': 0.14682653963894962, 'max_depth': 2.7544333006071584, 'min_child_weight': 1.7450408455106836, 'n_estimators': 538.2242908172191, 'subsample': 0.719030242269201}}

# %%
# xgboost模型训练
{'target': 1.0, 'params': {'Reg_alpha': 0.8346269874004455, 'Reg_lambda': 2.161253155833032, 
                           'colsample_bytree': 0.6000343124452034, 'gamma': 0.28139954357910385,
                           'learning_rate': 0.14682653963894962, 'max_depth': 2.7544333006071584,
                           'min_child_weight': 1.7450408455106836, 'n_estimators': 538.2242908172191, 
                           'subsample': 0.719030242269201}}


xgb1 = xgb.XGBClassifier(n_estimators=538,learning_rate=0.14,
                        max_depth=2,min_child_weight=1,gamma=0.28,
                        subsample=0.719,colsample_bytree=0.6,
                        objective='binary:logistic',nthread=2,
                        scale_pos_weight=1,seed=10,Reg_lambda = 2.16,
                         Reg_alpha = 0.834)
xgb1.fit(X_train, y_train)

y_test_pre = xgb1.predict(X_test)
y_test_true = np.array(y_test)
print("the xgboost model Accuracy : %.4g" % metrics.accuracy_score(y_pred=y_test_pre, y_true=y_test_true))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:31:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# the xgboost model Accuracy : 0.9511

# %%
# 特征重要性排名
xgb_predictors = [i for i in X_train.columns]
xgb_feat_imp = pd.Series(xgb1.feature_importances_, xgb_predictors).sort_values(ascending=False)
xgb_feat_imp[0:20].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(xgb_feat_imp[0:20])
# Out:
# T_EQUITY_ATTR_P      0.051794
# INT_FREE_CL          0.043985
# VAL_CHG_PROFIT       0.042888
# INT_CL               0.032508
# GROSS_MARGIN         0.030654
# CA_TURNOVER          0.030329
# BIZ_TAX_SURCHG       0.029626
# T_NCA                0.028813
# RETAINED_EARNINGS    0.028501
# PAID_IN_CAPITAL      0.023160
# OTH_COMPR_INCOME     0.022675
# T_SH_EQUITY          0.021292
# N_CE_BEG_BAL         0.020490
# ROA_EBIT             0.019434
# TEAP_TL              0.018958
# VAL_CHG_P_TR         0.018908
# NOPERATE_EXP         0.018807
# INV_INC_TR           0.018401
# NI_ATTR_P_CUT_YOY    0.018184
# N_TAN_A_TL           0.018026
# dtype: float32

# %%
xgb_feat_imp[0:20]
# Out:
# OPA_P_TR             0.079571
# CAP_FIX_RATIO        0.045631
# T_ASSETS             0.044712
# C_FR_OTH_FINAN_A     0.043357
# IC                   0.041259
# OTH_COMPR_INCOME     0.031570
# N_CF_OPA_LIAB        0.026072
# INCOME_TAX           0.025701
# VAL_CHG_P_TR         0.025426
# OP_TR                0.024222
# BIZ_TAX_SURCHG       0.023323
# INT_PAYABLE          0.021877
# RETAINED_EARNINGS    0.021384
# OTH_NCA              0.020770
# C_PAID_FOR_TAXES     0.019691
# T_NCA                0.018667
# N_CF_OPA_OPAP        0.017032
# VAL_CHG_PROFIT       0.015802
# N_TAN_A_TL           0.015382
# BASIC_EPS            0.013641
# dtype: float32

# %%
# 具体的模型得分报告
from sklearn.metrics import classification_report, roc_auc_score

print(classification_report(y_test_true, y_test_pre))
print("auc值为:", roc_auc_score(y_test_true, y_test_pre))

# ROC曲线绘制
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr1, tpr1, threshold1 = roc_curve(y_test_true, y_test_pre)
plt.plot(fpr1, tpr1, color='r')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99       170
#          1.0       0.91      0.71      0.80        14
#
#     accuracy                           0.97       184
#    macro avg       0.94      0.85      0.89       184
# weighted avg       0.97      0.97      0.97       184
#
# auc值为: 0.854201680672269
# Text(0.5, 1.0, 'XGBClassifier ROC Curve')
