# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split,cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %% [markdown]
# - 读取数据

# %%
ramdonForest_end_Data = pd.read_csv('./信息传输、软件和信息技术服务业_处理.csv',encoding = 'gbk')

# %%
ramdonForest_end_Data = ramdonForest_end_Data.drop(columns = 'Unnamed: 0')

# %%
ramdonForest_end_Data['FLAG'].groupby(ramdonForest_end_Data['FLAG']).count()
# Out:
# FLAG
# 0.0    1417
# 1.0      19
# Name: FLAG, dtype: int64

# %% [markdown]
# - 过采样数据

# %%
#定义SMOTE模型，random_state相当于随机数种子的作用
#smo = SMOTE(sampling_strategy={1:10,0:488 },random_state=42)
ros = RandomOverSampler(random_state=30,sampling_strategy=0.02)
X_ros,y_ros = ros.fit_resample(ramdonForest_end_Data.drop(columns = 'FLAG'),ramdonForest_end_Data['FLAG'])
#标准化数据
sc=StandardScaler()
sc.fit(X_ros)#计算样本的均值和标准差
X_ros=pd.DataFrame(sc.transform(X_ros))
#拆分专家样本集
X_train, X_test, y_train, y_test = train_test_split(X_ros,y_ros,test_size=0.3)
y_train.groupby(y_train).count()
# Out:
# FLAG
# 0.0    993
# 1.0     18
# Name: FLAG, dtype: int64

# %% [markdown]
# - XGBoost模型调整

# %%
# 贝叶斯优化调参

def modelfit(learning_rate, n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree,
             Reg_lambda, Reg_alpha):
    xgb1 =cross_val_score(xgb.XGBClassifier(objective='binary:logistic', nthread=2,
                             n_estimators=int(n_estimators),
                             learning_rate=float(learning_rate),
                             max_depth=int(max_depth), min_child_weight=int(min_child_weight),
                             gamma=float(gamma), subsample=float(subsample),
                             colsample_bytree=float(colsample_bytree),
                             Reg_lambda=float(Reg_lambda), Reg_alpha=float(Reg_alpha),
                             scale_pos_weight=100, seed=10, ),X_train, pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return xgb1


# 参数因子池
pool = {
    'learning_rate': (0.0001, 0.9999),
    'n_estimators': (400, 800),
    'max_depth': (1, 20),  # 树模型深度
    'min_child_weight': (1, 5),
    'gamma': (0.1, 0.7),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.6, 0.9),
    'Reg_lambda': (0.001, 3),
    'Reg_alpha': (0.001, 2)

}
# 定义贝叶斯调参模型
from bayes_opt import BayesianOptimization as bayes

optimizer = bayes(f=modelfit,
                  pbounds=pool,
                  verbose=2,
                  random_state=1,
                  )

# %%
# 调参并输出最优因子
optimizer.maximize(
    init_points=5,
    n_iter=25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | Reg_alpha | Reg_la... | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [00:58:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  1        |  0.8226   |  0.8346   |  2.161    |  0.6      |  0.2814   |  0.1468   |  2.754    |  1.745    |  538.2    |  0.719    |
# [00:58:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [00:58:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:58:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
#   return f(*args, **kwargs)
# [01:08:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:08:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:08:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  30       |  0.8242   |  1.931    |  1.682    |  0.7297   |  0.2129   |  0.2661   |  6.414    |  2.181    |  536.3    |  0.8036   |
# =====================================================================================================================================
# {'target': 0.8615102040816325, 'params': {'Reg_alpha': 1.8319806986182532, 'Reg_lambda': 1.8926638639468827, 'colsample_bytree': 0.7611027351015522, 'gamma': 0.15739800174892332, 'learning_rate': 0.4434035497095646, 'max_depth': 5.138826963224284, 'min_child_weight': 1.9907502368032426, 'n_estimators': 535.3873938717827, 'subsample': 0.655961155736557}}

# %%
# xgboost模型训练
{'target': 0.8615102040816325, 'params': {'Reg_alpha': 1.8319806986182532, 'Reg_lambda': 1.8926638639468827, 
                                          'colsample_bytree': 0.7611027351015522, 'gamma': 0.15739800174892332, 
                                          'learning_rate': 0.4434035497095646, 'max_depth': 5.138826963224284, 
                                          'min_child_weight': 1.9907502368032426, 'n_estimators': 535.3873938717827,
                                          'subsample': 0.655961155736557}}

xgb1 = xgb.XGBClassifier(n_estimators=535,learning_rate=0.44,
                        max_depth=5,min_child_weight=1,gamma=0.15,
                        subsample=0.65,colsample_bytree=0.76,
                        objective='binary:logistic',nthread=2,
                        scale_pos_weight=100,seed=10,Reg_lambda = 1.89,
                         Reg_alpha = 1.83)#scale_pos_weight很重要
xgb1.fit(X_train, y_train)

y_test_pre = xgb1.predict(X_test)
y_test_true = np.array(y_test)
print("the xgboost model auc: %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [01:35:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:35:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# the xgboost model auc: 0.8322

# %%
# 特征重要性排名
xgb_predictors = [i for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
xgb_feat_imp = pd.Series(xgb1.feature_importances_, xgb_predictors).sort_values(ascending=False)
xgb_feat_imp[0:20].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(xgb_feat_imp[0:20])
# Out:
# DILUTED_EPS           0.144606
# INTAN_ASSETS          0.137935
# T_SH_EQUITY           0.067052
# N_CE_END_BAL          0.047973
# PREPAYMENT            0.037992
# C_FR_OTH_OPERATE_A    0.036578
# BASIC_EPS             0.035494
# NI_NI                 0.035409
# N_CHANGE_IN_CASH      0.033659
# MINORITY_INT          0.032688
# AVAIL_FOR_SALE_FA     0.029691
# COMPR_INC_ATTR_M_S    0.025020
# N_CF_OPERATE_A        0.022004
# INVEST_INCOME         0.018614
# N_CF_FR_INVEST_A      0.017457
# OTH_PAYABLE           0.017027
# PAYROLL_PAYABLE       0.016667
# CAPITAL_RESER         0.015980
# DEFER_TAX_ASSETS      0.015405
# INCOME_TAX            0.013663
# dtype: float32

# %%
xgb_feat_imp[0:20]
# Out:
# DILUTED_EPS           0.144606
# INTAN_ASSETS          0.137935
# T_SH_EQUITY           0.067052
# N_CE_END_BAL          0.047973
# PREPAYMENT            0.037992
# C_FR_OTH_OPERATE_A    0.036578
# BASIC_EPS             0.035494
# NI_NI                 0.035409
# N_CHANGE_IN_CASH      0.033659
# MINORITY_INT          0.032688
# AVAIL_FOR_SALE_FA     0.029691
# COMPR_INC_ATTR_M_S    0.025020
# N_CF_OPERATE_A        0.022004
# INVEST_INCOME         0.018614
# N_CF_FR_INVEST_A      0.017457
# OTH_PAYABLE           0.017027
# PAYROLL_PAYABLE       0.016667
# CAPITAL_RESER         0.015980
# DEFER_TAX_ASSETS      0.015405
# INCOME_TAX            0.013663
# dtype: float32

# %%
# 具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:", roc_auc_score(y_test_true,y_test_pre))

# ROC曲线绘制
fpr1, tpr1, threshold1 = roc_curve(y_test_true, y_test_pre)
plt.plot(fpr1, tpr1, color='r')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       428
#          1.0       0.80      0.67      0.73         6
#
#     accuracy                           0.99       434
#    macro avg       0.90      0.83      0.86       434
# weighted avg       0.99      0.99      0.99       434
#
# auc值为: 0.8321651090342678
# Text(0.5, 1.0, 'XGBClassifier ROC Curve')

# %% [markdown]
# - LightGBM模型调整

# %%
#贝叶斯优化调参
def modelfit(learning_rate,n_estimators,max_depth,num_leaves,min_data_in_leaf,max_bin,feature_fraction,
            bagging_fraction,bagging_freq,lambda_l1,lambda_l2,min_split_gain):
    lgb1 = cross_val_score(lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                              n_estimators = int(n_estimators),
                              max_depth = int(max_depth),
                              num_leaves = int(num_leaves),
                              learning_rate = float(learning_rate),
                              min_data_in_leaf = int(min_data_in_leaf),
                              max_bin = int(max_bin),
                              feature_fraction = float(feature_fraction),
                              bagging_fraction = float(bagging_fraction),
                              bagging_freq = int(bagging_freq),
                              lambda_l1 = float(lambda_l1),lambda_l2 = float(lambda_l2),
                              min_split_gain = float(min_split_gain),
                              cat_smooth = 100,nthread = 4, ),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return lgb1

pool = {
    'learning_rate':(0.0001,0.9999),
    'n_estimators':(400,800),
    'max_depth':(1,20),              #树模型深度
    'num_leaves':(10,30),            #叶子树，树模型复杂度
    'min_data_in_leaf':(1,70),       #处理过拟合，一个叶子上数据的最小数量
    'max_bin':(5,255),               #工具箱数（叶子结点数+非叶子节点数？）
    'feature_fraction':(0.5,0.999),  #每次迭代中随机选择特征的比例。加速训练，处理过拟合
    'bagging_fraction':(0.5,0.999),  #不进行重采样的情况下随机选择部分数据
    'bagging_freq':(3,5),            #bagging的次数。0表示禁用bagging，非零值表示执行k次bagging
    'lambda_l1':(0.0001,0.9999),
    'lambda_l2':(0.0001,0.9999),
    'min_split_gain':(0.01,0.999)    #执行切分的最小增益
    
}

from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | lambda_l1 | lambda_l2 | learni... |  max_bin  | max_depth | min_da... | min_sp... | n_esti... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  1        |  0.8012   |  0.7081   |  4.441    |  0.5001   |  0.3024   |  0.1468   |  0.09242  |  51.57    |  7.566    |  28.38    |  0.5429   |  567.7    |  23.7     |
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# ...
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5133727637937384, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5133727637937384
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.0534193882382596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0534193882382596
# [LightGBM] [Warning] bagging_fraction is set=0.5072305094352731, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5072305094352731
# [LightGBM] [Warning] lambda_l2 is set=0.8729673921406531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8729673921406531
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  30       |  0.7322   |  0.5072   |  4.398    |  0.5134   |  0.05342  |  0.873    |  0.4106   |  103.5    |  3.825    |  59.01    |  0.7315   |  771.2    |  27.04    |
# =========================================================================================================================================================================
# {'target': 0.8308979591836735, 'params': {'bagging_fraction': 0.6754757549664127, 'bagging_freq': 4.231655051576414, 'feature_fraction': 0.5712525909183249, 'lambda_l1': 0.5044598506225632, 'lambda_l2': 0.5029524723756272, 'learning_rate': 0.11355357310140117, 'max_bin': 97.44504156878864, 'max_depth': 18.2356410110942, 'min_data_in_leaf': 3.1362926412057943, 'min_split_gain': 0.20767735206126722, 'n_estimators': 612.8297082396728, 'num_leaves': 24.47909369200142}}
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
{'target': 0.8308979591836735, 'params': {'bagging_fraction': 0.6754757549664127, 'bagging_freq': 4.231655051576414, 
                                          'feature_fraction': 0.5712525909183249, 'lambda_l1': 0.5044598506225632,
                                          'lambda_l2': 0.5029524723756272, 'learning_rate': 0.11355357310140117,
                                          'max_bin': 97.44504156878864, 'max_depth': 18.2356410110942, 
                                          'min_data_in_leaf': 3.1362926412057943, 'min_split_gain': 0.20767735206126722, 
                                          'n_estimators': 612.8297082396728, 'num_leaves': 24.47909369200142}}
lgb1 = lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                          bagging_fraction = 0.67, bagging_freq = 4,
                          feature_fraction = 0.57,lambda_l1 =  0.5,lambda_l2 = 0.5,
                          learning_rate = 0.11,max_bin = 97,max_depth = 18,
                          min_data_in_leaf = 3,min_split_gain = 0.2,
                          n_estimators = 612,num_leaves = 24,
                          cat_smooth = 100,nthread = 4)
#cat_smooth：可以减少噪声对分类特征的影响，尤其是对于数据较少的分类
lgb_model = lgb1.fit(X_train,pd.DataFrame(y_train))
y_test_pre = lgb1.predict(X_test)
y_test_true = np.array(y_test)
print ("the lightgbm model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.57, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.57
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] bagging_fraction is set=0.67, subsample=1.0 will be ignored. Current value: bagging_fraction=0.67
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# the lightgbm model auc : 0.8333
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#特征重要性排名
lgb_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
lgb_feat_imp = pd.Series(lgb_model.feature_importances_,lgb_predictors).sort_values(ascending=False)
lgb_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(lgb_feat_imp )
# Out:
# C_FR_BORR             21
# ST_BORR               17
# REFUND_OF_TAX         14
# N_CHANGE_IN_CASH      12
# C_FR_OTH_OPERATE_A    12
#                       ..
# T_COMPR_INCOME         0
# T_LIAB                 0
# T_CL                   0
# C_FR_SALE_G_S          0
# MINORITY_INT           0
# Length: 95, dtype: int32

# %%
print(lgb_feat_imp[0:20] )
# Out:
# C_FR_BORR              21
# ST_BORR                17
# REFUND_OF_TAX          14
# N_CHANGE_IN_CASH       12
# C_FR_OTH_OPERATE_A     12
# AVAIL_FOR_SALE_FA      11
# NOPERATE_EXP           10
# GOODWILL               10
# PAYROLL_PAYABLE         9
# NI_NI                   9
# BASIC_EPS               8
# PAID_IN_CAPITAL         8
# AP_TC                   7
# CAPITAL_RESER           7
# LT_EQUITY_INVEST        7
# C_PAID_OTH_FINAN_A      7
# DISP_FIX_ASSETS_OTH     7
# N_CF_FR_FINAN_A         6
# C_INF_FR_OPERATE_A      6
# OTH_RECEIV              6
# dtype: int32

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       428
#          1.0       1.00      0.67      0.80         6
#
#     accuracy                           1.00       434
#    macro avg       1.00      0.83      0.90       434
# weighted avg       1.00      1.00      0.99       434
#
# auc值为: 0.8333333333333333
# Text(0.5, 1.0, 'LGBClassifier ROC Curve')

# %% [markdown]
# - Catboost模型调整

# %%
def modelfit(learning_rate,depth,bagging_temperature):
    cat1 = cross_val_score(CatBoostClassifier(loss_function = 'Logloss',
                             eval_metric = 'AUC',
                             iterations = 2500,
                             learning_rate = float(learning_rate),
                             depth = int(depth),
                             verbose = 100,
                             bagging_temperature = float(bagging_temperature),
                             early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return cat1

pool = {
    'learning_rate':(0.01,0.999),
    'depth':(4,9),
    'bagging_temperature':(0.01,0.999)
}
from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... |   depth   | learni... |
# -------------------------------------------------------------
# 0:	total: 44.8ms	remaining: 1m 52s
# 100:	total: 2.23s	remaining: 53s
# 200:	total: 4.53s	remaining: 51.8s
# 300:	total: 6.89s	remaining: 50.3s
# 400:	total: 9.49s	remaining: 49.7s
# 500:	total: 11.9s	remaining: 47.6s
# 600:	total: 14.4s	remaining: 45.5s
# 700:	total: 16.9s	remaining: 43.4s
# 800:	total: 19.3s	remaining: 41s
# 900:	total: 21.4s	remaining: 38s
# 1000:	total: 23.5s	remaining: 35.2s
# 1100:	total: 25.6s	remaining: 32.5s
# 1200:	total: 27.8s	remaining: 30s
# 1300:	total: 30s	remaining: 27.6s
# 1400:	total: 32.2s	remaining: 25.3s
# 1500:	total: 34.5s	remaining: 23s
# 1600:	total: 36.8s	remaining: 20.7s
# 1700:	total: 39s	remaining: 18.3s
# 1800:	total: 41.3s	remaining: 16s
# 1900:	total: 43.5s	remaining: 13.7s
# 2000:	total: 45.7s	remaining: 11.4s
# 2100:	total: 47.9s	remaining: 9.09s
# 2200:	total: 50.1s	remaining: 6.8s
# 2300:	total: 52.3s	remaining: 4.52s
# 2400:	total: 54.5s	remaining: 2.25s
# 2499:	total: 56.6s	remaining: 0us
# 0:	total: 24.2ms	remaining: 1m
# 100:	total: 2.22s	remaining: 52.7s
# 200:	total: 4.52s	remaining: 51.7s
# 300:	total: 6.7s	remaining: 49s
# 400:	total: 8.85s	remaining: 46.3s
# 500:	total: 11.1s	remaining: 44.1s
# 600:	total: 13.2s	remaining: 41.9s
# 700:	total: 15.4s	remaining: 39.5s
# 800:	total: 17.6s	remaining: 37.3s
# 900:	total: 19.8s	remaining: 35.1s
# 1000:	total: 22s	remaining: 32.9s
# 1100:	total: 24.2s	remaining: 30.7s
# 1200:	total: 26.4s	remaining: 28.6s
# 1300:	total: 28.7s	remaining: 26.4s
# 1400:	total: 30.8s	remaining: 24.2s
# 1500:	total: 33.2s	remaining: 22.1s
# 1600:	total: 35.6s	remaining: 20s
# 1700:	total: 38s	remaining: 17.9s
# 1800:	total: 40.3s	remaining: 15.6s
# 1900:	total: 42.8s	remaining: 13.5s
# 2000:	total: 45.2s	remaining: 11.3s
# 2100:	total: 47.3s	remaining: 8.99s
# 2200:	total: 49.7s	remaining: 6.75s
# 2300:	total: 51.8s	remaining: 4.48s
# 2400:	total: 54s	remaining: 2.23s
# 2499:	total: 56.5s	remaining: 0us
# 0:	total: 36.1ms	remaining: 1m 30s
# 100:	total: 2.6s	remaining: 1m 1s
# 200:	total: 5.2s	remaining: 59.4s
# 300:	total: 7.71s	remaining: 56.3s
# 400:	total: 10.3s	remaining: 54.1s
# 500:	total: 12.5s	remaining: 49.9s
# 600:	total: 14.8s	remaining: 46.9s
# 700:	total: 17.4s	remaining: 44.7s
# 800:	total: 19.7s	remaining: 41.8s
# 900:	total: 21.9s	remaining: 38.9s
# 1000:	total: 24s	remaining: 36s
# 1100:	total: 26.2s	remaining: 33.3s
# 1200:	total: 28.3s	remaining: 30.6s
# 1300:	total: 30.4s	remaining: 28s
# 1400:	total: 32.6s	remaining: 25.6s
# 1500:	total: 34.7s	remaining: 23.1s
# 1600:	total: 36.8s	remaining: 20.7s
# 1700:	total: 39s	remaining: 18.3s
# 1800:	total: 41.1s	remaining: 16s
# 1900:	total: 43.3s	remaining: 13.6s
# 2000:	total: 45.4s	remaining: 11.3s
# 2100:	total: 47.5s	remaining: 9.02s
# 2200:	total: 49.6s	remaining: 6.74s
# 2300:	total: 51.7s	remaining: 4.47s
# 2400:	total: 53.8s	remaining: 2.22s
# 2499:	total: 56s	remaining: 0us
# 0:	total: 25.4ms	remaining: 1m 3s
# 100:	total: 2.13s	remaining: 50.7s
# 200:	total: 4.3s	remaining: 49.2s
# 300:	total: 6.38s	remaining: 46.6s
# 400:	total: 8.52s	remaining: 44.6s
# 500:	total: 10.8s	remaining: 42.9s
# 600:	total: 12.9s	remaining: 40.8s
# 700:	total: 15s	remaining: 38.6s
# 800:	total: 17.2s	remaining: 36.5s
# 900:	total: 19.3s	remaining: 34.3s
# 1000:	total: 21.4s	remaining: 32.1s
# 1100:	total: 23.6s	remaining: 29.9s
# 1200:	total: 25.7s	remaining: 27.8s
# 1300:	total: 27.8s	remaining: 25.6s
# 1400:	total: 29.9s	remaining: 23.5s
# 1500:	total: 32s	remaining: 21.3s
# 1600:	total: 34.2s	remaining: 19.2s
# 1700:	total: 36.3s	remaining: 17s
# 1800:	total: 38.4s	remaining: 14.9s
# 1900:	total: 40.5s	remaining: 12.8s
# 2000:	total: 42.6s	remaining: 10.6s
# 2100:	total: 44.8s	remaining: 8.51s
# 2200:	total: 46.9s	remaining: 6.37s
# 2300:	total: 49.1s	remaining: 4.24s
# 2400:	total: 51.2s	remaining: 2.11s
# 2499:	total: 53.3s	remaining: 0us
# 0:	total: 42.5ms	remaining: 1m 46s
# 100:	total: 2.19s	remaining: 52.1s
# 200:	total: 4.32s	remaining: 49.4s
# 300:	total: 6.42s	remaining: 46.9s
# 400:	total: 8.54s	remaining: 44.7s
# 500:	total: 10.7s	remaining: 42.6s
# 600:	total: 12.8s	remaining: 40.5s
# 700:	total: 14.9s	remaining: 38.3s
# 800:	total: 17.1s	remaining: 36.2s
# 900:	total: 19.2s	remaining: 34s
# 1000:	total: 21.3s	remaining: 31.9s
# 1100:	total: 23.4s	remaining: 29.8s
# 1200:	total: 25.5s	remaining: 27.6s
# 1300:	total: 27.7s	remaining: 25.5s
# 1400:	total: 29.9s	remaining: 23.5s
# 1500:	total: 32s	remaining: 21.3s
# 1600:	total: 34.2s	remaining: 19.2s
# 1700:	total: 36.3s	remaining: 17.1s
# 1800:	total: 38.5s	remaining: 14.9s
# 1900:	total: 40.6s	remaining: 12.8s
# 2000:	total: 42.9s	remaining: 10.7s
# 2100:	total: 45.2s	remaining: 8.59s
# 2200:	total: 47.5s	remaining: 6.45s
# 2300:	total: 49.7s	remaining: 4.3s
# 2400:	total: 52.1s	remaining: 2.15s
# 2499:	total: 54.5s	remaining: 0us
# 0:	total: 29.6ms	remaining: 1m 13s
# 100:	total: 2.46s	remaining: 58.4s
# 200:	total: 4.87s	remaining: 55.7s
# 300:	total: 7.21s	remaining: 52.7s
# 400:	total: 9.39s	remaining: 49.1s
# 500:	total: 11.8s	remaining: 47.1s
# 600:	total: 14s	remaining: 44.2s
# 700:	total: 16.3s	remaining: 41.7s
# 800:	total: 18.6s	remaining: 39.4s
# 900:	total: 20.9s	remaining: 37s
# 1000:	total: 23s	remaining: 34.5s
# 1100:	total: 25.2s	remaining: 32.1s
# 1200:	total: 27.5s	remaining: 29.8s
# 1300:	total: 30.4s	remaining: 28s
# 1400:	total: 33s	remaining: 25.9s
# 1500:	total: 35.1s	remaining: 23.4s
# 1600:	total: 37.2s	remaining: 20.9s
# 1700:	total: 39.4s	remaining: 18.5s
# 1800:	total: 41.6s	remaining: 16.1s
# 1900:	total: 43.9s	remaining: 13.8s
# 2000:	total: 46.2s	remaining: 11.5s
# 2100:	total: 48.6s	remaining: 9.23s
# 2200:	total: 51.1s	remaining: 6.93s
# 2300:	total: 53.5s	remaining: 4.63s
# 2400:	total: 55.8s	remaining: 2.3s
# 2499:	total: 57.9s	remaining: 0us
# 0:	total: 26.1ms	remaining: 1m 5s
# 100:	total: 2.27s	remaining: 53.9s
# 200:	total: 4.67s	remaining: 53.4s
# 300:	total: 6.91s	remaining: 50.5s
# 400:	total: 9.18s	remaining: 48s
# 500:	total: 11.3s	remaining: 45.3s
# 600:	total: 13.6s	remaining: 42.9s
# 700:	total: 15.8s	remaining: 40.7s
# 800:	total: 18.2s	remaining: 38.6s
# 900:	total: 20.6s	remaining: 36.6s
# 1000:	total: 22.9s	remaining: 34.3s
# 1100:	total: 25.2s	remaining: 32.1s
# 1200:	total: 27.5s	remaining: 29.7s
# 1300:	total: 29.9s	remaining: 27.5s
# 1400:	total: 32.1s	remaining: 25.2s
# 1500:	total: 34.2s	remaining: 22.8s
# 1600:	total: 36.3s	remaining: 20.4s
# 1700:	total: 38.4s	remaining: 18.1s
# 1800:	total: 40.6s	remaining: 15.7s
# 1900:	total: 42.7s	remaining: 13.4s
# 2000:	total: 44.8s	remaining: 11.2s
# 2100:	total: 47s	remaining: 8.92s
# 2200:	total: 49.1s	remaining: 6.67s
# 2300:	total: 51.2s	remaining: 4.43s
# 2400:	total: 53.4s	remaining: 2.2s
# 2499:	total: 55.5s	remaining: 0us
# 0:	total: 25ms	remaining: 1m 2s
# 100:	total: 2.19s	remaining: 52.1s
# 200:	total: 4.29s	remaining: 49.1s
# 300:	total: 6.4s	remaining: 46.7s
# 400:	total: 8.51s	remaining: 44.5s
# 500:	total: 10.6s	remaining: 42.4s
# 600:	total: 12.7s	remaining: 40.3s
# 700:	total: 14.9s	remaining: 38.1s
# 800:	total: 17s	remaining: 36s
# 900:	total: 19.1s	remaining: 33.9s
# 1000:	total: 21.3s	remaining: 31.9s
# 1100:	total: 23.4s	remaining: 29.7s
# 1200:	total: 25.6s	remaining: 27.6s
# 1300:	total: 27.7s	remaining: 25.6s
# 1400:	total: 29.9s	remaining: 23.4s
# 1500:	total: 32s	remaining: 21.3s
# 1600:	total: 34.1s	remaining: 19.1s
# 1700:	total: 36.2s	remaining: 17s
# 1800:	total: 38.3s	remaining: 14.9s
# 1900:	total: 40.4s	remaining: 12.7s
# 2000:	total: 42.5s	remaining: 10.6s
# 2100:	total: 44.7s	remaining: 8.48s
# 2200:	total: 46.8s	remaining: 6.36s
# 2300:	total: 48.9s	remaining: 4.23s
# 2400:	total: 51s	remaining: 2.1s
# 2499:	total: 53.1s	remaining: 0us
# 0:	total: 24.8ms	remaining: 1m 2s
# 100:	total: 2.15s	remaining: 51.1s
# 200:	total: 4.28s	remaining: 49s
# 300:	total: 6.41s	remaining: 46.8s
# 400:	total: 8.55s	remaining: 44.8s
# 500:	total: 10.7s	remaining: 42.7s
# 600:	total: 12.8s	remaining: 40.5s
# 700:	total: 14.9s	remaining: 38.3s
# 800:	total: 17s	remaining: 36.1s
# 900:	total: 19.2s	remaining: 34s
# 1000:	total: 21.3s	remaining: 31.9s
# 1100:	total: 23.4s	remaining: 29.7s
# 1200:	total: 25.5s	remaining: 27.6s
# 1300:	total: 27.6s	remaining: 25.5s
# 1400:	total: 29.7s	remaining: 23.3s
# 1500:	total: 31.9s	remaining: 21.2s
# 1600:	total: 34s	remaining: 19.1s
# 1700:	total: 36.1s	remaining: 17s
# 1800:	total: 38.3s	remaining: 14.9s
# 1900:	total: 40.4s	remaining: 12.7s
# 2000:	total: 42.5s	remaining: 10.6s
# 2100:	total: 44.6s	remaining: 8.47s
# 2200:	total: 46.7s	remaining: 6.35s
# 2300:	total: 48.9s	remaining: 4.23s
# 2400:	total: 51s	remaining: 2.1s
# 2499:	total: 53.1s	remaining: 0us
# 0:	total: 30.4ms	remaining: 1m 16s
# 100:	total: 2.15s	remaining: 51s
# 200:	total: 4.27s	remaining: 48.9s
# 300:	total: 6.39s	remaining: 46.7s
# 400:	total: 8.5s	remaining: 44.5s
# 500:	total: 10.6s	remaining: 42.3s
# 600:	total: 12.8s	remaining: 40.3s
# 700:	total: 14.9s	remaining: 38.1s
# 800:	total: 17s	remaining: 36.1s
# 900:	total: 19.2s	remaining: 34s
# 1000:	total: 21.3s	remaining: 31.8s
# 1100:	total: 23.4s	remaining: 29.8s
# 1200:	total: 25.5s	remaining: 27.6s
# 1300:	total: 27.7s	remaining: 25.5s
# 1400:	total: 29.8s	remaining: 23.4s
# 1500:	total: 32s	remaining: 21.3s
# 1600:	total: 34.2s	remaining: 19.2s
# 1700:	total: 36.6s	remaining: 17.2s
# 1800:	total: 39s	remaining: 15.2s
# 1900:	total: 41.5s	remaining: 13.1s
# 2000:	total: 43.7s	remaining: 10.9s
# 2100:	total: 46.2s	remaining: 8.77s
# 2200:	total: 48.8s	remaining: 6.62s
# 2300:	total: 51.4s	remaining: 4.44s
# 2400:	total: 53.7s	remaining: 2.22s
# 2499:	total: 56s	remaining: 0us
# 0:	total: 27.1ms	remaining: 1m 7s
# 100:	total: 2.23s	remaining: 53.1s
# 200:	total: 4.46s	remaining: 51.1s
# 300:	total: 6.69s	remaining: 48.9s
# 400:	total: 9.05s	remaining: 47.4s
# 500:	total: 11.5s	remaining: 45.7s
# 600:	total: 13.8s	remaining: 43.6s
# 700:	total: 16.1s	remaining: 41.4s
# 800:	total: 18.6s	remaining: 39.4s
# 900:	total: 21s	remaining: 37.3s
# 1000:	total: 23.3s	remaining: 34.9s
# 1100:	total: 25.7s	remaining: 32.6s
# 1200:	total: 28.4s	remaining: 30.7s
# 1300:	total: 30.8s	remaining: 28.4s
# 1400:	total: 33.2s	remaining: 26.1s
# 1500:	total: 35.8s	remaining: 23.8s
# 1600:	total: 38.1s	remaining: 21.4s
# 1700:	total: 40.3s	remaining: 18.9s
# 1800:	total: 42.5s	remaining: 16.5s
# 1900:	total: 44.9s	remaining: 14.1s
# 2000:	total: 47.2s	remaining: 11.8s
# 2100:	total: 49.4s	remaining: 9.37s
# 2200:	total: 51.6s	remaining: 7.01s
# 2300:	total: 53.7s	remaining: 4.65s
# 2400:	total: 55.9s	remaining: 2.3s
# 2499:	total: 58s	remaining: 0us
# 0:	total: 37.4ms	remaining: 1m 33s
# 100:	total: 2.31s	remaining: 54.8s
# 200:	total: 4.53s	remaining: 51.8s
# 300:	total: 6.76s	remaining: 49.4s
# 400:	total: 9.18s	remaining: 48s
# 500:	total: 11.6s	remaining: 46.1s
# 600:	total: 13.7s	remaining: 43.4s
# 700:	total: 15.9s	remaining: 40.9s
# 800:	total: 18.1s	remaining: 38.3s
# 900:	total: 20.2s	remaining: 35.9s
# 1000:	total: 22.5s	remaining: 33.6s
# 1100:	total: 24.6s	remaining: 31.3s
# 1200:	total: 26.7s	remaining: 28.9s
# 1300:	total: 28.9s	remaining: 26.6s
# 1400:	total: 31.1s	remaining: 24.4s
# 1500:	total: 33.3s	remaining: 22.1s
# 1600:	total: 35.4s	remaining: 19.9s
# 1700:	total: 37.6s	remaining: 17.7s
# 1800:	total: 39.8s	remaining: 15.4s
# 1900:	total: 42s	remaining: 13.2s
# 2000:	total: 44.4s	remaining: 11.1s
# 2100:	total: 46.7s	remaining: 8.86s
# 2200:	total: 48.9s	remaining: 6.64s
# 2300:	total: 51.1s	remaining: 4.42s
# 2400:	total: 53.3s	remaining: 2.19s
# 2499:	total: 55.5s	remaining: 0us
# 0:	total: 53.7ms	remaining: 2m 14s
# 100:	total: 2.42s	remaining: 57.5s
# 200:	total: 4.72s	remaining: 54s
# 300:	total: 6.95s	remaining: 50.8s
# 400:	total: 9.11s	remaining: 47.7s
# 500:	total: 11.4s	remaining: 45.4s
# 600:	total: 13.7s	remaining: 43.2s
# 700:	total: 16s	remaining: 41s
# 800:	total: 18.3s	remaining: 38.8s
# 900:	total: 20.9s	remaining: 37.1s
# 1000:	total: 23.2s	remaining: 34.7s
# 1100:	total: 25.5s	remaining: 32.4s
# 1200:	total: 27.8s	remaining: 30.1s
# 1300:	total: 30s	remaining: 27.6s
# 1400:	total: 32.2s	remaining: 25.2s
# 1500:	total: 34.4s	remaining: 22.9s
# 1600:	total: 36.7s	remaining: 20.6s
# 1700:	total: 38.9s	remaining: 18.3s
# 1800:	total: 41.2s	remaining: 16s
# 1900:	total: 43.5s	remaining: 13.7s
# 2000:	total: 45.8s	remaining: 11.4s
# 2100:	total: 47.9s	remaining: 9.1s
# 2200:	total: 50.2s	remaining: 6.81s
# 2300:	total: 52.4s	remaining: 4.53s
# 2400:	total: 54.7s	remaining: 2.25s
# 2499:	total: 57s	remaining: 0us
# 0:	total: 27.8ms	remaining: 1m 9s
# 100:	total: 2.24s	remaining: 53.3s
# 200:	total: 4.39s	remaining: 50.3s
# 300:	total: 6.69s	remaining: 48.9s
# 400:	total: 8.99s	remaining: 47.1s
# 500:	total: 11.2s	remaining: 44.5s
# 600:	total: 13.4s	remaining: 42.2s
# 700:	total: 15.5s	remaining: 39.9s
# 800:	total: 17.7s	remaining: 37.5s
# 900:	total: 19.9s	remaining: 35.3s
# 1000:	total: 22.1s	remaining: 33.1s
# 1100:	total: 24.3s	remaining: 30.8s
# 1200:	total: 26.4s	remaining: 28.6s
# 1300:	total: 28.7s	remaining: 26.5s
# 1400:	total: 31s	remaining: 24.3s
# 1500:	total: 33.2s	remaining: 22.1s
# 1600:	total: 35.4s	remaining: 19.9s
# 1700:	total: 37.6s	remaining: 17.7s
# 1800:	total: 39.9s	remaining: 15.5s
# 1900:	total: 42.1s	remaining: 13.3s
# 2000:	total: 44.3s	remaining: 11s
# 2100:	total: 46.5s	remaining: 8.83s
# 2200:	total: 48.7s	remaining: 6.62s
# 2300:	total: 51.1s	remaining: 4.42s
# 2400:	total: 53.3s	remaining: 2.2s
# 2499:	total: 55.5s	remaining: 0us
# 0:	total: 65.6ms	remaining: 2m 44s
# 100:	total: 2.48s	remaining: 58.8s
# 200:	total: 4.76s	remaining: 54.4s
# 300:	total: 7.08s	remaining: 51.7s
# 400:	total: 9.4s	remaining: 49.2s
# 500:	total: 11.8s	remaining: 47s
# 600:	total: 14s	remaining: 44.2s
# 700:	total: 16.2s	remaining: 41.5s
# 800:	total: 18.4s	remaining: 39s
# 900:	total: 20.7s	remaining: 36.8s
# 1000:	total: 23.2s	remaining: 34.7s
# 1100:	total: 25.6s	remaining: 32.6s
# 1200:	total: 28.5s	remaining: 30.8s
# 1300:	total: 31s	remaining: 28.6s
# 1400:	total: 33.3s	remaining: 26.1s
# 1500:	total: 36s	remaining: 24s
# 1600:	total: 38.8s	remaining: 21.8s
# 1700:	total: 41.5s	remaining: 19.5s
# 1800:	total: 44s	remaining: 17.1s
# 1900:	total: 46.3s	remaining: 14.6s
# 2000:	total: 49.2s	remaining: 12.3s
# 2100:	total: 51.4s	remaining: 9.77s
# 2200:	total: 54s	remaining: 7.33s
# 2300:	total: 56.4s	remaining: 4.88s
# 2400:	total: 59.1s	remaining: 2.44s
# 2499:	total: 1m 1s	remaining: 0us
# 0:	total: 37ms	remaining: 1m 32s
# 100:	total: 2.29s	remaining: 54.5s
# 200:	total: 4.42s	remaining: 50.6s
# 300:	total: 6.61s	remaining: 48.3s
# 400:	total: 8.79s	remaining: 46s
# 500:	total: 11s	remaining: 44.1s
# 600:	total: 13.3s	remaining: 41.9s
# 700:	total: 15.5s	remaining: 39.8s
# 800:	total: 17.9s	remaining: 37.9s
# 900:	total: 20.1s	remaining: 35.7s
# 1000:	total: 22.4s	remaining: 33.5s
# 1100:	total: 24.6s	remaining: 31.3s
# 1200:	total: 26.9s	remaining: 29.1s
# 1300:	total: 29.1s	remaining: 26.8s
# 1400:	total: 31.3s	remaining: 24.6s
# 1500:	total: 33.5s	remaining: 22.3s
# 1600:	total: 35.8s	remaining: 20.1s
# 1700:	total: 38.1s	remaining: 17.9s
# 1800:	total: 40.5s	remaining: 15.7s
# 1900:	total: 42.7s	remaining: 13.5s
# 2000:	total: 45.1s	remaining: 11.2s
# 2100:	total: 47.3s	remaining: 8.99s
# 2200:	total: 49.6s	remaining: 6.73s
# 2300:	total: 52s	remaining: 4.5s
# 2400:	total: 54.3s	remaining: 2.24s
# 2499:	total: 56.7s	remaining: 0us
# 0:	total: 23.3ms	remaining: 58.2s
# 100:	total: 2.27s	remaining: 53.8s
# 200:	total: 4.49s	remaining: 51.3s
# 300:	total: 6.6s	remaining: 48.2s
# 400:	total: 8.75s	remaining: 45.8s
# 500:	total: 11.1s	remaining: 44.3s
# 600:	total: 13.7s	remaining: 43.3s
# 700:	total: 16.3s	remaining: 41.8s
# 800:	total: 18.7s	remaining: 39.7s
# 900:	total: 21.1s	remaining: 37.4s
# 1000:	total: 23.4s	remaining: 35.1s
# 1100:	total: 25.8s	remaining: 32.7s
# 1200:	total: 28s	remaining: 30.3s
# 1300:	total: 30.3s	remaining: 27.9s
# 1400:	total: 32.5s	remaining: 25.5s
# 1500:	total: 34.7s	remaining: 23.1s
# 1600:	total: 37s	remaining: 20.8s
# 1700:	total: 39.2s	remaining: 18.4s
# 1800:	total: 41.4s	remaining: 16.1s
# 1900:	total: 43.7s	remaining: 13.8s
# 2000:	total: 46s	remaining: 11.5s
# 2100:	total: 48.2s	remaining: 9.15s
# 2200:	total: 50.4s	remaining: 6.84s
# 2300:	total: 52.6s	remaining: 4.55s
# 2400:	total: 54.8s	remaining: 2.26s
# 2499:	total: 56.9s	remaining: 0us
# 0:	total: 36.8ms	remaining: 1m 31s
# 100:	total: 2.31s	remaining: 54.8s
# 200:	total: 4.58s	remaining: 52.5s
# 300:	total: 6.84s	remaining: 50s
# 400:	total: 9.12s	remaining: 47.7s
# 500:	total: 11.4s	remaining: 45.3s
# 600:	total: 13.5s	remaining: 42.8s
# 700:	total: 16s	remaining: 41.1s
# 800:	total: 18.2s	remaining: 38.6s
# 900:	total: 20.4s	remaining: 36.3s
# 1000:	total: 22.9s	remaining: 34.2s
# 1100:	total: 25.4s	remaining: 32.3s
# 1200:	total: 27.9s	remaining: 30.2s
# 1300:	total: 30.5s	remaining: 28.1s
# 1400:	total: 33s	remaining: 25.9s
# 1500:	total: 35.5s	remaining: 23.6s
# 1600:	total: 38.1s	remaining: 21.4s
# 1700:	total: 40.5s	remaining: 19s
# 1800:	total: 42.9s	remaining: 16.7s
# 1900:	total: 45.4s	remaining: 14.3s
# 2000:	total: 47.9s	remaining: 11.9s
# 2100:	total: 50.2s	remaining: 9.53s
# 2200:	total: 52.7s	remaining: 7.16s
# 2300:	total: 55.5s	remaining: 4.8s
# 2400:	total: 58s	remaining: 2.39s
# 2499:	total: 1m	remaining: 0us
# 0:	total: 29.8ms	remaining: 1m 14s
# 100:	total: 2.54s	remaining: 1m
# 200:	total: 4.92s	remaining: 56.3s
# 300:	total: 7.43s	remaining: 54.3s
# 400:	total: 10.1s	remaining: 52.7s
# 500:	total: 12.8s	remaining: 51s
# 600:	total: 15.4s	remaining: 48.7s
# 700:	total: 18s	remaining: 46.3s
# 800:	total: 20.6s	remaining: 43.6s
# 900:	total: 23.2s	remaining: 41.1s
# 1000:	total: 25.6s	remaining: 38.4s
# 1100:	total: 27.9s	remaining: 35.5s
# 1200:	total: 30.2s	remaining: 32.7s
# 1300:	total: 32.5s	remaining: 30s
# 1400:	total: 34.8s	remaining: 27.3s
# 1500:	total: 37.1s	remaining: 24.7s
# 1600:	total: 39.4s	remaining: 22.1s
# 1700:	total: 41.6s	remaining: 19.6s
# 1800:	total: 44s	remaining: 17.1s
# 1900:	total: 46.3s	remaining: 14.6s
# 2000:	total: 48.5s	remaining: 12.1s
# 2100:	total: 50.8s	remaining: 9.66s
# 2200:	total: 53s	remaining: 7.2s
# 2300:	total: 55.2s	remaining: 4.77s
# 2400:	total: 57.7s	remaining: 2.38s
# 2499:	total: 1m	remaining: 0us
# 0:	total: 61.6ms	remaining: 2m 33s
# 100:	total: 2.66s	remaining: 1m 3s
# 200:	total: 4.89s	remaining: 55.9s
# 300:	total: 7.03s	remaining: 51.4s
# 400:	total: 9.38s	remaining: 49.1s
# 500:	total: 11.8s	remaining: 47.1s
# 600:	total: 14.4s	remaining: 45.4s
# 700:	total: 16.8s	remaining: 43.1s
# 800:	total: 19s	remaining: 40.3s
# 900:	total: 21.3s	remaining: 37.8s
# 1000:	total: 23.7s	remaining: 35.5s
# 1100:	total: 26.1s	remaining: 33.2s
# 1200:	total: 28.5s	remaining: 30.8s
# 1300:	total: 30.6s	remaining: 28.2s
# 1400:	total: 32.8s	remaining: 25.7s
# 1500:	total: 34.9s	remaining: 23.2s
# 1600:	total: 37.1s	remaining: 20.8s
# 1700:	total: 39.2s	remaining: 18.4s
# 1800:	total: 41.3s	remaining: 16s
# 1900:	total: 43.5s	remaining: 13.7s
# 2000:	total: 45.6s	remaining: 11.4s
# 2100:	total: 47.8s	remaining: 9.07s
# 2200:	total: 49.9s	remaining: 6.78s
# 2300:	total: 52s	remaining: 4.5s
# 2400:	total: 54.2s	remaining: 2.24s
# 2499:	total: 56.4s	remaining: 0us
# |  1        |  0.8865   |  0.4224   |  7.602    |  0.01011  |
# 0:	total: 15.1ms	remaining: 37.7s
# 100:	total: 595ms	remaining: 14.1s
# 200:	total: 994ms	remaining: 11.4s
# 300:	total: 1.4s	remaining: 10.2s
# 400:	total: 1.79s	remaining: 9.39s
# 500:	total: 2.17s	remaining: 8.67s
# 600:	total: 2.56s	remaining: 8.08s
# 700:	total: 2.94s	remaining: 7.54s
# 800:	total: 3.32s	remaining: 7.05s
# 900:	total: 3.71s	remaining: 6.59s
# 1000:	total: 4.09s	remaining: 6.13s
# 1100:	total: 4.49s	remaining: 5.7s
# 1200:	total: 4.87s	remaining: 5.27s
# 1300:	total: 5.25s	remaining: 4.84s
# 1400:	total: 5.64s	remaining: 4.43s
# 1500:	total: 6.08s	remaining: 4.05s
# 1600:	total: 6.61s	remaining: 3.71s
# 1700:	total: 7.01s	remaining: 3.29s
# 1800:	total: 7.59s	remaining: 2.94s
# 1900:	total: 8.01s	remaining: 2.52s
# 2000:	total: 8.41s	remaining: 2.1s
# 2100:	total: 8.85s	remaining: 1.68s
# 2200:	total: 9.29s	remaining: 1.26s
# 2300:	total: 9.73s	remaining: 841ms
# 2400:	total: 10.2s	remaining: 419ms
# 2499:	total: 10.6s	remaining: 0us
# 0:	total: 7.21ms	remaining: 18s
# 100:	total: 449ms	remaining: 10.7s
# 200:	total: 903ms	remaining: 10.3s
# 300:	total: 1.35s	remaining: 9.84s
# 400:	total: 1.79s	remaining: 9.36s
# 500:	total: 2.23s	remaining: 8.9s
# 600:	total: 2.68s	remaining: 8.47s
# 700:	total: 3.13s	remaining: 8.04s
# 800:	total: 3.58s	remaining: 7.59s
# 900:	total: 4.03s	remaining: 7.14s
# 1000:	total: 4.55s	remaining: 6.81s
# 1100:	total: 4.99s	remaining: 6.34s
# 1200:	total: 5.43s	remaining: 5.87s
# 1300:	total: 5.87s	remaining: 5.41s
# 1400:	total: 6.31s	remaining: 4.95s
# 1500:	total: 6.76s	remaining: 4.5s
# 1600:	total: 7.21s	remaining: 4.05s
# 1700:	total: 7.66s	remaining: 3.6s
# 1800:	total: 8.11s	remaining: 3.15s
# 1900:	total: 8.55s	remaining: 2.69s
# 2000:	total: 8.99s	remaining: 2.24s
# 2100:	total: 9.43s	remaining: 1.79s
# 2200:	total: 9.88s	remaining: 1.34s
# 2300:	total: 10.3s	remaining: 892ms
# 2400:	total: 10.8s	remaining: 444ms
# 2499:	total: 11.2s	remaining: 0us
# 0:	total: 10.8ms	remaining: 27.1s
# 100:	total: 578ms	remaining: 13.7s
# 200:	total: 974ms	remaining: 11.1s
# 300:	total: 1.41s	remaining: 10.3s
# 400:	total: 1.87s	remaining: 9.81s
# 500:	total: 2.34s	remaining: 9.34s
# 600:	total: 2.8s	remaining: 8.84s
# 700:	total: 3.35s	remaining: 8.6s
# 800:	total: 3.79s	remaining: 8.03s
# 900:	total: 4.24s	remaining: 7.52s
# 1000:	total: 4.69s	remaining: 7.03s
# 1100:	total: 5.16s	remaining: 6.56s
# 1200:	total: 5.64s	remaining: 6.1s
# 1300:	total: 6.1s	remaining: 5.62s
# 1400:	total: 6.56s	remaining: 5.15s
# 1500:	total: 7.03s	remaining: 4.68s
# 1600:	total: 7.52s	remaining: 4.22s
# 1700:	total: 8.01s	remaining: 3.76s
# 1800:	total: 8.48s	remaining: 3.29s
# 1900:	total: 8.94s	remaining: 2.81s
# 2000:	total: 9.4s	remaining: 2.34s
# 2100:	total: 9.85s	remaining: 1.87s
# 2200:	total: 10.3s	remaining: 1.4s
# 2300:	total: 10.8s	remaining: 931ms
# 2400:	total: 11.2s	remaining: 463ms
# 2499:	total: 11.7s	remaining: 0us
# 0:	total: 12.6ms	remaining: 31.6s
# 100:	total: 513ms	remaining: 12.2s
# 200:	total: 959ms	remaining: 11s
# 300:	total: 1.41s	remaining: 10.3s
# 400:	total: 1.87s	remaining: 9.79s
# 500:	total: 2.33s	remaining: 9.29s
# 600:	total: 2.78s	remaining: 8.79s
# 700:	total: 3.48s	remaining: 8.93s
# 800:	total: 3.98s	remaining: 8.43s
# 900:	total: 4.48s	remaining: 7.95s
# 1000:	total: 4.91s	remaining: 7.35s
# 1100:	total: 5.37s	remaining: 6.82s
# 1200:	total: 5.8s	remaining: 6.28s
# 1300:	total: 6.24s	remaining: 5.75s
# 1400:	total: 6.7s	remaining: 5.25s
# 1500:	total: 7.15s	remaining: 4.76s
# 1600:	total: 7.61s	remaining: 4.27s
# 1700:	total: 8.04s	remaining: 3.78s
# 1800:	total: 8.48s	remaining: 3.29s
# 1900:	total: 8.9s	remaining: 2.8s
# 2000:	total: 9.34s	remaining: 2.33s
# 2100:	total: 9.78s	remaining: 1.86s
# 2200:	total: 10.2s	remaining: 1.39s
# 2300:	total: 10.7s	remaining: 921ms
# 2400:	total: 11.1s	remaining: 458ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 14.2ms	remaining: 35.5s
# 100:	total: 503ms	remaining: 12s
# 200:	total: 919ms	remaining: 10.5s
# 300:	total: 1.35s	remaining: 9.89s
# 400:	total: 1.79s	remaining: 9.38s
# 500:	total: 2.26s	remaining: 9s
# 600:	total: 2.77s	remaining: 8.77s
# 700:	total: 3.24s	remaining: 8.31s
# 800:	total: 3.69s	remaining: 7.82s
# 900:	total: 4.13s	remaining: 7.33s
# 1000:	total: 4.56s	remaining: 6.83s
# 1100:	total: 4.99s	remaining: 6.34s
# 1200:	total: 5.43s	remaining: 5.88s
# 1300:	total: 5.88s	remaining: 5.42s
# 1400:	total: 6.32s	remaining: 4.96s
# 1500:	total: 6.74s	remaining: 4.49s
# 1600:	total: 7.16s	remaining: 4.02s
# 1700:	total: 7.62s	remaining: 3.58s
# 1800:	total: 8.04s	remaining: 3.12s
# 1900:	total: 8.47s	remaining: 2.67s
# 2000:	total: 8.9s	remaining: 2.22s
# 2100:	total: 9.34s	remaining: 1.77s
# 2200:	total: 9.78s	remaining: 1.33s
# 2300:	total: 10.2s	remaining: 883ms
# 2400:	total: 10.6s	remaining: 438ms
# 2499:	total: 11.1s	remaining: 0us
# 0:	total: 5.28ms	remaining: 13.2s
# 100:	total: 452ms	remaining: 10.7s
# 200:	total: 889ms	remaining: 10.2s
# 300:	total: 1.32s	remaining: 9.64s
# 400:	total: 1.75s	remaining: 9.17s
# 500:	total: 2.19s	remaining: 8.73s
# 600:	total: 2.62s	remaining: 8.27s
# 700:	total: 3.05s	remaining: 7.83s
# 800:	total: 3.49s	remaining: 7.4s
# 900:	total: 3.93s	remaining: 6.97s
# 1000:	total: 4.36s	remaining: 6.52s
# 1100:	total: 4.79s	remaining: 6.08s
# 1200:	total: 5.34s	remaining: 5.77s
# 1300:	total: 5.74s	remaining: 5.29s
# 1400:	total: 6.16s	remaining: 4.83s
# 1500:	total: 6.59s	remaining: 4.39s
# 1600:	total: 7.01s	remaining: 3.94s
# 1700:	total: 7.65s	remaining: 3.6s
# 1800:	total: 8.05s	remaining: 3.13s
# 1900:	total: 8.43s	remaining: 2.66s
# 2000:	total: 8.85s	remaining: 2.21s
# 2100:	total: 9.26s	remaining: 1.76s
# 2200:	total: 9.67s	remaining: 1.31s
# 2300:	total: 10.1s	remaining: 874ms
# 2400:	total: 10.5s	remaining: 435ms
# 2499:	total: 11s	remaining: 0us
# 0:	total: 5.37ms	remaining: 13.4s
# 100:	total: 450ms	remaining: 10.7s
# 200:	total: 892ms	remaining: 10.2s
# 300:	total: 1.33s	remaining: 9.71s
# 400:	total: 1.75s	remaining: 9.14s
# 500:	total: 2.17s	remaining: 8.66s
# 600:	total: 2.59s	remaining: 8.18s
# 700:	total: 3s	remaining: 7.7s
# 800:	total: 3.43s	remaining: 7.27s
# 900:	total: 3.87s	remaining: 6.87s
# 1000:	total: 4.29s	remaining: 6.42s
# 1100:	total: 4.72s	remaining: 6s
# 1200:	total: 5.16s	remaining: 5.58s
# 1300:	total: 5.62s	remaining: 5.17s
# 1400:	total: 6.05s	remaining: 4.75s
# 1500:	total: 6.49s	remaining: 4.32s
# 1600:	total: 6.93s	remaining: 3.89s
# 1700:	total: 7.35s	remaining: 3.45s
# 1800:	total: 7.77s	remaining: 3.02s
# 1900:	total: 8.2s	remaining: 2.58s
# 2000:	total: 8.62s	remaining: 2.15s
# 2100:	total: 9.05s	remaining: 1.72s
# 2200:	total: 9.47s	remaining: 1.29s
# 2300:	total: 9.89s	remaining: 856ms
# 2400:	total: 10.3s	remaining: 426ms
# 2499:	total: 10.7s	remaining: 0us
# 0:	total: 21ms	remaining: 52.4s
# 100:	total: 437ms	remaining: 10.4s
# 200:	total: 853ms	remaining: 9.75s
# 300:	total: 1.38s	remaining: 10.1s
# 400:	total: 1.82s	remaining: 9.52s
# 500:	total: 2.26s	remaining: 9.01s
# 600:	total: 2.69s	remaining: 8.5s
# 700:	total: 3.15s	remaining: 8.08s
# 800:	total: 3.59s	remaining: 7.61s
# 900:	total: 4.03s	remaining: 7.15s
# 1000:	total: 4.47s	remaining: 6.7s
# 1100:	total: 4.94s	remaining: 6.28s
# 1200:	total: 5.46s	remaining: 5.9s
# 1300:	total: 5.98s	remaining: 5.51s
# 1400:	total: 6.48s	remaining: 5.08s
# 1500:	total: 6.98s	remaining: 4.64s
# 1600:	total: 7.5s	remaining: 4.21s
# 1700:	total: 8.03s	remaining: 3.77s
# 1800:	total: 8.56s	remaining: 3.32s
# 1900:	total: 9.17s	remaining: 2.89s
# 2000:	total: 9.72s	remaining: 2.42s
# 2100:	total: 10.4s	remaining: 1.97s
# 2200:	total: 11s	remaining: 1.49s
# 2300:	total: 11.4s	remaining: 988ms
# 2400:	total: 11.9s	remaining: 489ms
# 2499:	total: 12.3s	remaining: 0us
# 0:	total: 5.48ms	remaining: 13.7s
# 100:	total: 465ms	remaining: 11s
# 200:	total: 919ms	remaining: 10.5s
# 300:	total: 1.46s	remaining: 10.7s
# 400:	total: 1.93s	remaining: 10.1s
# 500:	total: 2.38s	remaining: 9.49s
# 600:	total: 2.82s	remaining: 8.92s
# 700:	total: 3.25s	remaining: 8.35s
# 800:	total: 3.69s	remaining: 7.83s
# 900:	total: 4.15s	remaining: 7.37s
# 1000:	total: 4.59s	remaining: 6.88s
# 1100:	total: 5.03s	remaining: 6.39s
# 1200:	total: 5.47s	remaining: 5.92s
# 1300:	total: 5.92s	remaining: 5.46s
# 1400:	total: 6.42s	remaining: 5.03s
# 1500:	total: 6.88s	remaining: 4.58s
# 1600:	total: 7.34s	remaining: 4.12s
# 1700:	total: 7.77s	remaining: 3.65s
# 1800:	total: 8.22s	remaining: 3.19s
# 1900:	total: 8.67s	remaining: 2.73s
# 2000:	total: 9.13s	remaining: 2.28s
# 2100:	total: 9.69s	remaining: 1.84s
# 2200:	total: 10.2s	remaining: 1.38s
# 2300:	total: 10.6s	remaining: 915ms
# 2400:	total: 11s	remaining: 455ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 5.49ms	remaining: 13.7s
# 100:	total: 460ms	remaining: 10.9s
# 200:	total: 921ms	remaining: 10.5s
# 300:	total: 1.37s	remaining: 10s
# 400:	total: 1.82s	remaining: 9.55s
# 500:	total: 2.29s	remaining: 9.14s
# 600:	total: 2.75s	remaining: 8.7s
# 700:	total: 3.21s	remaining: 8.23s
# 800:	total: 3.66s	remaining: 7.77s
# 900:	total: 4.14s	remaining: 7.35s
# 1000:	total: 4.59s	remaining: 6.88s
# 1100:	total: 5.05s	remaining: 6.42s
# 1200:	total: 5.51s	remaining: 5.96s
# 1300:	total: 5.95s	remaining: 5.49s
# 1400:	total: 6.4s	remaining: 5.02s
# 1500:	total: 6.85s	remaining: 4.56s
# 1600:	total: 7.32s	remaining: 4.11s
# 1700:	total: 7.77s	remaining: 3.65s
# 1800:	total: 8.21s	remaining: 3.19s
# 1900:	total: 8.66s	remaining: 2.73s
# 2000:	total: 9.1s	remaining: 2.27s
# 2100:	total: 9.55s	remaining: 1.81s
# 2200:	total: 10s	remaining: 1.36s
# 2300:	total: 10.5s	remaining: 906ms
# 2400:	total: 11s	remaining: 453ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 12.7ms	remaining: 31.8s
# 100:	total: 508ms	remaining: 12.1s
# 200:	total: 981ms	remaining: 11.2s
# 300:	total: 1.42s	remaining: 10.4s
# 400:	total: 1.86s	remaining: 9.75s
# 500:	total: 2.41s	remaining: 9.6s
# 600:	total: 2.85s	remaining: 9s
# 700:	total: 3.28s	remaining: 8.41s
# 800:	total: 3.7s	remaining: 7.86s
# 900:	total: 4.14s	remaining: 7.35s
# 1000:	total: 4.69s	remaining: 7.03s
# 1100:	total: 5.09s	remaining: 6.47s
# 1200:	total: 5.65s	remaining: 6.11s
# 1300:	total: 6.04s	remaining: 5.57s
# 1400:	total: 6.48s	remaining: 5.08s
# 1500:	total: 6.92s	remaining: 4.61s
# 1600:	total: 7.36s	remaining: 4.13s
# 1700:	total: 7.78s	remaining: 3.65s
# 1800:	total: 8.19s	remaining: 3.18s
# 1900:	total: 8.6s	remaining: 2.71s
# 2000:	total: 9.03s	remaining: 2.25s
# 2100:	total: 9.46s	remaining: 1.79s
# 2200:	total: 9.88s	remaining: 1.34s
# 2300:	total: 10.3s	remaining: 892ms
# 2400:	total: 10.7s	remaining: 443ms
# 2499:	total: 11.2s	remaining: 0us
# 0:	total: 12.2ms	remaining: 30.5s
# 100:	total: 556ms	remaining: 13.2s
# 200:	total: 1.05s	remaining: 12s
# 300:	total: 1.53s	remaining: 11.2s
# 400:	total: 1.91s	remaining: 10s
# 500:	total: 2.31s	remaining: 9.23s
# 600:	total: 2.75s	remaining: 8.68s
# 700:	total: 3.17s	remaining: 8.14s
# 800:	total: 3.59s	remaining: 7.61s
# 900:	total: 4s	remaining: 7.09s
# 1000:	total: 4.42s	remaining: 6.63s
# 1100:	total: 4.85s	remaining: 6.16s
# 1200:	total: 5.27s	remaining: 5.7s
# 1300:	total: 5.71s	remaining: 5.26s
# 1400:	total: 6.12s	remaining: 4.8s
# 1500:	total: 6.51s	remaining: 4.34s
# 1600:	total: 6.92s	remaining: 3.89s
# 1700:	total: 7.35s	remaining: 3.45s
# 1800:	total: 7.79s	remaining: 3.02s
# 1900:	total: 8.22s	remaining: 2.59s
# 2000:	total: 8.66s	remaining: 2.16s
# 2100:	total: 9.08s	remaining: 1.72s
# 2200:	total: 9.5s	remaining: 1.29s
# 2300:	total: 9.92s	remaining: 858ms
# 2400:	total: 10.3s	remaining: 427ms
# 2499:	total: 10.8s	remaining: 0us
# 0:	total: 11.6ms	remaining: 29.1s
# 100:	total: 503ms	remaining: 11.9s
# 200:	total: 1.03s	remaining: 11.8s
# 300:	total: 1.51s	remaining: 11s
# 400:	total: 1.9s	remaining: 9.97s
# 500:	total: 2.3s	remaining: 9.17s
# 600:	total: 2.72s	remaining: 8.6s
# 700:	total: 3.16s	remaining: 8.11s
# 800:	total: 3.57s	remaining: 7.58s
# 900:	total: 4s	remaining: 7.1s
# 1000:	total: 4.44s	remaining: 6.65s
# 1100:	total: 4.88s	remaining: 6.2s
# 1200:	total: 5.31s	remaining: 5.74s
# 1300:	total: 5.72s	remaining: 5.27s
# 1400:	total: 6.13s	remaining: 4.81s
# 1500:	total: 6.55s	remaining: 4.36s
# 1600:	total: 6.99s	remaining: 3.92s
# 1700:	total: 7.41s	remaining: 3.48s
# 1800:	total: 7.82s	remaining: 3.04s
# 1900:	total: 8.27s	remaining: 2.6s
# 2000:	total: 8.75s	remaining: 2.18s
# 2100:	total: 9.17s	remaining: 1.74s
# 2200:	total: 9.6s	remaining: 1.3s
# 2300:	total: 10s	remaining: 868ms
# 2400:	total: 10.5s	remaining: 432ms
# 2499:	total: 10.9s	remaining: 0us
# 0:	total: 11.7ms	remaining: 29.2s
# 100:	total: 541ms	remaining: 12.9s
# 200:	total: 972ms	remaining: 11.1s
# 300:	total: 1.46s	remaining: 10.7s
# 400:	total: 2.02s	remaining: 10.6s
# 500:	total: 2.56s	remaining: 10.2s
# 600:	total: 3.03s	remaining: 9.58s
# 700:	total: 3.5s	remaining: 9s
# 800:	total: 3.95s	remaining: 8.38s
# 900:	total: 4.4s	remaining: 7.81s
# 1000:	total: 4.84s	remaining: 7.25s
# 1100:	total: 5.28s	remaining: 6.7s
# 1200:	total: 5.72s	remaining: 6.18s
# 1300:	total: 6.16s	remaining: 5.68s
# 1400:	total: 6.63s	remaining: 5.2s
# 1500:	total: 7.08s	remaining: 4.71s
# 1600:	total: 7.52s	remaining: 4.22s
# 1700:	total: 7.97s	remaining: 3.74s
# 1800:	total: 8.49s	remaining: 3.3s
# 1900:	total: 9.03s	remaining: 2.84s
# 2000:	total: 9.53s	remaining: 2.38s
# 2100:	total: 10s	remaining: 1.9s
# 2200:	total: 10.6s	remaining: 1.44s
# 2300:	total: 11.2s	remaining: 973ms
# 2400:	total: 11.7s	remaining: 482ms
# 2499:	total: 12.1s	remaining: 0us
# 0:	total: 5.6ms	remaining: 14s
# 100:	total: 458ms	remaining: 10.9s
# 200:	total: 941ms	remaining: 10.8s
# 300:	total: 1.97s	remaining: 14.4s
# 400:	total: 2.6s	remaining: 13.6s
# 500:	total: 3.09s	remaining: 12.3s
# 600:	total: 3.62s	remaining: 11.4s
# 700:	total: 4.12s	remaining: 10.6s
# 800:	total: 4.58s	remaining: 9.72s
# 900:	total: 5.05s	remaining: 8.96s
# 1000:	total: 5.62s	remaining: 8.41s
# 1100:	total: 6.14s	remaining: 7.8s
# 1200:	total: 6.62s	remaining: 7.16s
# 1300:	total: 7.09s	remaining: 6.54s
# 1400:	total: 7.61s	remaining: 5.97s
# 1500:	total: 8.12s	remaining: 5.4s
# 1600:	total: 8.61s	remaining: 4.84s
# 1700:	total: 9.05s	remaining: 4.25s
# 1800:	total: 9.56s	remaining: 3.71s
# 1900:	total: 10.1s	remaining: 3.17s
# 2000:	total: 10.5s	remaining: 2.62s
# 2100:	total: 11s	remaining: 2.09s
# 2200:	total: 11.5s	remaining: 1.56s
# 2300:	total: 11.9s	remaining: 1.03s
# 2400:	total: 12.4s	remaining: 510ms
# 2499:	total: 12.8s	remaining: 0us
# 0:	total: 5.26ms	remaining: 13.2s
# 100:	total: 452ms	remaining: 10.7s
# 200:	total: 888ms	remaining: 10.2s
# 300:	total: 1.32s	remaining: 9.69s
# 400:	total: 1.76s	remaining: 9.24s
# 500:	total: 2.2s	remaining: 8.77s
# 600:	total: 2.63s	remaining: 8.32s
# 700:	total: 3.08s	remaining: 7.91s
# 800:	total: 3.52s	remaining: 7.46s
# 900:	total: 3.96s	remaining: 7.02s
# 1000:	total: 4.38s	remaining: 6.57s
# 1100:	total: 4.82s	remaining: 6.13s
# 1200:	total: 5.26s	remaining: 5.69s
# 1300:	total: 5.75s	remaining: 5.3s
# 1400:	total: 6.37s	remaining: 4.99s
# 1500:	total: 6.74s	remaining: 4.48s
# 1600:	total: 7.11s	remaining: 3.99s
# 1700:	total: 7.52s	remaining: 3.53s
# 1800:	total: 7.94s	remaining: 3.08s
# 1900:	total: 8.37s	remaining: 2.64s
# 2000:	total: 8.78s	remaining: 2.19s
# 2100:	total: 9.2s	remaining: 1.75s
# 2200:	total: 9.63s	remaining: 1.31s
# 2300:	total: 10.1s	remaining: 871ms
# 2400:	total: 10.5s	remaining: 433ms
# 2499:	total: 10.9s	remaining: 0us
# 0:	total: 5.69ms	remaining: 14.2s
# 100:	total: 642ms	remaining: 15.2s
# 200:	total: 1.19s	remaining: 13.7s
# 300:	total: 1.58s	remaining: 11.6s
# 400:	total: 1.97s	remaining: 10.3s
# 500:	total: 2.39s	remaining: 9.54s
# 600:	total: 2.97s	remaining: 9.4s
# 700:	total: 3.35s	remaining: 8.6s
# 800:	total: 3.78s	remaining: 8.01s
# 900:	total: 4.21s	remaining: 7.47s
# 1000:	total: 4.64s	remaining: 6.95s
# 1100:	total: 5.09s	remaining: 6.46s
# 1200:	total: 5.53s	remaining: 5.98s
# 1300:	total: 5.97s	remaining: 5.51s
# 1400:	total: 6.41s	remaining: 5.03s
# 1500:	total: 6.85s	remaining: 4.56s
# 1600:	total: 7.29s	remaining: 4.09s
# 1700:	total: 7.72s	remaining: 3.63s
# 1800:	total: 8.16s	remaining: 3.17s
# 1900:	total: 8.59s	remaining: 2.71s
# 2000:	total: 9.02s	remaining: 2.25s
# 2100:	total: 9.45s	remaining: 1.79s
# 2200:	total: 9.88s	remaining: 1.34s
# 2300:	total: 10.3s	remaining: 891ms
# 2400:	total: 10.7s	remaining: 442ms
# 2499:	total: 11.1s	remaining: 0us
# 0:	total: 11.3ms	remaining: 28.2s
# 100:	total: 508ms	remaining: 12.1s
# 200:	total: 888ms	remaining: 10.2s
# 300:	total: 1.31s	remaining: 9.56s
# 400:	total: 1.74s	remaining: 9.09s
# 500:	total: 2.16s	remaining: 8.62s
# 600:	total: 2.58s	remaining: 8.16s
# 700:	total: 3s	remaining: 7.69s
# 800:	total: 3.41s	remaining: 7.24s
# 900:	total: 3.96s	remaining: 7.02s
# 1000:	total: 4.39s	remaining: 6.57s
# 1100:	total: 4.76s	remaining: 6.05s
# 1200:	total: 5.17s	remaining: 5.59s
# 1300:	total: 5.59s	remaining: 5.15s
# 1400:	total: 6.01s	remaining: 4.71s
# 1500:	total: 6.42s	remaining: 4.27s
# 1600:	total: 6.84s	remaining: 3.84s
# 1700:	total: 7.26s	remaining: 3.41s
# 1800:	total: 7.67s	remaining: 2.98s
# 1900:	total: 8.09s	remaining: 2.55s
# 2000:	total: 8.51s	remaining: 2.12s
# 2100:	total: 8.93s	remaining: 1.7s
# 2200:	total: 9.35s	remaining: 1.27s
# 2300:	total: 9.77s	remaining: 845ms
# 2400:	total: 10.2s	remaining: 420ms
# 2499:	total: 10.6s	remaining: 0us
# 0:	total: 5.09ms	remaining: 12.7s
# 100:	total: 446ms	remaining: 10.6s
# 200:	total: 885ms	remaining: 10.1s
# 300:	total: 1.33s	remaining: 9.71s
# 400:	total: 1.95s	remaining: 10.2s
# 500:	total: 2.35s	remaining: 9.4s
# 600:	total: 2.77s	remaining: 8.74s
# 700:	total: 3.2s	remaining: 8.22s
# 800:	total: 3.63s	remaining: 7.71s
# 900:	total: 4.07s	remaining: 7.23s
# 1000:	total: 4.52s	remaining: 6.76s
# 1100:	total: 4.96s	remaining: 6.3s
# 1200:	total: 5.4s	remaining: 5.84s
# 1300:	total: 5.84s	remaining: 5.39s
# 1400:	total: 6.29s	remaining: 4.93s
# 1500:	total: 6.72s	remaining: 4.47s
# 1600:	total: 7.16s	remaining: 4.02s
# 1700:	total: 7.6s	remaining: 3.57s
# 1800:	total: 8.03s	remaining: 3.12s
# 1900:	total: 8.46s	remaining: 2.67s
# 2000:	total: 8.93s	remaining: 2.23s
# 2100:	total: 9.44s	remaining: 1.79s
# 2200:	total: 9.89s	remaining: 1.34s
# 2300:	total: 10.3s	remaining: 893ms
# 2400:	total: 10.8s	remaining: 443ms
# 2499:	total: 11.2s	remaining: 0us
# 0:	total: 8.57ms	remaining: 21.4s
# 100:	total: 545ms	remaining: 12.9s
# 200:	total: 918ms	remaining: 10.5s
# 300:	total: 1.31s	remaining: 9.57s
# 400:	total: 1.74s	remaining: 9.11s
# 500:	total: 2.17s	remaining: 8.67s
# 600:	total: 2.6s	remaining: 8.23s
# 700:	total: 3.03s	remaining: 7.78s
# 800:	total: 3.46s	remaining: 7.33s
# 900:	total: 3.89s	remaining: 6.9s
# 1000:	total: 4.31s	remaining: 6.46s
# 1100:	total: 4.73s	remaining: 6.01s
# 1200:	total: 5.21s	remaining: 5.63s
# 1300:	total: 5.61s	remaining: 5.17s
# 1400:	total: 6.04s	remaining: 4.74s
# 1500:	total: 6.47s	remaining: 4.3s
# 1600:	total: 6.89s	remaining: 3.87s
# 1700:	total: 7.31s	remaining: 3.43s
# 1800:	total: 7.73s	remaining: 3s
# 1900:	total: 8.15s	remaining: 2.57s
# 2000:	total: 8.57s	remaining: 2.14s
# 2100:	total: 8.99s	remaining: 1.71s
# 2200:	total: 9.53s	remaining: 1.29s
# 2300:	total: 10s	remaining: 866ms
# 2400:	total: 10.4s	remaining: 428ms
# 2499:	total: 10.8s	remaining: 0us
# |  2        |  0.8403   |  0.309    |  4.734    |  0.1013   |
# 0:	total: 34.9ms	remaining: 1m 27s
# 100:	total: 901ms	remaining: 21.4s
# 200:	total: 1.53s	remaining: 17.5s
# 300:	total: 2.18s	remaining: 15.9s
# 400:	total: 2.95s	remaining: 15.4s
# 500:	total: 3.71s	remaining: 14.8s
# 600:	total: 4.44s	remaining: 14s
# 700:	total: 5.1s	remaining: 13.1s
# 800:	total: 5.77s	remaining: 12.2s
# 900:	total: 6.44s	remaining: 11.4s
# 1000:	total: 7.11s	remaining: 10.6s
# 1100:	total: 7.78s	remaining: 9.88s
# 1200:	total: 8.44s	remaining: 9.13s
# 1300:	total: 9.11s	remaining: 8.39s
# 1400:	total: 9.77s	remaining: 7.67s
# 1500:	total: 10.4s	remaining: 6.95s
# 1600:	total: 11.1s	remaining: 6.24s
# 1700:	total: 11.8s	remaining: 5.53s
# 1800:	total: 12.5s	remaining: 4.85s
# 1900:	total: 13.2s	remaining: 4.16s
# 2000:	total: 13.9s	remaining: 3.46s
# 2100:	total: 14.6s	remaining: 2.76s
# 2200:	total: 15.2s	remaining: 2.07s
# 2300:	total: 15.9s	remaining: 1.37s
# 2400:	total: 16.6s	remaining: 683ms
# 2499:	total: 17.2s	remaining: 0us
# 0:	total: 14.5ms	remaining: 36.2s
# 100:	total: 691ms	remaining: 16.4s
# 200:	total: 1.39s	remaining: 15.8s
# 300:	total: 2.08s	remaining: 15.2s
# 400:	total: 2.78s	remaining: 14.6s
# 500:	total: 3.48s	remaining: 13.9s
# 600:	total: 4.16s	remaining: 13.2s
# 700:	total: 4.86s	remaining: 12.5s
# 800:	total: 5.54s	remaining: 11.8s
# 900:	total: 6.23s	remaining: 11.1s
# 1000:	total: 6.92s	remaining: 10.4s
# 1100:	total: 7.6s	remaining: 9.66s
# 1200:	total: 8.29s	remaining: 8.97s
# 1300:	total: 8.98s	remaining: 8.27s
# 1400:	total: 9.65s	remaining: 7.57s
# 1500:	total: 10.3s	remaining: 6.88s
# 1600:	total: 11s	remaining: 6.2s
# 1700:	total: 11.7s	remaining: 5.51s
# 1800:	total: 12.5s	remaining: 4.87s
# 1900:	total: 13.3s	remaining: 4.18s
# 2000:	total: 14s	remaining: 3.49s
# 2100:	total: 14.7s	remaining: 2.79s
# 2200:	total: 15.4s	remaining: 2.09s
# 2300:	total: 16.1s	remaining: 1.39s
# 2400:	total: 16.8s	remaining: 693ms
# 2499:	total: 17.5s	remaining: 0us
# 0:	total: 8.24ms	remaining: 20.6s
# 100:	total: 736ms	remaining: 17.5s
# 200:	total: 1.45s	remaining: 16.6s
# 300:	total: 2.17s	remaining: 15.8s
# 400:	total: 2.86s	remaining: 15s
# 500:	total: 3.56s	remaining: 14.2s
# 600:	total: 4.32s	remaining: 13.6s
# 700:	total: 5.03s	remaining: 12.9s
# 800:	total: 5.81s	remaining: 12.3s
# 900:	total: 6.51s	remaining: 11.6s
# 1000:	total: 7.21s	remaining: 10.8s
# 1100:	total: 7.9s	remaining: 10s
# 1200:	total: 8.59s	remaining: 9.29s
# 1300:	total: 9.3s	remaining: 8.57s
# 1400:	total: 10s	remaining: 7.85s
# 1500:	total: 10.7s	remaining: 7.13s
# 1600:	total: 11.5s	remaining: 6.46s
# 1700:	total: 12.3s	remaining: 5.77s
# 1800:	total: 13s	remaining: 5.05s
# 1900:	total: 13.7s	remaining: 4.33s
# 2000:	total: 14.5s	remaining: 3.62s
# 2100:	total: 15.2s	remaining: 2.88s
# 2200:	total: 15.8s	remaining: 2.15s
# 2300:	total: 16.5s	remaining: 1.43s
# 2400:	total: 17.2s	remaining: 710ms
# 2499:	total: 17.9s	remaining: 0us
# 0:	total: 11.9ms	remaining: 29.7s
# 100:	total: 703ms	remaining: 16.7s
# 200:	total: 1.41s	remaining: 16.1s
# 300:	total: 2.11s	remaining: 15.4s
# 400:	total: 2.81s	remaining: 14.7s
# 500:	total: 3.51s	remaining: 14s
# 600:	total: 4.2s	remaining: 13.3s
# 700:	total: 4.96s	remaining: 12.7s
# 800:	total: 5.63s	remaining: 11.9s
# 900:	total: 6.32s	remaining: 11.2s
# 1000:	total: 7.07s	remaining: 10.6s
# 1100:	total: 7.75s	remaining: 9.85s
# 1200:	total: 8.45s	remaining: 9.14s
# 1300:	total: 9.13s	remaining: 8.42s
# 1400:	total: 9.81s	remaining: 7.7s
# 1500:	total: 10.5s	remaining: 6.99s
# 1600:	total: 11.2s	remaining: 6.28s
# 1700:	total: 11.9s	remaining: 5.58s
# 1800:	total: 12.6s	remaining: 4.89s
# 1900:	total: 13.3s	remaining: 4.2s
# 2000:	total: 14s	remaining: 3.49s
# 2100:	total: 14.7s	remaining: 2.79s
# 2200:	total: 15.4s	remaining: 2.09s
# 2300:	total: 16.1s	remaining: 1.39s
# 2400:	total: 16.8s	remaining: 692ms
# 2499:	total: 17.4s	remaining: 0us
# 0:	total: 8.76ms	remaining: 21.9s
# 100:	total: 683ms	remaining: 16.2s
# 200:	total: 1.36s	remaining: 15.6s
# 300:	total: 2.04s	remaining: 14.9s
# 400:	total: 2.71s	remaining: 14.2s
# 500:	total: 3.38s	remaining: 13.5s
# 600:	total: 4.05s	remaining: 12.8s
# 700:	total: 4.72s	remaining: 12.1s
# 800:	total: 5.39s	remaining: 11.4s
# 900:	total: 6.06s	remaining: 10.8s
# 1000:	total: 6.74s	remaining: 10.1s
# 1100:	total: 7.41s	remaining: 9.41s
# 1200:	total: 8.07s	remaining: 8.73s
# 1300:	total: 8.76s	remaining: 8.07s
# 1400:	total: 9.43s	remaining: 7.4s
# 1500:	total: 10.1s	remaining: 6.72s
# 1600:	total: 10.8s	remaining: 6.08s
# 1700:	total: 11.5s	remaining: 5.4s
# 1800:	total: 12.2s	remaining: 4.74s
# 1900:	total: 12.9s	remaining: 4.08s
# 2000:	total: 13.6s	remaining: 3.39s
# 2100:	total: 14.3s	remaining: 2.71s
# 2200:	total: 15s	remaining: 2.04s
# 2300:	total: 15.7s	remaining: 1.35s
# 2400:	total: 16.3s	remaining: 674ms
# 2499:	total: 17s	remaining: 0us
# 0:	total: 9ms	remaining: 22.5s
# 100:	total: 710ms	remaining: 16.9s
# 200:	total: 1.41s	remaining: 16.1s
# 300:	total: 2.12s	remaining: 15.5s
# 400:	total: 2.81s	remaining: 14.7s
# 500:	total: 3.5s	remaining: 14s
# 600:	total: 4.21s	remaining: 13.3s
# 700:	total: 4.91s	remaining: 12.6s
# 800:	total: 5.62s	remaining: 11.9s
# 900:	total: 6.33s	remaining: 11.2s
# 1000:	total: 7.04s	remaining: 10.5s
# 1100:	total: 7.74s	remaining: 9.83s
# 1200:	total: 8.44s	remaining: 9.13s
# 1300:	total: 9.15s	remaining: 8.43s
# 1400:	total: 9.86s	remaining: 7.74s
# 1500:	total: 10.6s	remaining: 7.04s
# 1600:	total: 11.3s	remaining: 6.33s
# 1700:	total: 12s	remaining: 5.63s
# 1800:	total: 12.7s	remaining: 4.94s
# 1900:	total: 13.5s	remaining: 4.25s
# 2000:	total: 14.2s	remaining: 3.55s
# 2100:	total: 14.9s	remaining: 2.84s
# 2200:	total: 15.7s	remaining: 2.13s
# 2300:	total: 16.4s	remaining: 1.42s
# 2400:	total: 17.1s	remaining: 706ms
# 2499:	total: 17.9s	remaining: 0us
# 0:	total: 9.87ms	remaining: 24.7s
# 100:	total: 725ms	remaining: 17.2s
# 200:	total: 1.43s	remaining: 16.3s
# 300:	total: 2.14s	remaining: 15.6s
# 400:	total: 2.84s	remaining: 14.9s
# 500:	total: 3.56s	remaining: 14.2s
# 600:	total: 4.25s	remaining: 13.4s
# 700:	total: 4.95s	remaining: 12.7s
# 800:	total: 5.64s	remaining: 12s
# 900:	total: 6.33s	remaining: 11.2s
# 1000:	total: 7.03s	remaining: 10.5s
# 1100:	total: 7.78s	remaining: 9.88s
# 1200:	total: 8.47s	remaining: 9.16s
# 1300:	total: 9.16s	remaining: 8.44s
# 1400:	total: 9.85s	remaining: 7.72s
# 1500:	total: 10.5s	remaining: 7.01s
# 1600:	total: 11.2s	remaining: 6.29s
# 1700:	total: 11.9s	remaining: 5.58s
# 1800:	total: 12.7s	remaining: 4.91s
# 1900:	total: 13.4s	remaining: 4.21s
# 2000:	total: 14.1s	remaining: 3.51s
# 2100:	total: 14.9s	remaining: 2.82s
# 2200:	total: 15.7s	remaining: 2.13s
# 2300:	total: 16.4s	remaining: 1.42s
# 2400:	total: 17.1s	remaining: 703ms
# 2499:	total: 17.7s	remaining: 0us
# 0:	total: 24.8ms	remaining: 1m 1s
# 100:	total: 721ms	remaining: 17.1s
# 200:	total: 1.42s	remaining: 16.3s
# 300:	total: 2.12s	remaining: 15.5s
# 400:	total: 2.8s	remaining: 14.7s
# 500:	total: 3.48s	remaining: 13.9s
# 600:	total: 4.16s	remaining: 13.1s
# 700:	total: 4.84s	remaining: 12.4s
# 800:	total: 5.51s	remaining: 11.7s
# 900:	total: 6.18s	remaining: 11s
# 1000:	total: 6.86s	remaining: 10.3s
# 1100:	total: 7.55s	remaining: 9.59s
# 1200:	total: 8.24s	remaining: 8.91s
# 1300:	total: 8.93s	remaining: 8.23s
# 1400:	total: 9.62s	remaining: 7.55s
# 1500:	total: 10.3s	remaining: 6.86s
# 1600:	total: 11s	remaining: 6.17s
# 1700:	total: 11.7s	remaining: 5.48s
# 1800:	total: 12.4s	remaining: 4.81s
# 1900:	total: 13.1s	remaining: 4.13s
# 2000:	total: 13.8s	remaining: 3.44s
# 2100:	total: 14.5s	remaining: 2.75s
# 2200:	total: 15.2s	remaining: 2.06s
# 2300:	total: 15.9s	remaining: 1.37s
# 2400:	total: 16.6s	remaining: 682ms
# 2499:	total: 17.2s	remaining: 0us
# 0:	total: 8.11ms	remaining: 20.3s
# 100:	total: 688ms	remaining: 16.3s
# 200:	total: 1.37s	remaining: 15.6s
# 300:	total: 2.05s	remaining: 15s
# 400:	total: 2.74s	remaining: 14.3s
# 500:	total: 3.41s	remaining: 13.6s
# 600:	total: 4.09s	remaining: 12.9s
# 700:	total: 4.79s	remaining: 12.3s
# 800:	total: 5.47s	remaining: 11.6s
# 900:	total: 6.16s	remaining: 10.9s
# 1000:	total: 6.85s	remaining: 10.3s
# 1100:	total: 7.54s	remaining: 9.59s
# 1200:	total: 8.23s	remaining: 8.9s
# 1300:	total: 8.93s	remaining: 8.23s
# 1400:	total: 9.61s	remaining: 7.54s
# 1500:	total: 10.3s	remaining: 6.86s
# 1600:	total: 11s	remaining: 6.17s
# 1700:	total: 11.7s	remaining: 5.49s
# 1800:	total: 12.4s	remaining: 4.83s
# 1900:	total: 13.2s	remaining: 4.16s
# 2000:	total: 13.9s	remaining: 3.46s
# 2100:	total: 14.6s	remaining: 2.77s
# 2200:	total: 15.3s	remaining: 2.07s
# 2300:	total: 16s	remaining: 1.39s
# 2400:	total: 16.7s	remaining: 689ms
# 2499:	total: 17.4s	remaining: 0us
# 0:	total: 16.5ms	remaining: 41.3s
# 100:	total: 771ms	remaining: 18.3s
# 200:	total: 1.47s	remaining: 16.8s
# 300:	total: 2.17s	remaining: 15.9s
# 400:	total: 2.88s	remaining: 15.1s
# 500:	total: 3.59s	remaining: 14.3s
# 600:	total: 4.28s	remaining: 13.5s
# 700:	total: 4.98s	remaining: 12.8s
# 800:	total: 5.68s	remaining: 12s
# 900:	total: 6.46s	remaining: 11.5s
# 1000:	total: 7.16s	remaining: 10.7s
# 1100:	total: 7.85s	remaining: 9.97s
# 1200:	total: 8.54s	remaining: 9.24s
# 1300:	total: 9.25s	remaining: 8.52s
# 1400:	total: 9.94s	remaining: 7.8s
# 1500:	total: 10.6s	remaining: 7.08s
# 1600:	total: 11.3s	remaining: 6.36s
# 1700:	total: 12s	remaining: 5.64s
# 1800:	total: 12.7s	remaining: 4.94s
# 1900:	total: 13.4s	remaining: 4.24s
# 2000:	total: 14.1s	remaining: 3.52s
# 2100:	total: 14.8s	remaining: 2.81s
# 2200:	total: 15.5s	remaining: 2.1s
# 2300:	total: 16.2s	remaining: 1.4s
# 2400:	total: 16.8s	remaining: 695ms
# 2499:	total: 17.5s	remaining: 0us
# 0:	total: 24.2ms	remaining: 1m
# 100:	total: 718ms	remaining: 17.1s
# 200:	total: 1.41s	remaining: 16.1s
# 300:	total: 2.11s	remaining: 15.4s
# 400:	total: 2.8s	remaining: 14.7s
# 500:	total: 3.52s	remaining: 14.1s
# 600:	total: 4.37s	remaining: 13.8s
# 700:	total: 5.21s	remaining: 13.4s
# 800:	total: 5.92s	remaining: 12.6s
# 900:	total: 6.62s	remaining: 11.7s
# 1000:	total: 7.3s	remaining: 10.9s
# 1100:	total: 7.98s	remaining: 10.1s
# 1200:	total: 8.65s	remaining: 9.36s
# 1300:	total: 9.36s	remaining: 8.63s
# 1400:	total: 10.1s	remaining: 7.88s
# 1500:	total: 10.7s	remaining: 7.15s
# 1600:	total: 11.4s	remaining: 6.43s
# 1700:	total: 12.1s	remaining: 5.7s
# 1800:	total: 12.9s	remaining: 5s
# 1900:	total: 13.6s	remaining: 4.29s
# 2000:	total: 14.3s	remaining: 3.57s
# 2100:	total: 15s	remaining: 2.85s
# 2200:	total: 15.7s	remaining: 2.14s
# 2300:	total: 16.4s	remaining: 1.42s
# 2400:	total: 17.1s	remaining: 707ms
# 2499:	total: 17.8s	remaining: 0us
# 0:	total: 8ms	remaining: 20s
# 100:	total: 727ms	remaining: 17.3s
# 200:	total: 1.5s	remaining: 17.2s
# 300:	total: 2.23s	remaining: 16.3s
# 400:	total: 2.93s	remaining: 15.3s
# 500:	total: 3.63s	remaining: 14.5s
# 600:	total: 4.33s	remaining: 13.7s
# 700:	total: 5.03s	remaining: 12.9s
# 800:	total: 5.72s	remaining: 12.1s
# 900:	total: 6.42s	remaining: 11.4s
# 1000:	total: 7.11s	remaining: 10.6s
# 1100:	total: 7.81s	remaining: 9.93s
# 1200:	total: 8.5s	remaining: 9.2s
# 1300:	total: 9.2s	remaining: 8.47s
# 1400:	total: 9.89s	remaining: 7.76s
# 1500:	total: 10.6s	remaining: 7.05s
# 1600:	total: 11.3s	remaining: 6.34s
# 1700:	total: 12s	remaining: 5.63s
# 1800:	total: 12.7s	remaining: 4.94s
# 1900:	total: 13.5s	remaining: 4.25s
# 2000:	total: 14.2s	remaining: 3.54s
# 2100:	total: 14.9s	remaining: 2.83s
# 2200:	total: 15.6s	remaining: 2.12s
# 2300:	total: 16.3s	remaining: 1.41s
# 2400:	total: 17s	remaining: 701ms
# 2499:	total: 17.7s	remaining: 0us
# 0:	total: 8.04ms	remaining: 20.1s
# 100:	total: 708ms	remaining: 16.8s
# 200:	total: 1.43s	remaining: 16.4s
# 300:	total: 2.13s	remaining: 15.5s
# ...
# 1200:	total: 14.7s	remaining: 15.9s
# 1300:	total: 15.9s	remaining: 14.7s
# 1400:	total: 17.1s	remaining: 13.4s
# 1500:	total: 18.5s	remaining: 12.3s
# 1600:	total: 19.7s	remaining: 11.1s
# 1700:	total: 20.9s	remaining: 9.84s
# 1800:	total: 22.2s	remaining: 8.62s
# 1900:	total: 23.5s	remaining: 7.41s
# 2000:	total: 24.7s	remaining: 6.17s
# 2100:	total: 26s	remaining: 4.93s
# 2200:	total: 27.2s	remaining: 3.69s
# 2300:	total: 28.6s	remaining: 2.47s
# 2400:	total: 29.8s	remaining: 1.23s
# 2499:	total: 31s	remaining: 0us
# 0:	total: 13ms	remaining: 32.5s
# 100:	total: 1.23s	remaining: 29.2s
# 200:	total: 2.44s	remaining: 27.9s
# 300:	total: 3.62s	remaining: 26.5s
# 400:	total: 4.8s	remaining: 25.1s
# 500:	total: 6.04s	remaining: 24.1s
# 600:	total: 7.23s	remaining: 22.8s
# 700:	total: 8.4s	remaining: 21.6s
# 800:	total: 9.57s	remaining: 20.3s
# 900:	total: 10.7s	remaining: 19.1s
# 1000:	total: 11.9s	remaining: 17.9s
# 1100:	total: 13.2s	remaining: 16.7s
# 1200:	total: 14.3s	remaining: 15.5s
# 1300:	total: 15.5s	remaining: 14.3s
# 1400:	total: 16.7s	remaining: 13.1s
# 1500:	total: 17.8s	remaining: 11.9s
# 1600:	total: 19s	remaining: 10.7s
# 1700:	total: 20.1s	remaining: 9.46s
# 1800:	total: 21.3s	remaining: 8.26s
# 1900:	total: 22.4s	remaining: 7.07s
# 2000:	total: 23.6s	remaining: 5.88s
# 2100:	total: 24.8s	remaining: 4.7s
# 2200:	total: 25.9s	remaining: 3.52s
# 2300:	total: 27.1s	remaining: 2.34s
# 2400:	total: 28.3s	remaining: 1.17s
# 2499:	total: 29.4s	remaining: 0us
# 0:	total: 25.2ms	remaining: 1m 2s
# 100:	total: 1.19s	remaining: 28.2s
# 200:	total: 2.36s	remaining: 27s
# 300:	total: 3.54s	remaining: 25.9s
# 400:	total: 4.74s	remaining: 24.8s
# 500:	total: 5.92s	remaining: 23.6s
# 600:	total: 7.1s	remaining: 22.4s
# 700:	total: 8.29s	remaining: 21.3s
# 800:	total: 9.48s	remaining: 20.1s
# 900:	total: 10.7s	remaining: 18.9s
# 1000:	total: 11.9s	remaining: 17.8s
# 1100:	total: 13.1s	remaining: 16.7s
# 1200:	total: 14.3s	remaining: 15.5s
# 1300:	total: 15.5s	remaining: 14.3s
# 1400:	total: 16.8s	remaining: 13.2s
# 1500:	total: 18s	remaining: 12s
# 1600:	total: 19.3s	remaining: 10.8s
# 1700:	total: 20.5s	remaining: 9.62s
# 1800:	total: 21.7s	remaining: 8.42s
# 1900:	total: 22.9s	remaining: 7.22s
# 2000:	total: 24.1s	remaining: 6.02s
# 2100:	total: 25.3s	remaining: 4.81s
# 2200:	total: 26.5s	remaining: 3.61s
# 2300:	total: 27.8s	remaining: 2.4s
# 2400:	total: 28.9s	remaining: 1.19s
# 2499:	total: 30.1s	remaining: 0us
# 0:	total: 12.4ms	remaining: 30.9s
# 100:	total: 1.18s	remaining: 27.9s
# 200:	total: 2.36s	remaining: 27s
# 300:	total: 3.54s	remaining: 25.9s
# 400:	total: 4.72s	remaining: 24.7s
# 500:	total: 5.91s	remaining: 23.6s
# 600:	total: 7.08s	remaining: 22.4s
# 700:	total: 8.26s	remaining: 21.2s
# 800:	total: 9.43s	remaining: 20s
# 900:	total: 10.6s	remaining: 18.8s
# 1000:	total: 11.8s	remaining: 17.6s
# 1100:	total: 13s	remaining: 16.5s
# 1200:	total: 14.1s	remaining: 15.3s
# 1300:	total: 15.3s	remaining: 14.1s
# 1400:	total: 16.4s	remaining: 12.9s
# 1500:	total: 17.6s	remaining: 11.7s
# 1600:	total: 18.8s	remaining: 10.5s
# 1700:	total: 19.9s	remaining: 9.37s
# 1800:	total: 21.1s	remaining: 8.2s
# 1900:	total: 22.3s	remaining: 7.02s
# 2000:	total: 23.5s	remaining: 5.86s
# 2100:	total: 24.7s	remaining: 4.69s
# 2200:	total: 25.9s	remaining: 3.51s
# 2300:	total: 27s	remaining: 2.34s
# 2400:	total: 28.2s	remaining: 1.16s
# 2499:	total: 29.4s	remaining: 0us
# 0:	total: 26.2ms	remaining: 1m 5s
# 100:	total: 1.21s	remaining: 28.8s
# 200:	total: 2.4s	remaining: 27.5s
# 300:	total: 3.62s	remaining: 26.4s
# 400:	total: 4.79s	remaining: 25s
# 500:	total: 5.95s	remaining: 23.8s
# 600:	total: 7.15s	remaining: 22.6s
# 700:	total: 8.32s	remaining: 21.4s
# 800:	total: 9.5s	remaining: 20.2s
# 900:	total: 10.7s	remaining: 19s
# 1000:	total: 11.9s	remaining: 17.8s
# 1100:	total: 13.1s	remaining: 16.6s
# 1200:	total: 14.3s	remaining: 15.5s
# 1300:	total: 15.5s	remaining: 14.3s
# 1400:	total: 16.8s	remaining: 13.2s
# 1500:	total: 18s	remaining: 12s
# 1600:	total: 19.2s	remaining: 10.8s
# 1700:	total: 20.4s	remaining: 9.58s
# 1800:	total: 21.6s	remaining: 8.37s
# 1900:	total: 22.8s	remaining: 7.17s
# 2000:	total: 23.9s	remaining: 5.96s
# 2100:	total: 25.1s	remaining: 4.77s
# 2200:	total: 26.5s	remaining: 3.6s
# 2300:	total: 27.7s	remaining: 2.4s
# 2400:	total: 28.9s	remaining: 1.19s
# 2499:	total: 30s	remaining: 0us
# |  4        |  0.8643   |  0.5429   |  6.096    |  0.6877   |
# 0:	total: 46.2ms	remaining: 1m 55s
# 100:	total: 4.39s	remaining: 1m 44s
# 200:	total: 8.76s	remaining: 1m 40s
# 300:	total: 13.1s	remaining: 1m 35s
# 400:	total: 17.5s	remaining: 1m 31s
# 500:	total: 21.8s	remaining: 1m 26s
# 600:	total: 26.2s	remaining: 1m 22s
# 700:	total: 30.5s	remaining: 1m 18s
# 800:	total: 34.9s	remaining: 1m 14s
# 900:	total: 39.3s	remaining: 1m 9s
# 1000:	total: 43.6s	remaining: 1m 5s
# 1100:	total: 48s	remaining: 1m
# 1200:	total: 52.3s	remaining: 56.6s
# 1300:	total: 56.7s	remaining: 52.2s
# 1400:	total: 1m	remaining: 47.8s
# 1500:	total: 1m 5s	remaining: 43.5s
# 1600:	total: 1m 9s	remaining: 39.1s
# 1700:	total: 1m 13s	remaining: 34.8s
# 1800:	total: 1m 18s	remaining: 30.4s
# 1900:	total: 1m 22s	remaining: 26s
# 2000:	total: 1m 27s	remaining: 21.7s
# 2100:	total: 1m 31s	remaining: 17.4s
# 2200:	total: 1m 35s	remaining: 13s
# 2300:	total: 1m 40s	remaining: 8.65s
# 2400:	total: 1m 44s	remaining: 4.3s
# 2499:	total: 1m 48s	remaining: 0us
# 0:	total: 56.4ms	remaining: 2m 20s
# 100:	total: 4.46s	remaining: 1m 45s
# 200:	total: 8.91s	remaining: 1m 41s
# 300:	total: 13.3s	remaining: 1m 36s
# 400:	total: 17.6s	remaining: 1m 32s
# 500:	total: 22s	remaining: 1m 27s
# 600:	total: 26.3s	remaining: 1m 23s
# 700:	total: 30.6s	remaining: 1m 18s
# 800:	total: 35s	remaining: 1m 14s
# 900:	total: 39.3s	remaining: 1m 9s
# 1000:	total: 43.7s	remaining: 1m 5s
# 1100:	total: 48s	remaining: 1m 1s
# 1200:	total: 52.4s	remaining: 56.7s
# 1300:	total: 56.7s	remaining: 52.3s
# 1400:	total: 1m 1s	remaining: 48.1s
# 1500:	total: 1m 5s	remaining: 43.8s
# 1600:	total: 1m 10s	remaining: 39.6s
# 1700:	total: 1m 15s	remaining: 35.2s
# 1800:	total: 1m 19s	remaining: 30.9s
# 1900:	total: 1m 24s	remaining: 26.5s
# 2000:	total: 1m 28s	remaining: 22.1s
# 2100:	total: 1m 33s	remaining: 17.7s
# 2200:	total: 1m 37s	remaining: 13.3s
# 2300:	total: 1m 42s	remaining: 8.85s
# 2400:	total: 1m 46s	remaining: 4.41s
# 2499:	total: 1m 51s	remaining: 0us
# 0:	total: 52.4ms	remaining: 2m 10s
# 100:	total: 4.62s	remaining: 1m 49s
# 200:	total: 9.24s	remaining: 1m 45s
# 300:	total: 13.8s	remaining: 1m 40s
# 400:	total: 18.4s	remaining: 1m 36s
# 500:	total: 23s	remaining: 1m 31s
# 600:	total: 27.5s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.6s	remaining: 1m 17s
# 900:	total: 41.2s	remaining: 1m 13s
# 1000:	total: 45.8s	remaining: 1m 8s
# 1100:	total: 50.4s	remaining: 1m 4s
# 1200:	total: 55s	remaining: 59.5s
# 1300:	total: 59.6s	remaining: 54.9s
# 1400:	total: 1m 4s	remaining: 50.3s
# 1500:	total: 1m 8s	remaining: 45.7s
# 1600:	total: 1m 13s	remaining: 41.1s
# 1700:	total: 1m 17s	remaining: 36.5s
# 1800:	total: 1m 22s	remaining: 32s
# 1900:	total: 1m 26s	remaining: 27.4s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 36s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.09s
# 2400:	total: 1m 49s	remaining: 4.52s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 49.3ms	remaining: 2m 3s
# 100:	total: 4.66s	remaining: 1m 50s
# 200:	total: 9.16s	remaining: 1m 44s
# 300:	total: 13.7s	remaining: 1m 40s
# 400:	total: 18.3s	remaining: 1m 35s
# 500:	total: 22.8s	remaining: 1m 31s
# 600:	total: 27.4s	remaining: 1m 26s
# 700:	total: 31.9s	remaining: 1m 21s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41s	remaining: 1m 12s
# 1000:	total: 45.5s	remaining: 1m 8s
# 1100:	total: 50.1s	remaining: 1m 3s
# 1200:	total: 54.9s	remaining: 59.3s
# 1300:	total: 59.4s	remaining: 54.8s
# 1400:	total: 1m 3s	remaining: 50.2s
# 1500:	total: 1m 8s	remaining: 45.6s
# 1600:	total: 1m 13s	remaining: 41s
# 1700:	total: 1m 17s	remaining: 36.5s
# 1800:	total: 1m 22s	remaining: 31.9s
# 1900:	total: 1m 26s	remaining: 27.3s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 35s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.6s
# 2300:	total: 1m 44s	remaining: 9.06s
# 2400:	total: 1m 49s	remaining: 4.51s
# 2499:	total: 1m 53s	remaining: 0us
# 0:	total: 54.4ms	remaining: 2m 16s
# 100:	total: 4.58s	remaining: 1m 48s
# 200:	total: 9.1s	remaining: 1m 44s
# 300:	total: 13.7s	remaining: 1m 39s
# 400:	total: 18.2s	remaining: 1m 35s
# 500:	total: 22.8s	remaining: 1m 30s
# 600:	total: 27.5s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41.2s	remaining: 1m 13s
# 1000:	total: 45.7s	remaining: 1m 8s
# 1100:	total: 50.2s	remaining: 1m 3s
# 1200:	total: 54.5s	remaining: 59s
# 1300:	total: 1m	remaining: 56s
# 1400:	total: 1m 5s	remaining: 51.7s
# 1500:	total: 1m 10s	remaining: 46.9s
# 1600:	total: 1m 14s	remaining: 42s
# 1700:	total: 1m 18s	remaining: 37s
# 1800:	total: 1m 23s	remaining: 32.3s
# 1900:	total: 1m 27s	remaining: 27.6s
# 2000:	total: 1m 31s	remaining: 22.9s
# 2100:	total: 1m 36s	remaining: 18.3s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.09s
# 2400:	total: 1m 49s	remaining: 4.5s
# 2499:	total: 1m 53s	remaining: 0us
# 0:	total: 57ms	remaining: 2m 22s
# 100:	total: 4.27s	remaining: 1m 41s
# 200:	total: 8.44s	remaining: 1m 36s
# 300:	total: 12.6s	remaining: 1m 32s
# 400:	total: 16.8s	remaining: 1m 28s
# 500:	total: 21s	remaining: 1m 23s
# 600:	total: 25.2s	remaining: 1m 19s
# 700:	total: 29.4s	remaining: 1m 15s
# 800:	total: 33.8s	remaining: 1m 11s
# 900:	total: 38.3s	remaining: 1m 7s
# 1000:	total: 42.8s	remaining: 1m 4s
# 1100:	total: 47.4s	remaining: 1m
# 1200:	total: 51.9s	remaining: 56.2s
# 1300:	total: 56.5s	remaining: 52.1s
# 1400:	total: 1m 1s	remaining: 48s
# 1500:	total: 1m 5s	remaining: 43.9s
# 1600:	total: 1m 10s	remaining: 39.6s
# 1700:	total: 1m 15s	remaining: 35.2s
# 1800:	total: 1m 19s	remaining: 30.9s
# 1900:	total: 1m 24s	remaining: 26.5s
# 2000:	total: 1m 28s	remaining: 22.1s
# 2100:	total: 1m 33s	remaining: 17.7s
# 2200:	total: 1m 37s	remaining: 13.3s
# 2300:	total: 1m 42s	remaining: 8.86s
# 2400:	total: 1m 46s	remaining: 4.41s
# 2499:	total: 1m 51s	remaining: 0us
# 0:	total: 54ms	remaining: 2m 14s
# 100:	total: 4.6s	remaining: 1m 49s
# 200:	total: 9.17s	remaining: 1m 44s
# 300:	total: 13.7s	remaining: 1m 40s
# 400:	total: 18.3s	remaining: 1m 35s
# 500:	total: 22.8s	remaining: 1m 30s
# 600:	total: 27.5s	remaining: 1m 26s
# 700:	total: 32.1s	remaining: 1m 22s
# 800:	total: 36.7s	remaining: 1m 17s
# 900:	total: 41.3s	remaining: 1m 13s
# 1000:	total: 45.9s	remaining: 1m 8s
# 1100:	total: 50.4s	remaining: 1m 4s
# 1200:	total: 55.1s	remaining: 59.5s
# 1300:	total: 59.6s	remaining: 54.9s
# 1400:	total: 1m 4s	remaining: 50.3s
# 1500:	total: 1m 8s	remaining: 45.7s
# 1600:	total: 1m 13s	remaining: 41.2s
# 1700:	total: 1m 17s	remaining: 36.6s
# 1800:	total: 1m 22s	remaining: 32s
# 1900:	total: 1m 27s	remaining: 27.4s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 36s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.1s
# 2400:	total: 1m 49s	remaining: 4.53s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 64.4ms	remaining: 2m 40s
# 100:	total: 4.63s	remaining: 1m 49s
# 200:	total: 9.16s	remaining: 1m 44s
# 300:	total: 13.7s	remaining: 1m 40s
# 400:	total: 18.6s	remaining: 1m 37s
# 500:	total: 23.2s	remaining: 1m 32s
# 600:	total: 27.8s	remaining: 1m 27s
# 700:	total: 32.3s	remaining: 1m 22s
# 800:	total: 36.9s	remaining: 1m 18s
# 900:	total: 41.4s	remaining: 1m 13s
# 1000:	total: 46s	remaining: 1m 8s
# 1100:	total: 50.6s	remaining: 1m 4s
# 1200:	total: 55.1s	remaining: 59.6s
# 1300:	total: 59.7s	remaining: 55s
# 1400:	total: 1m 4s	remaining: 50.4s
# 1500:	total: 1m 8s	remaining: 45.8s
# 1600:	total: 1m 13s	remaining: 41.2s
# 1700:	total: 1m 18s	remaining: 36.7s
# 1800:	total: 1m 22s	remaining: 32.1s
# 1900:	total: 1m 27s	remaining: 27.5s
# 2000:	total: 1m 31s	remaining: 22.9s
# 2100:	total: 1m 36s	remaining: 18.3s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.12s
# 2400:	total: 1m 49s	remaining: 4.53s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 52.6ms	remaining: 2m 11s
# 100:	total: 4.64s	remaining: 1m 50s
# 200:	total: 9.17s	remaining: 1m 44s
# 300:	total: 13.7s	remaining: 1m 40s
# 400:	total: 18.3s	remaining: 1m 35s
# 500:	total: 22.8s	remaining: 1m 31s
# 600:	total: 27.4s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41.1s	remaining: 1m 12s
# 1000:	total: 45.7s	remaining: 1m 8s
# 1100:	total: 50.3s	remaining: 1m 3s
# 1200:	total: 55s	remaining: 59.4s
# 1300:	total: 59.5s	remaining: 54.8s
# 1400:	total: 1m 4s	remaining: 50.2s
# 1500:	total: 1m 8s	remaining: 45.6s
# 1600:	total: 1m 13s	remaining: 41s
# 1700:	total: 1m 17s	remaining: 36.5s
# 1800:	total: 1m 22s	remaining: 31.9s
# 1900:	total: 1m 26s	remaining: 27.4s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 35s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.6s
# 2300:	total: 1m 45s	remaining: 9.08s
# 2400:	total: 1m 49s	remaining: 4.52s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 53.7ms	remaining: 2m 14s
# 100:	total: 4.66s	remaining: 1m 50s
# 200:	total: 9.21s	remaining: 1m 45s
# 300:	total: 13.8s	remaining: 1m 40s
# 400:	total: 18.3s	remaining: 1m 35s
# 500:	total: 22.8s	remaining: 1m 31s
# 600:	total: 27.4s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41s	remaining: 1m 12s
# 1000:	total: 45.6s	remaining: 1m 8s
# 1100:	total: 50.2s	remaining: 1m 3s
# 1200:	total: 54.9s	remaining: 59.4s
# 1300:	total: 59.4s	remaining: 54.8s
# 1400:	total: 1m 3s	remaining: 50.2s
# 1500:	total: 1m 8s	remaining: 45.6s
# 1600:	total: 1m 13s	remaining: 41s
# 1700:	total: 1m 17s	remaining: 36.5s
# 1800:	total: 1m 22s	remaining: 31.9s
# 1900:	total: 1m 26s	remaining: 27.4s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 36s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.09s
# 2400:	total: 1m 49s	remaining: 4.52s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 51.2ms	remaining: 2m 8s
# 100:	total: 4.66s	remaining: 1m 50s
# 200:	total: 9.25s	remaining: 1m 45s
# 300:	total: 13.8s	remaining: 1m 40s
# 400:	total: 18.4s	remaining: 1m 36s
# 500:	total: 22.9s	remaining: 1m 31s
# 600:	total: 27.4s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41.1s	remaining: 1m 12s
# 1000:	total: 45.6s	remaining: 1m 8s
# 1100:	total: 50.2s	remaining: 1m 3s
# 1200:	total: 54.7s	remaining: 59.2s
# 1300:	total: 59.3s	remaining: 54.6s
# 1400:	total: 1m 3s	remaining: 50.1s
# 1500:	total: 1m 8s	remaining: 45.5s
# 1600:	total: 1m 12s	remaining: 40.9s
# 1700:	total: 1m 17s	remaining: 36.4s
# 1800:	total: 1m 21s	remaining: 31.8s
# 1900:	total: 1m 26s	remaining: 27.3s
# 2000:	total: 1m 31s	remaining: 22.7s
# 2100:	total: 1m 35s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.6s
# 2300:	total: 1m 44s	remaining: 9.06s
# 2400:	total: 1m 49s	remaining: 4.51s
# 2499:	total: 1m 53s	remaining: 0us
# 0:	total: 52ms	remaining: 2m 9s
# 100:	total: 4.67s	remaining: 1m 50s
# 200:	total: 9.28s	remaining: 1m 46s
# 300:	total: 13.8s	remaining: 1m 41s
# 400:	total: 18.4s	remaining: 1m 36s
# 500:	total: 23s	remaining: 1m 31s
# 600:	total: 27.5s	remaining: 1m 26s
# 700:	total: 32.1s	remaining: 1m 22s
# 800:	total: 36.7s	remaining: 1m 17s
# 900:	total: 41.2s	remaining: 1m 13s
# 1000:	total: 45.8s	remaining: 1m 8s
# 1100:	total: 50.4s	remaining: 1m 4s
# 1200:	total: 54.9s	remaining: 59.4s
# 1300:	total: 59.4s	remaining: 54.8s
# 1400:	total: 1m 3s	remaining: 50.2s
# 1500:	total: 1m 8s	remaining: 45.6s
# 1600:	total: 1m 13s	remaining: 41.1s
# 1700:	total: 1m 17s	remaining: 36.5s
# 1800:	total: 1m 22s	remaining: 31.9s
# 1900:	total: 1m 26s	remaining: 27.3s
# 2000:	total: 1m 31s	remaining: 22.8s
# 2100:	total: 1m 36s	remaining: 18.2s
# 2200:	total: 1m 40s	remaining: 13.7s
# 2300:	total: 1m 45s	remaining: 9.09s
# 2400:	total: 1m 49s	remaining: 4.52s
# 2499:	total: 1m 54s	remaining: 0us
# 0:	total: 51.8ms	remaining: 2m 9s
# 100:	total: 4.7s	remaining: 1m 51s
# 200:	total: 9.29s	remaining: 1m 46s
# 300:	total: 13.9s	remaining: 1m 41s
# 400:	total: 18.4s	remaining: 1m 36s
# 500:	total: 22.9s	remaining: 1m 31s
# 600:	total: 27.5s	remaining: 1m 26s
# 700:	total: 32s	remaining: 1m 22s
# 800:	total: 36.5s	remaining: 1m 17s
# 900:	total: 41.1s	remaining: 1m 12s
# 1000:	total: 45.7s	remaining: 1m 8s
# 1100:	total: 50.3s	remaining: 1m 3s
# 1200:	total: 54.8s	remaining: 59.3s
# 1300:	total: 59.4s	remaining: 54.8s
# 1400:	total: 1m 3s	remaining: 50.2s

# %%
#categorical_features_indices = np.where(X_train.dtypes != np.float)[0]
cat1 = CatBoostClassifier(loss_function="Logloss",eval_metric="AUC",
                          iterations=2500,learning_rate=0.02,depth=4,verbose=100,bagging_temperature = 0.2,
                          early_stopping_rounds=500)
cat1.fit(X_train,pd.DataFrame(y_train))

y_test_pre = cat1.predict(X_test)
y_test_true = np.array(y_test)
print ("the catboost model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# 0:	total: 7.04ms	remaining: 17.6s
# 100:	total: 427ms	remaining: 10.2s
# 200:	total: 826ms	remaining: 9.44s
# 300:	total: 1.25s	remaining: 9.13s
# 400:	total: 1.63s	remaining: 8.53s
# 500:	total: 2.01s	remaining: 8.01s
# 600:	total: 2.39s	remaining: 7.55s
# 700:	total: 2.79s	remaining: 7.17s
# 800:	total: 3.18s	remaining: 6.74s
# 900:	total: 3.6s	remaining: 6.39s
# 1000:	total: 3.98s	remaining: 5.96s
# 1100:	total: 4.36s	remaining: 5.54s
# 1200:	total: 4.74s	remaining: 5.13s
# 1300:	total: 5.12s	remaining: 4.72s
# 1400:	total: 5.49s	remaining: 4.31s
# 1500:	total: 5.88s	remaining: 3.91s
# 1600:	total: 6.25s	remaining: 3.51s
# 1700:	total: 6.64s	remaining: 3.12s
# 1800:	total: 7.01s	remaining: 2.72s
# 1900:	total: 7.38s	remaining: 2.33s
# 2000:	total: 7.76s	remaining: 1.93s
# 2100:	total: 8.21s	remaining: 1.56s
# 2200:	total: 8.59s	remaining: 1.17s
# 2300:	total: 8.97s	remaining: 776ms
# 2400:	total: 9.44s	remaining: 389ms
# 2499:	total: 9.82s	remaining: 0us
# the catboost model auc : 0.8

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('CatBoostClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00       424
#          1.0       1.00      0.60      0.75        10
#
#     accuracy                           0.99       434
#    macro avg       1.00      0.80      0.87       434
# weighted avg       0.99      0.99      0.99       434
#
# auc值为: 0.8
# Text(0.5, 1.0, 'CatBoostClassifier ROC Curve')

# %%
#特征重要性排名
cat_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
cat_feat_imp = pd.Series(cat1.feature_importances_,cat_predictors).sort_values(ascending=False)
cat_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(cat_feat_imp)
# Out:
# REFUND_OF_TAX         7.027423
# C_FR_OTH_OPERATE_A    3.883715
# BIZ_TAX_SURCHG        3.488882
# N_INCOME_ATTR_P       3.356365
# DILUTED_EPS           3.263255
#                         ...
# COMPR_INC_ATTR_M_S    0.222960
# C_PAID_G_S            0.216037
# T_NCL                 0.165842
# GOODWILL              0.118116
# CAPITAL_RESER         0.108930
# Length: 95, dtype: float64

# %%
print(cat_feat_imp[0:20])
# Out:
# REFUND_OF_TAX          7.027423
# C_FR_OTH_OPERATE_A     3.883715
# BIZ_TAX_SURCHG         3.488882
# N_INCOME_ATTR_P        3.356365
# DILUTED_EPS            3.263255
# COMPR_INC_ATTR_P       2.544861
# CIP                    2.481570
# ADVANCE_RECEIPTS       2.296733
# C_FR_BORR              2.276898
# NOPERATE_EXP           2.216602
# C_INF_FR_OPERATE_A     2.159986
# DISP_FIX_ASSETS_OTH    1.932862
# T_COMPR_INCOME         1.892682
# N_INCOME               1.848293
# NI_NI                  1.768859
# AR                     1.709241
# FINAN_EXP              1.648139
# BASIC_EPS              1.629502
# ST_BORR                1.431862
# NOPERATE_INCOME        1.397885
# dtype: float64
