# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split,cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %% [markdown]
# - 读取数据

# %%
ramdonForest_end_Data = pd.read_csv('./金融业_处理.csv',encoding = 'gbk')

# %%
ramdonForest_end_Data = ramdonForest_end_Data.drop(columns = 'Unnamed: 0')

# %%
ramdonForest_end_Data['FLAG'].groupby(ramdonForest_end_Data['FLAG']).count()
# Out:
# FLAG
# 0.0    525
# 1.0     11
# Name: FLAG, dtype: int64

# %%
ramdonForest_end_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 86 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CASH_C_EQUIV         536 non-null    float64
#  1   TRADING_FA           536 non-null    float64
#  2   INT_RECEIV           536 non-null    float64
#  3   PUR_RESALE_FA        536 non-null    float64
#  4   AVAIL_FOR_SALE_FA    536 non-null    float64
#  5   LT_EQUITY_INVEST     536 non-null    float64
#  6   INVEST_REAL_ESTATE   536 non-null    float64
#  7   FIXED_ASSETS         536 non-null    float64
#  8   INTAN_ASSETS         536 non-null    float64
#  9   DEFER_TAX_ASSETS     536 non-null    float64
#  10  T_ASSETS             536 non-null    float64
#  11  LOAN_FR_OTH_BANK_FI  536 non-null    float64
#  12  TRADING_FL           536 non-null    float64
#  13  SOLD_FOR_REPUR_FA    536 non-null    float64
#  14  PAYROLL_PAYABLE      536 non-null    float64
#  15  TAXES_PAYABLE        536 non-null    float64
#  16  INT_PAYABLE          536 non-null    float64
#  17  BOND_PAYABLE         536 non-null    float64
#  18  DEFER_TAX_LIAB       536 non-null    float64
#  19  T_LIAB               536 non-null    float64
#  20  PAID_IN_CAPITAL      536 non-null    float64
#  21  CAPITAL_RESER        536 non-null    float64
#  22  SURPLUS_RESER        536 non-null    float64
#  23  ORDIN_RISK_RESER     536 non-null    float64
#  24  RETAINED_EARNINGS    536 non-null    float64
#  25  T_EQUITY_ATTR_P      536 non-null    float64
#  26  MINORITY_INT         536 non-null    float64
#  27  T_SH_EQUITY          536 non-null    float64
#  28  T_LIAB_EQUITY        536 non-null    float64
#  29  OTH_COMPRE_INCOME    536 non-null    float64
#  30  N_CF_FR_INVEST_A     536 non-null    float64
#  31  N_CF_OPERATE_A       536 non-null    float64
#  32  C_FR_CAP_CONTR       536 non-null    float64
#  33  C_PAID_INVEST        536 non-null    float64
#  34  C_INF_FR_INVEST_A    536 non-null    float64
#  35  C_PAID_FOR_OTH_OP_A  536 non-null    float64
#  36  PROC_SELL_INVEST     536 non-null    float64
#  37  C_INF_FR_OPERATE_A   536 non-null    float64
#  38  GAIN_INVEST          536 non-null    float64
#  39  N_CHANGE_IN_CASH     536 non-null    float64
#  40  FOREX_EFFECTS        536 non-null    float64
#  41  C_PAID_FOR_TAXES     536 non-null    float64
#  42  C_PAID_IFC           536 non-null    float64
#  43  C_PAID_DIV_PROF_INT  536 non-null    float64
#  44  C_OUTF_OPERATE_A     536 non-null    float64
#  45  C_FR_OTH_OPERATE_A   536 non-null    float64
#  46  C_OUTF_FR_INVEST_A   536 non-null    float64
#  47  C_FR_ISSUE_BOND      536 non-null    float64
#  48  C_PAID_FOR_DEBTS     536 non-null    float64
#  49  DISP_FIX_ASSETS_OTH  536 non-null    float64
#  50  N_CF_FR_FINAN_A      536 non-null    float64
#  51  N_CE_BEG_BAL         536 non-null    float64
#  52  N_CE_END_BAL         536 non-null    float64
#  53  PUR_FIX_ASSETS_OTH   536 non-null    float64
#  54  C_INF_FR_FINAN_A     536 non-null    float64
#  55  IFC_CASH_INCR        536 non-null    float64
#  56  C_PAID_TO_FOR_EMPL   536 non-null    float64
#  57  C_OUTF_FR_FINAN_A    536 non-null    float64
#  58  DILUTED_EPS          536 non-null    float64
#  59  A_J_INVEST_INCOME    536 non-null    float64
#  60  REVENUE              536 non-null    float64
#  61  T_REVENUE            536 non-null    float64
#  62  T_PROFIT             536 non-null    float64
#  63  BASIC_EPS            536 non-null    float64
#  64  OPERATE_PROFIT       536 non-null    float64
#  65  ASSETS_IMPAIR_LOSS   536 non-null    float64
#  66  COMPR_INC_ATTR_P     536 non-null    float64
#  67  OTH_COMPR_INCOME     536 non-null    float64
#  68  T_COMPR_INCOME       536 non-null    float64
#  69  INT_INCOME           536 non-null    float64
#  70  N_INCOME_ATTR_P      536 non-null    float64
#  71  INVEST_INCOME        536 non-null    float64
#  72  F_VALUE_CHG_GAIN     536 non-null    float64
#  73  COGS                 536 non-null    float64
#  74  N_INCOME             536 non-null    float64
#  75  BIZ_TAX_SURCHG       536 non-null    float64
#  76  NOPERATE_EXP         536 non-null    float64
#  77  COMPR_INC_ATTR_M_S   536 non-null    float64
#  78  FOREX_GAIN           536 non-null    float64
#  79  INCOME_TAX           536 non-null    float64
#  80  NOPERATE_INCOME      536 non-null    float64
#  81  MINORITY_GAIN        536 non-null    float64
#  82  COMMIS_INCOME        536 non-null    float64
#  83  T_COGS               536 non-null    float64
#  84  FLAG                 536 non-null    float64
#  85  NI_NI                536 non-null    float64
# dtypes: float64(86)
# memory usage: 360.2 KB

# %% [markdown]
# - 过采样数据

# %%
#定义SMOTE模型，random_state相当于随机数种子的作用
smo = SMOTE(sampling_strategy={1:30,0:525 },random_state=42)
#ros = RandomOverSampler(random_state=30,sampling_strategy=0.02)
X_smo,y_smo = smo.fit_resample(ramdonForest_end_Data.drop(columns = 'FLAG'),ramdonForest_end_Data['FLAG'])
#标准化数据
sc=StandardScaler()
sc.fit(X_smo)#计算样本的均值和标准差
X_smo=pd.DataFrame(sc.transform(X_smo))
#拆分专家样本集
X_train, X_test, y_train, y_test = train_test_split(X_smo,y_smo,test_size=0.3)
y_train.groupby(y_train).count()
# Out:
# FLAG
# 0.0    366
# 1.0     22
# Name: FLAG, dtype: int64

# %% [markdown]
# - XGBoost模型调整

# %%
# 贝叶斯优化调参

def modelfit(learning_rate, n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree,
             Reg_lambda, Reg_alpha):
    xgb1 =cross_val_score(xgb.XGBClassifier(objective='binary:logistic', nthread=2,
                             n_estimators=int(n_estimators),
                             learning_rate=float(learning_rate),
                             max_depth=int(max_depth), min_child_weight=int(min_child_weight),
                             gamma=float(gamma), subsample=float(subsample),
                             colsample_bytree=float(colsample_bytree),
                             Reg_lambda=float(Reg_lambda), Reg_alpha=float(Reg_alpha),
                             scale_pos_weight=100, seed=10, ),X_train, pd.DataFrame(y_train),scoring='roc_auc',cv=15).mean()
    return xgb1


# 参数因子池
pool = {
    'learning_rate': (0.0001, 0.9999),
    'n_estimators': (400, 800),
    'max_depth': (1, 20),  # 树模型深度
    'min_child_weight': (1, 5),
    'gamma': (0.1, 0.7),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.6, 0.9),
    'Reg_lambda': (0.001, 3),
    'Reg_alpha': (0.001, 2)

}
# 定义贝叶斯调参模型
from bayes_opt import BayesianOptimization as bayes

optimizer = bayes(f=modelfit,
                  pbounds=pool,
                  verbose=2,
                  random_state=1,
                  )

# %%
# 调参并输出最优因子
optimizer.maximize(
    init_points=5,
    n_iter=25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | Reg_alpha | Reg_la... | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [17:25:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:25:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:25:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  1        |  0.9546   |  0.8346   |  2.161    |  0.6      |  0.2814   |  0.1468   |  2.754    |  1.745    |  538.2    |  0.719    |
# [17:26:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  2        |  0.9032   |  1.078    |  1.258    |  0.8056   |  0.2227   |  0.878    |  1.52     |  3.682    |  566.9    |  0.7676   |
# [17:26:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:26:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:26:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ...
#   return f(*args, **kwargs)
# [17:51:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:51:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:51:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:51:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:51:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:51:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [17:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  30       |  0.9393   |  1.874    |  1.841    |  0.7078   |  0.3637   |  0.5782   |  11.53    |  4.457    |  676.5    |  0.6465   |
# =====================================================================================================================================
# {'target': 0.9602777777777778, 'params': {'Reg_alpha': 0.27071704881246544, 'Reg_lambda': 2.0825966191291365, 'colsample_bytree': 0.794259984756309, 'gamma': 0.34239495457485786, 'learning_rate': 0.8566783355527577, 'max_depth': 17.510414353756357, 'min_child_weight': 1.1363211475010626, 'n_estimators': 675.3523747794361, 'subsample': 0.6839100407115474}}

# %%
# xgboost模型训练
{'target': 0.8615102040816325, 'params': {'Reg_alpha': 1.8319806986182532, 'Reg_lambda': 1.8926638639468827, 
                                          'colsample_bytree': 0.7611027351015522, 'gamma': 0.15739800174892332, 
                                          'learning_rate': 0.4434035497095646, 'max_depth': 5.138826963224284, 
                                          'min_child_weight': 1.9907502368032426, 'n_estimators': 535.3873938717827,
                                          'subsample': 0.655961155736557}}
{'target': 0.9602777777777778, 'params': {'Reg_alpha': 0.27071704881246544, 'Reg_lambda': 2.0825966191291365, 
                                          'colsample_bytree': 0.794259984756309, 'gamma': 0.34239495457485786,
                                          'learning_rate': 0.8566783355527577, 'max_depth': 17.510414353756357, 
                                          'min_child_weight': 1.1363211475010626, 'n_estimators': 675.3523747794361,
                                          'subsample': 0.6839100407115474}}

xgb1 = xgb.XGBClassifier(n_estimators=675,learning_rate=0.85,
                        max_depth=17,min_child_weight=1,gamma=0.34,
                        subsample=0.68,colsample_bytree=0.79,
                        objective='binary:logistic',nthread=2,
                        scale_pos_weight=100,seed=10,Reg_lambda = 2.08,
                         Reg_alpha = 0.27)#scale_pos_weight很重要
xgb1.fit(X_train, y_train)

y_test_pre = xgb1.predict(X_test)
y_test_true = np.array(y_test)
print("the xgboost model auc: %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:56:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:56:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# the xgboost model auc: 0.9385

# %%
# 特征重要性排名
xgb_predictors = [i for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
xgb_feat_imp = pd.Series(xgb1.feature_importances_, xgb_predictors).sort_values(ascending=False)
xgb_feat_imp[0:20].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(xgb_feat_imp[0:20])
# Out:
# INT_INCOME             0.227614
# INCOME_TAX             0.145637
# PUR_FIX_ASSETS_OTH     0.119070
# OTH_COMPRE_INCOME      0.113162
# CAPITAL_RESER          0.081925
# C_PAID_FOR_OTH_OP_A    0.077963
# BOND_PAYABLE           0.070146
# C_INF_FR_INVEST_A      0.036063
# C_PAID_INVEST          0.015126
# GAIN_INVEST            0.013395
# NOPERATE_INCOME        0.013163
# INT_PAYABLE            0.009650
# A_J_INVEST_INCOME      0.008993
# T_COGS                 0.007941
# INVEST_REAL_ESTATE     0.007366
# FOREX_EFFECTS          0.006846
# C_PAID_DIV_PROF_INT    0.005739
# N_INCOME               0.005721
# LT_EQUITY_INVEST       0.005382
# COMMIS_INCOME          0.004165
# dtype: float32

# %%
xgb_feat_imp[0:20]
# Out:
# INT_INCOME             0.227614
# INCOME_TAX             0.145637
# PUR_FIX_ASSETS_OTH     0.119070
# OTH_COMPRE_INCOME      0.113162
# CAPITAL_RESER          0.081925
# C_PAID_FOR_OTH_OP_A    0.077963
# BOND_PAYABLE           0.070146
# C_INF_FR_INVEST_A      0.036063
# C_PAID_INVEST          0.015126
# GAIN_INVEST            0.013395
# NOPERATE_INCOME        0.013163
# INT_PAYABLE            0.009650
# A_J_INVEST_INCOME      0.008993
# T_COGS                 0.007941
# INVEST_REAL_ESTATE     0.007366
# FOREX_EFFECTS          0.006846
# C_PAID_DIV_PROF_INT    0.005739
# N_INCOME               0.005721
# LT_EQUITY_INVEST       0.005382
# COMMIS_INCOME          0.004165
# dtype: float32

# %%
# 具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:", roc_auc_score(y_test_true,y_test_pre))

# ROC曲线绘制
fpr1, tpr1, threshold1 = roc_curve(y_test_true, y_test_pre)
plt.plot(fpr1, tpr1, color='r')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98       156
#          1.0       0.67      0.91      0.77        11
#
#     accuracy                           0.96       167
#    macro avg       0.83      0.94      0.87       167
# weighted avg       0.97      0.96      0.97       167
#
# auc值为: 0.9385198135198135
# Text(0.5, 1.0, 'XGBClassifier ROC Curve')

# %% [markdown]
# - LightGBM模型调整

# %%
#贝叶斯优化调参
def modelfit(learning_rate,n_estimators,max_depth,num_leaves,min_data_in_leaf,max_bin,feature_fraction,
            bagging_fraction,bagging_freq,lambda_l1,lambda_l2,min_split_gain):
    lgb1 = cross_val_score(lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                              n_estimators = int(n_estimators),
                              max_depth = int(max_depth),
                              num_leaves = int(num_leaves),
                              learning_rate = float(learning_rate),
                              min_data_in_leaf = int(min_data_in_leaf),
                              max_bin = int(max_bin),
                              feature_fraction = float(feature_fraction),
                              bagging_fraction = float(bagging_fraction),
                              bagging_freq = int(bagging_freq),
                              lambda_l1 = float(lambda_l1),lambda_l2 = float(lambda_l2),
                              min_split_gain = float(min_split_gain),
                              cat_smooth = 100,nthread = 4, ),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=15).mean()
    return lgb1

pool = {
    'learning_rate':(0.0001,0.9999),
    'n_estimators':(400,800),
    'max_depth':(1,20),              #树模型深度
    'num_leaves':(10,30),            #叶子树，树模型复杂度
    'min_data_in_leaf':(1,70),       #处理过拟合，一个叶子上数据的最小数量
    'max_bin':(5,255),               #工具箱数（叶子结点数+非叶子节点数？）
    'feature_fraction':(0.5,0.999),  #每次迭代中随机选择特征的比例。加速训练，处理过拟合
    'bagging_fraction':(0.5,0.999),  #不进行重采样的情况下随机选择部分数据
    'bagging_freq':(3,5),            #bagging的次数。0表示禁用bagging，非零值表示执行k次bagging
    'lambda_l1':(0.0001,0.9999),
    'lambda_l2':(0.0001,0.9999),
    'min_split_gain':(0.01,0.999)    #执行切分的最小增益
    
}

from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | lambda_l1 | lambda_l2 | learni... |  max_bin  | max_depth | min_da... | min_sp... | n_esti... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  1        |  0.9572   |  0.7081   |  4.441    |  0.5001   |  0.3024   |  0.1468   |  0.09242  |  51.57    |  7.566    |  28.38    |  0.5429   |  567.7    |  23.7     |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  2        |  0.8716   |  0.602    |  4.756    |  0.5137   |  0.6704   |  0.4173   |  0.5587   |  40.1     |  4.764    |  56.25    |  0.9676   |  525.4    |  23.85    |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# ...
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# |  30       |  0.9547   |  0.9987   |  3.458    |  0.7872   |  0.5213   |  0.4885   |  0.6847   |  215.1    |  10.86    |  57.59    |  0.3898   |  423.9    |  12.94    |
# =========================================================================================================================================================================
# {'target': 0.9671111111111111, 'params': {'bagging_fraction': 0.7110935199734191, 'bagging_freq': 3.555519292015857, 'feature_fraction': 0.6395532402119111, 'lambda_l1': 0.1521666991300168, 'lambda_l2': 0.513562895462724, 'learning_rate': 0.24443610467110888, 'max_bin': 49.39043679507887, 'max_depth': 6.747496320755021, 'min_data_in_leaf': 25.845472970236372, 'min_split_gain': 0.9247731921667671, 'n_estimators': 562.6726408362506, 'num_leaves': 18.832655150382443}}

# %%
lgb1 = lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                          bagging_fraction = 0.71, bagging_freq = 5,
                          feature_fraction = 0.63,lambda_l1 =  0.15,lambda_l2 = 0.51,
                          learning_rate = 0.2,max_bin = 49,max_depth = 6,
                          min_data_in_leaf = 24,min_split_gain = 0.9,
                          n_estimators = 562,num_leaves = 20,
                          cat_smooth = 10,nthread = 4)
#cat_smooth：可以减少噪声对分类特征的影响，尤其是对于数据较少的分类
lgb_model = lgb1.fit(X_train,pd.DataFrame(y_train))
y_test_pre = lgb1.predict(X_test)
y_test_true = np.array(y_test)
print ("the lightgbm model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.63, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.63
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] lambda_l1 is set=0.15, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.15
# [LightGBM] [Warning] bagging_fraction is set=0.71, subsample=1.0 will be ignored. Current value: bagging_fraction=0.71
# [LightGBM] [Warning] lambda_l2 is set=0.51, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.51
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# the lightgbm model auc : 0.8604

# %%
#特征重要性排名
lgb_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
lgb_feat_imp = pd.Series(lgb_model.feature_importances_,lgb_predictors).sort_values(ascending=False)
lgb_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(lgb_feat_imp )
# Out:
# NOPERATE_EXP           7
# C_PAID_DIV_PROF_INT    6
# C_FR_CAP_CONTR         4
# FIXED_ASSETS           4
# T_COGS                 4
#                       ..
# INVEST_INCOME          0
# F_VALUE_CHG_GAIN       0
# OTH_COMPRE_INCOME      0
# T_LIAB_EQUITY          0
# T_SH_EQUITY            0
# Length: 85, dtype: int32

# %%
print(lgb_feat_imp[0:20] )
# Out:
# NOPERATE_EXP           7
# C_PAID_DIV_PROF_INT    6
# C_FR_CAP_CONTR         4
# FIXED_ASSETS           4
# T_COGS                 4
# FOREX_EFFECTS          4
# N_CF_FR_INVEST_A       4
# OPERATE_PROFIT         4
# DILUTED_EPS            3
# NOPERATE_INCOME        3
# BIZ_TAX_SURCHG         3
# BASIC_EPS              3
# C_INF_FR_OPERATE_A     2
# T_REVENUE              2
# NI_NI                  2
# PUR_FIX_ASSETS_OTH     2
# COMPR_INC_ATTR_M_S     2
# DEFER_TAX_ASSETS       2
# INTAN_ASSETS           2
# C_PAID_INVEST          1
# dtype: int32

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99       156
#          1.0       0.89      0.73      0.80        11
#
#     accuracy                           0.98       167
#    macro avg       0.93      0.86      0.89       167
# weighted avg       0.97      0.98      0.97       167
#
# auc值为: 0.8604312354312355
# Text(0.5, 1.0, 'LGBClassifier ROC Curve')

# %% [markdown]
# - Catboost模型调整

# %%
def modelfit(learning_rate,depth,bagging_temperature):
    cat1 = cross_val_score(CatBoostClassifier(loss_function = 'Logloss',
                             eval_metric = 'AUC',
                             iterations = 2500,
                             learning_rate = float(learning_rate),
                             depth = int(depth),
                             verbose = 100,
                             bagging_temperature = float(bagging_temperature),
                             early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=15).mean()
    return cat1

pool = {
    'learning_rate':(0.01,0.999),
    'depth':(4,9),
    'bagging_temperature':(0.01,0.999)
}
from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... |   depth   | learni... |
# -------------------------------------------------------------
# 0:	total: 85.6ms	remaining: 3m 33s
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_split.py:668: UserWarning: The least populated class in y has only 19 members, which is less than n_splits=20.
#   % (min_groups, self.n_splits)), UserWarning)
# 100:	total: 6.79s	remaining: 2m 41s
# 200:	total: 13s	remaining: 2m 29s
# 300:	total: 19.3s	remaining: 2m 21s
# 400:	total: 21.9s	remaining: 1m 54s
# 500:	total: 23.9s	remaining: 1m 35s
# 600:	total: 25.9s	remaining: 1m 21s
# 700:	total: 28s	remaining: 1m 11s
# 800:	total: 30s	remaining: 1m 3s
# 900:	total: 32.1s	remaining: 56.9s
# 1000:	total: 34.1s	remaining: 51s
# 1100:	total: 36.1s	remaining: 45.9s
# 1200:	total: 38.1s	remaining: 41.2s
# 1300:	total: 40.2s	remaining: 37.1s
# 1400:	total: 42.3s	remaining: 33.2s
# 1500:	total: 44.4s	remaining: 29.5s
# 1600:	total: 46.5s	remaining: 26.1s
# 1700:	total: 48.6s	remaining: 22.8s
# 1800:	total: 53.4s	remaining: 20.7s
# 1900:	total: 59.9s	remaining: 18.9s
# 2000:	total: 1m 5s	remaining: 16.4s
# 2100:	total: 1m 11s	remaining: 13.6s
# 2200:	total: 1m 17s	remaining: 10.6s
# 2300:	total: 1m 24s	remaining: 7.28s
# 2400:	total: 1m 30s	remaining: 3.73s
# 2499:	total: 1m 36s	remaining: 0us
# 0:	total: 63.5ms	remaining: 2m 38s
# 100:	total: 6.15s	remaining: 2m 26s
# 200:	total: 12.3s	remaining: 2m 20s
# 300:	total: 18.2s	remaining: 2m 13s
# 400:	total: 24.1s	remaining: 2m 6s
# 500:	total: 29.9s	remaining: 1m 59s
# 600:	total: 36s	remaining: 1m 53s
# 700:	total: 42s	remaining: 1m 47s
# 800:	total: 47.9s	remaining: 1m 41s
# 900:	total: 53.8s	remaining: 1m 35s
# 1000:	total: 1m	remaining: 1m 30s
# 1100:	total: 1m 5s	remaining: 1m 23s
# 1200:	total: 1m 11s	remaining: 1m 17s
# 1300:	total: 1m 17s	remaining: 1m 11s
# 1400:	total: 1m 23s	remaining: 1m 5s
# 1500:	total: 1m 29s	remaining: 59.7s
# 1600:	total: 1m 35s	remaining: 53.8s
# 1700:	total: 1m 41s	remaining: 47.9s
# 1800:	total: 1m 48s	remaining: 42s
# 1900:	total: 1m 54s	remaining: 36s
# 2000:	total: 2m	remaining: 30s
# 2100:	total: 2m 6s	remaining: 24s
# 2200:	total: 2m 12s	remaining: 18s
# 2300:	total: 2m 18s	remaining: 12s
# 2400:	total: 2m 23s	remaining: 5.92s
# 2499:	total: 2m 25s	remaining: 0us
# 0:	total: 22ms	remaining: 55s
# 100:	total: 2.03s	remaining: 48.2s
# 200:	total: 4.34s	remaining: 49.6s
# 300:	total: 6.53s	remaining: 47.7s
# 400:	total: 8.79s	remaining: 46s
# 500:	total: 11s	remaining: 44s
# 600:	total: 13.3s	remaining: 42s
# 700:	total: 15.6s	remaining: 40.1s
# 800:	total: 17.8s	remaining: 37.8s
# 900:	total: 20.4s	remaining: 36.2s
# 1000:	total: 22.9s	remaining: 34.2s
# 1100:	total: 25.1s	remaining: 31.9s
# 1200:	total: 27.4s	remaining: 29.6s
# 1300:	total: 29.6s	remaining: 27.3s
# 1400:	total: 32s	remaining: 25.1s
# 1500:	total: 34.1s	remaining: 22.7s
# 1600:	total: 36.2s	remaining: 20.3s
# 1700:	total: 38.4s	remaining: 18s
# 1800:	total: 40.8s	remaining: 15.8s
# 1900:	total: 43s	remaining: 13.5s
# 2000:	total: 45.1s	remaining: 11.2s
# 2100:	total: 47.3s	remaining: 8.98s
# 2200:	total: 49.6s	remaining: 6.73s
# 2300:	total: 51.8s	remaining: 4.48s
# 2400:	total: 54.1s	remaining: 2.23s
# 2499:	total: 56.5s	remaining: 0us
# 0:	total: 23.9ms	remaining: 59.8s
# 100:	total: 2.27s	remaining: 54s
# 200:	total: 4.59s	remaining: 52.5s
# 300:	total: 6.84s	remaining: 50s
# 400:	total: 9.1s	remaining: 47.6s
# 500:	total: 11.5s	remaining: 45.7s
# 600:	total: 13.7s	remaining: 43.4s
# 700:	total: 15.9s	remaining: 40.9s
# 800:	total: 18.2s	remaining: 38.6s
# 900:	total: 20.4s	remaining: 36.1s
# 1000:	total: 22.8s	remaining: 34.2s
# 1100:	total: 25.1s	remaining: 31.9s
# 1200:	total: 27.3s	remaining: 29.5s
# 1300:	total: 29.7s	remaining: 27.4s
# 1400:	total: 32.2s	remaining: 25.2s
# 1500:	total: 34.4s	remaining: 22.9s
# 1600:	total: 36.5s	remaining: 20.5s
# 1700:	total: 39s	remaining: 18.3s
# 1800:	total: 41.7s	remaining: 16.2s
# 1900:	total: 44.1s	remaining: 13.9s
# 2000:	total: 46.5s	remaining: 11.6s
# 2100:	total: 48.7s	remaining: 9.25s
# 2200:	total: 51.2s	remaining: 6.96s
# 2300:	total: 53.9s	remaining: 4.66s
# 2400:	total: 56.2s	remaining: 2.32s
# 2499:	total: 58.4s	remaining: 0us
# 0:	total: 40.5ms	remaining: 1m 41s
# 100:	total: 2.2s	remaining: 52.4s
# 200:	total: 4.46s	remaining: 51s
# 300:	total: 6.8s	remaining: 49.7s
# 400:	total: 8.99s	remaining: 47.1s
# 500:	total: 11.1s	remaining: 44.1s
# 600:	total: 13.1s	remaining: 41.4s
# 700:	total: 15.3s	remaining: 39.4s
# 800:	total: 17.5s	remaining: 37.1s
# 900:	total: 19.7s	remaining: 35s
# 1000:	total: 21.9s	remaining: 32.8s
# 1100:	total: 24.3s	remaining: 30.8s
# 1200:	total: 26.5s	remaining: 28.7s
# 1300:	total: 28.7s	remaining: 26.5s
# 1400:	total: 30.9s	remaining: 24.2s
# 1500:	total: 32.9s	remaining: 21.9s
# 1600:	total: 35s	remaining: 19.6s
# 1700:	total: 37s	remaining: 17.4s
# 1800:	total: 39.2s	remaining: 15.2s
# 1900:	total: 41.3s	remaining: 13s
# 2000:	total: 43.1s	remaining: 10.7s
# 2100:	total: 45.1s	remaining: 8.57s
# 2200:	total: 47.1s	remaining: 6.39s
# 2300:	total: 49.2s	remaining: 4.26s
# 2400:	total: 51.3s	remaining: 2.11s
# 2499:	total: 53.5s	remaining: 0us
# 0:	total: 29.5ms	remaining: 1m 13s
# 100:	total: 2.43s	remaining: 57.7s
# 200:	total: 4.68s	remaining: 53.5s
# 300:	total: 6.93s	remaining: 50.6s
# 400:	total: 9.28s	remaining: 48.6s
# 500:	total: 11.5s	remaining: 46s
# 600:	total: 13.7s	remaining: 43.3s
# 700:	total: 16.1s	remaining: 41.3s
# 800:	total: 18.3s	remaining: 38.8s
# 900:	total: 20.7s	remaining: 36.8s
# 1000:	total: 22.8s	remaining: 34.2s
# 1100:	total: 25.1s	remaining: 31.8s
# 1200:	total: 27.4s	remaining: 29.6s
# 1300:	total: 29.7s	remaining: 27.4s
# 1400:	total: 31.8s	remaining: 25s
# 1500:	total: 33.9s	remaining: 22.5s
# 1600:	total: 35.9s	remaining: 20.1s
# 1700:	total: 37.9s	remaining: 17.8s
# 1800:	total: 39.9s	remaining: 15.5s
# 1900:	total: 41.9s	remaining: 13.2s
# 2000:	total: 44s	remaining: 11s
# 2100:	total: 46.1s	remaining: 8.75s
# 2200:	total: 48.2s	remaining: 6.55s
# 2300:	total: 50.3s	remaining: 4.35s
# 2400:	total: 52.5s	remaining: 2.16s
# 2499:	total: 54.5s	remaining: 0us
# 0:	total: 28.6ms	remaining: 1m 11s
# 100:	total: 2.17s	remaining: 51.6s
# 200:	total: 4.58s	remaining: 52.4s
# 300:	total: 6.9s	remaining: 50.4s
# 400:	total: 9.19s	remaining: 48.1s
# 500:	total: 11.5s	remaining: 46s
# 600:	total: 13.8s	remaining: 43.6s
# 700:	total: 15.9s	remaining: 40.8s
# 800:	total: 18.1s	remaining: 38.3s
# 900:	total: 20.2s	remaining: 35.9s
# 1000:	total: 22.4s	remaining: 33.5s
# 1100:	total: 24.6s	remaining: 31.3s
# 1200:	total: 27s	remaining: 29.2s
# 1300:	total: 29.2s	remaining: 26.9s
# 1400:	total: 31.4s	remaining: 24.6s
# 1500:	total: 33.7s	remaining: 22.4s
# 1600:	total: 36s	remaining: 20.2s
# 1700:	total: 38s	remaining: 17.8s
# 1800:	total: 40.2s	remaining: 15.6s
# 1900:	total: 42.3s	remaining: 13.3s
# 2000:	total: 44.6s	remaining: 11.1s
# 2100:	total: 46.8s	remaining: 8.9s
# 2200:	total: 49s	remaining: 6.65s
# 2300:	total: 51.2s	remaining: 4.43s
# 2400:	total: 53.4s	remaining: 2.2s
# 2499:	total: 55.6s	remaining: 0us
# 0:	total: 63.8ms	remaining: 2m 39s
# 100:	total: 2.28s	remaining: 54.1s
# 200:	total: 4.67s	remaining: 53.4s
# 300:	total: 6.88s	remaining: 50.3s
# 400:	total: 9.08s	remaining: 47.6s
# 500:	total: 11.2s	remaining: 44.8s
# 600:	total: 13.4s	remaining: 42.4s
# 700:	total: 15.5s	remaining: 39.9s
# 800:	total: 17.8s	remaining: 37.8s
# 900:	total: 20.2s	remaining: 35.9s
# 1000:	total: 22.4s	remaining: 33.6s
# 1100:	total: 24.8s	remaining: 31.5s
# 1200:	total: 27.1s	remaining: 29.4s
# 1300:	total: 29.4s	remaining: 27.1s
# 1400:	total: 31.7s	remaining: 24.9s
# 1500:	total: 34s	remaining: 22.6s
# 1600:	total: 36.3s	remaining: 20.4s
# 1700:	total: 38.6s	remaining: 18.1s
# 1800:	total: 40.6s	remaining: 15.8s
# 1900:	total: 42.7s	remaining: 13.5s
# 2000:	total: 44.9s	remaining: 11.2s
# 2100:	total: 47.1s	remaining: 8.94s
# 2200:	total: 49.4s	remaining: 6.72s
# 2300:	total: 51.5s	remaining: 4.45s
# 2400:	total: 53.7s	remaining: 2.21s
# 2499:	total: 55.8s	remaining: 0us
# 0:	total: 24.6ms	remaining: 1m 1s
# 100:	total: 2.24s	remaining: 53.1s
# 200:	total: 4.57s	remaining: 52.3s
# 300:	total: 6.72s	remaining: 49.1s
# 400:	total: 8.75s	remaining: 45.8s
# 500:	total: 11s	remaining: 43.8s
# 600:	total: 13.3s	remaining: 42.1s
# 700:	total: 15.8s	remaining: 40.5s
# 800:	total: 18s	remaining: 38.1s
# 900:	total: 20.2s	remaining: 35.9s
# 1000:	total: 22.5s	remaining: 33.6s
# 1100:	total: 24.9s	remaining: 31.7s
# 1200:	total: 27.2s	remaining: 29.4s
# 1300:	total: 29.5s	remaining: 27.2s
# 1400:	total: 31.7s	remaining: 24.9s
# 1500:	total: 34s	remaining: 22.6s
# 1600:	total: 36.2s	remaining: 20.3s
# 1700:	total: 38.6s	remaining: 18.1s
# 1800:	total: 40.9s	remaining: 15.9s
# 1900:	total: 43.2s	remaining: 13.6s
# 2000:	total: 45.4s	remaining: 11.3s
# 2100:	total: 47.8s	remaining: 9.07s
# 2200:	total: 50.2s	remaining: 6.82s
# 2300:	total: 52.4s	remaining: 4.54s
# 2400:	total: 54.8s	remaining: 2.26s
# 2499:	total: 56.9s	remaining: 0us
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py:687: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py", line 191, in probe
#     target = self._cache[_hashable(x)]
# KeyError: (0.4224347626508457, 7.60162246721079, 0.010113116694354093)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_scorer.py", line 88, in __call__
#     *args, **kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_scorer.py", line 362, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_ranking.py", line 545, in roc_auc_score
#     sample_weight=sample_weight)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#   UserWarning,
# 0:	total: 22.7ms	remaining: 56.8s
# 100:	total: 2.16s	remaining: 51.3s
# 200:	total: 4.3s	remaining: 49.2s
# 300:	total: 6.3s	remaining: 46.1s
# 400:	total: 8.43s	remaining: 44.1s
# 500:	total: 10.6s	remaining: 42.3s
# 600:	total: 12.8s	remaining: 40.5s
# 700:	total: 15s	remaining: 38.5s
# 800:	total: 17.2s	remaining: 36.5s
# 900:	total: 19.5s	remaining: 34.5s
# 1000:	total: 21.6s	remaining: 32.4s
# 1100:	total: 23.8s	remaining: 30.3s
# 1200:	total: 26s	remaining: 28.1s
# 1300:	total: 28.1s	remaining: 25.9s
# 1400:	total: 30.5s	remaining: 23.9s
# 1500:	total: 32.7s	remaining: 21.8s
# 1600:	total: 35s	remaining: 19.7s
# 1700:	total: 37.2s	remaining: 17.5s
# 1800:	total: 39.6s	remaining: 15.4s
# 1900:	total: 41.7s	remaining: 13.1s
# 2000:	total: 43.8s	remaining: 10.9s
# 2100:	total: 46.1s	remaining: 8.75s
# 2200:	total: 48.3s	remaining: 6.57s
# 2300:	total: 50.6s	remaining: 4.38s
# 2400:	total: 52.8s	remaining: 2.18s
# 2499:	total: 54.9s	remaining: 0us
# 0:	total: 28.2ms	remaining: 1m 10s
# 100:	total: 2.18s	remaining: 51.9s
# 200:	total: 4.47s	remaining: 51.1s
# 300:	total: 6.68s	remaining: 48.8s
# 400:	total: 9s	remaining: 47.1s
# 500:	total: 11.4s	remaining: 45.3s
# 600:	total: 13.7s	remaining: 43.3s
# 700:	total: 15.9s	remaining: 40.8s
# 800:	total: 18.2s	remaining: 38.5s
# 900:	total: 20.7s	remaining: 36.7s
# 1000:	total: 23s	remaining: 34.4s
# 1100:	total: 25.2s	remaining: 32s
# 1200:	total: 27.4s	remaining: 29.6s
# 1300:	total: 29.6s	remaining: 27.3s
# 1400:	total: 31.5s	remaining: 24.7s
# 1500:	total: 33.9s	remaining: 22.5s
# 1600:	total: 35.9s	remaining: 20.2s
# 1700:	total: 38s	remaining: 17.8s
# 1800:	total: 39.8s	remaining: 15.5s
# 1900:	total: 41.8s	remaining: 13.2s
# 2000:	total: 43.9s	remaining: 10.9s
# 2100:	total: 45.8s	remaining: 8.7s
# 2200:	total: 47.7s	remaining: 6.47s
# 2300:	total: 49.8s	remaining: 4.31s
# 2400:	total: 51.9s	remaining: 2.14s
# 2499:	total: 54.1s	remaining: 0us
# 0:	total: 58.3ms	remaining: 2m 25s
# 100:	total: 2.27s	remaining: 54s
# 200:	total: 4.6s	remaining: 52.6s
# 300:	total: 6.86s	remaining: 50.1s
# 400:	total: 9.04s	remaining: 47.3s
# 500:	total: 11.3s	remaining: 45.2s
# 600:	total: 13.6s	remaining: 42.9s
# 700:	total: 15.9s	remaining: 40.7s
# 800:	total: 18.1s	remaining: 38.4s
# 900:	total: 20.5s	remaining: 36.3s
# 1000:	total: 22.7s	remaining: 34s
# 1100:	total: 24.8s	remaining: 31.5s
# 1200:	total: 27s	remaining: 29.2s
# 1300:	total: 29.1s	remaining: 26.8s
# 1400:	total: 31.3s	remaining: 24.5s
# 1500:	total: 33.4s	remaining: 22.2s
# 1600:	total: 35.7s	remaining: 20s
# 1700:	total: 38.1s	remaining: 17.9s
# 1800:	total: 40.2s	remaining: 15.6s
# 1900:	total: 42.7s	remaining: 13.5s
# 2000:	total: 44.8s	remaining: 11.2s
# 2100:	total: 47.2s	remaining: 8.97s
# 2200:	total: 49.4s	remaining: 6.72s
# 2300:	total: 51.7s	remaining: 4.47s
# 2400:	total: 53.9s	remaining: 2.22s
# 2499:	total: 56.4s	remaining: 0us
# 0:	total: 25.1ms	remaining: 1m 2s
# 100:	total: 2.31s	remaining: 54.8s
# 200:	total: 4.7s	remaining: 53.8s
# 300:	total: 6.96s	remaining: 50.9s
# 400:	total: 9.1s	remaining: 47.6s
# 500:	total: 11.3s	remaining: 45s
# 600:	total: 13.6s	remaining: 42.9s
# 700:	total: 15.7s	remaining: 40.4s
# 800:	total: 18s	remaining: 38.1s
# 900:	total: 20.4s	remaining: 36.2s
# 1000:	total: 22.8s	remaining: 34.2s
# 1100:	total: 25.2s	remaining: 32s
# 1200:	total: 27.6s	remaining: 29.9s
# 1300:	total: 29.9s	remaining: 27.6s
# 1400:	total: 32s	remaining: 25.1s
# 1500:	total: 34.2s	remaining: 22.7s
# 1600:	total: 36.4s	remaining: 20.4s
# 1700:	total: 38.6s	remaining: 18.1s
# 1800:	total: 40.8s	remaining: 15.8s
# 1900:	total: 43s	remaining: 13.5s
# 2000:	total: 45s	remaining: 11.2s
# 2100:	total: 47.3s	remaining: 8.98s
# 2200:	total: 49.7s	remaining: 6.75s
# 2300:	total: 51.9s	remaining: 4.49s
# 2400:	total: 54.1s	remaining: 2.23s
# 2499:	total: 56.7s	remaining: 0us
# 0:	total: 30.7ms	remaining: 1m 16s
# 100:	total: 2.5s	remaining: 59.5s
# 200:	total: 4.82s	remaining: 55.1s
# 300:	total: 6.91s	remaining: 50.5s
# 400:	total: 9.03s	remaining: 47.3s
# 500:	total: 11.1s	remaining: 44.3s
# 600:	total: 13.3s	remaining: 42s
# 700:	total: 15.7s	remaining: 40.3s
# 800:	total: 18.1s	remaining: 38.3s
# 900:	total: 20.3s	remaining: 36.1s
# 1000:	total: 22.7s	remaining: 34.1s
# 1100:	total: 25.1s	remaining: 31.9s
# 1200:	total: 27.4s	remaining: 29.6s
# 1300:	total: 29.8s	remaining: 27.5s
# 1400:	total: 32s	remaining: 25.1s
# 1500:	total: 34.4s	remaining: 22.9s
# 1600:	total: 36.7s	remaining: 20.6s
# 1700:	total: 39s	remaining: 18.3s
# 1800:	total: 41.2s	remaining: 16s
# 1900:	total: 43.3s	remaining: 13.7s
# 2000:	total: 45.6s	remaining: 11.4s
# 2100:	total: 47.7s	remaining: 9.06s
# 2200:	total: 49.8s	remaining: 6.77s
# 2300:	total: 52.1s	remaining: 4.5s
# 2400:	total: 54.1s	remaining: 2.23s
# 2499:	total: 56.1s	remaining: 0us
# 0:	total: 27.1ms	remaining: 1m 7s
# 100:	total: 2.39s	remaining: 56.8s
# 200:	total: 4.57s	remaining: 52.2s
# 300:	total: 6.78s	remaining: 49.5s
# 400:	total: 9.18s	remaining: 48s
# 500:	total: 11.6s	remaining: 46.3s
# 600:	total: 14s	remaining: 44.3s
# 700:	total: 16.4s	remaining: 42.2s
# 800:	total: 18.6s	remaining: 39.5s
# 900:	total: 21s	remaining: 37.2s
# 1000:	total: 23.2s	remaining: 34.7s
# 1100:	total: 25.3s	remaining: 32.2s
# 1200:	total: 27.4s	remaining: 29.7s
# 1300:	total: 29.7s	remaining: 27.4s
# 1400:	total: 32s	remaining: 25.1s
# 1500:	total: 34.5s	remaining: 22.9s
# 1600:	total: 36.8s	remaining: 20.6s
# 1700:	total: 39s	remaining: 18.3s
# 1800:	total: 41.3s	remaining: 16s
# 1900:	total: 43.6s	remaining: 13.7s
# 2000:	total: 45.8s	remaining: 11.4s
# 2100:	total: 47.9s	remaining: 9.09s
# 2200:	total: 50.1s	remaining: 6.8s
# 2300:	total: 52s	remaining: 4.5s
# 2400:	total: 53.9s	remaining: 2.22s
# 2499:	total: 55.8s	remaining: 0us
# 0:	total: 62.7ms	remaining: 2m 36s
# 100:	total: 1.95s	remaining: 46.4s
# 200:	total: 3.86s	remaining: 44.1s
# 300:	total: 5.84s	remaining: 42.7s
# 400:	total: 7.99s	remaining: 41.8s
# 500:	total: 10.3s	remaining: 41.1s
# 600:	total: 12.3s	remaining: 38.7s
# 700:	total: 14.3s	remaining: 36.7s
# 800:	total: 16.4s	remaining: 34.8s
# 900:	total: 18.5s	remaining: 32.8s
# 1000:	total: 20.5s	remaining: 30.7s
# 1100:	total: 22.8s	remaining: 28.9s
# 1200:	total: 24.9s	remaining: 26.9s
# 1300:	total: 27.1s	remaining: 25s
# 1400:	total: 29.2s	remaining: 22.9s
# 1500:	total: 31.5s	remaining: 20.9s
# 1600:	total: 33.5s	remaining: 18.8s
# 1700:	total: 35.7s	remaining: 16.8s
# 1800:	total: 37.9s	remaining: 14.7s
# 1900:	total: 40.1s	remaining: 12.6s
# 2000:	total: 42.1s	remaining: 10.5s
# 2100:	total: 44.6s	remaining: 8.46s
# 2200:	total: 46.8s	remaining: 6.35s
# 2300:	total: 48.9s	remaining: 4.23s
# 2400:	total: 50.9s	remaining: 2.1s
# 2499:	total: 53.2s	remaining: 0us
# 0:	total: 26.1ms	remaining: 1m 5s
# 100:	total: 2.14s	remaining: 50.8s
# 200:	total: 4.41s	remaining: 50.4s
# 300:	total: 6.4s	remaining: 46.8s
# 400:	total: 8.73s	remaining: 45.7s
# 500:	total: 10.9s	remaining: 43.7s
# 600:	total: 13.3s	remaining: 42.1s
# 700:	total: 15.7s	remaining: 40.3s
# 800:	total: 18.1s	remaining: 38.4s
# 900:	total: 20.2s	remaining: 35.9s
# 1000:	total: 22.5s	remaining: 33.6s
# 1100:	total: 24.6s	remaining: 31.2s
# 1200:	total: 26.8s	remaining: 29s
# 1300:	total: 28.7s	remaining: 26.5s
# 1400:	total: 30.8s	remaining: 24.1s
# 1500:	total: 32.8s	remaining: 21.8s
# 1600:	total: 34.9s	remaining: 19.6s
# 1700:	total: 37.1s	remaining: 17.4s
# 1800:	total: 39.5s	remaining: 15.3s
# 1900:	total: 42.1s	remaining: 13.3s
# 2000:	total: 44.4s	remaining: 11.1s
# 2100:	total: 46.6s	remaining: 8.85s
# 2200:	total: 48.8s	remaining: 6.63s
# 2300:	total: 51s	remaining: 4.41s
# 2400:	total: 53.3s	remaining: 2.2s
# 2499:	total: 55.5s	remaining: 0us
# 0:	total: 22.6ms	remaining: 56.4s
# 100:	total: 2.23s	remaining: 53s
# 200:	total: 4.46s	remaining: 51s
# 300:	total: 6.61s	remaining: 48.3s
# 400:	total: 8.83s	remaining: 46.2s
# 500:	total: 10.9s	remaining: 43.6s
# 600:	total: 13.3s	remaining: 42.1s
# 700:	total: 15.6s	remaining: 40s
# 800:	total: 17.7s	remaining: 37.5s
# 900:	total: 20s	remaining: 35.4s
# 1000:	total: 22.5s	remaining: 33.7s
# 1100:	total: 24.7s	remaining: 31.4s
# 1200:	total: 27s	remaining: 29.2s
# 1300:	total: 29.4s	remaining: 27.1s
# 1400:	total: 31.6s	remaining: 24.8s
# 1500:	total: 33.9s	remaining: 22.5s
# 1600:	total: 36.2s	remaining: 20.3s
# 1700:	total: 38.3s	remaining: 18s
# 1800:	total: 40.6s	remaining: 15.8s
# 1900:	total: 42.9s	remaining: 13.5s
# 2000:	total: 45.4s	remaining: 11.3s
# 2100:	total: 47.8s	remaining: 9.07s
# 2200:	total: 50.2s	remaining: 6.82s
# 2300:	total: 52.5s	remaining: 4.54s
# 2400:	total: 54.9s	remaining: 2.27s
# 2499:	total: 57.1s	remaining: 0us
# 0:	total: 49.3ms	remaining: 2m 3s
# 100:	total: 2.36s	remaining: 56.1s
# 200:	total: 4.79s	remaining: 54.7s
# 300:	total: 7.14s	remaining: 52.2s
# 400:	total: 9.4s	remaining: 49.2s
# 500:	total: 11.7s	remaining: 46.6s
# 600:	total: 13.9s	remaining: 44.1s
# 700:	total: 16.3s	remaining: 41.8s
# 800:	total: 18.5s	remaining: 39.1s
# 900:	total: 20.6s	remaining: 36.5s
# 1000:	total: 22.7s	remaining: 34s
# 1100:	total: 24.9s	remaining: 31.6s
# 1200:	total: 27.1s	remaining: 29.3s
# 1300:	total: 29.2s	remaining: 26.9s
# 1400:	total: 31.4s	remaining: 24.6s
# 1500:	total: 33.6s	remaining: 22.4s
# 1600:	total: 35.9s	remaining: 20.1s
# 1700:	total: 38.1s	remaining: 17.9s
# 1800:	total: 40.5s	remaining: 15.7s
# 1900:	total: 42.8s	remaining: 13.5s
# 2000:	total: 45.3s	remaining: 11.3s
# 2100:	total: 47.8s	remaining: 9.09s
# 2200:	total: 50.4s	remaining: 6.85s
# 2300:	total: 52.8s	remaining: 4.57s
# 2400:	total: 55.1s	remaining: 2.27s
# 2499:	total: 57.5s	remaining: 0us
# 0:	total: 64.7ms	remaining: 2m 41s
# 100:	total: 2.43s	remaining: 57.7s
# 200:	total: 4.67s	remaining: 53.4s
# 300:	total: 6.98s	remaining: 51s
# 400:	total: 9.42s	remaining: 49.3s
# 500:	total: 11.9s	remaining: 47.5s
# 600:	total: 14.3s	remaining: 45.2s
# 700:	total: 16.6s	remaining: 42.6s
# 800:	total: 18.8s	remaining: 39.9s
# 900:	total: 21.3s	remaining: 37.7s
# 1000:	total: 23.6s	remaining: 35.3s
# 1100:	total: 25.9s	remaining: 33s
# 1200:	total: 28.3s	remaining: 30.6s
# 1300:	total: 30.5s	remaining: 28.2s
# 1400:	total: 32.7s	remaining: 25.6s
# 1500:	total: 34.8s	remaining: 23.2s
# 1600:	total: 36.7s	remaining: 20.6s
# 1700:	total: 38.3s	remaining: 18s
# 1800:	total: 39.8s	remaining: 15.5s
# 1900:	total: 41.8s	remaining: 13.2s
# 2000:	total: 43.3s	remaining: 10.8s
# 2100:	total: 45s	remaining: 8.54s
# 2200:	total: 46.4s	remaining: 6.3s
# 2300:	total: 48.1s	remaining: 4.16s
# 2400:	total: 49.9s	remaining: 2.06s
# 2499:	total: 51.9s	remaining: 0us
# |  1        |  nan      |  0.4224   |  7.602    |  0.01011  |
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_split.py:668: UserWarning: The least populated class in y has only 19 members, which is less than n_splits=20.
#   % (min_groups, self.n_splits)), UserWarning)
# 0:	total: 7.3ms	remaining: 18.2s
# 100:	total: 447ms	remaining: 10.6s
# 200:	total: 869ms	remaining: 9.94s
# 300:	total: 1.27s	remaining: 9.31s
# 400:	total: 1.74s	remaining: 9.08s
# 500:	total: 2.15s	remaining: 8.6s
# 600:	total: 2.6s	remaining: 8.22s
# 700:	total: 3.06s	remaining: 7.85s
# 800:	total: 3.51s	remaining: 7.45s
# 900:	total: 3.93s	remaining: 6.98s
# 1000:	total: 4.48s	remaining: 6.71s
# 1100:	total: 4.89s	remaining: 6.21s
# 1200:	total: 5.37s	remaining: 5.81s
# 1300:	total: 5.84s	remaining: 5.38s
# 1400:	total: 6.3s	remaining: 4.94s
# 1500:	total: 6.74s	remaining: 4.48s
# 1600:	total: 7.17s	remaining: 4.03s
# 1700:	total: 7.59s	remaining: 3.56s
# 1800:	total: 8.03s	remaining: 3.12s
# 1900:	total: 8.47s	remaining: 2.67s
# 2000:	total: 8.91s	remaining: 2.22s
# 2100:	total: 9.35s	remaining: 1.77s
# 2200:	total: 9.78s	remaining: 1.33s
# 2300:	total: 10.3s	remaining: 887ms
# 2400:	total: 10.7s	remaining: 442ms
# 2499:	total: 11.2s	remaining: 0us
# 0:	total: 7ms	remaining: 17.5s
# 100:	total: 414ms	remaining: 9.84s
# 200:	total: 909ms	remaining: 10.4s
# 300:	total: 1.35s	remaining: 9.87s
# 400:	total: 1.81s	remaining: 9.46s
# 500:	total: 2.36s	remaining: 9.41s
# 600:	total: 2.8s	remaining: 8.85s
# 700:	total: 3.29s	remaining: 8.46s
# 800:	total: 3.73s	remaining: 7.92s
# 900:	total: 4.23s	remaining: 7.51s
# 1000:	total: 4.7s	remaining: 7.04s
# 1100:	total: 5.15s	remaining: 6.54s
# 1200:	total: 5.6s	remaining: 6.06s
# 1300:	total: 6.07s	remaining: 5.59s
# 1400:	total: 6.49s	remaining: 5.09s
# 1500:	total: 6.9s	remaining: 4.59s
# 1600:	total: 7.35s	remaining: 4.13s
# 1700:	total: 7.83s	remaining: 3.68s
# 1800:	total: 8.26s	remaining: 3.2s
# 1900:	total: 8.69s	remaining: 2.74s
# 2000:	total: 9.13s	remaining: 2.28s
# 2100:	total: 9.55s	remaining: 1.81s
# 2200:	total: 10.1s	remaining: 1.37s
# 2300:	total: 10.5s	remaining: 907ms
# 2400:	total: 10.9s	remaining: 450ms
# 2499:	total: 11.3s	remaining: 0us
# 0:	total: 6.11ms	remaining: 15.3s
# 100:	total: 518ms	remaining: 12.3s
# 200:	total: 1.01s	remaining: 11.6s
# 300:	total: 1.5s	remaining: 11s
# 400:	total: 1.97s	remaining: 10.3s
# 500:	total: 2.46s	remaining: 9.84s
# 600:	total: 2.92s	remaining: 9.23s
# 700:	total: 3.42s	remaining: 8.76s
# 800:	total: 3.85s	remaining: 8.17s
# 900:	total: 4.33s	remaining: 7.68s
# 1000:	total: 4.85s	remaining: 7.26s
# 1100:	total: 5.31s	remaining: 6.75s
# 1200:	total: 5.75s	remaining: 6.21s
# 1300:	total: 6.17s	remaining: 5.69s
# 1400:	total: 6.72s	remaining: 5.28s
# 1500:	total: 7.23s	remaining: 4.81s
# 1600:	total: 7.78s	remaining: 4.37s
# 1700:	total: 8.24s	remaining: 3.87s
# 1800:	total: 8.72s	remaining: 3.38s
# 1900:	total: 9.23s	remaining: 2.91s
# 2000:	total: 9.78s	remaining: 2.44s
# 2100:	total: 10.3s	remaining: 1.96s
# 2200:	total: 10.8s	remaining: 1.47s
# 2300:	total: 11.3s	remaining: 978ms
# 2400:	total: 11.8s	remaining: 487ms
# 2499:	total: 12.4s	remaining: 0us
# 0:	total: 7.01ms	remaining: 17.5s
# 100:	total: 485ms	remaining: 11.5s
# 200:	total: 970ms	remaining: 11.1s
# 300:	total: 1.49s	remaining: 10.9s
# 400:	total: 2s	remaining: 10.5s
# 500:	total: 2.49s	remaining: 9.95s
# 600:	total: 2.98s	remaining: 9.4s
# 700:	total: 3.4s	remaining: 8.72s
# 800:	total: 3.82s	remaining: 8.11s
# 900:	total: 4.37s	remaining: 7.75s
# 1000:	total: 4.86s	remaining: 7.27s
# 1100:	total: 5.29s	remaining: 6.72s
# 1200:	total: 5.71s	remaining: 6.18s
# 1300:	total: 6.13s	remaining: 5.65s
# 1400:	total: 6.58s	remaining: 5.16s
# 1500:	total: 7.12s	remaining: 4.74s
# 1600:	total: 7.64s	remaining: 4.29s
# 1700:	total: 8.17s	remaining: 3.84s
# 1800:	total: 8.66s	remaining: 3.36s
# 1900:	total: 9.1s	remaining: 2.87s
# 2000:	total: 9.52s	remaining: 2.38s
# 2100:	total: 9.97s	remaining: 1.89s
# 2200:	total: 10.4s	remaining: 1.41s
# 2300:	total: 10.9s	remaining: 944ms
# 2400:	total: 11.4s	remaining: 470ms
# 2499:	total: 11.9s	remaining: 0us
# 0:	total: 5.95ms	remaining: 14.9s
# 100:	total: 450ms	remaining: 10.7s
# 200:	total: 891ms	remaining: 10.2s
# 300:	total: 1.32s	remaining: 9.66s
# 400:	total: 1.76s	remaining: 9.22s
# 500:	total: 2.18s	remaining: 8.71s
# 600:	total: 2.61s	remaining: 8.24s
# 700:	total: 3.02s	remaining: 7.76s
# 800:	total: 3.47s	remaining: 7.36s
# 900:	total: 3.95s	remaining: 7.02s
# 1000:	total: 4.44s	remaining: 6.65s
# 1100:	total: 4.92s	remaining: 6.25s
# 1200:	total: 5.35s	remaining: 5.78s
# 1300:	total: 5.77s	remaining: 5.32s
# 1400:	total: 6.19s	remaining: 4.85s
# 1500:	total: 6.62s	remaining: 4.4s
# 1600:	total: 7.1s	remaining: 3.98s
# 1700:	total: 7.64s	remaining: 3.59s
# 1800:	total: 8.18s	remaining: 3.17s
# 1900:	total: 8.77s	remaining: 2.76s
# 2000:	total: 9.23s	remaining: 2.3s
# 2100:	total: 9.72s	remaining: 1.85s
# 2200:	total: 10.1s	remaining: 1.38s
# 2300:	total: 10.6s	remaining: 920ms
# 2400:	total: 11.1s	remaining: 457ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 15.8ms	remaining: 39.5s
# 100:	total: 455ms	remaining: 10.8s
# 200:	total: 886ms	remaining: 10.1s
# 300:	total: 1.3s	remaining: 9.53s
# 400:	total: 1.71s	remaining: 8.94s
# 500:	total: 2.17s	remaining: 8.66s
# 600:	total: 2.6s	remaining: 8.22s
# 700:	total: 3.08s	remaining: 7.9s
# 800:	total: 3.5s	remaining: 7.43s
# 900:	total: 3.91s	remaining: 6.95s
# 1000:	total: 4.32s	remaining: 6.47s
# 1100:	total: 4.79s	remaining: 6.08s
# 1200:	total: 5.29s	remaining: 5.72s
# 1300:	total: 5.77s	remaining: 5.32s
# 1400:	total: 6.22s	remaining: 4.88s
# 1500:	total: 6.71s	remaining: 4.47s
# 1600:	total: 7.2s	remaining: 4.04s
# 1700:	total: 7.66s	remaining: 3.6s
# 1800:	total: 8.17s	remaining: 3.17s
# 1900:	total: 8.67s	remaining: 2.73s
# 2000:	total: 9.09s	remaining: 2.27s
# 2100:	total: 9.55s	remaining: 1.81s
# 2200:	total: 9.96s	remaining: 1.35s
# 2300:	total: 10.4s	remaining: 899ms
# 2400:	total: 10.8s	remaining: 447ms
# 2499:	total: 11.3s	remaining: 0us
# 0:	total: 5.4ms	remaining: 13.5s
# 100:	total: 476ms	remaining: 11.3s
# 200:	total: 1.02s	remaining: 11.7s
# 300:	total: 1.48s	remaining: 10.8s
# 400:	total: 1.89s	remaining: 9.88s
# 500:	total: 2.29s	remaining: 9.14s
# 600:	total: 2.71s	remaining: 8.56s
# 700:	total: 3.23s	remaining: 8.3s
# 800:	total: 3.74s	remaining: 7.94s
# 900:	total: 4.16s	remaining: 7.39s
# 1000:	total: 4.59s	remaining: 6.88s
# 1100:	total: 5.01s	remaining: 6.36s
# 1200:	total: 5.5s	remaining: 5.95s
# 1300:	total: 5.97s	remaining: 5.5s
# 1400:	total: 6.42s	remaining: 5.04s
# 1500:	total: 6.89s	remaining: 4.59s
# 1600:	total: 7.36s	remaining: 4.13s
# 1700:	total: 7.86s	remaining: 3.69s
# 1800:	total: 8.3s	remaining: 3.22s
# 1900:	total: 8.73s	remaining: 2.75s
# 2000:	total: 9.16s	remaining: 2.28s
# 2100:	total: 9.63s	remaining: 1.83s
# 2200:	total: 10.1s	remaining: 1.37s
# 2300:	total: 10.5s	remaining: 910ms
# 2400:	total: 11s	remaining: 454ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 20.9ms	remaining: 52.1s
# 100:	total: 474ms	remaining: 11.2s
# 200:	total: 879ms	remaining: 10.1s
# 300:	total: 1.29s	remaining: 9.41s
# 400:	total: 1.71s	remaining: 8.93s
# 500:	total: 2.13s	remaining: 8.49s
# 600:	total: 2.55s	remaining: 8.07s
# 700:	total: 2.97s	remaining: 7.62s
# 800:	total: 3.39s	remaining: 7.18s
# 900:	total: 3.9s	remaining: 6.93s
# 1000:	total: 4.42s	remaining: 6.62s
# 1100:	total: 4.87s	remaining: 6.19s
# 1200:	total: 5.32s	remaining: 5.75s
# 1300:	total: 5.76s	remaining: 5.31s
# 1400:	total: 6.22s	remaining: 4.88s
# 1500:	total: 6.73s	remaining: 4.48s
# 1600:	total: 7.15s	remaining: 4.01s
# 1700:	total: 7.77s	remaining: 3.65s
# 1800:	total: 8.2s	remaining: 3.18s
# 1900:	total: 8.81s	remaining: 2.77s
# 2000:	total: 9.35s	remaining: 2.33s
# 2100:	total: 9.85s	remaining: 1.87s
# 2200:	total: 10.3s	remaining: 1.4s
# 2300:	total: 10.8s	remaining: 930ms
# 2400:	total: 11.2s	remaining: 461ms
# 2499:	total: 11.6s	remaining: 0us
# 0:	total: 15ms	remaining: 37.6s
# 100:	total: 462ms	remaining: 11s
# 200:	total: 917ms	remaining: 10.5s
# 300:	total: 1.35s	remaining: 9.88s
# 400:	total: 1.86s	remaining: 9.76s
# 500:	total: 2.33s	remaining: 9.32s
# 600:	total: 2.75s	remaining: 8.69s
# 700:	total: 3.17s	remaining: 8.13s
# 800:	total: 3.69s	remaining: 7.83s
# 900:	total: 4.21s	remaining: 7.48s
# 1000:	total: 4.68s	remaining: 7.01s
# 1100:	total: 5.25s	remaining: 6.67s
# 1200:	total: 5.73s	remaining: 6.2s
# 1300:	total: 6.18s	remaining: 5.7s
# 1400:	total: 6.69s	remaining: 5.25s
# 1500:	total: 7.12s	remaining: 4.74s
# 1600:	total: 7.64s	remaining: 4.29s
# 1700:	total: 8.1s	remaining: 3.8s
# 1800:	total: 8.61s	remaining: 3.34s
# 1900:	total: 9.1s	remaining: 2.87s
# 2000:	total: 9.57s	remaining: 2.39s
# 2100:	total: 10.1s	remaining: 1.92s
# 2200:	total: 10.6s	remaining: 1.44s
# 2300:	total: 11.2s	remaining: 965ms
# 2400:	total: 11.6s	remaining: 479ms
# 2499:	total: 12s	remaining: 0us
# 0:	total: 5.47ms	remaining: 13.7s
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py:687: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py", line 191, in probe
#     target = self._cache[_hashable(x)]
# KeyError: (0.3090069143328895, 4.733779454085565, 0.10132287022634101)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_scorer.py", line 88, in __call__
#     *args, **kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_scorer.py", line 362, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_ranking.py", line 545, in roc_auc_score
#     sample_weight=sample_weight)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#   File "D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\metrics\_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#   UserWarning,
# 100:	total: 599ms	remaining: 14.2s
# 200:	total: 1.11s	remaining: 12.7s
# 300:	total: 1.63s	remaining: 11.9s
# 400:	total: 2.08s	remaining: 10.9s
# 500:	total: 2.54s	remaining: 10.1s
# 600:	total: 2.99s	remaining: 9.46s
# 700:	total: 3.43s	remaining: 8.81s
# 800:	total: 3.88s	remaining: 8.23s
# 900:	total: 4.36s	remaining: 7.74s
# 1000:	total: 4.83s	remaining: 7.24s
# 1100:	total: 5.44s	remaining: 6.91s
# 1200:	total: 5.95s	remaining: 6.43s
# 1300:	total: 6.46s	remaining: 5.96s
# 1400:	total: 6.93s	remaining: 5.44s
# 1500:	total: 7.42s	remaining: 4.94s
# 1600:	total: 7.89s	remaining: 4.43s
# 1700:	total: 8.34s	remaining: 3.92s
# 1800:	total: 8.96s	remaining: 3.48s
# 1900:	total: 9.42s	remaining: 2.97s
# 2000:	total: 9.87s	remaining: 2.46s
# 2100:	total: 10.4s	remaining: 1.97s
# 2200:	total: 10.9s	remaining: 1.48s
# 2300:	total: 11.4s	remaining: 985ms
# 2400:	total: 11.9s	remaining: 489ms
# 2499:	total: 12.4s	remaining: 0us
# 0:	total: 6.19ms	remaining: 15.5s
# 100:	total: 525ms	remaining: 12.5s
# 200:	total: 977ms	remaining: 11.2s
# 300:	total: 1.4s	remaining: 10.3s
# 400:	total: 1.95s	remaining: 10.2s
# 500:	total: 2.39s	remaining: 9.54s
# 600:	total: 2.91s	remaining: 9.2s
# 700:	total: 3.43s	remaining: 8.81s
# 800:	total: 3.88s	remaining: 8.22s
# 900:	total: 4.41s	remaining: 7.83s
# 1000:	total: 4.87s	remaining: 7.29s
# 1100:	total: 5.38s	remaining: 6.84s
# 1200:	total: 5.85s	remaining: 6.33s
# 1300:	total: 6.34s	remaining: 5.84s
# 1400:	total: 6.84s	remaining: 5.37s
# 1500:	total: 7.28s	remaining: 4.85s
# 1600:	total: 7.71s	remaining: 4.33s
# 1700:	total: 8.24s	remaining: 3.87s
# 1800:	total: 8.68s	remaining: 3.37s
# 1900:	total: 9.19s	remaining: 2.9s
# 2000:	total: 9.66s	remaining: 2.41s
# 2100:	total: 10.2s	remaining: 1.93s
# 2200:	total: 10.6s	remaining: 1.44s
# 2300:	total: 11.1s	remaining: 959ms
# 2400:	total: 11.5s	remaining: 476ms
# 2499:	total: 12s	remaining: 0us
# 0:	total: 6.09ms	remaining: 15.2s
# 100:	total: 472ms	remaining: 11.2s
# 200:	total: 977ms	remaining: 11.2s
# 300:	total: 1.51s	remaining: 11s
# 400:	total: 2.04s	remaining: 10.7s
# 500:	total: 2.58s	remaining: 10.3s
# 600:	total: 3.07s	remaining: 9.69s
# 700:	total: 3.54s	remaining: 9.1s
# 800:	total: 4.01s	remaining: 8.51s
# 900:	total: 4.54s	remaining: 8.06s
# 1000:	total: 5.04s	remaining: 7.54s
# 1100:	total: 5.53s	remaining: 7.02s
# 1200:	total: 5.95s	remaining: 6.44s
# 1300:	total: 6.43s	remaining: 5.93s
# 1400:	total: 6.89s	remaining: 5.41s
# 1500:	total: 7.32s	remaining: 4.87s
# 1600:	total: 7.85s	remaining: 4.41s
# 1700:	total: 8.38s	remaining: 3.94s
# 1800:	total: 8.86s	remaining: 3.44s
# 1900:	total: 9.33s	remaining: 2.94s
# 2000:	total: 9.81s	remaining: 2.45s
# 2100:	total: 10.3s	remaining: 1.96s
# 2200:	total: 10.8s	remaining: 1.47s
# 2300:	total: 11.3s	remaining: 974ms
# 2400:	total: 11.7s	remaining: 482ms
# 2499:	total: 12.1s	remaining: 0us
# 0:	total: 5.6ms	remaining: 14s
# 100:	total: 451ms	remaining: 10.7s
# 200:	total: 899ms	remaining: 10.3s
# 300:	total: 1.39s	remaining: 10.2s
# 400:	total: 1.86s	remaining: 9.73s
# 500:	total: 2.33s	remaining: 9.3s
# 600:	total: 2.79s	remaining: 8.82s
# 700:	total: 3.22s	remaining: 8.27s
# 800:	total: 3.65s	remaining: 7.75s
# 900:	total: 4.14s	remaining: 7.35s
# 1000:	total: 4.57s	remaining: 6.85s
# 1100:	total: 5.01s	remaining: 6.36s
# 1200:	total: 5.49s	remaining: 5.93s
# 1300:	total: 5.98s	remaining: 5.51s
# 1400:	total: 6.51s	remaining: 5.11s
# 1500:	total: 6.96s	remaining: 4.63s
# 1600:	total: 7.49s	remaining: 4.21s
# 1700:	total: 8s	remaining: 3.76s
# 1800:	total: 8.49s	remaining: 3.3s
# 1900:	total: 8.99s	remaining: 2.83s
# 2000:	total: 9.48s	remaining: 2.36s
# 2100:	total: 10s	remaining: 1.9s
# 2200:	total: 10.5s	remaining: 1.42s
# 2300:	total: 10.9s	remaining: 945ms
# 2400:	total: 11.4s	remaining: 470ms
# 2499:	total: 11.8s	remaining: 0us
# 0:	total: 5.92ms	remaining: 14.8s
# 100:	total: 509ms	remaining: 12.1s
# 200:	total: 1.01s	remaining: 11.5s
# 300:	total: 1.51s	remaining: 11s
# 400:	total: 2.08s	remaining: 10.9s
# 500:	total: 2.52s	remaining: 10s
# 600:	total: 2.95s	remaining: 9.33s
# 700:	total: 3.48s	remaining: 8.94s
# 800:	total: 3.99s	remaining: 8.46s
# 900:	total: 4.54s	remaining: 8.06s
# 1000:	total: 5.01s	remaining: 7.5s
# 1100:	total: 5.49s	remaining: 6.98s
# 1200:	total: 5.99s	remaining: 6.48s
# 1300:	total: 6.44s	remaining: 5.94s
# 1400:	total: 6.96s	remaining: 5.46s
# 1500:	total: 7.44s	remaining: 4.95s
# 1600:	total: 7.9s	remaining: 4.44s
# 1700:	total: 8.4s	remaining: 3.95s
# 1800:	total: 8.87s	remaining: 3.44s
# 1900:	total: 9.32s	remaining: 2.94s
# 2000:	total: 9.83s	remaining: 2.45s
# 2100:	total: 10.3s	remaining: 1.96s
# 2200:	total: 10.8s	remaining: 1.47s
# 2300:	total: 11.2s	remaining: 972ms
# 2400:	total: 11.7s	remaining: 482ms
# 2499:	total: 12.1s	remaining: 0us
# 0:	total: 16ms	remaining: 40.1s
# 100:	total: 439ms	remaining: 10.4s
# 200:	total: 936ms	remaining: 10.7s
# 300:	total: 1.37s	remaining: 10s
# 400:	total: 1.81s	remaining: 9.47s
# 500:	total: 2.32s	remaining: 9.26s
# 600:	total: 2.82s	remaining: 8.92s
# 700:	total: 3.32s	remaining: 8.53s
# 800:	total: 3.85s	remaining: 8.17s
# 900:	total: 4.38s	remaining: 7.78s
# 1000:	total: 4.88s	remaining: 7.3s
# 1100:	total: 5.47s	remaining: 6.95s
# 1200:	total: 5.95s	remaining: 6.44s
# 1300:	total: 6.38s	remaining: 5.88s
# 1400:	total: 6.79s	remaining: 5.33s
# 1500:	total: 7.25s	remaining: 4.82s
# 1600:	total: 7.7s	remaining: 4.32s
# 1700:	total: 8.21s	remaining: 3.85s
# 1800:	total: 8.63s	remaining: 3.35s
# 1900:	total: 9.11s	remaining: 2.87s
# 2000:	total: 9.54s	remaining: 2.38s
# 2100:	total: 9.94s	remaining: 1.89s
# 2200:	total: 10.4s	remaining: 1.41s
# 2300:	total: 10.9s	remaining: 943ms
# 2400:	total: 11.3s	remaining: 467ms
# 2499:	total: 11.7s	remaining: 0us
# 0:	total: 14.3ms	remaining: 35.6s
# 100:	total: 461ms	remaining: 11s
# 200:	total: 904ms	remaining: 10.3s
# 300:	total: 1.4s	remaining: 10.2s
# 400:	total: 1.88s	remaining: 9.87s
# 500:	total: 2.31s	remaining: 9.23s
# 600:	total: 2.78s	remaining: 8.79s
# 700:	total: 3.24s	remaining: 8.31s
# 800:	total: 3.69s	remaining: 7.83s
# 900:	total: 4.14s	remaining: 7.35s
# 1000:	total: 4.61s	remaining: 6.91s
# 1100:	total: 5.05s	remaining: 6.41s
# 1200:	total: 5.51s	remaining: 5.96s
# 1300:	total: 6s	remaining: 5.53s
# 1400:	total: 6.43s	remaining: 5.05s
# 1500:	total: 6.91s	remaining: 4.6s
# 1600:	total: 7.32s	remaining: 4.11s
# 1700:	total: 7.82s	remaining: 3.67s
# 1800:	total: 8.24s	remaining: 3.2s
# 1900:	total: 8.81s	remaining: 2.78s
# 2000:	total: 9.26s	remaining: 2.31s
# 2100:	total: 9.71s	remaining: 1.84s
# 2200:	total: 10.1s	remaining: 1.38s
# 2300:	total: 10.6s	remaining: 915ms
# 2400:	total: 11.1s	remaining: 456ms
# 2499:	total: 11.5s	remaining: 0us
# 0:	total: 7.35ms	remaining: 18.4s
# 100:	total: 439ms	remaining: 10.4s
# 200:	total: 854ms	remaining: 9.77s
# 300:	total: 1.37s	remaining: 10s
# 400:	total: 1.81s	remaining: 9.5s
# 500:	total: 2.27s	remaining: 9.07s
# 600:	total: 2.87s	remaining: 9.07s
# 700:	total: 3.33s	remaining: 8.55s
# 800:	total: 3.78s	remaining: 8.03s
# 900:	total: 4.26s	remaining: 7.57s
# 1000:	total: 4.79s	remaining: 7.18s
# 1100:	total: 5.24s	remaining: 6.66s
# 1200:	total: 5.68s	remaining: 6.15s
# 1300:	total: 6.18s	remaining: 5.7s
# 1400:	total: 6.64s	remaining: 5.21s
# 1500:	total: 7.09s	remaining: 4.72s
# 1600:	total: 7.51s	remaining: 4.22s
# 1700:	total: 8.02s	remaining: 3.77s
# 1800:	total: 8.46s	remaining: 3.28s
# 1900:	total: 8.93s	remaining: 2.81s
# 2000:	total: 9.38s	remaining: 2.34s
# 2100:	total: 9.9s	remaining: 1.88s
# 2200:	total: 10.4s	remaining: 1.41s
# 2300:	total: 10.8s	remaining: 932ms
# 2400:	total: 11.3s	remaining: 466ms
# 2499:	total: 11.8s	remaining: 0us
# 0:	total: 5.8ms	remaining: 14.5s
# 100:	total: 429ms	remaining: 10.2s
# 200:	total: 910ms	remaining: 10.4s
# 300:	total: 1.38s	remaining: 10.1s
# 400:	total: 1.91s	remaining: 10s
# 500:	total: 2.39s	remaining: 9.53s
# 600:	total: 2.88s	remaining: 9.09s
# 700:	total: 3.35s	remaining: 8.6s
# 800:	total: 3.82s	remaining: 8.1s
# 900:	total: 4.26s	remaining: 7.57s
# 1000:	total: 4.67s	remaining: 7s
# 1100:	total: 5.24s	remaining: 6.66s
# 1200:	total: 5.75s	remaining: 6.22s
# 1300:	total: 6.29s	remaining: 5.8s
# 1400:	total: 6.83s	remaining: 5.36s
# 1500:	total: 7.29s	remaining: 4.85s
# 1600:	total: 7.79s	remaining: 4.37s
# 1700:	total: 8.25s	remaining: 3.87s
# 1800:	total: 8.69s	remaining: 3.37s
# 1900:	total: 9.25s	remaining: 2.91s
# 2000:	total: 9.69s	remaining: 2.42s
# 2100:	total: 10.1s	remaining: 1.92s
# 2200:	total: 10.7s	remaining: 1.45s
# 2300:	total: 11.2s	remaining: 968ms
# 2400:	total: 11.7s	remaining: 482ms
# 2499:	total: 12.2s	remaining: 0us
# 0:	total: 6.44ms	remaining: 16.1s
# 100:	total: 473ms	remaining: 11.2s
# 200:	total: 957ms	remaining: 10.9s
# 300:	total: 1.42s	remaining: 10.4s
# 400:	total: 1.9s	remaining: 9.92s
# 500:	total: 2.37s	remaining: 9.44s
# 600:	total: 2.83s	remaining: 8.93s
# 700:	total: 3.35s	remaining: 8.61s
# 800:	total: 3.85s	remaining: 8.17s
# 900:	total: 4.33s	remaining: 7.68s
# 1000:	total: 4.82s	remaining: 7.22s
# 1100:	total: 5.28s	remaining: 6.71s
# 1200:	total: 5.78s	remaining: 6.25s
# 1300:	total: 6.3s	remaining: 5.81s
# 1400:	total: 6.79s	remaining: 5.33s
# 1500:	total: 7.22s	remaining: 4.81s
# 1600:	total: 7.74s	remaining: 4.35s
# 1700:	total: 8.19s	remaining: 3.85s
# 1800:	total: 8.67s	remaining: 3.36s
# 1900:	total: 9.2s	remaining: 2.9s
# 2000:	total: 9.61s	remaining: 2.4s
# 2100:	total: 10.1s	remaining: 1.92s
# 2200:	total: 10.7s	remaining: 1.45s
# 2300:	total: 11.2s	remaining: 966ms
# 2400:	total: 11.6s	remaining: 480ms
# 2499:	total: 12.1s	remaining: 0us
# 0:	total: 7.37ms	remaining: 18.4s
# 100:	total: 487ms	remaining: 11.6s
# 200:	total: 925ms	remaining: 10.6s
# 300:	total: 1.46s	remaining: 10.7s
# 400:	total: 1.93s	remaining: 10.1s
# 500:	total: 2.4s	remaining: 9.57s
# 600:	total: 2.85s	remaining: 9.02s
# 700:	total: 3.34s	remaining: 8.56s
# 800:	total: 3.8s	remaining: 8.06s
# 900:	total: 4.28s	remaining: 7.59s
# 1000:	total: 4.75s	remaining: 7.11s
# 1100:	total: 5.2s	remaining: 6.6s
# 1200:	total: 5.7s	remaining: 6.17s
# 1300:	total: 6.23s	remaining: 5.74s
# 1400:	total: 6.66s	remaining: 5.22s
# 1500:	total: 7.1s	remaining: 4.73s
# 1600:	total: 7.52s	remaining: 4.22s
# 1700:	total: 7.95s	remaining: 3.73s
# 1800:	total: 8.4s	remaining: 3.26s
# 1900:	total: 8.86s	remaining: 2.79s
# 2000:	total: 9.34s	remaining: 2.33s
# 2100:	total: 9.79s	remaining: 1.86s
# 2200:	total: 10.2s	remaining: 1.39s
# 2300:	total: 10.7s	remaining: 927ms
# 2400:	total: 11.2s	remaining: 463ms
# 2499:	total: 11.6s	remaining: 0us
# |  2        |  nan      |  0.309    |  4.734    |  0.1013   |
# 0:	total: 12ms	remaining: 30s
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_split.py:668: UserWarning: The least populated class in y has only 19 members, which is less than n_splits=20.
#   % (min_groups, self.n_splits)), UserWarning)
# 100:	total: 674ms	remaining: 16s
# 200:	total: 1.41s	remaining: 16.1s
# 300:	total: 2.16s	remaining: 15.8s
# 400:	total: 2.95s	remaining: 15.4s
# 500:	total: 3.75s	remaining: 15s
# 600:	total: 4.59s	remaining: 14.5s
# 700:	total: 5.37s	remaining: 13.8s
# 800:	total: 6.1s	remaining: 12.9s
# 900:	total: 6.81s	remaining: 12.1s
# 1000:	total: 7.56s	remaining: 11.3s
# 1100:	total: 8.3s	remaining: 10.5s
# 1200:	total: 9.02s	remaining: 9.75s
# 1300:	total: 9.69s	remaining: 8.93s
# 1400:	total: 10.4s	remaining: 8.13s
# 1500:	total: 11s	remaining: 7.34s
# 1600:	total: 11.8s	remaining: 6.62s
# 1700:	total: 12.6s	remaining: 5.9s
# 1800:	total: 13.3s	remaining: 5.17s
# 1900:	total: 14.2s	remaining: 4.48s
# 2000:	total: 14.9s	remaining: 3.73s
# 2100:	total: 15.7s	remaining: 2.98s
# 2200:	total: 16.3s	remaining: 2.22s
# 2300:	total: 17s	remaining: 1.47s
# 2400:	total: 17.8s	remaining: 733ms
# 2499:	total: 18.5s	remaining: 0us
# 0:	total: 9.84ms	remaining: 24.6s
# 100:	total: 797ms	remaining: 18.9s
# 200:	total: 1.48s	remaining: 16.9s
# 300:	total: 2.16s	remaining: 15.8s
# 400:	total: 2.84s	remaining: 14.8s
# 500:	total: 3.51s	remaining: 14s
# 600:	total: 4.17s	remaining: 13.2s
# 700:	total: 4.84s	remaining: 12.4s
# 800:	total: 5.57s	remaining: 11.8s
# 900:	total: 6.31s	remaining: 11.2s
# 1000:	total: 7.02s	remaining: 10.5s
# 1100:	total: 7.79s	remaining: 9.9s
# 1200:	total: 8.51s	remaining: 9.21s
# 1300:	total: 9.35s	remaining: 8.62s
# 1400:	total: 10.1s	remaining: 7.96s
# 1500:	total: 10.9s	remaining: 7.25s
# 1600:	total: 11.7s	remaining: 6.55s
# 1700:	total: 12.5s	remaining: 5.87s
# 1800:	total: 13.2s	remaining: 5.14s
# 1900:	total: 14s	remaining: 4.41s
# 2000:	total: 14.8s	remaining: 3.69s
# 2100:	total: 15.6s	remaining: 2.96s
# 2200:	total: 16.3s	remaining: 2.21s
# 2300:	total: 17s	remaining: 1.47s
# 2400:	total: 17.7s	remaining: 730ms
# 2499:	total: 18.4s	remaining: 0us
# 0:	total: 8.13ms	remaining: 20.3s
# 100:	total: 760ms	remaining: 18.1s
# 200:	total: 1.54s	remaining: 17.6s
# 300:	total: 2.25s	remaining: 16.5s
# 400:	total: 2.94s	remaining: 15.4s
# 500:	total: 3.63s	remaining: 14.5s
# 600:	total: 4.31s	remaining: 13.6s
# 700:	total: 5s	remaining: 12.8s
# 800:	total: 5.75s	remaining: 12.2s
# 900:	total: 6.53s	remaining: 11.6s
# 1000:	total: 7.3s	remaining: 10.9s
# 1100:	total: 8.02s	remaining: 10.2s
# 1200:	total: 8.73s	remaining: 9.45s
# 1300:	total: 9.43s	remaining: 8.69s
# 1400:	total: 10.2s	remaining: 8.02s
# 1500:	total: 11.1s	remaining: 7.38s
# 1600:	total: 12.1s	remaining: 6.8s
# 1700:	total: 13s	remaining: 6.12s
# 1800:	total: 13.9s	remaining: 5.4s
# 1900:	total: 14.7s	remaining: 4.64s
# 2000:	total: 15.5s	remaining: 3.86s
# 2100:	total: 16.1s	remaining: 3.07s
# 2200:	total: 16.9s	remaining: 2.29s
# 2300:	total: 17.7s	remaining: 1.53s
# 2400:	total: 18.4s	remaining: 758ms
# 2499:	total: 19.1s	remaining: 0us
# 0:	total: 9.33ms	remaining: 23.3s
# 100:	total: 708ms	remaining: 16.8s
# 200:	total: 1.38s	remaining: 15.8s
# 300:	total: 2.09s	remaining: 15.3s
# 400:	total: 2.83s	remaining: 14.8s
# 500:	total: 3.57s	remaining: 14.3s
# 600:	total: 4.28s	remaining: 13.5s
# 700:	total: 4.99s	remaining: 12.8s
# 800:	total: 5.81s	remaining: 12.3s
# 900:	total: 6.55s	remaining: 11.6s
# 1000:	total: 7.25s	remaining: 10.9s
# 1100:	total: 7.92s	remaining: 10.1s
# 1200:	total: 8.64s	remaining: 9.34s
# 1300:	total: 9.36s	remaining: 8.63s
# 1400:	total: 10.1s	remaining: 7.92s
# 1500:	total: 10.8s	remaining: 7.18s
# 1600:	total: 11.5s	remaining: 6.46s
# 1700:	total: 12.2s	remaining: 5.75s
# 1800:	total: 13s	remaining: 5.04s
# 1900:	total: 13.8s	remaining: 4.34s
# 2000:	total: 14.6s	remaining: 3.63s
# 2100:	total: 15.3s	remaining: 2.91s
# 2200:	total: 16.1s	remaining: 2.18s
# 2300:	total: 16.8s	remaining: 1.45s
# 2400:	total: 17.6s	remaining: 728ms
# 2499:	total: 18.5s	remaining: 0us
# 0:	total: 9.2ms	remaining: 23s
# 100:	total: 761ms	remaining: 18.1s
# 200:	total: 1.47s	remaining: 16.8s
# 300:	total: 2.16s	remaining: 15.8s
# 400:	total: 2.92s	remaining: 15.3s
# 500:	total: 3.6s	remaining: 14.3s
# 600:	total: 4.33s	remaining: 13.7s
# 700:	total: 4.99s	remaining: 12.8s
# 800:	total: 5.7s	remaining: 12.1s
# 900:	total: 6.39s	remaining: 11.3s
# 1000:	total: 7.08s	remaining: 10.6s
# 1100:	total: 7.82s	remaining: 9.93s
# 1200:	total: 8.53s	remaining: 9.23s
# 1300:	total: 9.23s	remaining: 8.51s
# 1400:	total: 9.92s	remaining: 7.78s
# 1500:	total: 10.6s	remaining: 7.03s
# 1600:	total: 11.4s	remaining: 6.38s
# 1700:	total: 12.2s	remaining: 5.72s
# 1800:	total: 12.9s	remaining: 5.02s
# 1900:	total: 13.7s	remaining: 4.3s
# 2000:	total: 14.4s	remaining: 3.59s
# 2100:	total: 15.1s	remaining: 2.87s
# 2200:	total: 15.8s	remaining: 2.15s
# 2300:	total: 16.6s	remaining: 1.44s
# 2400:	total: 17.4s	remaining: 718ms
# 2499:	total: 18.2s	remaining: 0us
# 0:	total: 13.4ms	remaining: 33.4s
# 100:	total: 707ms	remaining: 16.8s
# 200:	total: 1.41s	remaining: 16.2s
# 300:	total: 2.23s	remaining: 16.3s
# 400:	total: 3.05s	remaining: 16s
# 500:	total: 3.77s	remaining: 15s
# 600:	total: 4.49s	remaining: 14.2s
# 700:	total: 5.29s	remaining: 13.6s
# 800:	total: 6.05s	remaining: 12.8s
# 900:	total: 6.89s	remaining: 12.2s
# 1000:	total: 7.68s	remaining: 11.5s
# 1100:	total: 8.4s	remaining: 10.7s
# 1200:	total: 9.08s	remaining: 9.82s
# 1300:	total: 9.91s	remaining: 9.13s
# 1400:	total: 10.7s	remaining: 8.39s
# 1500:	total: 11.4s	remaining: 7.6s
# 1600:	total: 12.1s	remaining: 6.81s
# 1700:	total: 12.9s	remaining: 6.07s
# 1800:	total: 13.7s	remaining: 5.33s
# 1900:	total: 14.5s	remaining: 4.56s
# 2000:	total: 15.1s	remaining: 3.77s
# 2100:	total: 15.8s	remaining: 3s
# 2200:	total: 16.5s	remaining: 2.25s
# 2300:	total: 17.2s	remaining: 1.49s
# 2400:	total: 18s	remaining: 741ms
# 2499:	total: 18.7s	remaining: 0us
# 0:	total: 9.11ms	remaining: 22.8s
# 100:	total: 800ms	remaining: 19s
# 200:	total: 1.57s	remaining: 18s
# 300:	total: 2.3s	remaining: 16.8s
# 400:	total: 3.01s	remaining: 15.8s
# 500:	total: 3.72s	remaining: 14.8s
# 600:	total: 4.48s	remaining: 14.1s
# 700:	total: 5.34s	remaining: 13.7s
# 800:	total: 6.08s	remaining: 12.9s
# 900:	total: 6.85s	remaining: 12.2s
# 1000:	total: 7.64s	remaining: 11.4s
# 1100:	total: 8.39s	remaining: 10.7s
# 1200:	total: 9.13s	remaining: 9.87s
# 1300:	total: 9.96s	remaining: 9.18s
# 1400:	total: 10.8s	remaining: 8.47s
# 1500:	total: 11.5s	remaining: 7.68s
# 1600:	total: 12.3s	remaining: 6.9s
# 1700:	total: 13s	remaining: 6.1s
# 1800:	total: 13.8s	remaining: 5.34s
# 1900:	total: 14.6s	remaining: 4.61s
# 2000:	total: 15.4s	remaining: 3.85s
# 2100:	total: 16.2s	remaining: 3.08s
# 2200:	total: 16.9s	remaining: 2.3s
# 2300:	total: 17.7s	remaining: 1.53s
# 2400:	total: 18.5s	remaining: 763ms
# 2499:	total: 19.3s	remaining: 0us
# 0:	total: 9.23ms	remaining: 23.1s
# 100:	total: 783ms	remaining: 18.6s
# 200:	total: 1.46s	remaining: 16.8s
# 300:	total: 2.22s	remaining: 16.2s
# 400:	total: 2.98s	remaining: 15.6s
# 500:	total: 3.66s	remaining: 14.6s
# 600:	total: 4.39s	remaining: 13.9s
# 700:	total: 5.09s	remaining: 13.1s
# ...
# 900:	total: 11.3s	remaining: 20.1s
# 1000:	total: 12.4s	remaining: 18.6s
# 1100:	total: 13.8s	remaining: 17.5s
# 1200:	total: 14.9s	remaining: 16.2s
# 1300:	total: 16.1s	remaining: 14.8s
# 1400:	total: 17.3s	remaining: 13.5s
# 1500:	total: 18.4s	remaining: 12.2s
# 1600:	total: 19.5s	remaining: 11s
# 1700:	total: 20.6s	remaining: 9.7s
# 1800:	total: 21.8s	remaining: 8.45s
# 1900:	total: 22.9s	remaining: 7.22s
# 2000:	total: 24.1s	remaining: 6.01s
# 2100:	total: 25.2s	remaining: 4.79s
# 2200:	total: 26.4s	remaining: 3.58s
# 2300:	total: 27.5s	remaining: 2.38s
# 2400:	total: 28.6s	remaining: 1.18s
# 2499:	total: 29.8s	remaining: 0us
# 0:	total: 14ms	remaining: 34.9s
# 100:	total: 1.38s	remaining: 32.7s
# 200:	total: 2.91s	remaining: 33.2s
# 300:	total: 4.27s	remaining: 31.2s
# 400:	total: 5.83s	remaining: 30.5s
# 500:	total: 7.38s	remaining: 29.4s
# 600:	total: 9.04s	remaining: 28.6s
# 700:	total: 10.7s	remaining: 27.5s
# 800:	total: 12.3s	remaining: 26s
# 900:	total: 13.5s	remaining: 24s
# 1000:	total: 14.9s	remaining: 22.3s
# 1100:	total: 16.5s	remaining: 20.9s
# 1200:	total: 17.8s	remaining: 19.2s
# 1300:	total: 19.1s	remaining: 17.6s
# 1400:	total: 20.3s	remaining: 15.9s
# 1500:	total: 21.6s	remaining: 14.4s
# 1600:	total: 22.8s	remaining: 12.8s
# 1700:	total: 24s	remaining: 11.3s
# 1800:	total: 25.2s	remaining: 9.76s
# 1900:	total: 26.4s	remaining: 8.3s
# 2000:	total: 27.5s	remaining: 6.87s
# 2100:	total: 28.8s	remaining: 5.47s
# 2200:	total: 30.2s	remaining: 4.1s
# 2300:	total: 31.4s	remaining: 2.72s
# 2400:	total: 32.6s	remaining: 1.34s
# 2499:	total: 33.9s	remaining: 0us
# 0:	total: 15.1ms	remaining: 37.7s
# 100:	total: 1.41s	remaining: 33.4s
# 200:	total: 2.8s	remaining: 32s
# 300:	total: 4.01s	remaining: 29.3s
# 400:	total: 5.26s	remaining: 27.5s
# 500:	total: 6.41s	remaining: 25.6s
# 600:	total: 7.59s	remaining: 24s
# 700:	total: 8.78s	remaining: 22.5s
# 800:	total: 9.94s	remaining: 21.1s
# 900:	total: 11.2s	remaining: 19.8s
# 1000:	total: 12.3s	remaining: 18.5s
# 1100:	total: 13.6s	remaining: 17.3s
# 1200:	total: 14.8s	remaining: 16.1s
# 1300:	total: 16.2s	remaining: 15s
# 1400:	total: 17.5s	remaining: 13.8s
# 1500:	total: 18.7s	remaining: 12.5s
# 1600:	total: 19.9s	remaining: 11.2s
# 1700:	total: 21.1s	remaining: 9.92s
# 1800:	total: 22.4s	remaining: 8.68s
# 1900:	total: 23.7s	remaining: 7.47s
# 2000:	total: 24.9s	remaining: 6.2s
# 2100:	total: 26s	remaining: 4.94s
# 2200:	total: 27.1s	remaining: 3.68s
# 2300:	total: 28.2s	remaining: 2.44s
# 2400:	total: 29.4s	remaining: 1.21s
# 2499:	total: 30.5s	remaining: 0us
# 0:	total: 22.5ms	remaining: 56.3s
# 100:	total: 1.25s	remaining: 29.7s
# 200:	total: 2.43s	remaining: 27.8s
# 300:	total: 3.61s	remaining: 26.4s
# 400:	total: 4.75s	remaining: 24.9s
# 500:	total: 5.86s	remaining: 23.4s
# 600:	total: 6.98s	remaining: 22.1s
# 700:	total: 8.06s	remaining: 20.7s
# 800:	total: 9.15s	remaining: 19.4s
# 900:	total: 10.3s	remaining: 18.2s
# 1000:	total: 11.4s	remaining: 17s
# 1100:	total: 12.5s	remaining: 15.9s
# 1200:	total: 13.8s	remaining: 14.9s
# 1300:	total: 15s	remaining: 13.8s
# 1400:	total: 16.2s	remaining: 12.7s
# 1500:	total: 17.4s	remaining: 11.5s
# 1600:	total: 18.6s	remaining: 10.4s
# 1700:	total: 19.9s	remaining: 9.35s
# 1800:	total: 21.2s	remaining: 8.22s
# 1900:	total: 22.5s	remaining: 7.09s
# 2000:	total: 23.9s	remaining: 5.95s
# 2100:	total: 25.2s	remaining: 4.79s
# 2200:	total: 26.5s	remaining: 3.6s
# 2300:	total: 27.9s	remaining: 2.41s
# 2400:	total: 29.2s	remaining: 1.2s
# 2499:	total: 30.6s	remaining: 0us
# 0:	total: 19ms	remaining: 47.4s
# 100:	total: 1.42s	remaining: 33.7s
# 200:	total: 2.79s	remaining: 31.9s
# 300:	total: 4.16s	remaining: 30.4s
# 400:	total: 5.48s	remaining: 28.7s
# 500:	total: 6.95s	remaining: 27.7s
# 600:	total: 8.26s	remaining: 26.1s
# 700:	total: 9.7s	remaining: 24.9s
# 800:	total: 11.3s	remaining: 24s
# 900:	total: 12.7s	remaining: 22.6s
# 1000:	total: 14.2s	remaining: 21.3s
# 1100:	total: 15.7s	remaining: 19.9s
# 1200:	total: 17s	remaining: 18.4s
# 1300:	total: 18.4s	remaining: 17s
# 1400:	total: 19.7s	remaining: 15.5s
# 1500:	total: 21.2s	remaining: 14.1s
# 1600:	total: 22.6s	remaining: 12.7s
# 1700:	total: 24s	remaining: 11.3s
# 1800:	total: 25.5s	remaining: 9.9s
# 1900:	total: 27.8s	remaining: 8.75s
# 2000:	total: 29.1s	remaining: 7.26s
# 2100:	total: 30.5s	remaining: 5.78s
# 2200:	total: 31.7s	remaining: 4.31s
# 2300:	total: 33.7s	remaining: 2.91s
# 2400:	total: 35.1s	remaining: 1.45s
# 2499:	total: 36.4s	remaining: 0us
# 0:	total: 13.2ms	remaining: 32.9s
# 100:	total: 1.24s	remaining: 29.5s
# 200:	total: 2.66s	remaining: 30.4s
# 300:	total: 3.97s	remaining: 29s
# 400:	total: 5.34s	remaining: 27.9s
# 500:	total: 6.67s	remaining: 26.6s
# 600:	total: 8.26s	remaining: 26.1s
# 700:	total: 9.67s	remaining: 24.8s
# 800:	total: 11s	remaining: 23.2s
# 900:	total: 12.2s	remaining: 21.6s
# 1000:	total: 13.4s	remaining: 20.1s
# 1100:	total: 14.7s	remaining: 18.7s
# 1200:	total: 16s	remaining: 17.4s
# 1300:	total: 17.3s	remaining: 15.9s
# 1400:	total: 18.5s	remaining: 14.5s
# 1500:	total: 19.8s	remaining: 13.2s
# 1600:	total: 21.2s	remaining: 11.9s
# 1700:	total: 22.5s	remaining: 10.6s
# 1800:	total: 23.8s	remaining: 9.22s
# 1900:	total: 25s	remaining: 7.88s
# 2000:	total: 26.2s	remaining: 6.54s
# 2100:	total: 27.5s	remaining: 5.21s
# 2200:	total: 28.7s	remaining: 3.9s
# 2300:	total: 29.8s	remaining: 2.58s
# 2400:	total: 30.9s	remaining: 1.27s
# 2499:	total: 32s	remaining: 0us
# |  4        |  nan      |  0.5429   |  6.096    |  0.6877   |
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_split.py:668: UserWarning: The least populated class in y has only 19 members, which is less than n_splits=20.
#   % (min_groups, self.n_splits)), UserWarning)
# 0:	total: 84ms	remaining: 3m 29s
# 100:	total: 3.72s	remaining: 1m 28s
# 200:	total: 7.45s	remaining: 1m 25s
# 300:	total: 11.1s	remaining: 1m 21s
# 400:	total: 14.8s	remaining: 1m 17s
# 500:	total: 18.2s	remaining: 1m 12s
# 600:	total: 21.9s	remaining: 1m 9s
# 700:	total: 25.6s	remaining: 1m 5s
# 800:	total: 29.4s	remaining: 1m 2s
# 900:	total: 33.2s	remaining: 58.9s
# 1000:	total: 36.9s	remaining: 55.3s
# 1100:	total: 40.5s	remaining: 51.5s
# 1200:	total: 44.1s	remaining: 47.7s
# 1300:	total: 47.8s	remaining: 44s
# 1400:	total: 51.5s	remaining: 40.4s
# 1500:	total: 55.1s	remaining: 36.7s
# 1600:	total: 58.7s	remaining: 33s
# 1700:	total: 1m 2s	remaining: 29.3s
# 1800:	total: 1m 6s	remaining: 25.7s
# 1900:	total: 1m 10s	remaining: 22.1s
# 2000:	total: 1m 14s	remaining: 18.5s
# 2100:	total: 1m 18s	remaining: 14.9s
# 2200:	total: 1m 22s	remaining: 11.2s
# 2300:	total: 1m 26s	remaining: 7.5s
# 2400:	total: 1m 31s	remaining: 3.75s
# 2499:	total: 1m 35s	remaining: 0us
# 0:	total: 54.3ms	remaining: 2m 15s
# 100:	total: 4.17s	remaining: 1m 39s
# 200:	total: 8.15s	remaining: 1m 33s
# 300:	total: 12.1s	remaining: 1m 28s
# 400:	total: 16s	remaining: 1m 23s
# 500:	total: 19.7s	remaining: 1m 18s
# 600:	total: 23.4s	remaining: 1m 13s
# 700:	total: 27.1s	remaining: 1m 9s
# 800:	total: 30.9s	remaining: 1m 5s
# 900:	total: 34.6s	remaining: 1m 1s
# 1000:	total: 38.4s	remaining: 57.4s
# 1100:	total: 42.1s	remaining: 53.5s
# 1200:	total: 45.8s	remaining: 49.5s
# 1300:	total: 49.5s	remaining: 45.6s
# 1400:	total: 53.3s	remaining: 41.8s
# 1500:	total: 57s	remaining: 38s
# 1600:	total: 1m	remaining: 34.2s
# 1700:	total: 1m 4s	remaining: 30.4s
# 1800:	total: 1m 8s	remaining: 26.5s
# 1900:	total: 1m 12s	remaining: 22.7s
# 2000:	total: 1m 15s	remaining: 18.9s
# 2100:	total: 1m 19s	remaining: 15.1s
# 2200:	total: 1m 23s	remaining: 11.3s
# 2300:	total: 1m 27s	remaining: 7.58s
# 2400:	total: 1m 31s	remaining: 3.79s
# 2499:	total: 1m 36s	remaining: 0us
# 0:	total: 54.9ms	remaining: 2m 17s
# 100:	total: 4.11s	remaining: 1m 37s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.21220327498447075, 8.390587181954727, 0.037086329672748976)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-7d46391b1c97> in <module>
#       1 optimizer.maximize(
#       2     init_points = 5,
# ----> 3     n_iter = 25,
#       4 )
#       5 print(optimizer.max)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-52-146f2c84a981> in modelfit(learning_rate, depth, bagging_temperature)
#       7                              verbose = 100,
#       8                              bagging_temperature = float(bagging_temperature),
# ----> 9                              early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
#      10     return cat1
#      11
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     443                                 fit_params=fit_params,
#     444                                 pre_dispatch=pre_dispatch,
# --> 445                                 error_score=error_score)
#     446     return cv_results['test_score']
#     447
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     250             return_times=True, return_estimator=return_estimator,
#     251             error_score=error_score)
# --> 252         for train, test in cv.split(X, y, groups))
#     253
#     254     # For callabe scoring, the return type is only know after calling. If the
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     591             estimator.fit(X_train, **fit_params)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#     595     except Exception as e:
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4539         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4540                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 4541                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4542         return self
#    4543
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1921                 params,
#    1922                 allow_clear_pool,
# -> 1923                 train_params["init_model"]
#    1924             )
#    1925
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1364
#    1365     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1366         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1367         self._set_trained_model_attributes()
#    1368
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
#categorical_features_indices = np.where(X_train.dtypes != np.float)[0]
#|  4        |  nan      |  0.5429   |  6.096    |  0.6877   |
cat1 = CatBoostClassifier(loss_function="Logloss",eval_metric="AUC",
                          iterations=2000,learning_rate=0.01,depth=7,verbose=100,bagging_temperature = 0.54,
                          early_stopping_rounds=500)
cat1.fit(X_train,pd.DataFrame(y_train))

y_test_pre = cat1.predict(X_test)
y_test_true = np.array(y_test)
print ("the catboost model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# 0:	total: 23.2ms	remaining: 46.4s
# 100:	total: 1.93s	remaining: 36.3s
# 200:	total: 3.89s	remaining: 34.8s
# 300:	total: 6.03s	remaining: 34.1s
# 400:	total: 8.15s	remaining: 32.5s
# 500:	total: 10.4s	remaining: 31.1s
# 600:	total: 12.6s	remaining: 29.2s
# 700:	total: 14.7s	remaining: 27.3s
# 800:	total: 16.8s	remaining: 25.2s
# 900:	total: 19.2s	remaining: 23.5s
# 1000:	total: 21.6s	remaining: 21.5s
# 1100:	total: 23.9s	remaining: 19.5s
# 1200:	total: 26.2s	remaining: 17.4s
# 1300:	total: 28.4s	remaining: 15.2s
# 1400:	total: 30.5s	remaining: 13s
# 1500:	total: 32.6s	remaining: 10.8s
# 1600:	total: 34.7s	remaining: 8.64s
# 1700:	total: 36.7s	remaining: 6.46s
# 1800:	total: 38.8s	remaining: 4.29s
# 1900:	total: 40.8s	remaining: 2.13s
# 1999:	total: 43s	remaining: 0us
# the catboost model auc : 0.8125

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('CatBoostClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       159
#          1.0       1.00      0.62      0.77         8
#
#     accuracy                           0.98       167
#    macro avg       0.99      0.81      0.88       167
# weighted avg       0.98      0.98      0.98       167
#
# auc值为: 0.8125
# Text(0.5, 1.0, 'CatBoostClassifier ROC Curve')

# %%
#特征重要性排名
cat_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
cat_feat_imp = pd.Series(cat1.feature_importances_,cat_predictors).sort_values(ascending=False)
cat_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(cat_feat_imp)
# Out:
# FIXED_ASSETS          5.856338
# NOPERATE_EXP          5.281998
# NI_NI                 3.245830
# NOPERATE_INCOME       3.090624
# DILUTED_EPS           3.077128
#                         ...
# CAPITAL_RESER         0.384169
# C_PAID_IFC            0.361908
# C_PAID_TO_FOR_EMPL    0.351094
# T_SH_EQUITY           0.310797
# ORDIN_RISK_RESER      0.307041
# Length: 85, dtype: float64

# %%
print(cat_feat_imp[0:20])
# Out:
# FIXED_ASSETS          5.856338
# NOPERATE_EXP          5.281998
# NI_NI                 3.245830
# NOPERATE_INCOME       3.090624
# DILUTED_EPS           3.077128
# FOREX_EFFECTS         3.008858
# INTAN_ASSETS          2.962905
# OPERATE_PROFIT        2.742282
# COGS                  2.512261
# T_COGS                2.315078
# BASIC_EPS             2.262083
# N_CF_OPERATE_A        1.884387
# INT_PAYABLE           1.763143
# N_CHANGE_IN_CASH      1.696700
# LT_EQUITY_INVEST      1.688887
# PROC_SELL_INVEST      1.672747
# C_FR_CAP_CONTR        1.643884
# F_VALUE_CHG_GAIN      1.639367
# C_FR_OTH_OPERATE_A    1.503199
# ASSETS_IMPAIR_LOSS    1.459923
# dtype: float64
