# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split,cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %% [markdown]
# - 读取数据

# %%
ramdonForest_end_Data = pd.read_csv('./房地产业_处理.csv ')

# %%
ramdonForest_end_Data = ramdonForest_end_Data.drop(columns = 'Unnamed: 0')

# %%
ramdonForest_end_Data['FLAG'].groupby(ramdonForest_end_Data['FLAG']).count()
# Out:
# FLAG
# 0.0    571
# 1.0     12
# Name: FLAG, dtype: int64

# %% [markdown]
# - 过采样数据

# %%
#定义SMOTE模型，random_state相当于随机数种子的作用
smo = SMOTE(sampling_strategy={1: 50,0:571},random_state=42)

#ros = RandomOverSampler(random_state=30,sampling_strategy=0.02)
X_smo,y_smo = smo.fit_resample(ramdonForest_end_Data.drop(columns = 'FLAG'),ramdonForest_end_Data['FLAG'])
#标准化数据
sc=StandardScaler()
sc.fit(X_smo)#计算样本的均值和标准差
X_smo=pd.DataFrame(sc.transform(X_smo))
#拆分专家样本集
X_train, X_test, y_train, y_test = train_test_split(X_smo,y_smo,test_size=0.3)
y_test.groupby(y_test).count()
# Out:
# FLAG
# 0.0    167
# 1.0     20
# Name: FLAG, dtype: int64

# %% [markdown]
# - XGBoost模型调整

# %%
# 贝叶斯优化调参

def modelfit(learning_rate, n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree,
             Reg_lambda, Reg_alpha):
    xgb1 =cross_val_score(xgb.XGBClassifier(objective='binary:logistic', nthread=2,
                             n_estimators=int(n_estimators),
                             learning_rate=float(learning_rate),
                             max_depth=int(max_depth), min_child_weight=int(min_child_weight),
                             gamma=float(gamma), subsample=float(subsample),
                             colsample_bytree=float(colsample_bytree),
                             Reg_lambda=float(Reg_lambda), Reg_alpha=float(Reg_alpha),
                             scale_pos_weight=1, seed=10, ),X_train, pd.DataFrame(y_train),scoring='roc_auc',cv=10).mean()
    return xgb1


# 参数因子池
pool = {
    'learning_rate': (0.0001, 0.9999),
    'n_estimators': (400, 800),
    'max_depth': (1, 20),  # 树模型深度
    'min_child_weight': (1, 5),
    'gamma': (0.1, 0.7),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.6, 0.9),
    'Reg_lambda': (0.001, 3),
    'Reg_alpha': (0.001, 2)

}
# 定义贝叶斯调参模型
from bayes_opt import BayesianOptimization as bayes

optimizer = bayes(f=modelfit,
                  pbounds=pool,
                  verbose=2,
                  random_state=1,
                  )

# %%
# 调参并输出最优因子
optimizer.maximize(
    init_points=5,
    n_iter=25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | Reg_alpha | Reg_la... | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [22:28:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  1        |  0.9055   |  0.8346   |  2.161    |  0.6      |  0.2814   |  0.1468   |  2.754    |  1.745    |  538.2    |  0.719    |
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  2        |  0.865    |  1.078    |  1.258    |  0.8056   |  0.2227   |  0.878    |  1.52     |  3.682    |  566.9    |  0.7676   |
# [22:28:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  3        |  0.8976   |  0.2816   |  0.5951   |  0.8402   |  0.681    |  0.3135   |  14.15    |  4.506    |  757.8    |  0.6255   |
# [22:28:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:28:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:28:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ...
#   return f(*args, **kwargs)
# [22:31:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  29       |  0.8825   |  0.8588   |  2.429    |  0.8491   |  0.4904   |  0.577    |  1.437    |  1.528    |  573.8    |  0.6135   |
# [22:31:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [22:31:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:31:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  30       |  0.7997   |  1.425    |  2.043    |  0.7696   |  0.4255   |  0.8526   |  10.08    |  4.902    |  718.3    |  0.7196   |
# =====================================================================================================================================
# {'target': 0.9410670731707317, 'params': {'Reg_alpha': 1.5130022596645705, 'Reg_lambda': 2.0410805478332694, 'colsample_bytree': 0.735364564085565, 'gamma': 0.30100378662553695, 'learning_rate': 0.5043495416115212, 'max_depth': 2.856794467607827, 'min_child_weight': 4.1507084391722024, 'n_estimators': 475.1994819592191, 'subsample': 0.7961785086442654}}

# %%
# xgboost模型训练
{'target': 0.9410670731707317, 'params': {'Reg_alpha': 1.5130022596645705, 'Reg_lambda': 2.0410805478332694, 
                                         'colsample_bytree': 0.735364564085565, 'gamma': 0.30100378662553695, 
                                         'learning_rate': 0.5043495416115212, 'max_depth': 2.856794467607827, 
                                         'min_child_weight': 4.1507084391722024, 'n_estimators': 475.1994819592191, 
                                         'subsample': 0.7961785086442654}}

xgb1 = xgb.XGBClassifier(n_estimators=475,learning_rate=0.5,
                        max_depth=2,min_child_weight=4,gamma=0.3,
                        subsample=0.79,colsample_bytree=0.73,
                        objective='binary:logistic',nthread=2,
                        scale_pos_weight=100,seed=10,Reg_lambda = 2.04,
                         Reg_alpha = 1.51)#scale_pos_weight很重要
xgb1.fit(X_train, y_train)

y_test_pre = xgb1.predict(X_test)
y_test_true = np.array(y_test)
print("the xgboost model auc: %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# the xgboost model auc: 0.8122

# %%
# 特征重要性排名
xgb_predictors = [i for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
xgb_feat_imp = pd.Series(xgb1.feature_importances_, xgb_predictors).sort_values(ascending=False)
xgb_feat_imp[0:20].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(xgb_feat_imp[0:20])
# Out:
# LT_EQUITY_INVEST     0.195347
# DILUTED_EPS          0.175754
# OR_TC                0.109960
# S_RESER_PS           0.106756
# OPA_P_TP             0.065587
# EBIT_TR              0.057323
# RETAINED_EARNINGS    0.053263
# N_CF_OPER_A_PS       0.033731
# NOPERATE_EXP         0.032908
# NOPG_TR              0.026026
# PAYROLL_PAYABLE      0.020590
# OP_TL                0.019250
# GAIN_INVEST          0.017816
# PERIOD_EXP_TR        0.014710
# NP_MARGIN            0.010588
# N_CF_OPA_OPAP        0.008158
# NCL_WC               0.006457
# NA_PS_YTD            0.006000
# NI_ATTR_P_YOY        0.005135
# IT_TR                0.004855
# dtype: float32

# %%
xgb_feat_imp[0:20]
# Out:
# LT_EQUITY_INVEST     0.195347
# DILUTED_EPS          0.175754
# OR_TC                0.109960
# S_RESER_PS           0.106756
# OPA_P_TP             0.065587
# EBIT_TR              0.057323
# RETAINED_EARNINGS    0.053263
# N_CF_OPER_A_PS       0.033731
# NOPERATE_EXP         0.032908
# NOPG_TR              0.026026
# PAYROLL_PAYABLE      0.020590
# OP_TL                0.019250
# GAIN_INVEST          0.017816
# PERIOD_EXP_TR        0.014710
# NP_MARGIN            0.010588
# N_CF_OPA_OPAP        0.008158
# NCL_WC               0.006457
# NA_PS_YTD            0.006000
# NI_ATTR_P_YOY        0.005135
# IT_TR                0.004855
# dtype: float32

# %%
# 具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:", roc_auc_score(y_test_true,y_test_pre))

# ROC曲线绘制
fpr1, tpr1, threshold1 = roc_curve(y_test_true, y_test_pre)
plt.plot(fpr1, tpr1, color='r')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98       168
#          1.0       0.78      0.64      0.70        11
#
#     accuracy                           0.97       179
#    macro avg       0.88      0.81      0.84       179
# weighted avg       0.96      0.97      0.96       179
#
# auc值为: 0.8122294372294372
# Text(0.5, 1.0, 'XGBClassifier ROC Curve')

# %% [markdown]
# - LightGBM模型调整

# %%
#贝叶斯优化调参
def modelfit(learning_rate,n_estimators,max_depth,num_leaves,min_data_in_leaf,max_bin,feature_fraction,
            bagging_fraction,bagging_freq,lambda_l1,lambda_l2,min_split_gain):
    lgb1 = cross_val_score(lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                              n_estimators = int(n_estimators),
                              max_depth = int(max_depth),
                              num_leaves = int(num_leaves),
                              learning_rate = float(learning_rate),
                              min_data_in_leaf = int(min_data_in_leaf),
                              max_bin = int(max_bin),
                              feature_fraction = float(feature_fraction),
                              bagging_fraction = float(bagging_fraction),
                              bagging_freq = int(bagging_freq),
                              lambda_l1 = float(lambda_l1),lambda_l2 = float(lambda_l2),
                              min_split_gain = float(min_split_gain),
                              cat_smooth = 100,nthread = 4, ),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=10).mean()
    return lgb1

pool = {
    'learning_rate':(0.0001,0.9999),
    'n_estimators':(400,800),
    'max_depth':(1,20),              #树模型深度
    'num_leaves':(10,30),            #叶子树，树模型复杂度
    'min_data_in_leaf':(1,70),       #处理过拟合，一个叶子上数据的最小数量
    'max_bin':(5,255),               #工具箱数（叶子结点数+非叶子节点数？）
    'feature_fraction':(0.5,0.999),  #每次迭代中随机选择特征的比例。加速训练，处理过拟合
    'bagging_fraction':(0.5,0.999),  #不进行重采样的情况下随机选择部分数据
    'bagging_freq':(3,5),            #bagging的次数。0表示禁用bagging，非零值表示执行k次bagging
    'lambda_l1':(0.0001,0.9999),
    'lambda_l2':(0.0001,0.9999),
    'min_split_gain':(0.01,0.999)    #执行切分的最小增益
    
}

from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | lambda_l1 | lambda_l2 | learni... |  max_bin  | max_depth | min_da... | min_sp... | n_esti... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# |  1        |  0.9811   |  0.7081   |  4.441    |  0.5001   |  0.3024   |  0.1468   |  0.09242  |  51.57    |  7.566    |  28.38    |  0.5429   |  567.7    |  23.7     |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  2        |  0.9676   |  0.602    |  4.756    |  0.5137   |  0.6704   |  0.4173   |  0.5587   |  40.1     |  4.764    |  56.25    |  0.9676   |  525.4    |  23.85    |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5424370614735192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5424370614735192
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] lambda_l1 is set=0.039146972276235786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.039146972276235786
# [LightGBM] [Warning] bagging_fraction is set=0.9373181869957231, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9373181869957231
# [LightGBM] [Warning] lambda_l2 is set=0.169896453480656, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.169896453480656
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  3        |  0.9809   |  0.9373   |  4.789    |  0.5424   |  0.03915  |  0.1699   |  0.8781   |  29.59    |  9.001    |  67.09    |  0.5373   |  676.8    |  16.31    |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5091258503947517, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5091258503947517
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] lambda_l1 is set=0.7500942860819785, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7500942860819785
# [LightGBM] [Warning] bagging_fraction is set=0.8425639629131103, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8425639629131103
# [LightGBM] [Warning] lambda_l2 is set=0.9887633166887134, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9887633166887134
# ...
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.692677598609923, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.692677598609923
# [LightGBM] [Warning] min_data_in_leaf is set=62, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=62
# [LightGBM] [Warning] lambda_l1 is set=0.048051412266495126, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.048051412266495126
# [LightGBM] [Warning] bagging_fraction is set=0.9927564038468308, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9927564038468308
# [LightGBM] [Warning] lambda_l2 is set=0.30810514120231575, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.30810514120231575
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.692677598609923, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.692677598609923
# [LightGBM] [Warning] min_data_in_leaf is set=62, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=62
# [LightGBM] [Warning] lambda_l1 is set=0.048051412266495126, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.048051412266495126
# [LightGBM] [Warning] bagging_fraction is set=0.9927564038468308, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9927564038468308
# [LightGBM] [Warning] lambda_l2 is set=0.30810514120231575, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.30810514120231575
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.692677598609923, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.692677598609923
# [LightGBM] [Warning] min_data_in_leaf is set=62, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=62
# [LightGBM] [Warning] lambda_l1 is set=0.048051412266495126, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.048051412266495126
# [LightGBM] [Warning] bagging_fraction is set=0.9927564038468308, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9927564038468308
# [LightGBM] [Warning] lambda_l2 is set=0.30810514120231575, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.30810514120231575
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# |  29       |  0.9817   |  0.9928   |  3.881    |  0.6927   |  0.04805  |  0.3081   |  0.778    |  239.1    |  6.509    |  62.95    |  0.7258   |  632.2    |  10.48    |
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7872020101067311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7872020101067311
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] lambda_l1 is set=0.5213261515347362, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5213261515347362
# [LightGBM] [Warning] bagging_fraction is set=0.9986874410459254, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9986874410459254
# [LightGBM] [Warning] lambda_l2 is set=0.48845410359929775, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.48845410359929775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# |  30       |  0.966    |  0.9987   |  3.458    |  0.7872   |  0.5213   |  0.4885   |  0.6847   |  215.1    |  10.86    |  57.59    |  0.3898   |  423.9    |  12.94    |
# =========================================================================================================================================================================
# {'target': 0.9892276422764226, 'params': {'bagging_fraction': 0.639793231483858, 'bagging_freq': 3.192328417134088, 'feature_fraction': 0.9929346076707571, 'lambda_l1': 0.3766077874502772, 'lambda_l2': 0.8605066072234286, 'learning_rate': 0.17600132433207039, 'max_bin': 108.38666822011855, 'max_depth': 11.059913426473914, 'min_data_in_leaf': 59.7196904006754, 'min_split_gain': 0.1680910099486412, 'n_estimators': 772.7992017161348, 'num_leaves': 27.660861976873065}}

# %%
{'target': 0.9555080721747388, 'params': {'bagging_fraction': 0.7080939803465844, 'bagging_freq': 4.440648986884316,
                                          'feature_fraction': 0.500057073033855, 'lambda_l1': 0.3023721061173134,
                                          'lambda_l2': 0.14682653963894962, 'learning_rate': 0.09242012704984405, 
                                          'max_bin': 51.56505284441773, 'max_depth': 7.5656538138179075, 
                                          'min_data_in_leaf': 28.376955721916225, 'min_split_gain': 0.54288974992932,
                                          'n_estimators': 567.6778057613179, 'num_leaves': 23.70439000793519}}
lgb1 = lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                          bagging_fraction = 0.63,bagging_freq = 3,
                          feature_fraction = 0.99,lambda_l1 =  0.3,lambda_l2 = 0.86,
                          learning_rate = 0.17,max_bin = 108,max_depth = 11,
                          min_data_in_leaf = 59,min_split_gain = 0.16,
                          n_estimators = 772,num_leaves = 27,
                          cat_smooth = 10,nthread = 4)
#cat_smooth：可以减少噪声对分类特征的影响，尤其是对于数据较少的分类
lgb_model = lgb1.fit(X_train,pd.DataFrame(y_train))
y_test_pre = lgb1.predict(X_test)
y_test_true = np.array(y_test)
print ("the lightgbm model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.99, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.99
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] lambda_l1 is set=0.3, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.63, subsample=1.0 will be ignored. Current value: bagging_fraction=0.63
# [LightGBM] [Warning] lambda_l2 is set=0.86, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.86
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# the lightgbm model auc : 0.85

# %%
#特征重要性排名
lgb_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
lgb_feat_imp = pd.Series(lgb_model.feature_importances_,lgb_predictors).sort_values(ascending=False)
lgb_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(lgb_feat_imp[0:20])
# Out:
# PERIOD_EXP_TR         8
# LT_EQUITY_INVEST      8
# NA_PS_YTD             6
# DEFER_TAX_LIAB        6
# C_PAID_OTH_FINAN_A    5
# AVAIL_FOR_SALE_FA     5
# OR_TC                 5
# ADMIN_EXP_TR          5
# FCFE                  5
# ST_BORR               5
# OTH_NCA               4
# EBIT_TR               4
# NOPERATE_EXP          4
# NOPG_TR               4
# N_TAN_A_TL            4
# NI_ATTR_P_YOY         3
# N_CF_FA_PROPT         3
# ADMIN_EXP             3
# N_C_IN_CASH_PS        3
# FCFF_PS               3
# dtype: int32

# %%
print(lgb_feat_imp[0:20] )
# Out:
# PERIOD_EXP_TR         8
# LT_EQUITY_INVEST      8
# NA_PS_YTD             6
# DEFER_TAX_LIAB        6
# C_PAID_OTH_FINAN_A    5
# AVAIL_FOR_SALE_FA     5
# OR_TC                 5
# ADMIN_EXP_TR          5
# FCFE                  5
# ST_BORR               5
# OTH_NCA               4
# EBIT_TR               4
# NOPERATE_EXP          4
# NOPG_TR               4
# N_TAN_A_TL            4
# NI_ATTR_P_YOY         3
# N_CF_FA_PROPT         3
# ADMIN_EXP             3
# N_C_IN_CASH_PS        3
# FCFF_PS               3
# dtype: int32

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98       167
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.97       187
#    macro avg       0.98      0.85      0.90       187
# weighted avg       0.97      0.97      0.97       187
#
# auc值为: 0.85
# Text(0.5, 1.0, 'LGBClassifier ROC Curve')

# %% [markdown]
# - Catboost模型调整

# %%
def modelfit(learning_rate,depth,bagging_temperature):
    cat1 = cross_val_score(CatBoostClassifier(loss_function = 'Logloss',
                             eval_metric = 'AUC',
                             iterations = 2500,
                             learning_rate = float(learning_rate),
                             depth = int(depth),
                             verbose = 100,
                             bagging_temperature = float(bagging_temperature),
                             early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=10).mean()
    return cat1

pool = {
    'learning_rate':(0.01,0.999),
    'depth':(4,9),
    'bagging_temperature':(0.01,0.999)
}
from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... |   depth   | learni... |
# -------------------------------------------------------------
# 0:	total: 100ms	remaining: 4m 10s
# 100:	total: 5.39s	remaining: 2m 7s
# 200:	total: 10.9s	remaining: 2m 4s
# 300:	total: 16.3s	remaining: 1m 58s
# 400:	total: 21.2s	remaining: 1m 50s
# 500:	total: 26s	remaining: 1m 43s
# 600:	total: 30.7s	remaining: 1m 37s
# 700:	total: 35.9s	remaining: 1m 32s
# 800:	total: 41.2s	remaining: 1m 27s
# 900:	total: 46.3s	remaining: 1m 22s
# 1000:	total: 52.2s	remaining: 1m 18s
# 1100:	total: 57.2s	remaining: 1m 12s
# 1200:	total: 1m 2s	remaining: 1m 7s
# 1300:	total: 1m 7s	remaining: 1m 2s
# 1400:	total: 1m 13s	remaining: 57.5s
# 1500:	total: 1m 18s	remaining: 52.4s
# 1600:	total: 1m 23s	remaining: 47.2s
# 1700:	total: 1m 29s	remaining: 41.9s
# 1800:	total: 1m 34s	remaining: 36.7s
# 1900:	total: 1m 40s	remaining: 31.6s
# 2000:	total: 1m 45s	remaining: 26.3s
# 2100:	total: 1m 50s	remaining: 21s
# 2200:	total: 1m 55s	remaining: 15.7s
# 2300:	total: 2m	remaining: 10.5s
# 2400:	total: 2m 5s	remaining: 5.19s
# 2499:	total: 2m 11s	remaining: 0us
# 0:	total: 118ms	remaining: 4m 53s
# 100:	total: 5.3s	remaining: 2m 5s
# 200:	total: 10.7s	remaining: 2m 2s
# 300:	total: 16.2s	remaining: 1m 58s
# 400:	total: 21.9s	remaining: 1m 54s
# 500:	total: 27.5s	remaining: 1m 49s
# 600:	total: 33s	remaining: 1m 44s
# 700:	total: 38.3s	remaining: 1m 38s
# 800:	total: 43.5s	remaining: 1m 32s
# 900:	total: 48.8s	remaining: 1m 26s
# 1000:	total: 54s	remaining: 1m 20s
# 1100:	total: 59.3s	remaining: 1m 15s
# 1200:	total: 1m 5s	remaining: 1m 10s
# 1300:	total: 1m 10s	remaining: 1m 5s
# 1400:	total: 1m 16s	remaining: 59.7s
# 1500:	total: 1m 21s	remaining: 54.3s
# 1600:	total: 1m 27s	remaining: 49.2s
# 1700:	total: 1m 33s	remaining: 44s
# 1800:	total: 1m 39s	remaining: 38.5s
# 1900:	total: 1m 44s	remaining: 33s
# 2000:	total: 1m 50s	remaining: 27.4s
# 2100:	total: 1m 55s	remaining: 22s
# 2200:	total: 2m 1s	remaining: 16.5s
# 2300:	total: 2m 6s	remaining: 11s
# 2400:	total: 2m 12s	remaining: 5.48s
# 2499:	total: 2m 19s	remaining: 0us
# 0:	total: 117ms	remaining: 4m 51s
# 100:	total: 5.6s	remaining: 2m 13s
# 200:	total: 11.3s	remaining: 2m 9s
# 300:	total: 16.7s	remaining: 2m 2s
# 400:	total: 22.5s	remaining: 1m 57s
# 500:	total: 28.1s	remaining: 1m 52s
# 600:	total: 33.5s	remaining: 1m 45s
# 700:	total: 38.8s	remaining: 1m 39s
# 800:	total: 44s	remaining: 1m 33s
# 900:	total: 49.2s	remaining: 1m 27s
# 1000:	total: 54.3s	remaining: 1m 21s
# 1100:	total: 59.4s	remaining: 1m 15s
# 1200:	total: 1m 4s	remaining: 1m 9s
# 1300:	total: 1m 9s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.4s
# 1500:	total: 1m 19s	remaining: 53s
# 1600:	total: 1m 24s	remaining: 47.6s
# 1700:	total: 1m 29s	remaining: 42.3s
# 1800:	total: 1m 35s	remaining: 37s
# 1900:	total: 1m 40s	remaining: 31.6s
# 2000:	total: 1m 45s	remaining: 26.3s
# 2100:	total: 1m 50s	remaining: 21s
# 2200:	total: 1m 55s	remaining: 15.7s
# 2300:	total: 2m	remaining: 10.4s
# 2400:	total: 2m 5s	remaining: 5.18s
# 2499:	total: 2m 11s	remaining: 0us
# 0:	total: 69ms	remaining: 2m 52s
# 100:	total: 5.28s	remaining: 2m 5s
# 200:	total: 10.6s	remaining: 2m 1s
# 300:	total: 16.5s	remaining: 2m
# 400:	total: 21.7s	remaining: 1m 53s
# 500:	total: 26.8s	remaining: 1m 47s
# 600:	total: 32s	remaining: 1m 41s
# 700:	total: 37.6s	remaining: 1m 36s
# 800:	total: 42.8s	remaining: 1m 30s
# 900:	total: 48s	remaining: 1m 25s
# 1000:	total: 53.2s	remaining: 1m 19s
# 1100:	total: 58.5s	remaining: 1m 14s
# 1200:	total: 1m 3s	remaining: 1m 8s
# 1300:	total: 1m 9s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.4s
# 1500:	total: 1m 19s	remaining: 53s
# 1600:	total: 1m 24s	remaining: 47.6s
# 1700:	total: 1m 29s	remaining: 42.2s
# 1800:	total: 1m 35s	remaining: 36.9s
# 1900:	total: 1m 40s	remaining: 31.6s
# 2000:	total: 1m 45s	remaining: 26.3s
# 2100:	total: 1m 50s	remaining: 21s
# 2200:	total: 1m 55s	remaining: 15.8s
# 2300:	total: 2m 1s	remaining: 10.5s
# 2400:	total: 2m 6s	remaining: 5.21s
# 2499:	total: 2m 11s	remaining: 0us
# 0:	total: 68.4ms	remaining: 2m 50s
# 100:	total: 5.63s	remaining: 2m 13s
# 200:	total: 10.9s	remaining: 2m 5s
# 300:	total: 16.1s	remaining: 1m 57s
# 400:	total: 21.4s	remaining: 1m 51s
# 500:	total: 26.6s	remaining: 1m 46s
# 600:	total: 31.7s	remaining: 1m 40s
# 700:	total: 36.9s	remaining: 1m 34s
# 800:	total: 42s	remaining: 1m 29s
# 900:	total: 47.3s	remaining: 1m 23s
# 1000:	total: 52.9s	remaining: 1m 19s
# 1100:	total: 59.3s	remaining: 1m 15s
# 1200:	total: 1m 4s	remaining: 1m 9s
# 1300:	total: 1m 9s	remaining: 1m 4s
# 1400:	total: 1m 15s	remaining: 59.1s
# 1500:	total: 1m 21s	remaining: 53.9s
# 1600:	total: 1m 26s	remaining: 48.6s
# 1700:	total: 1m 32s	remaining: 43.2s
# 1800:	total: 1m 37s	remaining: 37.8s
# 1900:	total: 1m 42s	remaining: 32.2s
# 2000:	total: 1m 47s	remaining: 26.8s
# 2100:	total: 1m 52s	remaining: 21.3s
# 2200:	total: 1m 57s	remaining: 16s
# 2300:	total: 2m 2s	remaining: 10.6s
# 2400:	total: 2m 7s	remaining: 5.27s
# 2499:	total: 2m 13s	remaining: 0us
# 0:	total: 95.7ms	remaining: 3m 59s
# 100:	total: 5.31s	remaining: 2m 6s
# 200:	total: 10.9s	remaining: 2m 4s
# 300:	total: 16.5s	remaining: 2m
# 400:	total: 21.8s	remaining: 1m 54s
# 500:	total: 27.4s	remaining: 1m 49s
# 600:	total: 33s	remaining: 1m 44s
# 700:	total: 38.7s	remaining: 1m 39s
# 800:	total: 44.1s	remaining: 1m 33s
# 900:	total: 50s	remaining: 1m 28s
# 1000:	total: 55.4s	remaining: 1m 22s
# 1100:	total: 1m	remaining: 1m 17s
# 1200:	total: 1m 6s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 6s
# 1400:	total: 1m 17s	remaining: 1m
# 1500:	total: 1m 23s	remaining: 55.3s
# 1600:	total: 1m 28s	remaining: 49.7s
# 1700:	total: 1m 34s	remaining: 44.2s
# 1800:	total: 1m 39s	remaining: 38.7s
# 1900:	total: 1m 45s	remaining: 33.1s
# 2000:	total: 1m 50s	remaining: 27.7s
# 2100:	total: 1m 56s	remaining: 22.1s
# 2200:	total: 2m 2s	remaining: 16.6s
# 2300:	total: 2m 7s	remaining: 11.1s
# 2400:	total: 2m 17s	remaining: 5.68s
# 2499:	total: 2m 24s	remaining: 0us
# 0:	total: 79.7ms	remaining: 3m 19s
# 100:	total: 5.59s	remaining: 2m 12s
# 200:	total: 10.9s	remaining: 2m 4s
# 300:	total: 16.3s	remaining: 1m 58s
# 400:	total: 21.3s	remaining: 1m 51s
# 500:	total: 26.3s	remaining: 1m 44s
# 600:	total: 31.2s	remaining: 1m 38s
# 700:	total: 36.4s	remaining: 1m 33s
# 800:	total: 42s	remaining: 1m 29s
# 900:	total: 48.1s	remaining: 1m 25s
# 1000:	total: 53.7s	remaining: 1m 20s
# 1100:	total: 59.2s	remaining: 1m 15s
# 1200:	total: 1m 4s	remaining: 1m 10s
# 1300:	total: 1m 10s	remaining: 1m 4s
# 1400:	total: 1m 15s	remaining: 59s
# 1500:	total: 1m 20s	remaining: 53.4s
# 1600:	total: 1m 25s	remaining: 48.1s
# 1700:	total: 1m 30s	remaining: 42.6s
# 1800:	total: 1m 35s	remaining: 37.2s
# 1900:	total: 1m 41s	remaining: 31.9s
# 2000:	total: 1m 46s	remaining: 26.5s
# 2100:	total: 1m 51s	remaining: 21.1s
# 2200:	total: 1m 56s	remaining: 15.8s
# 2300:	total: 2m 1s	remaining: 10.5s
# 2400:	total: 2m 6s	remaining: 5.23s
# 2499:	total: 2m 11s	remaining: 0us
# 0:	total: 103ms	remaining: 4m 17s
# 100:	total: 5.45s	remaining: 2m 9s
# 200:	total: 10.8s	remaining: 2m 3s
# 300:	total: 16.2s	remaining: 1m 58s
# 400:	total: 22s	remaining: 1m 55s
# 500:	total: 27.7s	remaining: 1m 50s
# 600:	total: 33.3s	remaining: 1m 45s
# 700:	total: 39s	remaining: 1m 40s
# 800:	total: 44.8s	remaining: 1m 34s
# 900:	total: 50.8s	remaining: 1m 30s
# 1000:	total: 56.4s	remaining: 1m 24s
# 1100:	total: 1m 2s	remaining: 1m 18s
# 1200:	total: 1m 7s	remaining: 1m 13s
# 1300:	total: 1m 12s	remaining: 1m 6s
# 1400:	total: 1m 17s	remaining: 1m
# 1500:	total: 1m 23s	remaining: 55.4s
# 1600:	total: 1m 28s	remaining: 49.9s
# 1700:	total: 1m 34s	remaining: 44.5s
# 1800:	total: 1m 40s	remaining: 38.9s
# 1900:	total: 1m 45s	remaining: 33.1s
# 2000:	total: 1m 50s	remaining: 27.5s
# 2100:	total: 1m 55s	remaining: 21.9s
# 2200:	total: 2m	remaining: 16.3s
# 2300:	total: 2m 5s	remaining: 10.8s
# 2400:	total: 2m 10s	remaining: 5.39s
# 2499:	total: 2m 15s	remaining: 0us
# 0:	total: 80.3ms	remaining: 3m 20s
# 100:	total: 5.11s	remaining: 2m 1s
# 200:	total: 10.2s	remaining: 1m 56s
# 300:	total: 15.1s	remaining: 1m 50s
# 400:	total: 20.1s	remaining: 1m 45s
# 500:	total: 25s	remaining: 1m 39s
# 600:	total: 29.9s	remaining: 1m 34s
# 700:	total: 34.8s	remaining: 1m 29s
# 800:	total: 39.7s	remaining: 1m 24s
# 900:	total: 44.8s	remaining: 1m 19s
# 1000:	total: 49.8s	remaining: 1m 14s
# 1100:	total: 55s	remaining: 1m 9s
# 1200:	total: 1m	remaining: 1m 5s
# 1300:	total: 1m 6s	remaining: 1m 1s
# 1400:	total: 1m 12s	remaining: 56.7s
# 1500:	total: 1m 17s	remaining: 51.7s
# 1600:	total: 1m 22s	remaining: 46.5s
# 1700:	total: 1m 27s	remaining: 41.3s
# 1800:	total: 1m 33s	remaining: 36.3s
# 1900:	total: 1m 38s	remaining: 31.1s
# 2000:	total: 1m 43s	remaining: 25.9s
# 2100:	total: 1m 48s	remaining: 20.7s
# 2200:	total: 1m 53s	remaining: 15.5s
# 2300:	total: 1m 58s	remaining: 10.3s
# 2400:	total: 2m 4s	remaining: 5.12s
# 2499:	total: 2m 9s	remaining: 0us
# 0:	total: 61.1ms	remaining: 2m 32s
# 100:	total: 5.04s	remaining: 1m 59s
# 200:	total: 9.98s	remaining: 1m 54s
# 300:	total: 15.2s	remaining: 1m 51s
# 400:	total: 20.8s	remaining: 1m 48s
# 500:	total: 26.4s	remaining: 1m 45s
# 600:	total: 31.7s	remaining: 1m 40s
# 700:	total: 36.9s	remaining: 1m 34s
# 800:	total: 42.3s	remaining: 1m 29s
# 900:	total: 47.9s	remaining: 1m 25s
# 1000:	total: 53.3s	remaining: 1m 19s
# 1100:	total: 58.5s	remaining: 1m 14s
# 1200:	total: 1m 3s	remaining: 1m 8s
# 1300:	total: 1m 8s	remaining: 1m 3s
# 1400:	total: 1m 13s	remaining: 57.8s
# 1500:	total: 1m 18s	remaining: 52.3s
# 1600:	total: 1m 23s	remaining: 47s
# 1700:	total: 1m 28s	remaining: 41.7s
# 1800:	total: 1m 33s	remaining: 36.4s
# 1900:	total: 1m 38s	remaining: 31.1s
# 2000:	total: 1m 43s	remaining: 25.9s
# 2100:	total: 1m 49s	remaining: 20.7s
# 2200:	total: 1m 54s	remaining: 15.5s
# 2300:	total: 1m 59s	remaining: 10.3s
# 2400:	total: 2m 4s	remaining: 5.13s
# 2499:	total: 2m 9s	remaining: 0us
# |  1        |  0.9812   |  0.4224   |  7.602    |  0.01011  |
# 0:	total: 12.9ms	remaining: 32.2s
# 100:	total: 974ms	remaining: 23.1s
# 200:	total: 2.06s	remaining: 23.5s
# 300:	total: 3.08s	remaining: 22.5s
# 400:	total: 4.04s	remaining: 21.1s
# 500:	total: 5s	remaining: 19.9s
# 600:	total: 5.97s	remaining: 18.9s
# 700:	total: 6.96s	remaining: 17.8s
# 800:	total: 7.97s	remaining: 16.9s
# 900:	total: 8.97s	remaining: 15.9s
# 1000:	total: 9.93s	remaining: 14.9s
# 1100:	total: 10.9s	remaining: 13.9s
# 1200:	total: 11.9s	remaining: 12.9s
# 1300:	total: 12.9s	remaining: 11.9s
# 1400:	total: 13.9s	remaining: 10.9s
# 1500:	total: 14.9s	remaining: 9.95s
# 1600:	total: 15.9s	remaining: 8.94s
# 1700:	total: 16.9s	remaining: 7.95s
# 1800:	total: 17.9s	remaining: 6.96s
# 1900:	total: 18.9s	remaining: 5.97s
# 2000:	total: 19.9s	remaining: 4.97s
# 2100:	total: 21s	remaining: 3.98s
# 2200:	total: 22s	remaining: 2.98s
# 2300:	total: 23s	remaining: 1.99s
# 2400:	total: 24s	remaining: 988ms
# 2499:	total: 25s	remaining: 0us
# 0:	total: 27.6ms	remaining: 1m 8s
# 100:	total: 980ms	remaining: 23.3s
# 200:	total: 1.98s	remaining: 22.7s
# 300:	total: 3s	remaining: 22s
# 400:	total: 4.04s	remaining: 21.1s
# 500:	total: 5.17s	remaining: 20.6s
# 600:	total: 6.33s	remaining: 20s
# 700:	total: 7.4s	remaining: 19s
# 800:	total: 8.42s	remaining: 17.9s
# 900:	total: 9.43s	remaining: 16.7s
# 1000:	total: 10.5s	remaining: 15.8s
# 1100:	total: 11.6s	remaining: 14.7s
# 1200:	total: 12.6s	remaining: 13.6s
# 1300:	total: 13.6s	remaining: 12.5s
# 1400:	total: 14.6s	remaining: 11.4s
# 1500:	total: 15.5s	remaining: 10.3s
# 1600:	total: 16.4s	remaining: 9.24s
# 1700:	total: 17.4s	remaining: 8.17s
# 1800:	total: 18.5s	remaining: 7.19s
# 1900:	total: 19.6s	remaining: 6.18s
# 2000:	total: 20.6s	remaining: 5.13s
# 2100:	total: 21.5s	remaining: 4.09s
# 2200:	total: 22.5s	remaining: 3.05s
# 2300:	total: 23.4s	remaining: 2.03s
# 2400:	total: 24.4s	remaining: 1.01s
# 2499:	total: 25.4s	remaining: 0us
# 0:	total: 35.6ms	remaining: 1m 29s
# 100:	total: 1.06s	remaining: 25.1s
# 200:	total: 2.27s	remaining: 26s
# 300:	total: 3.3s	remaining: 24.1s
# 400:	total: 4.37s	remaining: 22.9s
# 500:	total: 5.37s	remaining: 21.4s
# 600:	total: 6.34s	remaining: 20s
# 700:	total: 7.26s	remaining: 18.6s
# 800:	total: 8.26s	remaining: 17.5s
# 900:	total: 9.26s	remaining: 16.4s
# 1000:	total: 10.4s	remaining: 15.6s
# 1100:	total: 12s	remaining: 15.2s
# 1200:	total: 13.3s	remaining: 14.4s
# 1300:	total: 14.9s	remaining: 13.7s
# 1400:	total: 16.3s	remaining: 12.8s
# 1500:	total: 17.5s	remaining: 11.7s
# 1600:	total: 19s	remaining: 10.7s
# 1700:	total: 20.3s	remaining: 9.52s
# 1800:	total: 21.4s	remaining: 8.29s
# 1900:	total: 22.6s	remaining: 7.11s
# 2000:	total: 23.7s	remaining: 5.92s
# 2100:	total: 24.7s	remaining: 4.69s
# 2200:	total: 26s	remaining: 3.53s
# 2300:	total: 26.9s	remaining: 2.33s
# 2400:	total: 28s	remaining: 1.15s
# 2499:	total: 29s	remaining: 0us
# 0:	total: 15.6ms	remaining: 39s
# 100:	total: 981ms	remaining: 23.3s
# 200:	total: 2.05s	remaining: 23.4s
# 300:	total: 3.07s	remaining: 22.4s
# 400:	total: 4.28s	remaining: 22.4s
# 500:	total: 5.33s	remaining: 21.3s
# 600:	total: 6.66s	remaining: 21s
# 700:	total: 7.89s	remaining: 20.3s
# 800:	total: 9s	remaining: 19.1s
# 900:	total: 10.1s	remaining: 17.9s
# 1000:	total: 11.1s	remaining: 16.7s
# 1100:	total: 12.2s	remaining: 15.6s
# 1200:	total: 13.3s	remaining: 14.3s
# 1300:	total: 14.3s	remaining: 13.2s
# 1400:	total: 15.3s	remaining: 12s
# 1500:	total: 16.3s	remaining: 10.9s
# 1600:	total: 17.4s	remaining: 9.74s
# 1700:	total: 18.4s	remaining: 8.63s
# 1800:	total: 19.4s	remaining: 7.52s
# 1900:	total: 20.4s	remaining: 6.42s
# 2000:	total: 21.4s	remaining: 5.34s
# 2100:	total: 22.4s	remaining: 4.26s
# 2200:	total: 23.4s	remaining: 3.18s
# 2300:	total: 24.4s	remaining: 2.11s
# 2400:	total: 25.4s	remaining: 1.05s
# 2499:	total: 26.4s	remaining: 0us
# 0:	total: 21ms	remaining: 52.6s
# 100:	total: 1000ms	remaining: 23.8s
# 200:	total: 2.04s	remaining: 23.4s
# 300:	total: 3.05s	remaining: 22.3s
# 400:	total: 4.04s	remaining: 21.1s
# 500:	total: 5.05s	remaining: 20.2s
# 600:	total: 6.02s	remaining: 19s
# 700:	total: 6.97s	remaining: 17.9s
# 800:	total: 7.99s	remaining: 16.9s
# 900:	total: 8.99s	remaining: 16s
# 1000:	total: 9.97s	remaining: 14.9s
# 1100:	total: 11s	remaining: 14s
# 1200:	total: 12s	remaining: 13s
# 1300:	total: 12.9s	remaining: 11.9s
# 1400:	total: 13.9s	remaining: 10.9s
# 1500:	total: 14.9s	remaining: 9.88s
# 1600:	total: 15.8s	remaining: 8.86s
# 1700:	total: 16.7s	remaining: 7.84s
# 1800:	total: 17.6s	remaining: 6.84s
# 1900:	total: 18.6s	remaining: 5.86s
# 2000:	total: 19.6s	remaining: 4.88s
# 2100:	total: 20.5s	remaining: 3.89s
# 2200:	total: 21.4s	remaining: 2.91s
# 2300:	total: 22.5s	remaining: 1.95s
# 2400:	total: 23.5s	remaining: 969ms
# 2499:	total: 24.5s	remaining: 0us
# 0:	total: 22.7ms	remaining: 56.7s
# 100:	total: 982ms	remaining: 23.3s
# 200:	total: 2.05s	remaining: 23.5s
# 300:	total: 3.06s	remaining: 22.4s
# 400:	total: 4.04s	remaining: 21.1s
# 500:	total: 5.03s	remaining: 20.1s
# 600:	total: 6.05s	remaining: 19.1s
# 700:	total: 7.07s	remaining: 18.2s
# 800:	total: 8.12s	remaining: 17.2s
# 900:	total: 9.29s	remaining: 16.5s
# 1000:	total: 10.5s	remaining: 15.8s
# 1100:	total: 11.6s	remaining: 14.7s
# 1200:	total: 12.5s	remaining: 13.6s
# 1300:	total: 13.6s	remaining: 12.5s
# 1400:	total: 15.2s	remaining: 12s
# 1500:	total: 16.6s	remaining: 11.1s
# 1600:	total: 17.7s	remaining: 9.93s
# 1700:	total: 18.6s	remaining: 8.76s
# 1800:	total: 19.6s	remaining: 7.61s
# 1900:	total: 20.6s	remaining: 6.48s
# 2000:	total: 21.6s	remaining: 5.38s
# 2100:	total: 22.5s	remaining: 4.28s
# 2200:	total: 23.5s	remaining: 3.19s
# 2300:	total: 24.6s	remaining: 2.13s
# 2400:	total: 25.6s	remaining: 1.06s
# 2499:	total: 26.6s	remaining: 0us
# 0:	total: 15ms	remaining: 37.6s
# 100:	total: 947ms	remaining: 22.5s
# 200:	total: 1.96s	remaining: 22.4s
# 300:	total: 2.95s	remaining: 21.5s
# 400:	total: 3.97s	remaining: 20.8s
# 500:	total: 4.97s	remaining: 19.8s
# 600:	total: 5.93s	remaining: 18.8s
# 700:	total: 6.97s	remaining: 17.9s
# 800:	total: 7.94s	remaining: 16.8s
# 900:	total: 8.96s	remaining: 15.9s
# 1000:	total: 9.95s	remaining: 14.9s
# 1100:	total: 10.9s	remaining: 13.9s
# 1200:	total: 11.9s	remaining: 12.9s
# 1300:	total: 13s	remaining: 12s
# 1400:	total: 14s	remaining: 11s
# 1500:	total: 14.9s	remaining: 9.94s
# 1600:	total: 15.9s	remaining: 8.92s
# 1700:	total: 16.9s	remaining: 7.94s
# 1800:	total: 17.9s	remaining: 6.94s
# 1900:	total: 18.9s	remaining: 5.96s
# 2000:	total: 20s	remaining: 4.98s
# 2100:	total: 20.9s	remaining: 3.96s
# 2200:	total: 21.9s	remaining: 2.98s
# 2300:	total: 22.8s	remaining: 1.97s
# 2400:	total: 23.8s	remaining: 980ms
# 2499:	total: 24.7s	remaining: 0us
# 0:	total: 24.1ms	remaining: 1m
# 100:	total: 891ms	remaining: 21.2s
# 200:	total: 1.82s	remaining: 20.8s
# 300:	total: 2.91s	remaining: 21.3s
# 400:	total: 3.94s	remaining: 20.6s
# 500:	total: 5s	remaining: 20s
# 600:	total: 6.14s	remaining: 19.4s
# 700:	total: 7.12s	remaining: 18.3s
# 800:	total: 8.08s	remaining: 17.1s
# 900:	total: 9.07s	remaining: 16.1s
# 1000:	total: 10.4s	remaining: 15.5s
# 1100:	total: 11.4s	remaining: 14.5s
# 1200:	total: 12.5s	remaining: 13.5s
# 1300:	total: 13.4s	remaining: 12.4s
# 1400:	total: 14.4s	remaining: 11.3s
# 1500:	total: 15.3s	remaining: 10.2s
# 1600:	total: 16.3s	remaining: 9.15s
# 1700:	total: 17.4s	remaining: 8.18s
# 1800:	total: 18.5s	remaining: 7.18s
# 1900:	total: 19.6s	remaining: 6.17s
# 2000:	total: 20.7s	remaining: 5.17s
# 2100:	total: 21.8s	remaining: 4.13s
# 2200:	total: 22.9s	remaining: 3.11s
# 2300:	total: 23.9s	remaining: 2.07s
# 2400:	total: 24.9s	remaining: 1.02s
# 2499:	total: 25.9s	remaining: 0us
# 0:	total: 16.5ms	remaining: 41.2s
# 100:	total: 990ms	remaining: 23.5s
# 200:	total: 1.97s	remaining: 22.6s
# 300:	total: 3s	remaining: 21.9s
# 400:	total: 4.06s	remaining: 21.3s
# 500:	total: 5.04s	remaining: 20.1s
# 600:	total: 6.07s	remaining: 19.2s
# 700:	total: 7.12s	remaining: 18.3s
# 800:	total: 8.07s	remaining: 17.1s
# 900:	total: 9s	remaining: 16s
# 1000:	total: 10.1s	remaining: 15.1s
# 1100:	total: 11.1s	remaining: 14s
# 1200:	total: 12.1s	remaining: 13.1s
# 1300:	total: 13.2s	remaining: 12.2s
# 1400:	total: 14.2s	remaining: 11.2s
# 1500:	total: 15.2s	remaining: 10.1s
# 1600:	total: 16.1s	remaining: 9.04s
# 1700:	total: 17s	remaining: 8s
# 1800:	total: 17.9s	remaining: 6.96s
# 1900:	total: 18.9s	remaining: 5.96s
# 2000:	total: 19.8s	remaining: 4.94s
# 2100:	total: 20.7s	remaining: 3.94s
# 2200:	total: 21.6s	remaining: 2.94s
# 2300:	total: 22.6s	remaining: 1.96s
# 2400:	total: 23.6s	remaining: 971ms
# 2499:	total: 24.5s	remaining: 0us
# 0:	total: 16.2ms	remaining: 40.5s
# 100:	total: 940ms	remaining: 22.3s
# 200:	total: 1.91s	remaining: 21.8s
# 300:	total: 2.91s	remaining: 21.2s
# 400:	total: 3.83s	remaining: 20.1s
# 500:	total: 4.77s	remaining: 19s
# 600:	total: 5.78s	remaining: 18.3s
# 700:	total: 6.78s	remaining: 17.4s
# 800:	total: 7.78s	remaining: 16.5s
# 900:	total: 9.1s	remaining: 16.2s
# 1000:	total: 10.2s	remaining: 15.2s
# 1100:	total: 11.1s	remaining: 14.1s
# 1200:	total: 12s	remaining: 13s
# 1300:	total: 13s	remaining: 12s
# 1400:	total: 14s	remaining: 11s
# 1500:	total: 15.1s	remaining: 10s
# 1600:	total: 16.1s	remaining: 9.04s
# 1700:	total: 17.1s	remaining: 8.03s
# 1800:	total: 18.1s	remaining: 7.04s
# 1900:	total: 19.3s	remaining: 6.07s
# 2000:	total: 20.3s	remaining: 5.05s
# 2100:	total: 21.3s	remaining: 4.05s
# 2200:	total: 22.3s	remaining: 3.03s
# 2300:	total: 23.3s	remaining: 2.01s
# 2400:	total: 24.3s	remaining: 1s
# 2499:	total: 25.4s	remaining: 0us
# |  2        |  0.9771   |  0.309    |  4.734    |  0.1013   |
# 0:	total: 18.3ms	remaining: 45.8s
# 100:	total: 1.86s	remaining: 44.3s
# 200:	total: 3.56s	remaining: 40.7s
# 300:	total: 5.38s	remaining: 39.3s
# 400:	total: 7.17s	remaining: 37.5s
# 500:	total: 8.93s	remaining: 35.6s
# 600:	total: 10.6s	remaining: 33.5s
# 700:	total: 12.4s	remaining: 31.8s
# 800:	total: 14.1s	remaining: 29.9s
# 900:	total: 15.8s	remaining: 28.1s
# 1000:	total: 17.5s	remaining: 26.2s
# 1100:	total: 19.2s	remaining: 24.4s
# 1200:	total: 21s	remaining: 22.7s
# 1300:	total: 22.7s	remaining: 20.9s
# 1400:	total: 24.6s	remaining: 19.3s
# 1500:	total: 26.3s	remaining: 17.5s
# 1600:	total: 28s	remaining: 15.7s
# 1700:	total: 29.9s	remaining: 14.1s
# 1800:	total: 31.7s	remaining: 12.3s
# 1900:	total: 33.5s	remaining: 10.5s
# 2000:	total: 35.3s	remaining: 8.79s
# 2100:	total: 36.9s	remaining: 7.01s
# 2200:	total: 38.6s	remaining: 5.24s
# 2300:	total: 40.4s	remaining: 3.49s
# 2400:	total: 42.2s	remaining: 1.74s
# 2499:	total: 44s	remaining: 0us
# 0:	total: 24ms	remaining: 1m
# 100:	total: 1.82s	remaining: 43.1s
# 200:	total: 3.54s	remaining: 40.5s
# 300:	total: 5.19s	remaining: 37.9s
# 400:	total: 6.82s	remaining: 35.7s
# 500:	total: 8.54s	remaining: 34.1s
# 600:	total: 10.3s	remaining: 32.5s
# 700:	total: 11.9s	remaining: 30.5s
# 800:	total: 13.5s	remaining: 28.6s
# 900:	total: 15.1s	remaining: 26.8s
# 1000:	total: 16.9s	remaining: 25.3s
# 1100:	total: 18.6s	remaining: 23.7s
# 1200:	total: 20.3s	remaining: 22s
# 1300:	total: 22.2s	remaining: 20.4s
# 1400:	total: 23.8s	remaining: 18.7s
# 1500:	total: 25.6s	remaining: 17s
# 1600:	total: 27.3s	remaining: 15.3s
# 1700:	total: 29.1s	remaining: 13.7s
# 1800:	total: 31s	remaining: 12s
# 1900:	total: 34.7s	remaining: 10.9s
# 2000:	total: 36.7s	remaining: 9.16s
# 2100:	total: 38.6s	remaining: 7.33s
# 2200:	total: 41.1s	remaining: 5.59s
# 2300:	total: 42.9s	remaining: 3.71s
# 2400:	total: 44.4s	remaining: 1.83s
# 2499:	total: 46s	remaining: 0us
# 0:	total: 17.7ms	remaining: 44.2s
# 100:	total: 1.59s	remaining: 37.9s
# 200:	total: 3.18s	remaining: 36.4s
# 300:	total: 4.75s	remaining: 34.7s
# 400:	total: 6.33s	remaining: 33.1s
# 500:	total: 7.92s	remaining: 31.6s
# 600:	total: 9.55s	remaining: 30.2s
# 700:	total: 11.3s	remaining: 29.1s
# 800:	total: 13.1s	remaining: 27.8s
# 900:	total: 14.9s	remaining: 26.5s
# 1000:	total: 16.7s	remaining: 25s
# 1100:	total: 18.5s	remaining: 23.5s
# 1200:	total: 20.3s	remaining: 22s
# 1300:	total: 22.1s	remaining: 20.4s
# 1400:	total: 23.9s	remaining: 18.8s
# 1500:	total: 25.5s	remaining: 17s
# 1600:	total: 27.1s	remaining: 15.2s
# 1700:	total: 28.6s	remaining: 13.4s
# 1800:	total: 30.3s	remaining: 11.8s
# 1900:	total: 32s	remaining: 10.1s
# 2000:	total: 33.6s	remaining: 8.38s
# 2100:	total: 35.2s	remaining: 6.68s
# 2200:	total: 36.8s	remaining: 4.99s
# 2300:	total: 38.4s	remaining: 3.32s
# 2400:	total: 40s	remaining: 1.65s
# 2499:	total: 41.6s	remaining: 0us
# 0:	total: 39.7ms	remaining: 1m 39s
# 100:	total: 1.67s	remaining: 39.6s
# 200:	total: 3.35s	remaining: 38.3s
# 300:	total: 5s	remaining: 36.6s
# 400:	total: 6.69s	remaining: 35s
# 500:	total: 8.37s	remaining: 33.4s
# 600:	total: 10s	remaining: 31.7s
# 700:	total: 11.7s	remaining: 30s
# 800:	total: 13.3s	remaining: 28.3s
# 900:	total: 15s	remaining: 26.5s
# 1000:	total: 16.7s	remaining: 25.1s
# 1100:	total: 18.4s	remaining: 23.4s
# 1200:	total: 20s	remaining: 21.7s
# 1300:	total: 21.7s	remaining: 20s
# 1400:	total: 23.3s	remaining: 18.3s
# 1500:	total: 25s	remaining: 16.6s
# 1600:	total: 26.6s	remaining: 14.9s
# 1700:	total: 28.2s	remaining: 13.2s
# 1800:	total: 29.9s	remaining: 11.6s
# 1900:	total: 31.6s	remaining: 9.97s
# 2000:	total: 33.3s	remaining: 8.29s
# 2100:	total: 34.9s	remaining: 6.62s
# 2200:	total: 36.4s	remaining: 4.95s
# 2300:	total: 38s	remaining: 3.29s
# 2400:	total: 39.6s	remaining: 1.63s
# 2499:	total: 41.3s	remaining: 0us
# 0:	total: 35.9ms	remaining: 1m 29s
# 100:	total: 1.6s	remaining: 38s
# 200:	total: 3.18s	remaining: 36.4s
# 300:	total: 4.77s	remaining: 34.9s
# 400:	total: 6.37s	remaining: 33.3s
# 500:	total: 7.95s	remaining: 31.7s
# 600:	total: 9.67s	remaining: 30.5s
# 700:	total: 11.3s	remaining: 29s
# 800:	total: 12.8s	remaining: 27.2s
# 900:	total: 14.5s	remaining: 25.7s
# 1000:	total: 16s	remaining: 24s
# 1100:	total: 17.5s	remaining: 22.3s
# 1200:	total: 19.1s	remaining: 20.6s
# 1300:	total: 20.7s	remaining: 19.1s
# 1400:	total: 22.4s	remaining: 17.6s
# 1500:	total: 24.1s	remaining: 16.1s
# 1600:	total: 25.8s	remaining: 14.5s
# 1700:	total: 27.4s	remaining: 12.9s
# 1800:	total: 29.2s	remaining: 11.3s
# 1900:	total: 31.2s	remaining: 9.82s
# 2000:	total: 32.9s	remaining: 8.2s
# 2100:	total: 34.9s	remaining: 6.63s
# 2200:	total: 37.2s	remaining: 5.05s
# 2300:	total: 39.4s	remaining: 3.41s
# 2400:	total: 41.3s	remaining: 1.7s
# 2499:	total: 42.8s	remaining: 0us
# 0:	total: 17.6ms	remaining: 43.9s
# 100:	total: 1.62s	remaining: 38.5s
# 200:	total: 3.2s	remaining: 36.6s
# 300:	total: 4.82s	remaining: 35.2s
# 400:	total: 6.41s	remaining: 33.6s
# 500:	total: 8s	remaining: 31.9s
# 600:	total: 9.59s	remaining: 30.3s
# 700:	total: 11.2s	remaining: 28.7s
# 800:	total: 12.8s	remaining: 27.2s
# 900:	total: 14.4s	remaining: 25.6s
# 1000:	total: 16.1s	remaining: 24s
# 1100:	total: 17.7s	remaining: 22.5s
# 1200:	total: 19.3s	remaining: 20.9s
# 1300:	total: 20.9s	remaining: 19.2s
# 1400:	total: 22.5s	remaining: 17.6s
# 1500:	total: 24s	remaining: 16s
# 1600:	total: 25.6s	remaining: 14.4s
# 1700:	total: 27.3s	remaining: 12.8s
# 1800:	total: 29s	remaining: 11.3s
# 1900:	total: 30.8s	remaining: 9.69s
# 2000:	total: 32.4s	remaining: 8.08s
# 2100:	total: 34.1s	remaining: 6.48s
# 2200:	total: 35.8s	remaining: 4.86s
# 2300:	total: 37.4s	remaining: 3.23s
# 2400:	total: 39.1s	remaining: 1.61s
# 2499:	total: 40.7s	remaining: 0us
# 0:	total: 19.5ms	remaining: 48.7s
# 100:	total: 1.64s	remaining: 38.9s
# 200:	total: 3.24s	remaining: 37s
# 300:	total: 5.23s	remaining: 38.2s
# 400:	total: 7s	remaining: 36.6s
# 500:	total: 8.66s	remaining: 34.5s
# 600:	total: 10.5s	remaining: 33.1s
# 700:	total: 12.1s	remaining: 31s
# 800:	total: 13.7s	remaining: 29.1s
# 900:	total: 15.3s	remaining: 27.2s
# 1000:	total: 16.9s	remaining: 25.4s
# 1100:	total: 18.5s	remaining: 23.6s
# 1200:	total: 20.2s	remaining: 21.8s
# 1300:	total: 21.8s	remaining: 20.1s
# 1400:	total: 23.4s	remaining: 18.4s
# 1500:	total: 25.1s	remaining: 16.7s
# 1600:	total: 26.7s	remaining: 15s
# 1700:	total: 28.3s	remaining: 13.3s
# 1800:	total: 30s	remaining: 11.6s
# 1900:	total: 31.7s	remaining: 9.99s
# 2000:	total: 33.3s	remaining: 8.29s
# 2100:	total: 34.8s	remaining: 6.62s
# 2200:	total: 36.5s	remaining: 4.96s
# 2300:	total: 38s	remaining: 3.29s
# 2400:	total: 39.6s	remaining: 1.63s
# 2499:	total: 41.1s	remaining: 0us
# 0:	total: 19.4ms	remaining: 48.5s
# 100:	total: 1.64s	remaining: 38.9s
# 200:	total: 3.19s	remaining: 36.4s
# 300:	total: 4.72s	remaining: 34.5s
# 400:	total: 6.24s	remaining: 32.7s
# 500:	total: 7.78s	remaining: 31.1s
# 600:	total: 9.31s	remaining: 29.4s
# 700:	total: 10.9s	remaining: 27.8s
# 800:	total: 12.4s	remaining: 26.3s
# 900:	total: 14s	remaining: 24.9s
# 1000:	total: 15.6s	remaining: 23.4s
# 1100:	total: 17.2s	remaining: 21.9s
# 1200:	total: 18.9s	remaining: 20.4s
# 1300:	total: 20.5s	remaining: 18.9s
# 1400:	total: 22.1s	remaining: 17.3s
# 1500:	total: 23.7s	remaining: 15.7s
# 1600:	total: 25.3s	remaining: 14.2s
# 1700:	total: 27s	remaining: 12.7s
# 1800:	total: 28.7s	remaining: 11.1s
# 1900:	total: 30.4s	remaining: 9.57s
# 2000:	total: 32s	remaining: 7.98s
# 2100:	total: 33.6s	remaining: 6.38s
# 2200:	total: 35.2s	remaining: 4.78s
# 2300:	total: 36.8s	remaining: 3.18s
# 2400:	total: 38.4s	remaining: 1.58s
# 2499:	total: 40s	remaining: 0us
# 0:	total: 37.1ms	remaining: 1m 32s
# 100:	total: 1.6s	remaining: 38.1s
# 200:	total: 3.29s	remaining: 37.6s
# 300:	total: 4.94s	remaining: 36.1s
# 400:	total: 6.61s	remaining: 34.6s
# 500:	total: 8.22s	remaining: 32.8s
# 600:	total: 9.88s	remaining: 31.2s
# 700:	total: 11.5s	remaining: 29.4s
# 800:	total: 13.1s	remaining: 27.7s
# 900:	total: 14.8s	remaining: 26.3s
# 1000:	total: 16.4s	remaining: 24.5s
# 1100:	total: 17.9s	remaining: 22.7s
# 1200:	total: 19.5s	remaining: 21s
# 1300:	total: 21s	remaining: 19.4s
# 1400:	total: 22.6s	remaining: 17.7s
# 1500:	total: 24.1s	remaining: 16.1s
# 1600:	total: 25.7s	remaining: 14.4s
# 1700:	total: 27.3s	remaining: 12.8s
# 1800:	total: 29.1s	remaining: 11.3s
# 1900:	total: 30.8s	remaining: 9.7s
# 2000:	total: 32.4s	remaining: 8.08s
# 2100:	total: 34s	remaining: 6.46s
# 2200:	total: 35.6s	remaining: 4.84s
# 2300:	total: 37.3s	remaining: 3.23s
# 2400:	total: 38.9s	remaining: 1.6s
# 2499:	total: 40.5s	remaining: 0us
# 0:	total: 47.3ms	remaining: 1m 58s
# 100:	total: 1.62s	remaining: 38.4s
# 200:	total: 3.21s	remaining: 36.8s
# 300:	total: 4.85s	remaining: 35.4s
# 400:	total: 6.62s	remaining: 34.6s
# 500:	total: 8.26s	remaining: 32.9s
# 600:	total: 9.92s	remaining: 31.3s
# 700:	total: 11.5s	remaining: 29.6s
# 800:	total: 13.1s	remaining: 27.9s
# 900:	total: 14.7s	remaining: 26.1s
# 1000:	total: 16.3s	remaining: 24.4s
# 1100:	total: 17.9s	remaining: 22.8s
# 1200:	total: 19.5s	remaining: 21.1s
# 1300:	total: 21.1s	remaining: 19.4s
# 1400:	total: 22.7s	remaining: 17.8s
# 1500:	total: 24.3s	remaining: 16.2s
# 1600:	total: 25.9s	remaining: 14.5s
# 1700:	total: 27.5s	remaining: 12.9s
# 1800:	total: 29.2s	remaining: 11.3s
# 1900:	total: 30.9s	remaining: 9.73s
# 2000:	total: 32.5s	remaining: 8.11s
# 2100:	total: 34.2s	remaining: 6.49s
# 2200:	total: 35.8s	remaining: 4.87s
# 2300:	total: 37.4s	remaining: 3.24s
# 2400:	total: 39.1s	remaining: 1.61s
# 2499:	total: 40.7s	remaining: 0us
# |  3        |  0.9712   |  0.1942   |  5.728    |  0.4024   |
# 0:	total: 52.4ms	remaining: 2m 10s
# 100:	total: 2.87s	remaining: 1m 8s
# 200:	total: 5.73s	remaining: 1m 5s
# 300:	total: 8.54s	remaining: 1m 2s
# 400:	total: 11.4s	remaining: 59.6s
# 500:	total: 14.2s	remaining: 56.7s
# 600:	total: 17.1s	remaining: 54s
# 700:	total: 19.9s	remaining: 51.2s
# 800:	total: 22.7s	remaining: 48.2s
# 900:	total: 25.5s	remaining: 45.2s
# 1000:	total: 28.2s	remaining: 42.3s
# 1100:	total: 31.2s	remaining: 39.7s
# 1200:	total: 34.3s	remaining: 37.1s
# 1300:	total: 37.1s	remaining: 34.2s
# 1400:	total: 40s	remaining: 31.4s
# 1500:	total: 43s	remaining: 28.6s
# 1600:	total: 46s	remaining: 25.8s
# 1700:	total: 48.9s	remaining: 23s
# 1800:	total: 52s	remaining: 20.2s
# 1900:	total: 55s	remaining: 17.3s
# 2000:	total: 58.1s	remaining: 14.5s
# 2100:	total: 1m 1s	remaining: 11.6s
# 2200:	total: 1m 3s	remaining: 8.68s
# 2300:	total: 1m 6s	remaining: 5.78s
# 2400:	total: 1m 9s	remaining: 2.88s
# 2499:	total: 1m 12s	remaining: 0us
# 0:	total: 31.9ms	remaining: 1m 19s
# 100:	total: 2.88s	remaining: 1m 8s
# 200:	total: 5.75s	remaining: 1m 5s
# 300:	total: 8.63s	remaining: 1m 3s
# 400:	total: 11.6s	remaining: 1m
# 500:	total: 14.5s	remaining: 57.8s
# 600:	total: 17.3s	remaining: 54.6s
# 700:	total: 20.1s	remaining: 51.5s
# 800:	total: 22.8s	remaining: 48.3s
# 900:	total: 25.4s	remaining: 45.2s
# 1000:	total: 28.1s	remaining: 42.1s
# 1100:	total: 31s	remaining: 39.4s
# 1200:	total: 33.7s	remaining: 36.4s
# 1300:	total: 36.4s	remaining: 33.6s
# 1400:	total: 39.1s	remaining: 30.7s
# 1500:	total: 41.9s	remaining: 27.9s
# 1600:	total: 44.6s	remaining: 25s
# 1700:	total: 47.4s	remaining: 22.2s
# 1800:	total: 50.2s	remaining: 19.5s
# 1900:	total: 53s	remaining: 16.7s
# 2000:	total: 55.8s	remaining: 13.9s
# 2100:	total: 58.6s	remaining: 11.1s
# 2200:	total: 1m 1s	remaining: 8.35s
# 2300:	total: 1m 4s	remaining: 5.56s
# 2400:	total: 1m 7s	remaining: 2.77s
# 2499:	total: 1m 10s	remaining: 0us
# 0:	total: 30.7ms	remaining: 1m 16s
# 100:	total: 3.01s	remaining: 1m 11s
# 200:	total: 6.09s	remaining: 1m 9s
# 300:	total: 9.23s	remaining: 1m 7s
# 400:	total: 12.1s	remaining: 1m 3s
# 500:	total: 15s	remaining: 59.9s
# 600:	total: 17.9s	remaining: 56.7s
# 700:	total: 20.8s	remaining: 53.3s
# 800:	total: 23.6s	remaining: 50.1s
# 900:	total: 26.4s	remaining: 46.8s
# 1000:	total: 29.2s	remaining: 43.7s
# 1100:	total: 32.2s	remaining: 40.9s
# 1200:	total: 35.1s	remaining: 37.9s
# 1300:	total: 37.8s	remaining: 34.8s
# 1400:	total: 40.4s	remaining: 31.7s
# 1500:	total: 43.1s	remaining: 28.7s
# 1600:	total: 45.8s	remaining: 25.7s
# 1700:	total: 48.5s	remaining: 22.8s
# 1800:	total: 51.3s	remaining: 19.9s
# 1900:	total: 54.3s	remaining: 17.1s
# 2000:	total: 57.4s	remaining: 14.3s
# 2100:	total: 1m	remaining: 11.5s
# 2200:	total: 1m 3s	remaining: 8.58s
# 2300:	total: 1m 6s	remaining: 5.71s
# 2400:	total: 1m 8s	remaining: 2.84s
# 2499:	total: 1m 11s	remaining: 0us
# 0:	total: 35.3ms	remaining: 1m 28s
# 100:	total: 2.98s	remaining: 1m 10s
# 200:	total: 6.1s	remaining: 1m 9s
# 300:	total: 9.3s	remaining: 1m 7s
# 400:	total: 12.5s	remaining: 1m 5s
# 500:	total: 15.9s	remaining: 1m 3s
# 600:	total: 20.5s	remaining: 1m 4s
# 700:	total: 24.1s	remaining: 1m 1s
# 800:	total: 27.3s	remaining: 57.9s
# 900:	total: 30.6s	remaining: 54.4s
# 1000:	total: 33.7s	remaining: 50.4s
# 1100:	total: 36.8s	remaining: 46.8s
# 1200:	total: 39.7s	remaining: 42.9s
# 1300:	total: 42.5s	remaining: 39.2s
# 1400:	total: 45.4s	remaining: 35.6s
# 1500:	total: 48.3s	remaining: 32.2s
# 1600:	total: 51.3s	remaining: 28.8s
# 1700:	total: 54.3s	remaining: 25.5s
# 1800:	total: 57.3s	remaining: 22.2s
# 1900:	total: 1m	remaining: 18.9s
# 2000:	total: 1m 2s	remaining: 15.7s
# 2100:	total: 1m 5s	remaining: 12.5s
# 2200:	total: 1m 8s	remaining: 9.36s
# 2300:	total: 1m 11s	remaining: 6.2s
# 2400:	total: 1m 14s	remaining: 3.07s
# 2499:	total: 1m 17s	remaining: 0us
# 0:	total: 42.3ms	remaining: 1m 45s
# 100:	total: 2.98s	remaining: 1m 10s
# 200:	total: 5.81s	remaining: 1m 6s
# 300:	total: 8.68s	remaining: 1m 3s
# 400:	total: 11.5s	remaining: 1m
# 500:	total: 14.3s	remaining: 57.2s
# 600:	total: 17.1s	remaining: 54.1s
# 700:	total: 19.9s	remaining: 51.1s
# 800:	total: 22.7s	remaining: 48.1s
# 900:	total: 25.4s	remaining: 45.1s
# 1000:	total: 28.2s	remaining: 42.2s
# 1100:	total: 31.2s	remaining: 39.7s
# 1200:	total: 34.2s	remaining: 37s
# 1300:	total: 37.2s	remaining: 34.3s
# 1400:	total: 40s	remaining: 31.4s
# 1500:	total: 42.7s	remaining: 28.4s
# 1600:	total: 45.5s	remaining: 25.5s
# 1700:	total: 48.2s	remaining: 22.7s
# 1800:	total: 51s	remaining: 19.8s
# 1900:	total: 53.8s	remaining: 16.9s
# 2000:	total: 56.6s	remaining: 14.1s
# 2100:	total: 59.4s	remaining: 11.3s
# 2200:	total: 1m 2s	remaining: 8.5s
# 2300:	total: 1m 5s	remaining: 5.66s
# 2400:	total: 1m 8s	remaining: 2.82s
# 2499:	total: 1m 11s	remaining: 0us
# 0:	total: 44.8ms	remaining: 1m 52s
# 100:	total: 2.91s	remaining: 1m 9s
# 200:	total: 5.76s	remaining: 1m 5s
# 300:	total: 8.63s	remaining: 1m 3s
# 400:	total: 11.5s	remaining: 1m
# 500:	total: 14.3s	remaining: 57.1s
# 600:	total: 17.2s	remaining: 54.4s
# 700:	total: 20.1s	remaining: 51.6s
# 800:	total: 23.1s	remaining: 48.9s
# 900:	total: 25.9s	remaining: 45.9s
# 1000:	total: 28.8s	remaining: 43.1s
# 1100:	total: 31.8s	remaining: 40.4s
# 1200:	total: 34.5s	remaining: 37.4s
# 1300:	total: 37.3s	remaining: 34.3s
# 1400:	total: 40s	remaining: 31.3s
# 1500:	total: 42.7s	remaining: 28.4s
# 1600:	total: 45.4s	remaining: 25.5s
# 1700:	total: 48.2s	remaining: 22.6s
# 1800:	total: 51s	remaining: 19.8s
# 1900:	total: 53.9s	remaining: 17s
# 2000:	total: 56.7s	remaining: 14.2s
# 2100:	total: 59.7s	remaining: 11.3s
# 2200:	total: 1m 2s	remaining: 8.52s
# 2300:	total: 1m 5s	remaining: 5.68s
# 2400:	total: 1m 8s	remaining: 2.83s
# 2499:	total: 1m 11s	remaining: 0us
# 0:	total: 47.9ms	remaining: 1m 59s
# 100:	total: 2.98s	remaining: 1m 10s
# 200:	total: 5.89s	remaining: 1m 7s
# 300:	total: 8.84s	remaining: 1m 4s
# 400:	total: 11.8s	remaining: 1m 1s
# 500:	total: 14.7s	remaining: 58.8s
# 600:	total: 17.5s	remaining: 55.4s
# 700:	total: 20.4s	remaining: 52.3s
# 800:	total: 23.2s	remaining: 49.2s
# 900:	total: 26.1s	remaining: 46.4s
# 1000:	total: 29s	remaining: 43.4s
# 1100:	total: 32.2s	remaining: 40.9s
# 1200:	total: 35.2s	remaining: 38.1s
# 1300:	total: 38s	remaining: 35s
# 1400:	total: 40.9s	remaining: 32.1s
# 1500:	total: 43.9s	remaining: 29.2s
# 1600:	total: 46.7s	remaining: 26.2s
# 1700:	total: 49.6s	remaining: 23.3s
# 1800:	total: 52.4s	remaining: 20.3s
# 1900:	total: 55.3s	remaining: 17.4s
# 2000:	total: 58.2s	remaining: 14.5s
# 2100:	total: 1m 1s	remaining: 11.6s
# 2200:	total: 1m 3s	remaining: 8.67s
# 2300:	total: 1m 6s	remaining: 5.76s
# 2400:	total: 1m 9s	remaining: 2.87s
# 2499:	total: 1m 12s	remaining: 0us
# 0:	total: 36ms	remaining: 1m 30s
# 100:	total: 2.81s	remaining: 1m 6s
# 200:	total: 5.63s	remaining: 1m 4s
# 300:	total: 8.46s	remaining: 1m 1s
# 400:	total: 11.3s	remaining: 59s
# 500:	total: 14s	remaining: 56s
# 600:	total: 16.8s	remaining: 53s
# 700:	total: 19.5s	remaining: 50.1s
# 800:	total: 22.2s	remaining: 47.2s
# 900:	total: 25s	remaining: 44.3s
# 1000:	total: 27.8s	remaining: 41.6s
# 1100:	total: 30.6s	remaining: 38.9s
# 1200:	total: 33.4s	remaining: 36.1s
# 1300:	total: 36.1s	remaining: 33.3s
# 1400:	total: 38.9s	remaining: 30.5s
# 1500:	total: 41.7s	remaining: 27.7s
# 1600:	total: 44.5s	remaining: 25s
# 1700:	total: 47.4s	remaining: 22.3s
# 1800:	total: 50.2s	remaining: 19.5s
# 1900:	total: 53.1s	remaining: 16.7s
# 2000:	total: 56s	remaining: 14s
# 2100:	total: 58.7s	remaining: 11.1s
# 2200:	total: 1m 1s	remaining: 8.33s
# 2300:	total: 1m 4s	remaining: 5.54s
# 2400:	total: 1m 6s	remaining: 2.75s
# 2499:	total: 1m 9s	remaining: 0us
# 0:	total: 30.8ms	remaining: 1m 17s
# 100:	total: 2.79s	remaining: 1m 6s
# 200:	total: 5.61s	remaining: 1m 4s
# 300:	total: 8.53s	remaining: 1m 2s
# 400:	total: 11.4s	remaining: 59.4s
# 500:	total: 14.2s	remaining: 56.6s
# 600:	total: 17.2s	remaining: 54.4s
# 700:	total: 20.2s	remaining: 51.9s
# 800:	total: 23.1s	remaining: 48.9s
# 900:	total: 25.9s	remaining: 46s
# 1000:	total: 28.7s	remaining: 43s
# 1100:	total: 32.9s	remaining: 41.8s
# 1200:	total: 36.7s	remaining: 39.7s
# 1300:	total: 39.9s	remaining: 36.8s
# 1400:	total: 43.1s	remaining: 33.8s
# 1500:	total: 46.9s	remaining: 31.2s
# 1600:	total: 49.7s	remaining: 27.9s
# 1700:	total: 52.5s	remaining: 24.7s
# 1800:	total: 56.3s	remaining: 21.8s
# 1900:	total: 59.7s	remaining: 18.8s
# 2000:	total: 1m 3s	remaining: 15.8s
# 2100:	total: 1m 7s	remaining: 12.7s
# 2200:	total: 1m 10s	remaining: 9.53s
# 2300:	total: 1m 13s	remaining: 6.4s
# 2400:	total: 1m 16s	remaining: 3.17s
# 2499:	total: 1m 19s	remaining: 0us
# 0:	total: 28.3ms	remaining: 1m 10s
# 100:	total: 2.7s	remaining: 1m 4s
# 200:	total: 5.42s	remaining: 1m 1s
# 300:	total: 8.18s	remaining: 59.7s
# 400:	total: 11s	remaining: 57.4s
# 500:	total: 13.7s	remaining: 54.9s
# 600:	total: 16.5s	remaining: 52.3s
# 700:	total: 19.3s	remaining: 49.6s
# 800:	total: 22.1s	remaining: 46.9s
# 900:	total: 25.2s	remaining: 44.7s
# 1000:	total: 28.1s	remaining: 42.1s
# 1100:	total: 31.3s	remaining: 39.8s
# 1200:	total: 34.3s	remaining: 37.1s
# 1300:	total: 37.4s	remaining: 34.5s
# 1400:	total: 40.5s	remaining: 31.7s
# 1500:	total: 43.4s	remaining: 28.9s
# 1600:	total: 46.2s	remaining: 26s
# 1700:	total: 49.1s	remaining: 23.1s
# 1800:	total: 52s	remaining: 20.2s
# 1900:	total: 54.9s	remaining: 17.3s
# 2000:	total: 57.8s	remaining: 14.4s
# 2100:	total: 1m	remaining: 11.5s
# 2200:	total: 1m 3s	remaining: 8.65s
# 2300:	total: 1m 6s	remaining: 5.76s
# 2400:	total: 1m 9s	remaining: 2.87s
# 2499:	total: 1m 12s	remaining: 0us
# |  4        |  0.9438   |  0.5429   |  6.096    |  0.6877   |
# 0:	total: 119ms	remaining: 4m 58s
# 100:	total: 10.5s	remaining: 4m 9s
# 200:	total: 21s	remaining: 3m 59s
# 300:	total: 31s	remaining: 3m 46s
# 400:	total: 40.7s	remaining: 3m 33s
# 500:	total: 50.6s	remaining: 3m 21s
# 600:	total: 1m	remaining: 3m 10s
# 700:	total: 1m 10s	remaining: 3m
# 800:	total: 1m 20s	remaining: 2m 50s
# 900:	total: 1m 30s	remaining: 2m 40s
# 1000:	total: 1m 40s	remaining: 2m 30s
# 1100:	total: 1m 49s	remaining: 2m 19s
# 1200:	total: 1m 59s	remaining: 2m 9s
# 1300:	total: 2m 10s	remaining: 1m 59s
# 1400:	total: 2m 20s	remaining: 1m 50s
# 1500:	total: 2m 30s	remaining: 1m 40s
# 1600:	total: 2m 40s	remaining: 1m 30s
# 1700:	total: 2m 49s	remaining: 1m 19s
# 1800:	total: 2m 59s	remaining: 1m 9s
# 1900:	total: 3m 9s	remaining: 59.6s
# 2000:	total: 3m 19s	remaining: 49.7s
# 2100:	total: 3m 28s	remaining: 39.7s
# 2200:	total: 3m 38s	remaining: 29.7s
# 2300:	total: 3m 48s	remaining: 19.8s
# 2400:	total: 3m 58s	remaining: 9.83s
# 2499:	total: 4m 8s	remaining: 0us
# 0:	total: 123ms	remaining: 5m 7s
# 100:	total: 9.83s	remaining: 3m 53s
# 200:	total: 19.5s	remaining: 3m 42s
# 300:	total: 29.5s	remaining: 3m 35s
# 400:	total: 39.7s	remaining: 3m 27s
# 500:	total: 49.7s	remaining: 3m 18s
# 600:	total: 59.6s	remaining: 3m 8s
# 700:	total: 1m 9s	remaining: 2m 58s
# 800:	total: 1m 19s	remaining: 2m 48s
# 900:	total: 1m 29s	remaining: 2m 39s
# 1000:	total: 1m 40s	remaining: 2m 29s
# 1100:	total: 1m 50s	remaining: 2m 20s
# 1200:	total: 2m 1s	remaining: 2m 11s
# 1300:	total: 2m 11s	remaining: 2m 1s
# 1400:	total: 2m 22s	remaining: 1m 51s
# 1500:	total: 2m 32s	remaining: 1m 41s
# 1600:	total: 2m 42s	remaining: 1m 31s
# 1700:	total: 2m 53s	remaining: 1m 21s
# 1800:	total: 3m 3s	remaining: 1m 11s
# 1900:	total: 3m 13s	remaining: 1m
# 2000:	total: 3m 24s	remaining: 50.9s
# 2100:	total: 3m 34s	remaining: 40.8s
# 2200:	total: 3m 45s	remaining: 30.6s
# 2300:	total: 3m 55s	remaining: 20.3s
# 2400:	total: 4m 5s	remaining: 10.1s
# 2499:	total: 4m 15s	remaining: 0us
# 0:	total: 125ms	remaining: 5m 12s
# 100:	total: 10.4s	remaining: 4m 5s
# 200:	total: 20.8s	remaining: 3m 57s
# 300:	total: 31s	remaining: 3m 46s
# 400:	total: 41.2s	remaining: 3m 35s
# 500:	total: 51.5s	remaining: 3m 25s
# 600:	total: 1m 1s	remaining: 3m 14s
# 700:	total: 1m 11s	remaining: 3m 4s
# 800:	total: 1m 22s	remaining: 2m 54s
# 900:	total: 1m 32s	remaining: 2m 44s
# 1000:	total: 1m 42s	remaining: 2m 33s
# 1100:	total: 1m 53s	remaining: 2m 23s
# 1200:	total: 2m 3s	remaining: 2m 13s
# 1300:	total: 2m 13s	remaining: 2m 2s
# 1400:	total: 2m 24s	remaining: 1m 53s
# 1500:	total: 2m 35s	remaining: 1m 43s
# 1600:	total: 2m 45s	remaining: 1m 33s
# 1700:	total: 2m 56s	remaining: 1m 22s
# 1800:	total: 3m 7s	remaining: 1m 12s
# 1900:	total: 3m 18s	remaining: 1m 2s
# 2000:	total: 3m 28s	remaining: 52s
# 2100:	total: 3m 39s	remaining: 41.6s
# 2200:	total: 3m 49s	remaining: 31.2s
# 2300:	total: 3m 59s	remaining: 20.8s
# 2400:	total: 4m 10s	remaining: 10.3s
# 2499:	total: 4m 20s	remaining: 0us
# 0:	total: 104ms	remaining: 4m 21s
# 100:	total: 10.5s	remaining: 4m 10s
# 200:	total: 20.9s	remaining: 3m 59s
# 300:	total: 31.4s	remaining: 3m 49s
# 400:	total: 42s	remaining: 3m 39s
# 500:	total: 52.8s	remaining: 3m 30s
# 600:	total: 1m 3s	remaining: 3m 21s
# 700:	total: 1m 14s	remaining: 3m 10s
# 800:	total: 1m 24s	remaining: 2m 59s
# 900:	total: 1m 35s	remaining: 2m 49s
# 1000:	total: 1m 45s	remaining: 2m 38s
# 1100:	total: 1m 56s	remaining: 2m 27s
# 1200:	total: 2m 6s	remaining: 2m 16s
# 1300:	total: 2m 16s	remaining: 2m 6s
# 1400:	total: 2m 27s	remaining: 1m 55s
# 1500:	total: 2m 37s	remaining: 1m 44s
# 1600:	total: 2m 47s	remaining: 1m 34s
# 1700:	total: 2m 58s	remaining: 1m 23s
# 1800:	total: 3m 8s	remaining: 1m 13s
# 1900:	total: 3m 18s	remaining: 1m 2s
# 2000:	total: 3m 28s	remaining: 52.1s
# 2100:	total: 3m 39s	remaining: 41.6s
# 2200:	total: 3m 49s	remaining: 31.2s
# 2300:	total: 4m	remaining: 20.8s
# 2400:	total: 4m 11s	remaining: 10.3s
# 2499:	total: 4m 21s	remaining: 0us
# 0:	total: 110ms	remaining: 4m 35s
# 100:	total: 10.4s	remaining: 4m 6s
# 200:	total: 20.8s	remaining: 3m 57s
# 300:	total: 31.9s	remaining: 3m 53s
# 400:	total: 42.8s	remaining: 3m 44s
# 500:	total: 53.3s	remaining: 3m 32s
# 600:	total: 1m 4s	remaining: 3m 22s
# 700:	total: 1m 14s	remaining: 3m 11s
# 800:	total: 1m 25s	remaining: 3m
# 900:	total: 1m 35s	remaining: 2m 49s
# 1000:	total: 1m 45s	remaining: 2m 38s
# 1100:	total: 1m 56s	remaining: 2m 27s
# 1200:	total: 2m 6s	remaining: 2m 16s
# 1300:	total: 2m 16s	remaining: 2m 6s
# 1400:	total: 2m 26s	remaining: 1m 55s
# 1500:	total: 2m 36s	remaining: 1m 44s
# 1600:	total: 2m 47s	remaining: 1m 33s
# 1700:	total: 2m 57s	remaining: 1m 23s
# 1800:	total: 3m 7s	remaining: 1m 12s
# 1900:	total: 3m 17s	remaining: 1m 2s
# 2000:	total: 3m 27s	remaining: 51.8s
# 2100:	total: 3m 37s	remaining: 41.4s
# 2200:	total: 3m 48s	remaining: 31s
# 2300:	total: 3m 59s	remaining: 20.7s
# 2400:	total: 4m 9s	remaining: 10.3s
# 2499:	total: 4m 19s	remaining: 0us
# 0:	total: 121ms	remaining: 5m 1s
# 100:	total: 10.4s	remaining: 4m 7s
# 200:	total: 20.5s	remaining: 3m 54s
# 300:	total: 30.8s	remaining: 3m 45s
# 400:	total: 41.1s	remaining: 3m 35s
# 500:	total: 51.4s	remaining: 3m 25s
# 600:	total: 1m 1s	remaining: 3m 14s
# 700:	total: 1m 11s	remaining: 3m 4s
# 800:	total: 1m 22s	remaining: 2m 54s
# 900:	total: 1m 32s	remaining: 2m 44s
# 1000:	total: 1m 43s	remaining: 2m 34s
# 1100:	total: 1m 53s	remaining: 2m 24s
# 1200:	total: 2m 4s	remaining: 2m 14s
# 1300:	total: 2m 14s	remaining: 2m 3s
# 1400:	total: 2m 24s	remaining: 1m 53s
# 1500:	total: 2m 34s	remaining: 1m 42s
# 1600:	total: 2m 44s	remaining: 1m 32s
# 1700:	total: 2m 54s	remaining: 1m 22s
# 1800:	total: 3m 4s	remaining: 1m 11s
# 1900:	total: 3m 15s	remaining: 1m 1s
# 2000:	total: 3m 25s	remaining: 51.2s
# 2100:	total: 3m 36s	remaining: 41.1s
# 2200:	total: 3m 46s	remaining: 30.8s
# 2300:	total: 3m 57s	remaining: 20.5s
# 2400:	total: 4m 8s	remaining: 10.2s
# 2499:	total: 4m 18s	remaining: 0us
# 0:	total: 106ms	remaining: 4m 24s
# 100:	total: 10.1s	remaining: 3m 59s
# 200:	total: 20.2s	remaining: 3m 51s
# 300:	total: 30.3s	remaining: 3m 41s
# 400:	total: 40.5s	remaining: 3m 32s
# 500:	total: 50.4s	remaining: 3m 21s
# 600:	total: 1m	remaining: 3m 10s
# 700:	total: 1m 10s	remaining: 3m
# 800:	total: 1m 20s	remaining: 2m 50s
# 900:	total: 1m 30s	remaining: 2m 40s
# 1000:	total: 1m 40s	remaining: 2m 30s
# 1100:	total: 1m 50s	remaining: 2m 20s
# 1200:	total: 2m	remaining: 2m 10s
# 1300:	total: 2m 10s	remaining: 2m
# 1400:	total: 2m 20s	remaining: 1m 50s
# 1500:	total: 2m 30s	remaining: 1m 40s
# 1600:	total: 2m 40s	remaining: 1m 30s
# 1700:	total: 2m 50s	remaining: 1m 20s
# 1800:	total: 3m 1s	remaining: 1m 10s
# 1900:	total: 3m 11s	remaining: 1m
# 2000:	total: 3m 21s	remaining: 50.2s
# 2100:	total: 3m 31s	remaining: 40.2s
# 2200:	total: 3m 41s	remaining: 30.1s
# 2300:	total: 3m 51s	remaining: 20s
# 2400:	total: 4m 1s	remaining: 9.97s
# 2499:	total: 4m 11s	remaining: 0us
# 0:	total: 113ms	remaining: 4m 43s
# 100:	total: 10.2s	remaining: 4m 2s
# 200:	total: 20s	remaining: 3m 48s
# 300:	total: 30.1s	remaining: 3m 39s
# 400:	total: 40.1s	remaining: 3m 29s
# 500:	total: 50.1s	remaining: 3m 20s
# 600:	total: 1m	remaining: 3m 10s
# 700:	total: 1m 10s	remaining: 3m 1s
# 800:	total: 1m 21s	remaining: 2m 52s
# 900:	total: 1m 31s	remaining: 2m 42s
# 1000:	total: 1m 41s	remaining: 2m 32s
# 1100:	total: 1m 51s	remaining: 2m 21s
# 1200:	total: 2m 1s	remaining: 2m 11s
# 1300:	total: 2m 11s	remaining: 2m 1s
# 1400:	total: 2m 21s	remaining: 1m 51s
# 1500:	total: 2m 32s	remaining: 1m 41s
# 1600:	total: 2m 42s	remaining: 1m 31s
# 1700:	total: 2m 52s	remaining: 1m 21s
# 1800:	total: 3m 2s	remaining: 1m 10s
# 1900:	total: 3m 12s	remaining: 1m
# 2000:	total: 3m 22s	remaining: 50.6s
# 2100:	total: 3m 33s	remaining: 40.5s
# 2200:	total: 3m 43s	remaining: 30.3s
# 2300:	total: 3m 53s	remaining: 20.2s
# 2400:	total: 4m 3s	remaining: 10s
# 2499:	total: 4m 13s	remaining: 0us
# 0:	total: 104ms	remaining: 4m 19s
# 100:	total: 10.2s	remaining: 4m 2s
# 200:	total: 20.5s	remaining: 3m 54s
# 300:	total: 30.7s	remaining: 3m 44s
# 400:	total: 41.1s	remaining: 3m 35s
# 500:	total: 51.9s	remaining: 3m 27s
# 600:	total: 1m 2s	remaining: 3m 18s
# 700:	total: 1m 13s	remaining: 3m 8s
# 800:	total: 1m 23s	remaining: 2m 58s
# 900:	total: 1m 34s	remaining: 2m 47s
# 1000:	total: 1m 44s	remaining: 2m 36s
# 1100:	total: 1m 54s	remaining: 2m 25s
# 1200:	total: 2m 5s	remaining: 2m 15s
# 1300:	total: 2m 15s	remaining: 2m 4s
# 1400:	total: 2m 25s	remaining: 1m 54s
# 1500:	total: 2m 35s	remaining: 1m 43s
# 1600:	total: 2m 45s	remaining: 1m 33s
# 1700:	total: 2m 56s	remaining: 1m 23s
# 1800:	total: 3m 7s	remaining: 1m 12s
# 1900:	total: 3m 17s	remaining: 1m 2s
# 2000:	total: 3m 27s	remaining: 51.7s
# 2100:	total: 3m 37s	remaining: 41.3s
# 2200:	total: 3m 48s	remaining: 31s
# 2300:	total: 3m 58s	remaining: 20.6s
# 2400:	total: 4m 8s	remaining: 10.3s
# 2499:	total: 4m 19s	remaining: 0us
# 0:	total: 142ms	remaining: 5m 54s
# 100:	total: 10.7s	remaining: 4m 13s
# 200:	total: 21.4s	remaining: 4m 5s
# 300:	total: 32.5s	remaining: 3m 57s
# 400:	total: 43s	remaining: 3m 45s
# 500:	total: 52.8s	remaining: 3m 30s
# 600:	total: 1m 2s	remaining: 3m 16s
# 700:	total: 1m 11s	remaining: 3m 2s
# 800:	total: 1m 20s	remaining: 2m 51s
# 900:	total: 1m 31s	remaining: 2m 42s
# 1000:	total: 1m 42s	remaining: 2m 33s
# 1100:	total: 1m 53s	remaining: 2m 23s
# 1200:	total: 2m 3s	remaining: 2m 14s
# 1300:	total: 2m 14s	remaining: 2m 4s
# 1400:	total: 2m 25s	remaining: 1m 53s
# 1500:	total: 2m 35s	remaining: 1m 43s
# 1600:	total: 2m 46s	remaining: 1m 33s
# 1700:	total: 2m 56s	remaining: 1m 22s
# 1800:	total: 3m 6s	remaining: 1m 12s
# 1900:	total: 3m 16s	remaining: 1m 1s
# 2000:	total: 3m 26s	remaining: 51.4s
# 2100:	total: 3m 36s	remaining: 41.1s
# 2200:	total: 3m 46s	remaining: 30.8s
# 2300:	total: 3m 56s	remaining: 20.4s
# 2400:	total: 4m 6s	remaining: 10.2s
# 2499:	total: 4m 17s	remaining: 0us
# |  5        |  0.9794   |  0.2122   |  8.391    |  0.03709  |
# 0:	total: 85.7ms	remaining: 3m 34s
# 100:	total: 5.23s	remaining: 2m 4s
# 200:	total: 10.4s	remaining: 1m 59s
# 300:	total: 15.7s	remaining: 1m 54s
# 400:	total: 20.8s	remaining: 1m 48s
# 500:	total: 26.1s	remaining: 1m 44s
# 600:	total: 31.5s	remaining: 1m 39s
# 700:	total: 37s	remaining: 1m 35s
# 800:	total: 42.4s	remaining: 1m 30s
# 900:	total: 47.7s	remaining: 1m 24s
# 1000:	total: 53.1s	remaining: 1m 19s
# 1100:	total: 58.5s	remaining: 1m 14s
# 1200:	total: 1m 3s	remaining: 1m 9s
# 1300:	total: 1m 9s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.4s
# 1500:	total: 1m 19s	remaining: 53s
# 1600:	total: 1m 25s	remaining: 47.9s
# 1700:	total: 1m 30s	remaining: 42.7s
# 1800:	total: 1m 36s	remaining: 37.5s
# 1900:	total: 1m 42s	remaining: 32.2s
# 2000:	total: 1m 47s	remaining: 26.9s
# 2100:	total: 1m 52s	remaining: 21.4s
# 2200:	total: 1m 58s	remaining: 16s
# 2300:	total: 2m 3s	remaining: 10.7s
# 2400:	total: 2m 8s	remaining: 5.29s
# 2499:	total: 2m 13s	remaining: 0us
# 0:	total: 67ms	remaining: 2m 47s
# 100:	total: 5.47s	remaining: 2m 10s
# 200:	total: 10.8s	remaining: 2m 2s
# 300:	total: 16.1s	remaining: 1m 57s
# 400:	total: 21.6s	remaining: 1m 52s
# 500:	total: 27s	remaining: 1m 47s
# 600:	total: 32.3s	remaining: 1m 42s
# 700:	total: 37.6s	remaining: 1m 36s
# 800:	total: 42.9s	remaining: 1m 30s
# 900:	total: 48s	remaining: 1m 25s
# ...
# 0:	total: 71.4ms	remaining: 2m 58s
# 100:	total: 5.66s	remaining: 2m 14s
# 200:	total: 11.4s	remaining: 2m 10s
# 300:	total: 17.3s	remaining: 2m 6s
# 400:	total: 22.7s	remaining: 1m 58s
# 500:	total: 28.2s	remaining: 1m 52s
# 600:	total: 33.8s	remaining: 1m 46s
# 700:	total: 39.5s	remaining: 1m 41s
# 800:	total: 45.2s	remaining: 1m 35s
# 900:	total: 50.7s	remaining: 1m 30s
# 1000:	total: 56.3s	remaining: 1m 24s
# 1100:	total: 1m 2s	remaining: 1m 18s
# 1200:	total: 1m 7s	remaining: 1m 13s
# 1300:	total: 1m 13s	remaining: 1m 7s
# 1400:	total: 1m 19s	remaining: 1m 2s
# 1500:	total: 1m 24s	remaining: 56.4s
# 1600:	total: 1m 30s	remaining: 50.8s
# 1700:	total: 1m 36s	remaining: 45.2s
# 1800:	total: 1m 41s	remaining: 39.4s
# 1900:	total: 1m 47s	remaining: 33.8s
# 2000:	total: 1m 52s	remaining: 28.2s
# 2100:	total: 1m 58s	remaining: 22.5s
# 2200:	total: 2m 4s	remaining: 16.9s
# 2300:	total: 2m 9s	remaining: 11.2s
# 2400:	total: 2m 15s	remaining: 5.58s
# 2499:	total: 2m 21s	remaining: 0us
# 0:	total: 106ms	remaining: 4m 24s
# 100:	total: 5.89s	remaining: 2m 19s
# 200:	total: 11.7s	remaining: 2m 14s
# 300:	total: 17.5s	remaining: 2m 7s
# 400:	total: 23.2s	remaining: 2m 1s
# 500:	total: 28.8s	remaining: 1m 54s
# 600:	total: 34.5s	remaining: 1m 48s
# 700:	total: 40.4s	remaining: 1m 43s
# 800:	total: 46.2s	remaining: 1m 38s
# 900:	total: 52s	remaining: 1m 32s
# 1000:	total: 57.9s	remaining: 1m 26s
# 1100:	total: 1m 3s	remaining: 1m 20s
# 1200:	total: 1m 9s	remaining: 1m 14s
# 1300:	total: 1m 14s	remaining: 1m 8s
# 1400:	total: 1m 20s	remaining: 1m 3s
# 1500:	total: 1m 26s	remaining: 57.3s
# 1600:	total: 1m 31s	remaining: 51.6s
# 1700:	total: 1m 37s	remaining: 45.9s
# 1800:	total: 1m 43s	remaining: 40.3s
# 1900:	total: 1m 49s	remaining: 34.6s
# 2000:	total: 1m 55s	remaining: 28.9s
# 2100:	total: 2m 1s	remaining: 23s
# 2200:	total: 2m 6s	remaining: 17.2s
# 2300:	total: 2m 12s	remaining: 11.4s
# 2400:	total: 2m 17s	remaining: 5.67s
# 2499:	total: 2m 23s	remaining: 0us
# 0:	total: 90.5ms	remaining: 3m 46s
# 100:	total: 5.46s	remaining: 2m 9s
# 200:	total: 11s	remaining: 2m 6s
# 300:	total: 16.5s	remaining: 2m
# 400:	total: 22.3s	remaining: 1m 56s
# 500:	total: 28s	remaining: 1m 51s
# 600:	total: 33.8s	remaining: 1m 46s
# 700:	total: 39.2s	remaining: 1m 40s
# 800:	total: 44.6s	remaining: 1m 34s
# 900:	total: 50.1s	remaining: 1m 28s
# 1000:	total: 55.8s	remaining: 1m 23s
# 1100:	total: 1m 1s	remaining: 1m 18s
# 1200:	total: 1m 6s	remaining: 1m 12s
# 1300:	total: 1m 12s	remaining: 1m 6s
# 1400:	total: 1m 17s	remaining: 1m 1s
# 1500:	total: 1m 23s	remaining: 55.6s
# 1600:	total: 1m 29s	remaining: 50s
# 1700:	total: 1m 34s	remaining: 44.5s
# 1800:	total: 1m 40s	remaining: 38.9s
# 1900:	total: 1m 45s	remaining: 33.3s
# 2000:	total: 1m 51s	remaining: 27.7s
# 2100:	total: 1m 56s	remaining: 22.1s
# 2200:	total: 2m 2s	remaining: 16.6s
# 2300:	total: 2m 7s	remaining: 11s
# 2400:	total: 2m 13s	remaining: 5.49s
# 2499:	total: 2m 18s	remaining: 0us
# 0:	total: 59.6ms	remaining: 2m 28s
# 100:	total: 5.47s	remaining: 2m 9s
# 200:	total: 11.1s	remaining: 2m 6s
# 300:	total: 16.6s	remaining: 2m 1s
# 400:	total: 22.6s	remaining: 1m 58s
# 500:	total: 28.5s	remaining: 1m 53s
# 600:	total: 34.4s	remaining: 1m 48s
# 700:	total: 40.2s	remaining: 1m 43s
# 800:	total: 46s	remaining: 1m 37s
# 900:	total: 51.8s	remaining: 1m 31s
# 1000:	total: 57.3s	remaining: 1m 25s
# 1100:	total: 1m 2s	remaining: 1m 19s
# 1200:	total: 1m 8s	remaining: 1m 14s
# 1300:	total: 1m 14s	remaining: 1m 8s
# 1400:	total: 1m 20s	remaining: 1m 2s
# 1500:	total: 1m 25s	remaining: 57s
# 1600:	total: 1m 31s	remaining: 51.3s
# 1700:	total: 1m 36s	remaining: 45.5s
# 1800:	total: 1m 42s	remaining: 39.7s
# 1900:	total: 1m 48s	remaining: 34.1s
# 2000:	total: 1m 53s	remaining: 28.3s
# 2100:	total: 1m 58s	remaining: 22.6s
# 2200:	total: 2m 4s	remaining: 16.9s
# 2300:	total: 2m 10s	remaining: 11.3s
# 2400:	total: 2m 16s	remaining: 5.63s
# 2499:	total: 2m 22s	remaining: 0us
# 0:	total: 116ms	remaining: 4m 50s
# 100:	total: 5.83s	remaining: 2m 18s
# 200:	total: 11.7s	remaining: 2m 14s
# 300:	total: 17.5s	remaining: 2m 8s
# 400:	total: 23.3s	remaining: 2m 1s
# 500:	total: 28.9s	remaining: 1m 55s
# 600:	total: 34.5s	remaining: 1m 48s
# 700:	total: 40.1s	remaining: 1m 42s
# 800:	total: 45.9s	remaining: 1m 37s
# 900:	total: 51.5s	remaining: 1m 31s
# 1000:	total: 57.2s	remaining: 1m 25s
# 1100:	total: 1m 2s	remaining: 1m 19s
# 1200:	total: 1m 8s	remaining: 1m 14s
# 1300:	total: 1m 14s	remaining: 1m 8s
# 1400:	total: 1m 20s	remaining: 1m 3s
# 1500:	total: 1m 26s	remaining: 57.4s
# 1600:	total: 1m 31s	remaining: 51.6s
# 1700:	total: 1m 37s	remaining: 45.8s
# 1800:	total: 1m 43s	remaining: 40.1s
# 1900:	total: 1m 49s	remaining: 34.4s
# 2000:	total: 1m 54s	remaining: 28.6s
# 2100:	total: 2m	remaining: 22.9s
# 2200:	total: 2m 6s	remaining: 17.1s
# 2300:	total: 2m 11s	remaining: 11.4s
# 2400:	total: 2m 17s	remaining: 5.67s
# 2499:	total: 2m 23s	remaining: 0us
# 0:	total: 70.2ms	remaining: 2m 55s
# 100:	total: 5.73s	remaining: 2m 16s
# 200:	total: 11.3s	remaining: 2m 9s
# 300:	total: 16.8s	remaining: 2m 2s
# 400:	total: 22.1s	remaining: 1m 55s
# 500:	total: 27.1s	remaining: 1m 48s
# 600:	total: 32.6s	remaining: 1m 43s
# 700:	total: 38s	remaining: 1m 37s
# 800:	total: 43.3s	remaining: 1m 31s
# 900:	total: 48.9s	remaining: 1m 26s
# 1000:	total: 54.7s	remaining: 1m 21s
# 1100:	total: 1m	remaining: 1m 16s
# 1200:	total: 1m 5s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 5s
# 1400:	total: 1m 16s	remaining: 60s
# 1500:	total: 1m 21s	remaining: 54.6s
# 1600:	total: 1m 27s	remaining: 49.3s
# 1700:	total: 1m 33s	remaining: 43.9s
# 1800:	total: 1m 38s	remaining: 38.3s
# 1900:	total: 1m 44s	remaining: 32.9s
# 2000:	total: 1m 50s	remaining: 27.4s
# 2100:	total: 1m 55s	remaining: 21.9s
# 2200:	total: 2m 1s	remaining: 16.4s
# 2300:	total: 2m 6s	remaining: 10.9s
# 2400:	total: 2m 11s	remaining: 5.43s
# 2499:	total: 2m 17s	remaining: 0us
# 0:	total: 78.2ms	remaining: 3m 15s
# 100:	total: 5.27s	remaining: 2m 5s
# 200:	total: 10.5s	remaining: 2m
# 300:	total: 16.3s	remaining: 1m 59s
# 400:	total: 22s	remaining: 1m 55s
# 500:	total: 27.5s	remaining: 1m 49s
# 600:	total: 33.1s	remaining: 1m 44s
# 700:	total: 38.7s	remaining: 1m 39s
# 800:	total: 44.2s	remaining: 1m 33s
# 900:	total: 49.6s	remaining: 1m 27s
# 1000:	total: 55.1s	remaining: 1m 22s
# 1100:	total: 1m	remaining: 1m 17s
# 1200:	total: 1m 6s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 5s
# 1400:	total: 1m 16s	remaining: 1m
# 1500:	total: 1m 22s	remaining: 54.8s
# 1600:	total: 1m 27s	remaining: 49.2s
# 1700:	total: 1m 33s	remaining: 43.8s
# 1800:	total: 1m 38s	remaining: 38.3s
# 1900:	total: 1m 44s	remaining: 32.8s
# 2000:	total: 1m 49s	remaining: 27.3s
# 2100:	total: 1m 55s	remaining: 21.9s
# 2200:	total: 2m	remaining: 16.4s
# 2300:	total: 2m 6s	remaining: 10.9s
# 2400:	total: 2m 11s	remaining: 5.43s
# 2499:	total: 2m 17s	remaining: 0us
# 0:	total: 74.1ms	remaining: 3m 5s
# 100:	total: 5.63s	remaining: 2m 13s
# 200:	total: 11.2s	remaining: 2m 7s
# 300:	total: 16.7s	remaining: 2m 2s
# 400:	total: 22.3s	remaining: 1m 56s
# 500:	total: 28s	remaining: 1m 51s
# 600:	total: 33.7s	remaining: 1m 46s
# 700:	total: 39.4s	remaining: 1m 41s
# 800:	total: 45.5s	remaining: 1m 36s
# 900:	total: 51.5s	remaining: 1m 31s
# 1000:	total: 57.1s	remaining: 1m 25s
# 1100:	total: 1m 2s	remaining: 1m 19s
# 1200:	total: 1m 8s	remaining: 1m 13s
# 1300:	total: 1m 13s	remaining: 1m 8s
# 1400:	total: 1m 19s	remaining: 1m 2s
# 1500:	total: 1m 25s	remaining: 56.9s
# 1600:	total: 1m 31s	remaining: 51.2s
# 1700:	total: 1m 36s	remaining: 45.4s
# 1800:	total: 1m 42s	remaining: 39.7s
# 1900:	total: 1m 47s	remaining: 33.9s
# 2000:	total: 1m 53s	remaining: 28.3s
# 2100:	total: 1m 59s	remaining: 22.6s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.7282672353105268, 7.64306006925346, 0.2025464632348702)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-7d46391b1c97> in <module>
#       1 optimizer.maximize(
#       2     init_points = 5,
# ----> 3     n_iter = 25,
#       4 )
#       5 print(optimizer.max)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# D:\AZhongnan University\python\Ana\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-173-dd82fa275d4f> in modelfit(learning_rate, depth, bagging_temperature)
#       7                              verbose = 100,
#       8                              bagging_temperature = float(bagging_temperature),
# ----> 9                              early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=10).mean()
#      10     return cat1
#      11
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     443                                 fit_params=fit_params,
#     444                                 pre_dispatch=pre_dispatch,
# --> 445                                 error_score=error_score)
#     446     return cv_results['test_score']
#     447
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     250             return_times=True, return_estimator=return_estimator,
#     251             error_score=error_score)
# --> 252         for train, test in cv.split(X, y, groups))
#     253
#     254     # For callabe scoring, the return type is only know after calling. If the
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     591             estimator.fit(X_train, **fit_params)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#     595     except Exception as e:
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4539         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4540                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 4541                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4542         return self
#    4543
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1921                 params,
#    1922                 allow_clear_pool,
# -> 1923                 train_params["init_model"]
#    1924             )
#    1925
#
# D:\AZhongnan University\python\Ana\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1364
#    1365     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1366         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1367         self._set_trained_model_attributes()
#    1368
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
#categorical_features_indices = np.where(X_train.dtypes != np.float)[0]

cat1 = CatBoostClassifier(loss_function="Logloss",eval_metric="AUC",
                          iterations=2500,learning_rate=0.01,depth=7,verbose=100,bagging_temperature = 0.42,
                          early_stopping_rounds=500)
cat1.fit(X_train,pd.DataFrame(y_train))

y_test_pre = cat1.predict(X_test)
y_test_true = np.array(y_test)
print ("the catboost model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# 0:	total: 68.6ms	remaining: 2m 51s
# 100:	total: 5.04s	remaining: 1m 59s
# 200:	total: 9.99s	remaining: 1m 54s
# 300:	total: 14.9s	remaining: 1m 49s
# 400:	total: 19.9s	remaining: 1m 44s
# 500:	total: 24.8s	remaining: 1m 39s
# 600:	total: 30s	remaining: 1m 34s
# 700:	total: 34.9s	remaining: 1m 29s
# 800:	total: 39.9s	remaining: 1m 24s
# 900:	total: 44.9s	remaining: 1m 19s
# 1000:	total: 50.1s	remaining: 1m 15s
# 1100:	total: 55.4s	remaining: 1m 10s
# 1200:	total: 1m	remaining: 1m 5s
# 1300:	total: 1m 6s	remaining: 1m
# 1400:	total: 1m 11s	remaining: 56.1s
# 1500:	total: 1m 16s	remaining: 51.2s
# 1600:	total: 1m 22s	remaining: 46.3s
# 1700:	total: 1m 28s	remaining: 41.3s
# 1800:	total: 1m 33s	remaining: 36.2s
# 1900:	total: 1m 38s	remaining: 31.2s
# 2000:	total: 1m 44s	remaining: 26s
# 2100:	total: 1m 49s	remaining: 20.8s
# 2200:	total: 1m 55s	remaining: 15.6s
# 2300:	total: 2m	remaining: 10.4s
# 2400:	total: 2m 5s	remaining: 5.18s
# 2499:	total: 2m 11s	remaining: 0us
# the catboost model auc : 0.825

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('CatBoostClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98       167
#          1.0       1.00      0.65      0.79        20
#
#     accuracy                           0.96       187
#    macro avg       0.98      0.82      0.88       187
# weighted avg       0.96      0.96      0.96       187
#
# auc值为: 0.825
# Text(0.5, 1.0, 'CatBoostClassifier ROC Curve')

# %%
#特征重要性排名
cat_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
cat_feat_imp = pd.Series(cat1.feature_importances_,cat_predictors).sort_values(ascending=False)
cat_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(cat_feat_imp)
# Out:
# INCOME_TAX           2.524713
# RETAINED_EARNINGS    2.371421
# OTH_NCA              1.853066
# OR_TC                1.795289
# DEFER_TAX_LIAB       1.754735
#                        ...
# EQU_MULTIPLIER       0.073190
# TAXES_PAYABLE        0.072997
# REPAY_TA             0.070505
# N_TAN_A_ND           0.064383
# AP_TURNOVER          0.028162
# Length: 254, dtype: float64

# %%
print(cat_feat_imp[0:20])
# Out:
# INCOME_TAX            2.524713
# RETAINED_EARNINGS     2.371421
# OTH_NCA               1.853066
# OR_TC                 1.795289
# DEFER_TAX_LIAB        1.754735
# LT_EQUITY_INVEST      1.478554
# BIZ_TAX_SURCHG        1.422587
# NOPG_TR               1.324570
# C_PAID_OTH_FINAN_A    1.136174
# VAL_CHG_PROFIT        1.126608
# FOREX_EFFECTS         1.096175
# PERIOD_EXP_TR         1.006891
# TP_TR                 0.973867
# EBIT_TR               0.927881
# IN_TC                 0.922039
# ST_BORR               0.890893
# C_PAID_FOR_TAXES      0.867475
# N_CE_BEG_BAL          0.817710
# T_EQUITY_ATTR_P       0.808398
# AVAIL_FOR_SALE_FA     0.800955
# dtype: float64
