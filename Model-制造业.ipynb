# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split,cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %% [markdown]
# - 读取数据

# %%
ramdonForest_end_Data = pd.read_csv('./制造业_处理.csv',encoding = 'gbk')

# %%
ramdonForest_end_Data = ramdonForest_end_Data.drop(columns = 'Unnamed: 0')

# %% [markdown]
# - 过采样数据

# %%
#定义SMOTE模型，random_state相当于随机数种子的作用
#smo = SMOTE(sampling_strategy={1: 180,0:1000 },random_state=42)

ros = RandomOverSampler(random_state=30,sampling_strategy=0.02)
X_ros,y_ros = ros.fit_resample(ramdonForest_end_Data.drop(columns = 'FLAG'),ramdonForest_end_Data['FLAG'])
#标准化数据
sc=StandardScaler()
sc.fit(X_ros)#计算样本的均值和标准差
X_ros=pd.DataFrame(sc.transform(X_ros))
#拆分专家样本集
X_train, X_test, y_train, y_test = train_test_split(X_ros,y_ros,test_size=0.3)
y_train.groupby(y_train).count()
# Out:
# FLAG
# 0.0    7855
# 1.0     155
# Name: FLAG, dtype: int64

# %% [markdown]
# - XGBoost模型调整

# %%
# 贝叶斯优化调参

def modelfit(learning_rate, n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree,
             Reg_lambda, Reg_alpha):
    xgb1 =cross_val_score(xgb.XGBClassifier(objective='binary:logistic', nthread=2,
                             n_estimators=int(n_estimators),
                             learning_rate=float(learning_rate),
                             max_depth=int(max_depth), min_child_weight=int(min_child_weight),
                             gamma=float(gamma), subsample=float(subsample),
                             colsample_bytree=float(colsample_bytree),
                             Reg_lambda=float(Reg_lambda), Reg_alpha=float(Reg_alpha),
                             scale_pos_weight=1, seed=10, ),X_train, pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return xgb1


# 参数因子池
pool = {
    'learning_rate': (0.0001, 0.9999),
    'n_estimators': (400, 800),
    'max_depth': (1, 20),  # 树模型深度
    'min_child_weight': (1, 5),
    'gamma': (0.1, 0.7),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.6, 0.9),
    'Reg_lambda': (0.001, 3),
    'Reg_alpha': (0.001, 2)

}
# 定义贝叶斯调参模型
from bayes_opt import BayesianOptimization as bayes

optimizer = bayes(f=modelfit,
                  pbounds=pool,
                  verbose=2,
                  random_state=1,
                  )

# %%
# 调参并输出最优因子
optimizer.maximize(
    init_points=5,
    n_iter=25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | Reg_alpha | Reg_la... | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [01:37:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:37:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:37:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:37:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:38:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:38:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:39:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:39:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  1        |  0.7231   |  0.8346   |  2.161    |  0.6      |  0.2814   |  0.1468   |  2.754    |  1.745    |  538.2    |  0.719    |
# [01:40:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:40:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:40:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [01:41:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:41:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
#   return f(*args, **kwargs)
# [02:46:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:46:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:46:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:46:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:46:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:46:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [02:47:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [02:47:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# |  30       |  0.6335   |  1.425    |  2.043    |  0.7696   |  0.4255   |  0.8526   |  10.08    |  4.902    |  718.3    |  0.7196   |
# =====================================================================================================================================
# {'target': 0.7444264044676394, 'params': {'Reg_alpha': 0.29038201070971426, 'Reg_lambda': 2.137858204924039, 'colsample_bytree': 0.8305698845925207, 'gamma': 0.3565468551752967, 'learning_rate': 0.17428190980188565, 'max_depth': 2.7278661991091258, 'min_child_weight': 4.166716234372528, 'n_estimators': 539.470863842672, 'subsample': 0.827410536318948}}

# %%
# xgboost模型训练
{'target': 0.7444264044676394, 'params': {'Reg_alpha': 0.29038201070971426, 'Reg_lambda': 2.137858204924039,
                                          'colsample_bytree': 0.8305698845925207, 'gamma': 0.3565468551752967,
                                          'learning_rate': 0.17428190980188565, 'max_depth': 2.7278661991091258,
                                          'min_child_weight': 4.166716234372528, 'n_estimators': 539.470863842672,
                                          'subsample': 0.827410536318948}}


xgb1 = xgb.XGBClassifier(n_estimators=539,learning_rate=0.17,
                        max_depth=2,min_child_weight=4,gamma=0.35,
                        subsample=0.82,colsample_bytree=0.83,
                        objective='binary:logistic',nthread=2,
                        scale_pos_weight=100,seed=10,Reg_lambda = 2.13,
                         Reg_alpha = 0.29)#scale_pos_weight很重要
xgb1.fit(X_train, y_train)

y_test_pre = xgb1.predict(X_test)
y_test_true = np.array(y_test)
print("the xgboost model auc: %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:53:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { Reg_alpha, Reg_lambda } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:53:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# the xgboost model auc: 0.8738

# %%
# 特征重要性排名
xgb_predictors = [i for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
xgb_feat_imp = pd.Series(xgb1.feature_importances_, xgb_predictors).sort_values(ascending=False)
xgb_feat_imp[0:20].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(xgb_feat_imp[0:20])
# Out:
# DILUTED_EPS           0.071119
# INT_PAYABLE           0.054069
# BASIC_EPS             0.049517
# C_INF_FR_OPERATE_A    0.036825
# COGS                  0.029479
# N_CF_FR_INVEST_A      0.029146
# T_REVENUE             0.028104
# C_PAID_TO_FOR_EMPL    0.028012
# OTH_COMPRE_INCOME     0.022976
# ASSETS_IMPAIR_LOSS    0.022773
# REFUND_OF_TAX         0.021334
# MINORITY_GAIN         0.019575
# PAID_IN_CAPITAL       0.018585
# C_OUTF_FR_INVEST_A    0.017614
# OPERATE_PROFIT        0.014892
# RETAINED_EARNINGS     0.014707
# ADVANCE_RECEIPTS      0.014369
# INVEST_INCOME         0.014146
# INTAN_ASSETS          0.013769
# C_OUTF_OPERATE_A      0.013500
# dtype: float32

# %%
xgb_feat_imp[0:20]
# Out:
# DILUTED_EPS           0.071119
# INT_PAYABLE           0.054069
# BASIC_EPS             0.049517
# C_INF_FR_OPERATE_A    0.036825
# COGS                  0.029479
# N_CF_FR_INVEST_A      0.029146
# T_REVENUE             0.028104
# C_PAID_TO_FOR_EMPL    0.028012
# OTH_COMPRE_INCOME     0.022976
# ASSETS_IMPAIR_LOSS    0.022773
# REFUND_OF_TAX         0.021334
# MINORITY_GAIN         0.019575
# PAID_IN_CAPITAL       0.018585
# C_OUTF_FR_INVEST_A    0.017614
# OPERATE_PROFIT        0.014892
# RETAINED_EARNINGS     0.014707
# ADVANCE_RECEIPTS      0.014369
# INVEST_INCOME         0.014146
# INTAN_ASSETS          0.013769
# C_OUTF_OPERATE_A      0.013500
# dtype: float32

# %%
# 具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:", roc_auc_score(y_test_true,y_test_pre))

# ROC曲线绘制
fpr1, tpr1, threshold1 = roc_curve(y_test_true, y_test_pre)
plt.plot(fpr1, tpr1, color='r')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3364
#          1.0       0.92      0.70      0.79        69
#
#     accuracy                           0.99      3433
#    macro avg       0.96      0.85      0.89      3433
# weighted avg       0.99      0.99      0.99      3433
#
# auc值为: 0.8472315566354753
# Text(0.5, 1.0, 'XGBClassifier ROC Curve')

# %% [markdown]
# - LightGBM模型调整

# %%
#贝叶斯优化调参
def modelfit(learning_rate,n_estimators,max_depth,num_leaves,min_data_in_leaf,max_bin,feature_fraction,
            bagging_fraction,bagging_freq,lambda_l1,lambda_l2,min_split_gain):
    lgb1 = cross_val_score(lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                              n_estimators = int(n_estimators),
                              max_depth = int(max_depth),
                              num_leaves = int(num_leaves),
                              learning_rate = float(learning_rate),
                              min_data_in_leaf = int(min_data_in_leaf),
                              max_bin = int(max_bin),
                              feature_fraction = float(feature_fraction),
                              bagging_fraction = float(bagging_fraction),
                              bagging_freq = int(bagging_freq),
                              lambda_l1 = float(lambda_l1),lambda_l2 = float(lambda_l2),
                              min_split_gain = float(min_split_gain),
                              cat_smooth = 100,nthread = 4, ),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return lgb1

pool = {
    'learning_rate':(0.0001,0.9999),
    'n_estimators':(400,800),
    'max_depth':(1,20),              #树模型深度
    'num_leaves':(10,30),            #叶子树，树模型复杂度
    'min_data_in_leaf':(1,70),       #处理过拟合，一个叶子上数据的最小数量
    'max_bin':(5,255),               #工具箱数（叶子结点数+非叶子节点数？）
    'feature_fraction':(0.5,0.999),  #每次迭代中随机选择特征的比例。加速训练，处理过拟合
    'bagging_fraction':(0.5,0.999),  #不进行重采样的情况下随机选择部分数据
    'bagging_freq':(3,5),            #bagging的次数。0表示禁用bagging，非零值表示执行k次bagging
    'lambda_l1':(0.0001,0.9999),
    'lambda_l2':(0.0001,0.9999),
    'min_split_gain':(0.01,0.999)    #执行切分的最小增益
    
}

from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | lambda_l1 | lambda_l2 | learni... |  max_bin  | max_depth | min_da... | min_sp... | n_esti... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.500057073033855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.500057073033855
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] lambda_l1 is set=0.3023721061173134, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3023721061173134
# [LightGBM] [Warning] bagging_fraction is set=0.7080939803465844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7080939803465844
# [LightGBM] [Warning] lambda_l2 is set=0.14682653963894962, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14682653963894962
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  1        |  0.89     |  0.7081   |  4.441    |  0.5001   |  0.3024   |  0.1468   |  0.09242  |  51.57    |  7.566    |  28.38    |  0.5429   |  567.7    |  23.7     |
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.5136664090057651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5136664090057651
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] lambda_l1 is set=0.6704334166763666, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6704334166763666
# [LightGBM] [Warning] bagging_fraction is set=0.6020216726160272, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6020216726160272
# [LightGBM] [Warning] lambda_l2 is set=0.41732134140665356, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.41732134140665356
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# |  2        |  0.8301   |  0.602    |  4.756    |  0.5137   |  0.6704   |  0.4173   |  0.5587   |  40.1     |  4.764    |  56.25    |  0.9676   |  525.4    |  23.85    |
# ...
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7477929032856548, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7477929032856548
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.96275176923308, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.96275176923308
# [LightGBM] [Warning] bagging_fraction is set=0.7190270392325901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7190270392325901
# [LightGBM] [Warning] lambda_l2 is set=0.29131720951178314, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.29131720951178314
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# |  30       |  0.7824   |  0.719    |  3.046    |  0.7478   |  0.9628   |  0.2913   |  0.5413   |  128.2    |  8.644    |  33.52    |  0.07696  |  638.3    |  23.9     |
# =========================================================================================================================================================================
# {'target': 0.8976103167529914, 'params': {'bagging_fraction': 0.6899424245303116, 'bagging_freq': 3.3595080734663636, 'feature_fraction': 0.7006874690394542, 'lambda_l1': 0.8528279027389037, 'lambda_l2': 0.9091432181917809, 'learning_rate': 0.05492573645530399, 'max_bin': 125.69457123084301, 'max_depth': 3.9425150361540835, 'min_data_in_leaf': 33.15414509767213, 'min_split_gain': 0.04210591375321138, 'n_estimators': 643.2020652098663, 'num_leaves': 25.5114215116726}}

# %%
{'target': 0.8976103167529914, 'params': {'bagging_fraction': 0.6899424245303116, 'bagging_freq': 3.3595080734663636,
                                          'feature_fraction': 0.7006874690394542, 'lambda_l1': 0.8528279027389037, 
                                          'lambda_l2': 0.9091432181917809, 'learning_rate': 0.05492573645530399, 
                                          'max_bin': 125.69457123084301, 'max_depth': 3.9425150361540835, 
                                          'min_data_in_leaf': 33.15414509767213, 'min_split_gain': 0.04210591375321138,
                                          'n_estimators': 643.2020652098663, 'num_leaves': 25.5114215116726}}
lgb1 = lgb.LGBMClassifier(boosting_type='gbdt',objective= 'binary',metric =  'binary_logloss,auc',
                          bagging_fraction = 0.68, bagging_freq = 6,
                          feature_fraction = 0.7,lambda_l1 =  0.85,lambda_l2 = 0.90,
                          learning_rate = 0.2,max_bin = 125,max_depth = 3,
                          min_data_in_leaf = 33,min_split_gain = 0.1,
                          n_estimators = 800,num_leaves = 30,
                          cat_smooth = 100,nthread = 4)
#cat_smooth：可以减少噪声对分类特征的影响，尤其是对于数据较少的分类
lgb_model = lgb1.fit(X_train,pd.DataFrame(y_train))
y_test_pre = lgb1.predict(X_test)
y_test_true = np.array(y_test)
print ("the lightgbm model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# D:\AZhongnan University\python\Ana\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] lambda_l1 is set=0.85, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.85
# [LightGBM] [Warning] bagging_fraction is set=0.68, subsample=1.0 will be ignored. Current value: bagging_fraction=0.68
# [LightGBM] [Warning] lambda_l2 is set=0.9, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# the lightgbm model auc : 0.8472

# %%
#特征重要性排名
lgb_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
lgb_feat_imp = pd.Series(lgb_model.feature_importances_,lgb_predictors).sort_values(ascending=False)
lgb_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(lgb_feat_imp )
# Out:
# NOTES_PAYABLE          24
# INVEST_INCOME          23
# ASSETS_IMPAIR_LOSS     21
# MINORITY_INT           21
# DISP_FIX_ASSETS_OTH    21
#                        ..
# C_FR_SALE_G_S           2
# C_FR_BORR               1
# REVENUE                 1
# T_ASSETS                1
# T_LIAB_EQUITY           0
# Length: 98, dtype: int32

# %%
print(lgb_feat_imp[0:20] )
# Out:
# NOTES_PAYABLE          24
# INVEST_INCOME          23
# ASSETS_IMPAIR_LOSS     21
# MINORITY_INT           21
# DISP_FIX_ASSETS_OTH    21
# ADVANCE_RECEIPTS       20
# OTH_CA                 20
# PREPAYMENT             20
# IN_TC                  20
# FOREX_EFFECTS          20
# NOPERATE_INCOME        19
# N_CE_BEG_BAL           18
# AP_TC                  17
# OTH_RECEIV             17
# NOPERATE_EXP           17
# INT_PAYABLE            16
# C_PAID_OTH_FINAN_A     16
# C_PAID_FOR_TAXES       15
# ST_BORR                15
# PAID_IN_CAPITAL        15
# dtype: int32

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3364
#          1.0       0.92      0.70      0.79        69
#
#     accuracy                           0.99      3433
#    macro avg       0.96      0.85      0.89      3433
# weighted avg       0.99      0.99      0.99      3433
#
# auc值为: 0.8472315566354753
# Text(0.5, 1.0, 'LGBClassifier ROC Curve')

# %% [markdown]
# - Catboost模型调整

# %%
def modelfit(learning_rate,depth,bagging_temperature):
    cat1 = cross_val_score(CatBoostClassifier(loss_function = 'Logloss',
                             eval_metric = 'AUC',
                             iterations = 2500,
                             learning_rate = float(learning_rate),
                             depth = int(depth),
                             verbose = 100,
                             bagging_temperature = float(bagging_temperature),
                             early_stopping_rounds = 500),X_train,pd.DataFrame(y_train),scoring='roc_auc',cv=20).mean()
    return cat1

pool = {
    'learning_rate':(0.01,0.999),
    'depth':(4,9),
    'bagging_temperature':(0.01,0.999)
}
from bayes_opt import BayesianOptimization as bayes
optimizer = bayes(f=modelfit,
                 pbounds = pool,
                 verbose = 2,
                 random_state = 1,
                 )

# %%
optimizer.maximize(
    init_points = 5,
    n_iter = 25,
)
print(optimizer.max)
# Out:
# |   iter    |  target   | baggin... |   depth   | learni... |
# -------------------------------------------------------------
# 0:	total: 40.8ms	remaining: 1m 41s
# 100:	total: 2.87s	remaining: 1m 8s
# 200:	total: 5.59s	remaining: 1m 4s
# 300:	total: 8.37s	remaining: 1m 1s
# 400:	total: 11.1s	remaining: 58s
# 500:	total: 13.8s	remaining: 55s
# 600:	total: 16.5s	remaining: 52s
# 700:	total: 19.2s	remaining: 49.2s
# 800:	total: 22s	remaining: 46.7s
# 900:	total: 24.9s	remaining: 44.2s
# 1000:	total: 27.7s	remaining: 41.5s
# 1100:	total: 30.5s	remaining: 38.8s
# 1200:	total: 33.4s	remaining: 36.1s
# 1300:	total: 36.2s	remaining: 33.4s
# 1400:	total: 39.1s	remaining: 30.7s
# 1500:	total: 42.2s	remaining: 28.1s
# 1600:	total: 45s	remaining: 25.3s
# 1700:	total: 47.8s	remaining: 22.5s
# 1800:	total: 50.6s	remaining: 19.7s
# 1900:	total: 53.9s	remaining: 17s
# 2000:	total: 57.2s	remaining: 14.3s
# 2100:	total: 1m	remaining: 11.5s
# 2200:	total: 1m 4s	remaining: 8.7s
# 2300:	total: 1m 7s	remaining: 5.83s
# 2400:	total: 1m 10s	remaining: 2.9s
# 2499:	total: 1m 13s	remaining: 0us
# 0:	total: 68.3ms	remaining: 2m 50s
# 100:	total: 3.14s	remaining: 1m 14s
# 200:	total: 6.11s	remaining: 1m 9s
# 300:	total: 9.36s	remaining: 1m 8s
# 400:	total: 12.4s	remaining: 1m 5s
# 500:	total: 15.5s	remaining: 1m 1s
# 600:	total: 18.9s	remaining: 59.6s
# 700:	total: 22.1s	remaining: 56.7s
# 800:	total: 25.2s	remaining: 53.5s
# 900:	total: 28.2s	remaining: 50.1s
# 1000:	total: 31.3s	remaining: 46.8s
# 1100:	total: 34.2s	remaining: 43.4s
# 1200:	total: 37.2s	remaining: 40.3s
# 1300:	total: 40.3s	remaining: 37.2s
# 1400:	total: 43.5s	remaining: 34.2s
# 1500:	total: 46.7s	remaining: 31.1s
# 1600:	total: 49.8s	remaining: 27.9s
# 1700:	total: 53s	remaining: 24.9s
# 1800:	total: 56.5s	remaining: 21.9s
# 1900:	total: 1m	remaining: 18.9s
# 2000:	total: 1m 3s	remaining: 15.8s
# 2100:	total: 1m 6s	remaining: 12.5s
# 2200:	total: 1m 8s	remaining: 9.35s
# 2300:	total: 1m 11s	remaining: 6.2s
# 2400:	total: 1m 14s	remaining: 3.08s
# 2499:	total: 1m 17s	remaining: 0us
# 0:	total: 42.9ms	remaining: 1m 47s
# 100:	total: 2.95s	remaining: 1m 10s
# 200:	total: 5.87s	remaining: 1m 7s
# 300:	total: 9.02s	remaining: 1m 5s
# 400:	total: 12.3s	remaining: 1m 4s
# 500:	total: 15.5s	remaining: 1m 1s
# 600:	total: 18.4s	remaining: 58.2s
# 700:	total: 21.3s	remaining: 54.7s
# 800:	total: 24.3s	remaining: 51.6s
# 900:	total: 27.4s	remaining: 48.6s
# 1000:	total: 30.4s	remaining: 45.6s
# 1100:	total: 33.4s	remaining: 42.5s
# 1200:	total: 36.4s	remaining: 39.4s
# 1300:	total: 39.4s	remaining: 36.3s
# 1400:	total: 42.3s	remaining: 33.2s
# 1500:	total: 45.2s	remaining: 30.1s
# 1600:	total: 48.3s	remaining: 27.1s
# 1700:	total: 51.3s	remaining: 24.1s
# 1800:	total: 54.3s	remaining: 21.1s
# 1900:	total: 57.3s	remaining: 18s
# 2000:	total: 1m	remaining: 15s
# 2100:	total: 1m 3s	remaining: 12s
# 2200:	total: 1m 6s	remaining: 9s
# 2300:	total: 1m 9s	remaining: 5.99s
# 2400:	total: 1m 12s	remaining: 2.98s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 34.9ms	remaining: 1m 27s
# 100:	total: 3.01s	remaining: 1m 11s
# 200:	total: 5.97s	remaining: 1m 8s
# 300:	total: 9.19s	remaining: 1m 7s
# 400:	total: 12.2s	remaining: 1m 3s
# 500:	total: 15.2s	remaining: 1m
# 600:	total: 18.3s	remaining: 57.9s
# 700:	total: 21.3s	remaining: 54.6s
# 800:	total: 24.3s	remaining: 51.5s
# 900:	total: 27.4s	remaining: 48.6s
# 1000:	total: 30.5s	remaining: 45.7s
# 1100:	total: 33.6s	remaining: 42.7s
# 1200:	total: 36.6s	remaining: 39.5s
# 1300:	total: 39.5s	remaining: 36.4s
# 1400:	total: 42.5s	remaining: 33.3s
# 1500:	total: 45.4s	remaining: 30.2s
# 1600:	total: 48.5s	remaining: 27.2s
# 1700:	total: 51.4s	remaining: 24.1s
# 1800:	total: 54.4s	remaining: 21.1s
# 1900:	total: 57.4s	remaining: 18.1s
# 2000:	total: 1m	remaining: 15.1s
# 2100:	total: 1m 3s	remaining: 12s
# 2200:	total: 1m 6s	remaining: 9.02s
# 2300:	total: 1m 9s	remaining: 6s
# 2400:	total: 1m 12s	remaining: 2.98s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 76.7ms	remaining: 3m 11s
# 100:	total: 2.96s	remaining: 1m 10s
# 200:	total: 6.02s	remaining: 1m 8s
# 300:	total: 9.1s	remaining: 1m 6s
# 400:	total: 12s	remaining: 1m 3s
# 500:	total: 15s	remaining: 59.8s
# 600:	total: 18.1s	remaining: 57.1s
# 700:	total: 21.3s	remaining: 54.6s
# 800:	total: 24.3s	remaining: 51.6s
# 900:	total: 27.4s	remaining: 48.6s
# 1000:	total: 30.5s	remaining: 45.7s
# 1100:	total: 33.6s	remaining: 42.6s
# 1200:	total: 36.6s	remaining: 39.6s
# 1300:	total: 39.6s	remaining: 36.5s
# 1400:	total: 42.6s	remaining: 33.4s
# 1500:	total: 45.5s	remaining: 30.3s
# 1600:	total: 48.7s	remaining: 27.4s
# 1700:	total: 51.8s	remaining: 24.3s
# 1800:	total: 54.8s	remaining: 21.3s
# 1900:	total: 57.9s	remaining: 18.2s
# 2000:	total: 1m	remaining: 15.2s
# 2100:	total: 1m 3s	remaining: 12.1s
# 2200:	total: 1m 6s	remaining: 9.09s
# 2300:	total: 1m 9s	remaining: 6.04s
# 2400:	total: 1m 12s	remaining: 3s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 59.1ms	remaining: 2m 27s
# 100:	total: 3.05s	remaining: 1m 12s
# 200:	total: 5.97s	remaining: 1m 8s
# 300:	total: 8.92s	remaining: 1m 5s
# 400:	total: 11.9s	remaining: 1m 2s
# 500:	total: 15s	remaining: 59.9s
# 600:	total: 18.1s	remaining: 57.1s
# 700:	total: 21.1s	remaining: 54.1s
# 800:	total: 24s	remaining: 50.8s
# 900:	total: 27.1s	remaining: 48.1s
# 1000:	total: 30.1s	remaining: 45.1s
# 1100:	total: 33.1s	remaining: 42.1s
# 1200:	total: 36.1s	remaining: 39s
# 1300:	total: 39.1s	remaining: 36s
# 1400:	total: 42.1s	remaining: 33s
# 1500:	total: 45.1s	remaining: 30s
# 1600:	total: 48.4s	remaining: 27.2s
# 1700:	total: 51.7s	remaining: 24.3s
# 1800:	total: 54.8s	remaining: 21.3s
# 1900:	total: 57.8s	remaining: 18.2s
# 2000:	total: 1m	remaining: 15.2s
# 2100:	total: 1m 3s	remaining: 12.1s
# 2200:	total: 1m 6s	remaining: 9.09s
# 2300:	total: 1m 9s	remaining: 6.05s
# 2400:	total: 1m 12s	remaining: 3.01s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 49.4ms	remaining: 2m 3s
# 100:	total: 3s	remaining: 1m 11s
# 200:	total: 5.95s	remaining: 1m 8s
# 300:	total: 8.88s	remaining: 1m 4s
# 400:	total: 11.9s	remaining: 1m 2s
# 500:	total: 15s	remaining: 59.9s
# 600:	total: 18s	remaining: 56.9s
# 700:	total: 20.9s	remaining: 53.8s
# 800:	total: 23.9s	remaining: 50.8s
# 900:	total: 27.1s	remaining: 48.1s
# 1000:	total: 30.3s	remaining: 45.4s
# 1100:	total: 33.2s	remaining: 42.2s
# 1200:	total: 36.2s	remaining: 39.2s
# 1300:	total: 39.5s	remaining: 36.4s
# 1400:	total: 42.5s	remaining: 33.4s
# 1500:	total: 45.5s	remaining: 30.3s
# 1600:	total: 48.5s	remaining: 27.2s
# 1700:	total: 51.6s	remaining: 24.2s
# 1800:	total: 54.6s	remaining: 21.2s
# 1900:	total: 57.6s	remaining: 18.1s
# 2000:	total: 1m	remaining: 15.1s
# 2100:	total: 1m 3s	remaining: 12.1s
# 2200:	total: 1m 6s	remaining: 9.02s
# 2300:	total: 1m 9s	remaining: 5.99s
# 2400:	total: 1m 12s	remaining: 2.98s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 33.9ms	remaining: 1m 24s
# 100:	total: 2.94s	remaining: 1m 9s
# 200:	total: 6.02s	remaining: 1m 8s
# 300:	total: 9.03s	remaining: 1m 5s
# 400:	total: 11.9s	remaining: 1m 2s
# 500:	total: 14.9s	remaining: 59.3s
# 600:	total: 17.8s	remaining: 56.3s
# 700:	total: 20.9s	remaining: 53.6s
# 800:	total: 23.9s	remaining: 50.7s
# 900:	total: 27s	remaining: 47.9s
# 1000:	total: 29.9s	remaining: 44.8s
# 1100:	total: 32.8s	remaining: 41.7s
# 1200:	total: 35.9s	remaining: 38.8s
# 1300:	total: 38.9s	remaining: 35.8s
# 1400:	total: 41.9s	remaining: 32.9s
# 1500:	total: 44.9s	remaining: 29.9s
# 1600:	total: 48s	remaining: 26.9s
# 1700:	total: 51.1s	remaining: 24s
# 1800:	total: 54.1s	remaining: 21s
# 1900:	total: 57.1s	remaining: 18s
# 2000:	total: 1m	remaining: 15s
# 2100:	total: 1m 3s	remaining: 12s
# 2200:	total: 1m 6s	remaining: 9.04s
# 2300:	total: 1m 9s	remaining: 6.03s
# 2400:	total: 1m 12s	remaining: 3s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 44.4ms	remaining: 1m 51s
# 100:	total: 3.01s	remaining: 1m 11s
# 200:	total: 5.88s	remaining: 1m 7s
# 300:	total: 8.88s	remaining: 1m 4s
# 400:	total: 11.9s	remaining: 1m 2s
# 500:	total: 15s	remaining: 59.7s
# 600:	total: 17.9s	remaining: 56.6s
# 700:	total: 20.9s	remaining: 53.7s
# 800:	total: 24s	remaining: 50.9s
# 900:	total: 27s	remaining: 47.9s
# 1000:	total: 29.9s	remaining: 44.8s
# 1100:	total: 33s	remaining: 41.9s
# 1200:	total: 36s	remaining: 38.9s
# 1300:	total: 39s	remaining: 36s
# 1400:	total: 42s	remaining: 32.9s
# 1500:	total: 45.1s	remaining: 30s
# 1600:	total: 48s	remaining: 27s
# 1700:	total: 51.2s	remaining: 24.1s
# 1800:	total: 54.3s	remaining: 21.1s
# 1900:	total: 57.2s	remaining: 18s
# 2000:	total: 1m	remaining: 15s
# 2100:	total: 1m 3s	remaining: 12s
# 2200:	total: 1m 6s	remaining: 8.98s
# 2300:	total: 1m 9s	remaining: 5.97s
# 2400:	total: 1m 11s	remaining: 2.97s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 48.2ms	remaining: 2m
# 100:	total: 3.1s	remaining: 1m 13s
# 200:	total: 6.22s	remaining: 1m 11s
# 300:	total: 9.43s	remaining: 1m 8s
# 400:	total: 12.5s	remaining: 1m 5s
# 500:	total: 15.5s	remaining: 1m 1s
# 600:	total: 18.4s	remaining: 58.3s
# 700:	total: 21.5s	remaining: 55.1s
# 800:	total: 24.5s	remaining: 52s
# 900:	total: 27.5s	remaining: 48.8s
# 1000:	total: 30.6s	remaining: 45.8s
# 1100:	total: 33.5s	remaining: 42.6s
# 1200:	total: 36.5s	remaining: 39.5s
# 1300:	total: 39.5s	remaining: 36.4s
# 1400:	total: 42.6s	remaining: 33.4s
# 1500:	total: 45.6s	remaining: 30.3s
# 1600:	total: 48.7s	remaining: 27.4s
# 1700:	total: 51.8s	remaining: 24.3s
# 1800:	total: 55s	remaining: 21.3s
# 1900:	total: 58.1s	remaining: 18.3s
# 2000:	total: 1m 1s	remaining: 15.2s
# 2100:	total: 1m 4s	remaining: 12.2s
# 2200:	total: 1m 7s	remaining: 9.11s
# 2300:	total: 1m 10s	remaining: 6.05s
# 2400:	total: 1m 13s	remaining: 3.01s
# 2499:	total: 1m 16s	remaining: 0us
# 0:	total: 33.9ms	remaining: 1m 24s
# 100:	total: 3.09s	remaining: 1m 13s
# 200:	total: 6.13s	remaining: 1m 10s
# 300:	total: 9.11s	remaining: 1m 6s
# 400:	total: 12s	remaining: 1m 3s
# 500:	total: 15.1s	remaining: 1m
# 600:	total: 18.3s	remaining: 57.9s
# 700:	total: 21.5s	remaining: 55.2s
# 800:	total: 24.6s	remaining: 52.1s
# 900:	total: 27.7s	remaining: 49.1s
# 1000:	total: 30.7s	remaining: 46s
# 1100:	total: 33.9s	remaining: 43s
# 1200:	total: 37s	remaining: 40s
# 1300:	total: 40.1s	remaining: 37s
# 1400:	total: 43.2s	remaining: 33.9s
# 1500:	total: 46.2s	remaining: 30.7s
# 1600:	total: 49.2s	remaining: 27.6s
# 1700:	total: 52.2s	remaining: 24.5s
# 1800:	total: 55.1s	remaining: 21.4s
# 1900:	total: 58.1s	remaining: 18.3s
# 2000:	total: 1m 1s	remaining: 15.2s
# 2100:	total: 1m 4s	remaining: 12.2s
# 2200:	total: 1m 7s	remaining: 9.11s
# 2300:	total: 1m 9s	remaining: 6.05s
# 2400:	total: 1m 12s	remaining: 3.01s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 45.7ms	remaining: 1m 54s
# 100:	total: 3.13s	remaining: 1m 14s
# 200:	total: 6.14s	remaining: 1m 10s
# 300:	total: 9.04s	remaining: 1m 6s
# 400:	total: 12.1s	remaining: 1m 3s
# 500:	total: 15.3s	remaining: 1m 1s
# 600:	total: 18.4s	remaining: 58.1s
# 700:	total: 21.5s	remaining: 55.2s
# 800:	total: 24.8s	remaining: 52.6s
# 900:	total: 28.9s	remaining: 51.3s
# 1000:	total: 31.9s	remaining: 47.8s
# 1100:	total: 35.1s	remaining: 44.6s
# 1200:	total: 38.2s	remaining: 41.3s
# 1300:	total: 41.3s	remaining: 38.1s
# 1400:	total: 44.3s	remaining: 34.8s
# 1500:	total: 47.4s	remaining: 31.5s
# 1600:	total: 50.5s	remaining: 28.4s
# 1700:	total: 53.6s	remaining: 25.2s
# 1800:	total: 56.7s	remaining: 22s
# 1900:	total: 59.8s	remaining: 18.8s
# 2000:	total: 1m 3s	remaining: 15.7s
# 2100:	total: 1m 6s	remaining: 12.6s
# 2200:	total: 1m 9s	remaining: 9.4s
# 2300:	total: 1m 12s	remaining: 6.25s
# 2400:	total: 1m 15s	remaining: 3.1s
# 2499:	total: 1m 18s	remaining: 0us
# 0:	total: 47.6ms	remaining: 1m 58s
# 100:	total: 2.96s	remaining: 1m 10s
# 200:	total: 6.05s	remaining: 1m 9s
# 300:	total: 9.14s	remaining: 1m 6s
# 400:	total: 12.3s	remaining: 1m 4s
# 500:	total: 15.4s	remaining: 1m 1s
# 600:	total: 18.5s	remaining: 58.5s
# 700:	total: 21.6s	remaining: 55.5s
# 800:	total: 24.6s	remaining: 52.2s
# 900:	total: 27.7s	remaining: 49.1s
# 1000:	total: 30.9s	remaining: 46.2s
# 1100:	total: 34.3s	remaining: 43.6s
# 1200:	total: 37.6s	remaining: 40.7s
# 1300:	total: 40.9s	remaining: 37.7s
# 1400:	total: 44s	remaining: 34.5s
# 1500:	total: 47.3s	remaining: 31.5s
# 1600:	total: 50.2s	remaining: 28.2s
# 1700:	total: 53.1s	remaining: 25s
# 1800:	total: 56.1s	remaining: 21.8s
# 1900:	total: 59s	remaining: 18.6s
# 2000:	total: 1m 2s	remaining: 15.5s
# 2100:	total: 1m 5s	remaining: 12.3s
# 2200:	total: 1m 8s	remaining: 9.25s
# 2300:	total: 1m 11s	remaining: 6.14s
# 2400:	total: 1m 13s	remaining: 3.05s
# 2499:	total: 1m 16s	remaining: 0us
# 0:	total: 41.5ms	remaining: 1m 43s
# 100:	total: 3.17s	remaining: 1m 15s
# 200:	total: 6.14s	remaining: 1m 10s
# 300:	total: 9.17s	remaining: 1m 6s
# 400:	total: 12.3s	remaining: 1m 4s
# 500:	total: 15.4s	remaining: 1m 1s
# 600:	total: 18.5s	remaining: 58.6s
# 700:	total: 21.8s	remaining: 56s
# 800:	total: 25.1s	remaining: 53.2s
# 900:	total: 28.2s	remaining: 50.1s
# 1000:	total: 31.5s	remaining: 47.2s
# 1100:	total: 34.8s	remaining: 44.2s
# 1200:	total: 38s	remaining: 41.1s
# 1300:	total: 41.1s	remaining: 37.8s
# 1400:	total: 44s	remaining: 34.6s
# 1500:	total: 47s	remaining: 31.3s
# 1600:	total: 49.9s	remaining: 28s
# 1700:	total: 53s	remaining: 24.9s
# 1800:	total: 56.1s	remaining: 21.8s
# 1900:	total: 59.4s	remaining: 18.7s
# 2000:	total: 1m 2s	remaining: 15.6s
# 2100:	total: 1m 5s	remaining: 12.4s
# 2200:	total: 1m 8s	remaining: 9.3s
# 2300:	total: 1m 11s	remaining: 6.19s
# 2400:	total: 1m 14s	remaining: 3.08s
# 2499:	total: 1m 17s	remaining: 0us
# 0:	total: 48.6ms	remaining: 2m 1s
# 100:	total: 3.19s	remaining: 1m 15s
# 200:	total: 6.21s	remaining: 1m 11s
# 300:	total: 9.58s	remaining: 1m 9s
# 400:	total: 12.9s	remaining: 1m 7s
# 500:	total: 16.2s	remaining: 1m 4s
# 600:	total: 19.4s	remaining: 1m 1s
# 700:	total: 22.7s	remaining: 58.2s
# 800:	total: 25.7s	remaining: 54.5s
# 900:	total: 29s	remaining: 51.5s
# 1000:	total: 32.2s	remaining: 48.2s
# 1100:	total: 35.3s	remaining: 44.8s
# 1200:	total: 38.3s	remaining: 41.4s
# 1300:	total: 41.3s	remaining: 38.1s
# 1400:	total: 44.2s	remaining: 34.7s
# 1500:	total: 47.2s	remaining: 31.4s
# 1600:	total: 50.1s	remaining: 28.1s
# 1700:	total: 53s	remaining: 24.9s
# 1800:	total: 55.9s	remaining: 21.7s
# 1900:	total: 59s	remaining: 18.6s
# 2000:	total: 1m 2s	remaining: 15.5s
# 2100:	total: 1m 6s	remaining: 12.6s
# 2200:	total: 1m 9s	remaining: 9.48s
# 2300:	total: 1m 12s	remaining: 6.3s
# 2400:	total: 1m 16s	remaining: 3.13s
# 2499:	total: 1m 19s	remaining: 0us
# 0:	total: 40.3ms	remaining: 1m 40s
# 100:	total: 3.31s	remaining: 1m 18s
# 200:	total: 6.37s	remaining: 1m 12s
# 300:	total: 9.53s	remaining: 1m 9s
# 400:	total: 12.6s	remaining: 1m 6s
# 500:	total: 15.6s	remaining: 1m 2s
# 600:	total: 18.6s	remaining: 58.7s
# 700:	total: 21.6s	remaining: 55.4s
# 800:	total: 24.5s	remaining: 52s
# 900:	total: 27.4s	remaining: 48.7s
# 1000:	total: 30.4s	remaining: 45.5s
# 1100:	total: 33.5s	remaining: 42.5s
# 1200:	total: 36.6s	remaining: 39.6s
# 1300:	total: 39.6s	remaining: 36.5s
# 1400:	total: 42.8s	remaining: 33.6s
# 1500:	total: 46s	remaining: 30.6s
# 1600:	total: 49s	remaining: 27.5s
# 1700:	total: 51.9s	remaining: 24.4s
# 1800:	total: 54.9s	remaining: 21.3s
# 1900:	total: 58s	remaining: 18.3s
# 2000:	total: 1m 1s	remaining: 15.2s
# 2100:	total: 1m 3s	remaining: 12.1s
# 2200:	total: 1m 6s	remaining: 9.08s
# 2300:	total: 1m 9s	remaining: 6.04s
# 2400:	total: 1m 12s	remaining: 3s
# 2499:	total: 1m 15s	remaining: 0us
# 0:	total: 44.3ms	remaining: 1m 50s
# 100:	total: 3.09s	remaining: 1m 13s
# 200:	total: 6.19s	remaining: 1m 10s
# 300:	total: 9.16s	remaining: 1m 6s
# 400:	total: 12.4s	remaining: 1m 4s
# 500:	total: 15.5s	remaining: 1m 1s
# 600:	total: 18.5s	remaining: 58.6s
# 700:	total: 21.7s	remaining: 55.7s
# 800:	total: 24.8s	remaining: 52.7s
# 900:	total: 27.9s	remaining: 49.5s
# 1000:	total: 31.1s	remaining: 46.6s
# 1100:	total: 34.1s	remaining: 43.3s
# 1200:	total: 37.2s	remaining: 40.3s
# 1300:	total: 40.3s	remaining: 37.1s
# 1400:	total: 43.3s	remaining: 33.9s
# 1500:	total: 46.2s	remaining: 30.8s
# 1600:	total: 49.4s	remaining: 27.7s
# 1700:	total: 52.5s	remaining: 24.7s
# 1800:	total: 55.5s	remaining: 21.6s
# 1900:	total: 58.7s	remaining: 18.5s
# 2000:	total: 1m 1s	remaining: 15.4s
# 2100:	total: 1m 4s	remaining: 12.3s
# 2200:	total: 1m 8s	remaining: 9.27s
# 2300:	total: 1m 11s	remaining: 6.18s
# 2400:	total: 1m 14s	remaining: 3.07s
# 2499:	total: 1m 17s	remaining: 0us
# 0:	total: 39.2ms	remaining: 1m 38s
# 100:	total: 3.15s	remaining: 1m 14s
# 200:	total: 6.16s	remaining: 1m 10s
# 300:	total: 9.25s	remaining: 1m 7s
# 400:	total: 12.2s	remaining: 1m 4s
# 500:	total: 15.2s	remaining: 1m
# 600:	total: 18.3s	remaining: 57.7s
# 700:	total: 21.4s	remaining: 54.9s
# 800:	total: 24.4s	remaining: 51.9s
# 900:	total: 27.4s	remaining: 48.7s
# 1000:	total: 30.3s	remaining: 45.4s
# 1100:	total: 33.3s	remaining: 42.3s
# 1200:	total: 36.6s	remaining: 39.6s
# 1300:	total: 39.9s	remaining: 36.8s
# 1400:	total: 43.2s	remaining: 33.9s
# 1500:	total: 46.3s	remaining: 30.8s
# 1600:	total: 49.4s	remaining: 27.7s
# 1700:	total: 52.6s	remaining: 24.7s
# 1800:	total: 55.5s	remaining: 21.5s
# 1900:	total: 58.5s	remaining: 18.4s
# 2000:	total: 1m 1s	remaining: 15.3s
# 2100:	total: 1m 4s	remaining: 12.3s
# 2200:	total: 1m 7s	remaining: 9.19s
# 2300:	total: 1m 10s	remaining: 6.12s
# 2400:	total: 1m 13s	remaining: 3.05s
# 2499:	total: 1m 16s	remaining: 0us
# 0:	total: 61.4ms	remaining: 2m 33s
# 100:	total: 3.12s	remaining: 1m 14s
# 200:	total: 6.19s	remaining: 1m 10s
# 300:	total: 9.27s	remaining: 1m 7s
# 400:	total: 12.4s	remaining: 1m 4s
# 500:	total: 15.5s	remaining: 1m 1s
# 600:	total: 18.9s	remaining: 59.6s
# 700:	total: 21.9s	remaining: 56.2s
# 800:	total: 25s	remaining: 53s
# 900:	total: 28s	remaining: 49.7s
# 1000:	total: 31s	remaining: 46.4s
# 1100:	total: 34s	remaining: 43.1s
# 1200:	total: 36.9s	remaining: 39.9s
# 1300:	total: 40s	remaining: 36.9s
# 1400:	total: 43s	remaining: 33.8s
# 1500:	total: 46.2s	remaining: 30.8s
# 1600:	total: 49.5s	remaining: 27.8s
# 1700:	total: 52.5s	remaining: 24.7s
# 1800:	total: 55.8s	remaining: 21.7s
# 1900:	total: 59.1s	remaining: 18.6s
# 2000:	total: 1m 2s	remaining: 15.5s
# 2100:	total: 1m 5s	remaining: 12.4s
# 2200:	total: 1m 8s	remaining: 9.3s
# 2300:	total: 1m 11s	remaining: 6.18s
# 2400:	total: 1m 14s	remaining: 3.07s
# 2499:	total: 1m 17s	remaining: 0us
# 0:	total: 52.4ms	remaining: 2m 11s
# 100:	total: 3.43s	remaining: 1m 21s
# 200:	total: 6.6s	remaining: 1m 15s
# 300:	total: 9.75s	remaining: 1m 11s
# 400:	total: 12.8s	remaining: 1m 7s
# 500:	total: 16.1s	remaining: 1m 4s
# 600:	total: 19.2s	remaining: 1m
# 700:	total: 22.3s	remaining: 57.3s
# 800:	total: 25.2s	remaining: 53.4s
# 900:	total: 28.2s	remaining: 50s
# 1000:	total: 31.3s	remaining: 46.9s
# 1100:	total: 34.5s	remaining: 43.8s
# 1200:	total: 37.8s	remaining: 40.9s
# 1300:	total: 40.8s	remaining: 37.6s
# 1400:	total: 43.7s	remaining: 34.3s
# 1500:	total: 46.8s	remaining: 31.2s
# 1600:	total: 49.8s	remaining: 28s
# 1700:	total: 52.8s	remaining: 24.8s
# 1800:	total: 56s	remaining: 21.7s
# 1900:	total: 59s	remaining: 18.6s
# 2000:	total: 1m 2s	remaining: 15.6s
# 2100:	total: 1m 5s	remaining: 12.5s
# 2200:	total: 1m 8s	remaining: 9.36s
# 2300:	total: 1m 12s	remaining: 6.23s
# 2400:	total: 1m 15s	remaining: 3.1s
# 2499:	total: 1m 18s	remaining: 0us
# |  1        |  0.9411   |  0.4224   |  7.602    |  0.01011  |
# 0:	total: 9.56ms	remaining: 23.9s
# 100:	total: 990ms	remaining: 23.5s
# 200:	total: 1.85s	remaining: 21.1s
# 300:	total: 2.8s	remaining: 20.5s
# 400:	total: 3.62s	remaining: 18.9s
# 500:	total: 4.55s	remaining: 18.2s
# 600:	total: 5.45s	remaining: 17.2s
# 700:	total: 6.39s	remaining: 16.4s
# 800:	total: 7.31s	remaining: 15.5s
# 900:	total: 8.19s	remaining: 14.5s
# 1000:	total: 9.13s	remaining: 13.7s
# 1100:	total: 10.1s	remaining: 12.8s
# 1200:	total: 11.1s	remaining: 12s
# 1300:	total: 12.1s	remaining: 11.1s
# 1400:	total: 13.1s	remaining: 10.3s
# 1500:	total: 14s	remaining: 9.31s
# 1600:	total: 14.9s	remaining: 8.35s
# 1700:	total: 15.8s	remaining: 7.43s
# 1800:	total: 16.7s	remaining: 6.49s
# 1900:	total: 17.6s	remaining: 5.54s
# 2000:	total: 18.4s	remaining: 4.59s
# 2100:	total: 19.3s	remaining: 3.66s
# 2200:	total: 20.1s	remaining: 2.73s
# 2300:	total: 20.9s	remaining: 1.81s
# 2400:	total: 21.7s	remaining: 895ms
# 2499:	total: 22.5s	remaining: 0us
# 0:	total: 9.79ms	remaining: 24.5s
# 100:	total: 853ms	remaining: 20.3s
# 200:	total: 1.73s	remaining: 19.8s
# 300:	total: 2.6s	remaining: 19s
# 400:	total: 3.51s	remaining: 18.4s
# 500:	total: 4.44s	remaining: 17.7s
# 600:	total: 5.31s	remaining: 16.8s
# 700:	total: 6.17s	remaining: 15.8s
# 800:	total: 7.1s	remaining: 15.1s
# 900:	total: 8.03s	remaining: 14.3s
# 1000:	total: 8.96s	remaining: 13.4s
# 1100:	total: 9.91s	remaining: 12.6s
# 1200:	total: 10.7s	remaining: 11.6s
# 1300:	total: 11.6s	remaining: 10.7s
# 1400:	total: 12.5s	remaining: 9.78s
# 1500:	total: 13.4s	remaining: 8.91s
# 1600:	total: 14.4s	remaining: 8.06s
# 1700:	total: 15.2s	remaining: 7.14s
# 1800:	total: 16.1s	remaining: 6.26s
# 1900:	total: 17.1s	remaining: 5.38s
# 2000:	total: 18s	remaining: 4.49s
# 2100:	total: 18.9s	remaining: 3.58s
# 2200:	total: 19.7s	remaining: 2.67s
# 2300:	total: 20.4s	remaining: 1.76s
# 2400:	total: 21.2s	remaining: 873ms
# 2499:	total: 22.1s	remaining: 0us
# 0:	total: 10.5ms	remaining: 26.1s
# 100:	total: 866ms	remaining: 20.6s
# 200:	total: 1.72s	remaining: 19.7s
# 300:	total: 2.53s	remaining: 18.5s
# 400:	total: 3.38s	remaining: 17.7s
# 500:	total: 4.21s	remaining: 16.8s
# 600:	total: 4.97s	remaining: 15.7s
# 700:	total: 5.81s	remaining: 14.9s
# 800:	total: 6.62s	remaining: 14s
# 900:	total: 7.44s	remaining: 13.2s
# 1000:	total: 8.29s	remaining: 12.4s
# 1100:	total: 9.07s	remaining: 11.5s
# 1200:	total: 9.84s	remaining: 10.6s
# 1300:	total: 10.7s	remaining: 9.88s
# 1400:	total: 11.5s	remaining: 9.06s
# 1500:	total: 12.4s	remaining: 8.23s
# 1600:	total: 13.2s	remaining: 7.4s
# 1700:	total: 14s	remaining: 6.58s
# 1800:	total: 14.9s	remaining: 5.76s
# 1900:	total: 15.7s	remaining: 4.93s
# 2000:	total: 16.4s	remaining: 4.09s
# 2100:	total: 17.2s	remaining: 3.27s
# 2200:	total: 18.1s	remaining: 2.46s
# 2300:	total: 18.8s	remaining: 1.63s
# 2400:	total: 19.6s	remaining: 807ms
# 2499:	total: 20.3s	remaining: 0us
# 0:	total: 9.55ms	remaining: 23.9s
# 100:	total: 895ms	remaining: 21.3s
# 200:	total: 1.71s	remaining: 19.6s
# 300:	total: 2.55s	remaining: 18.7s
# 400:	total: 3.33s	remaining: 17.4s
# 500:	total: 4.16s	remaining: 16.6s
# 600:	total: 5.02s	remaining: 15.9s
# 700:	total: 5.81s	remaining: 14.9s
# 800:	total: 6.65s	remaining: 14.1s
# 900:	total: 7.53s	remaining: 13.4s
# 1000:	total: 8.37s	remaining: 12.5s
# 1100:	total: 9.21s	remaining: 11.7s
# 1200:	total: 10.1s	remaining: 10.9s
# 1300:	total: 11s	remaining: 10.1s
# 1400:	total: 11.8s	remaining: 9.29s
# 1500:	total: 12.7s	remaining: 8.46s
# 1600:	total: 13.5s	remaining: 7.59s
# 1700:	total: 14.3s	remaining: 6.73s
# 1800:	total: 15.1s	remaining: 5.86s
# 1900:	total: 15.9s	remaining: 5.01s
# 2000:	total: 16.7s	remaining: 4.16s
# 2100:	total: 17.5s	remaining: 3.32s
# 2200:	total: 18.3s	remaining: 2.48s
# 2300:	total: 19.1s	remaining: 1.65s
# 2400:	total: 20s	remaining: 823ms
# 2499:	total: 20.7s	remaining: 0us
# 0:	total: 12.4ms	remaining: 31s
# 100:	total: 902ms	remaining: 21.4s
# 200:	total: 1.75s	remaining: 20s
# 300:	total: 2.63s	remaining: 19.2s
# 400:	total: 3.45s	remaining: 18.1s
# 500:	total: 4.26s	remaining: 17s
# 600:	total: 5.04s	remaining: 15.9s
# 700:	total: 5.88s	remaining: 15.1s
# 800:	total: 6.76s	remaining: 14.3s
# 900:	total: 7.62s	remaining: 13.5s
# 1000:	total: 8.46s	remaining: 12.7s
# 1100:	total: 9.37s	remaining: 11.9s
# 1200:	total: 10.3s	remaining: 11.1s
# 1300:	total: 11.2s	remaining: 10.3s
# 1400:	total: 12.1s	remaining: 9.52s
# 1500:	total: 13.1s	remaining: 8.72s
# 1600:	total: 14.1s	remaining: 7.89s
# 1700:	total: 15s	remaining: 7.04s
# 1800:	total: 15.9s	remaining: 6.18s
# 1900:	total: 16.9s	remaining: 5.32s
# 2000:	total: 17.8s	remaining: 4.43s
# 2100:	total: 18.7s	remaining: 3.54s
# 2200:	total: 19.6s	remaining: 2.66s
# 2300:	total: 20.4s	remaining: 1.77s
# 2400:	total: 21.3s	remaining: 880ms
# 2499:	total: 22.2s	remaining: 0us
# 0:	total: 22.6ms	remaining: 56.4s
# 100:	total: 904ms	remaining: 21.5s
# 200:	total: 1.75s	remaining: 20s
# 300:	total: 2.67s	remaining: 19.5s
# 400:	total: 3.58s	remaining: 18.8s
# 500:	total: 4.45s	remaining: 17.8s
# 600:	total: 5.36s	remaining: 16.9s
# 700:	total: 6.28s	remaining: 16.1s
# 800:	total: 7.15s	remaining: 15.2s
# 900:	total: 8.06s	remaining: 14.3s
# 1000:	total: 9s	remaining: 13.5s
# 1100:	total: 9.82s	remaining: 12.5s
# 1200:	total: 10.7s	remaining: 11.6s
# 1300:	total: 11.7s	remaining: 10.7s
# 1400:	total: 12.6s	remaining: 9.87s
# 1500:	total: 13.4s	remaining: 8.91s
# 1600:	total: 14.3s	remaining: 8.02s
# 1700:	total: 15.1s	remaining: 7.09s
# 1800:	total: 15.9s	remaining: 6.19s
# 1900:	total: 16.8s	remaining: 5.29s
# 2000:	total: 17.6s	remaining: 4.38s
# 2100:	total: 18.4s	remaining: 3.49s
# 2200:	total: 19.2s	remaining: 2.6s
# 2300:	total: 20s	remaining: 1.73s
# 2400:	total: 20.8s	remaining: 857ms
# 2499:	total: 21.6s	remaining: 0us
# 0:	total: 11.2ms	remaining: 28.1s
# 100:	total: 877ms	remaining: 20.8s
# 200:	total: 1.74s	remaining: 19.9s
# 300:	total: 2.54s	remaining: 18.5s
# 400:	total: 3.37s	remaining: 17.6s
# 500:	total: 4.19s	remaining: 16.7s
# 600:	total: 5.06s	remaining: 16s
# 700:	total: 5.96s	remaining: 15.3s
# 800:	total: 6.77s	remaining: 14.4s
# 900:	total: 7.61s	remaining: 13.5s
# 1000:	total: 8.43s	remaining: 12.6s
# 1100:	total: 9.21s	remaining: 11.7s
# 1200:	total: 10s	remaining: 10.8s
# 1300:	total: 10.8s	remaining: 9.93s
# 1400:	total: 11.5s	remaining: 9.06s
# 1500:	total: 12.4s	remaining: 8.24s
# 1600:	total: 13.2s	remaining: 7.39s
# 1700:	total: 13.9s	remaining: 6.55s
# 1800:	total: 14.8s	remaining: 5.73s
# 1900:	total: 15.6s	remaining: 4.9s
# 2000:	total: 16.3s	remaining: 4.08s
# 2100:	total: 17.1s	remaining: 3.25s
# 2200:	total: 17.9s	remaining: 2.43s
# 2300:	total: 18.7s	remaining: 1.62s
# 2400:	total: 19.5s	remaining: 804ms
# 2499:	total: 20.3s	remaining: 0us
# 0:	total: 9.34ms	remaining: 23.3s
# 100:	total: 847ms	remaining: 20.1s
# 200:	total: 1.71s	remaining: 19.6s
# 300:	total: 2.54s	remaining: 18.5s
# 400:	total: 3.36s	remaining: 17.6s
# 500:	total: 4.22s	remaining: 16.9s
# 600:	total: 5.05s	remaining: 16s
# 700:	total: 5.93s	remaining: 15.2s
# 800:	total: 6.78s	remaining: 14.4s
# 900:	total: 7.63s	remaining: 13.5s
# 1000:	total: 8.47s	remaining: 12.7s
# 1100:	total: 9.32s	remaining: 11.8s
# 1200:	total: 10.2s	remaining: 11s
# 1300:	total: 11s	remaining: 10.2s
# 1400:	total: 11.8s	remaining: 9.27s
# 1500:	total: 12.6s	remaining: 8.42s
# 1600:	total: 13.5s	remaining: 7.58s
# 1700:	total: 14.3s	remaining: 6.73s
# 1800:	total: 15.2s	remaining: 5.9s
# 1900:	total: 16.1s	remaining: 5.08s
# 2000:	total: 16.9s	remaining: 4.21s
# 2100:	total: 17.7s	remaining: 3.36s
# 2200:	total: 18.5s	remaining: 2.51s
# 2300:	total: 19.3s	remaining: 1.67s
# 2400:	total: 20.2s	remaining: 831ms
# 2499:	total: 20.9s	remaining: 0us
# 0:	total: 14.3ms	remaining: 35.6s
# 100:	total: 881ms	remaining: 20.9s
# 200:	total: 1.7s	remaining: 19.5s
# 300:	total: 2.59s	remaining: 18.9s
# 400:	total: 3.38s	remaining: 17.7s
# 500:	total: 4.23s	remaining: 16.9s
# 600:	total: 5.13s	remaining: 16.2s
# 700:	total: 5.97s	remaining: 15.3s
# 800:	total: 6.77s	remaining: 14.4s
# 900:	total: 7.57s	remaining: 13.4s
# 1000:	total: 8.36s	remaining: 12.5s
# 1100:	total: 9.2s	remaining: 11.7s
# 1200:	total: 10s	remaining: 10.9s
# 1300:	total: 10.8s	remaining: 9.97s
# 1400:	total: 11.6s	remaining: 9.1s
# 1500:	total: 12.4s	remaining: 8.28s
# 1600:	total: 13.3s	remaining: 7.48s
# 1700:	total: 14.1s	remaining: 6.63s
# 1800:	total: 15s	remaining: 5.81s
# 1900:	total: 15.8s	remaining: 4.96s
# 2000:	total: 16.6s	remaining: 4.13s
# 2100:	total: 17.4s	remaining: 3.31s
# 2200:	total: 18.3s	remaining: 2.49s
# 2300:	total: 19.1s	remaining: 1.65s
# 2400:	total: 19.9s	remaining: 822ms
# 2499:	total: 20.8s	remaining: 0us
# 0:	total: 14.6ms	remaining: 36.4s
# 100:	total: 945ms	remaining: 22.5s
# 200:	total: 1.94s	remaining: 22.2s
# 300:	total: 2.91s	remaining: 21.3s
# 400:	total: 3.83s	remaining: 20s
# 500:	total: 4.71s	remaining: 18.8s
# 600:	total: 5.63s	remaining: 17.8s
# 700:	total: 6.52s	remaining: 16.7s
# 800:	total: 7.5s	remaining: 15.9s
# 900:	total: 8.33s	remaining: 14.8s
# 1000:	total: 9.13s	remaining: 13.7s
# 1100:	total: 9.95s	remaining: 12.6s
# 1200:	total: 11.1s	remaining: 12s
# 1300:	total: 11.9s	remaining: 11s
# 1400:	total: 12.7s	remaining: 9.97s
# 1500:	total: 13.5s	remaining: 9s
# 1600:	total: 14.3s	remaining: 8.04s
# 1700:	total: 15.1s	remaining: 7.11s
# 1800:	total: 16s	remaining: 6.2s
# 1900:	total: 17.3s	remaining: 5.45s
# 2000:	total: 18.2s	remaining: 4.54s
# 2100:	total: 19.2s	remaining: 3.64s
# 2200:	total: 20.1s	remaining: 2.73s
# 2300:	total: 21.2s	remaining: 1.83s
# 2400:	total: 22.2s	remaining: 914ms
# 2499:	total: 23s	remaining: 0us
# 0:	total: 12ms	remaining: 29.9s
# 100:	total: 1.05s	remaining: 24.9s
# 200:	total: 2.09s	remaining: 23.9s
# 300:	total: 3.16s	remaining: 23.1s
# 400:	total: 4.13s	remaining: 21.6s
# 500:	total: 5.06s	remaining: 20.2s
# 600:	total: 5.94s	remaining: 18.8s
# 700:	total: 7.02s	remaining: 18s
# 800:	total: 7.95s	remaining: 16.9s
# 900:	total: 8.92s	remaining: 15.8s
# 1000:	total: 9.87s	remaining: 14.8s
# 1100:	total: 10.8s	remaining: 13.7s
# 1200:	total: 11.7s	remaining: 12.6s
# 1300:	total: 12.6s	remaining: 11.6s
# 1400:	total: 13.5s	remaining: 10.6s
# 1500:	total: 14.5s	remaining: 9.63s
# 1600:	total: 15.4s	remaining: 8.67s
# 1700:	total: 16.4s	remaining: 7.68s
# 1800:	total: 17.2s	remaining: 6.69s
# 1900:	total: 18.1s	remaining: 5.71s
# 2000:	total: 19s	remaining: 4.75s
# 2100:	total: 19.9s	remaining: 3.78s
# 2200:	total: 20.8s	remaining: 2.82s
# 2300:	total: 21.6s	remaining: 1.87s
# 2400:	total: 22.5s	remaining: 927ms
# 2499:	total: 23.3s	remaining: 0us
# 0:	total: 12.5ms	remaining: 31.2s
# 100:	total: 1.09s	remaining: 26s
# 200:	total: 1.91s	remaining: 21.9s
# 300:	total: 2.73s	remaining: 19.9s
# 400:	total: 3.63s	remaining: 19s
# 500:	total: 4.45s	remaining: 17.8s
# 600:	total: 5.38s	remaining: 17s
# 700:	total: 6.41s	remaining: 16.5s
# 800:	total: 7.35s	remaining: 15.6s
# 900:	total: 8.19s	remaining: 14.5s
# 1000:	total: 9.02s	remaining: 13.5s
# 1100:	total: 9.84s	remaining: 12.5s
# 1200:	total: 10.7s	remaining: 11.6s
# 1300:	total: 11.5s	remaining: 10.6s
# 1400:	total: 12.4s	remaining: 9.71s
# 1500:	total: 13.2s	remaining: 8.77s
# 1600:	total: 14s	remaining: 7.87s
# 1700:	total: 14.9s	remaining: 7.01s
# 1800:	total: 15.8s	remaining: 6.11s
# 1900:	total: 16.6s	remaining: 5.23s
# 2000:	total: 17.4s	remaining: 4.33s
# 2100:	total: 18.4s	remaining: 3.5s
# 2200:	total: 19.2s	remaining: 2.61s
# 2300:	total: 20s	remaining: 1.73s
# 2400:	total: 20.8s	remaining: 858ms
# 2499:	total: 21.5s	remaining: 0us
# 0:	total: 10.5ms	remaining: 26.3s
# 100:	total: 835ms	remaining: 19.8s
# 200:	total: 1.66s	remaining: 19s
# 300:	total: 2.49s	remaining: 18.2s
# 400:	total: 3.29s	remaining: 17.3s
# 500:	total: 4.09s	remaining: 16.3s
# 600:	total: 4.88s	remaining: 15.4s
# 700:	total: 5.71s	remaining: 14.7s
# 800:	total: 6.5s	remaining: 13.8s
# 900:	total: 7.27s	remaining: 12.9s
# 1000:	total: 8.05s	remaining: 12.1s
# 1100:	total: 8.81s	remaining: 11.2s
# 1200:	total: 9.68s	remaining: 10.5s
# 1300:	total: 10.5s	remaining: 9.71s
# 1400:	total: 11.4s	remaining: 8.98s
# 1500:	total: 12.3s	remaining: 8.21s
# 1600:	total: 13.2s	remaining: 7.44s
# 1700:	total: 14s	remaining: 6.59s
# 1800:	total: 15s	remaining: 5.81s
# 1900:	total: 15.8s	remaining: 4.97s
# 2000:	total: 16.6s	remaining: 4.14s
# 2100:	total: 17.4s	remaining: 3.3s
# 2200:	total: 18.2s	remaining: 2.47s
# 2300:	total: 19s	remaining: 1.64s
# 2400:	total: 19.7s	remaining: 813ms
# 2499:	total: 20.4s	remaining: 0us
# 0:	total: 18.1ms	remaining: 45.3s
# 100:	total: 886ms	remaining: 21.1s
# 200:	total: 1.69s	remaining: 19.3s
# 300:	total: 2.51s	remaining: 18.3s
# 400:	total: 3.29s	remaining: 17.2s
# 500:	total: 4.12s	remaining: 16.4s
# 600:	total: 4.97s	remaining: 15.7s
# 700:	total: 5.77s	remaining: 14.8s
# 800:	total: 6.55s	remaining: 13.9s
# 900:	total: 7.36s	remaining: 13.1s
# 1000:	total: 8.17s	remaining: 12.2s
# 1100:	total: 8.96s	remaining: 11.4s
# 1200:	total: 9.85s	remaining: 10.7s
# 1300:	total: 10.7s	remaining: 9.87s
# 1400:	total: 11.6s	remaining: 9.07s
# 1500:	total: 12.4s	remaining: 8.25s
# 1600:	total: 13.3s	remaining: 7.44s
# 1700:	total: 14.1s	remaining: 6.63s
# 1800:	total: 14.9s	remaining: 5.8s
# 1900:	total: 15.8s	remaining: 4.98s
# 2000:	total: 16.7s	remaining: 4.16s
# 2100:	total: 17.5s	remaining: 3.33s
# 2200:	total: 18.4s	remaining: 2.49s
# 2300:	total: 19.3s	remaining: 1.67s
# 2400:	total: 20.1s	remaining: 828ms
# 2499:	total: 21s	remaining: 0us
# 0:	total: 13.4ms	remaining: 33.4s
# 100:	total: 798ms	remaining: 19s
# 200:	total: 1.66s	remaining: 19s
# 300:	total: 2.52s	remaining: 18.4s
# 400:	total: 3.35s	remaining: 17.5s
# 500:	total: 4.22s	remaining: 16.9s
# 600:	total: 5.04s	remaining: 15.9s
# 700:	total: 5.89s	remaining: 15.1s
# 800:	total: 6.74s	remaining: 14.3s
# 900:	total: 7.57s	remaining: 13.4s
# 1000:	total: 8.39s	remaining: 12.6s
# 1100:	total: 9.22s	remaining: 11.7s
# 1200:	total: 10.1s	remaining: 10.9s
# 1300:	total: 11s	remaining: 10.1s
# 1400:	total: 11.8s	remaining: 9.28s
# 1500:	total: 12.7s	remaining: 8.43s
# 1600:	total: 13.5s	remaining: 7.57s
# 1700:	total: 14.3s	remaining: 6.7s
# 1800:	total: 15s	remaining: 5.84s
# 1900:	total: 15.8s	remaining: 4.99s
# 2000:	total: 16.7s	remaining: 4.16s
# 2100:	total: 17.5s	remaining: 3.33s
# 2200:	total: 18.4s	remaining: 2.5s
# 2300:	total: 19.2s	remaining: 1.66s
# 2400:	total: 20s	remaining: 826ms
# 2499:	total: 20.8s	remaining: 0us
# 0:	total: 15.5ms	remaining: 38.8s
# 100:	total: 943ms	remaining: 22.4s
# 200:	total: 1.8s	remaining: 20.6s
# 300:	total: 2.67s	remaining: 19.5s
# 400:	total: 3.68s	remaining: 19.2s
# 500:	total: 4.68s	remaining: 18.7s
# 600:	total: 5.61s	remaining: 17.7s
# 700:	total: 6.53s	remaining: 16.7s
# 800:	total: 7.48s	remaining: 15.9s
# 900:	total: 8.42s	remaining: 14.9s
# 1000:	total: 9.38s	remaining: 14s
# 1100:	total: 10.3s	remaining: 13.1s
# 1200:	total: 11.2s	remaining: 12.1s
# 1300:	total: 12.1s	remaining: 11.2s
# 1400:	total: 13s	remaining: 10.2s
# 1500:	total: 13.9s	remaining: 9.23s
# 1600:	total: 14.8s	remaining: 8.31s
# 1700:	total: 15.7s	remaining: 7.37s
# 1800:	total: 16.6s	remaining: 6.46s
# 1900:	total: 17.5s	remaining: 5.52s
# 2000:	total: 18.4s	remaining: 4.59s
# 2100:	total: 19.2s	remaining: 3.65s
# 2200:	total: 20.2s	remaining: 2.74s
# 2300:	total: 21s	remaining: 1.81s
# 2400:	total: 21.8s	remaining: 899ms
# 2499:	total: 22.7s	remaining: 0us
# 0:	total: 13.4ms	remaining: 33.4s
# 100:	total: 910ms	remaining: 21.6s
# 200:	total: 1.79s	remaining: 20.5s
# 300:	total: 2.7s	remaining: 19.7s
# 400:	total: 3.58s	remaining: 18.7s
# 500:	total: 4.45s	remaining: 17.7s
# 600:	total: 5.31s	remaining: 16.8s
# 700:	total: 6.19s	remaining: 15.9s
# 800:	total: 7.14s	remaining: 15.1s
# 900:	total: 8.02s	remaining: 14.2s
# 1000:	total: 8.84s	remaining: 13.2s
# 1100:	total: 9.72s	remaining: 12.4s
# 1200:	total: 10.6s	remaining: 11.5s
# 1300:	total: 11.4s	remaining: 10.5s
# 1400:	total: 12.3s	remaining: 9.64s
# 1500:	total: 13.2s	remaining: 8.8s
# 1600:	total: 14.1s	remaining: 7.93s
# 1700:	total: 14.9s	remaining: 7.01s
# 1800:	total: 15.8s	remaining: 6.13s
# 1900:	total: 16.6s	remaining: 5.23s
# 2000:	total: 17.5s	remaining: 4.36s
# 2100:	total: 18.3s	remaining: 3.47s
# 2200:	total: 19.1s	remaining: 2.59s
# 2300:	total: 19.9s	remaining: 1.72s
# 2400:	total: 20.7s	remaining: 855ms
# 2499:	total: 21.6s	remaining: 0us
# 0:	total: 14.7ms	remaining: 36.8s
# 100:	total: 917ms	remaining: 21.8s
# 200:	total: 1.79s	remaining: 20.5s
# 300:	total: 2.65s	remaining: 19.4s
# 400:	total: 3.5s	remaining: 18.3s
# 500:	total: 4.49s	remaining: 17.9s
# 600:	total: 5.4s	remaining: 17.1s
# 700:	total: 6.27s	remaining: 16.1s
# 800:	total: 7.16s	remaining: 15.2s
# 900:	total: 8.01s	remaining: 14.2s
# 1000:	total: 8.87s	remaining: 13.3s
# 1100:	total: 9.7s	remaining: 12.3s
# 1200:	total: 10.6s	remaining: 11.4s
# 1300:	total: 11.4s	remaining: 10.5s
# 1400:	total: 12.2s	remaining: 9.61s
# 1500:	total: 13.1s	remaining: 8.71s
# 1600:	total: 13.9s	remaining: 7.8s
# 1700:	total: 14.7s	remaining: 6.89s
# 1800:	total: 15.5s	remaining: 6.02s
# 1900:	total: 16.3s	remaining: 5.14s
# 2000:	total: 17.1s	remaining: 4.27s
# 2100:	total: 17.9s	remaining: 3.4s
# 2200:	total: 18.7s	remaining: 2.55s
# 2300:	total: 19.6s	remaining: 1.69s
# 2400:	total: 20.3s	remaining: 837ms
# 2499:	total: 21.1s	remaining: 0us
# 0:	total: 11.1ms	remaining: 27.8s
# 100:	total: 850ms	remaining: 20.2s
# 200:	total: 1.71s	remaining: 19.6s
# 300:	total: 2.57s	remaining: 18.8s
# 400:	total: 3.42s	remaining: 17.9s
# 500:	total: 4.28s	remaining: 17.1s
# 600:	total: 5.12s	remaining: 16.2s
# 700:	total: 5.93s	remaining: 15.2s
# 800:	total: 6.74s	remaining: 14.3s
# 900:	total: 7.56s	remaining: 13.4s
# 1000:	total: 8.43s	remaining: 12.6s
# 1100:	total: 9.23s	remaining: 11.7s
# 1200:	total: 10.1s	remaining: 11s
# 1300:	total: 11s	remaining: 10.1s
# 1400:	total: 11.8s	remaining: 9.24s
# 1500:	total: 12.6s	remaining: 8.41s
# 1600:	total: 13.5s	remaining: 7.56s
# 1700:	total: 14.4s	remaining: 6.75s
# 1800:	total: 15.2s	remaining: 5.92s
# 1900:	total: 16.1s	remaining: 5.06s
# 2000:	total: 17.1s	remaining: 4.27s
# 2100:	total: 18s	remaining: 3.42s
# 2200:	total: 18.8s	remaining: 2.56s
# 2300:	total: 19.6s	remaining: 1.7s
# 2400:	total: 20.5s	remaining: 843ms
# 2499:	total: 21.2s	remaining: 0us
# 0:	total: 11.3ms	remaining: 28.3s
# 100:	total: 943ms	remaining: 22.4s
# 200:	total: 1.78s	remaining: 20.4s
# 300:	total: 2.62s	remaining: 19.2s
# 400:	total: 3.51s	remaining: 18.4s
# 500:	total: 4.33s	remaining: 17.3s
# 600:	total: 5.19s	remaining: 16.4s
# 700:	total: 5.99s	remaining: 15.4s
# 800:	total: 6.84s	remaining: 14.5s
# 900:	total: 7.74s	remaining: 13.7s
# 1000:	total: 8.66s	remaining: 13s
# 1100:	total: 9.56s	remaining: 12.1s
# 1200:	total: 10.5s	remaining: 11.3s
# 1300:	total: 11.4s	remaining: 10.5s
# 1400:	total: 12.2s	remaining: 9.59s
# 1500:	total: 13.1s	remaining: 8.73s
# 1600:	total: 14.1s	remaining: 7.89s
# 1700:	total: 15s	remaining: 7.04s
# 1800:	total: 15.9s	remaining: 6.16s
# 1900:	total: 16.9s	remaining: 5.33s
# 2000:	total: 18s	remaining: 4.49s
# 2100:	total: 19.1s	remaining: 3.62s
# 2200:	total: 20s	remaining: 2.71s
# 2300:	total: 20.9s	remaining: 1.81s
# 2400:	total: 21.8s	remaining: 899ms
# 2499:	total: 22.6s	remaining: 0us
# |  2        |  0.9404   |  0.309    |  4.734    |  0.1013   |
# 0:	total: 22ms	remaining: 54.9s
# 100:	total: 1.15s	remaining: 27.3s
# 200:	total: 2.36s	remaining: 27s
# 300:	total: 3.56s	remaining: 26s
# 400:	total: 4.76s	remaining: 24.9s
# 500:	total: 5.91s	remaining: 23.6s
# 600:	total: 7.04s	remaining: 22.3s
# 700:	total: 8.16s	remaining: 21s
# 800:	total: 9.27s	remaining: 19.7s
# 900:	total: 10.4s	remaining: 18.4s
# 1000:	total: 11.5s	remaining: 17.2s
# 1100:	total: 12.6s	remaining: 16.1s
# 1200:	total: 13.7s	remaining: 14.9s
# 1300:	total: 14.9s	remaining: 13.7s
# 1400:	total: 16s	remaining: 12.6s
# 1500:	total: 17.2s	remaining: 11.4s
# 1600:	total: 18.3s	remaining: 10.3s
# 1700:	total: 19.4s	remaining: 9.12s
# 1800:	total: 20.5s	remaining: 7.97s
# 1900:	total: 21.7s	remaining: 6.84s
# 2000:	total: 22.8s	remaining: 5.68s
# 2100:	total: 23.9s	remaining: 4.54s
# 2200:	total: 25s	remaining: 3.4s
# 2300:	total: 26.1s	remaining: 2.25s
# 2400:	total: 27.2s	remaining: 1.12s
# 2499:	total: 28.3s	remaining: 0us
# 0:	total: 16ms	remaining: 40s
# 100:	total: 1.28s	remaining: 30.4s
# 200:	total: 2.53s	remaining: 28.9s
# 300:	total: 3.82s	remaining: 27.9s
# 400:	total: 5s	remaining: 26.2s
# 500:	total: 6.18s	remaining: 24.7s
# 600:	total: 7.42s	remaining: 23.4s
# 700:	total: 8.56s	remaining: 22s
# 800:	total: 9.7s	remaining: 20.6s
# 900:	total: 10.8s	remaining: 19.2s
# 1000:	total: 12s	remaining: 18s
# 1100:	total: 13.1s	remaining: 16.6s
# 1200:	total: 14.2s	remaining: 15.4s
# 1300:	total: 15.4s	remaining: 14.2s
# 1400:	total: 16.5s	remaining: 12.9s
# 1500:	total: 17.6s	remaining: 11.7s
# 1600:	total: 18.8s	remaining: 10.5s
# 1700:	total: 20s	remaining: 9.4s
# 1800:	total: 21.2s	remaining: 8.24s
# 1900:	total: 22.5s	remaining: 7.08s
# 2000:	total: 23.7s	remaining: 5.91s
# 2100:	total: 24.9s	remaining: 4.73s
# 2200:	total: 26.1s	remaining: 3.54s
# 2300:	total: 27.3s	remaining: 2.36s
# 2400:	total: 28.5s	remaining: 1.18s
# 2499:	total: 29.8s	remaining: 0us
# 0:	total: 19.7ms	remaining: 49.3s
# 100:	total: 1.34s	remaining: 31.9s
# 200:	total: 2.76s	remaining: 31.6s
# 300:	total: 4.07s	remaining: 29.7s
# 400:	total: 5.3s	remaining: 27.8s
# 500:	total: 6.52s	remaining: 26s
# 600:	total: 7.75s	remaining: 24.5s
# 700:	total: 8.94s	remaining: 22.9s
# 800:	total: 10.1s	remaining: 21.5s
# 900:	total: 11.3s	remaining: 20s
# 1000:	total: 12.4s	remaining: 18.6s
# 1100:	total: 13.6s	remaining: 17.3s
# 1200:	total: 14.8s	remaining: 16s
# 1300:	total: 15.9s	remaining: 14.7s
# 1400:	total: 17s	remaining: 13.3s
# 1500:	total: 18.1s	remaining: 12.1s
# 1600:	total: 19.2s	remaining: 10.8s
# 1700:	total: 20.3s	remaining: 9.53s
# 1800:	total: 21.4s	remaining: 8.31s
# 1900:	total: 22.7s	remaining: 7.14s
# 2000:	total: 23.9s	remaining: 5.96s
# 2100:	total: 25s	remaining: 4.75s
# 2200:	total: 26.1s	remaining: 3.55s
# 2300:	total: 27.3s	remaining: 2.36s
# 2400:	total: 28.4s	remaining: 1.17s
# 2499:	total: 29.6s	remaining: 0us
# 0:	total: 15.1ms	remaining: 37.7s
# 100:	total: 1.18s	remaining: 28.1s
# 200:	total: 2.37s	remaining: 27.1s
# 300:	total: 3.55s	remaining: 26s
# 400:	total: 4.77s	remaining: 25s
# 500:	total: 5.94s	remaining: 23.7s
# 600:	total: 7.14s	remaining: 22.6s
# 700:	total: 8.49s	remaining: 21.8s
# 800:	total: 9.8s	remaining: 20.8s
# 900:	total: 11s	remaining: 19.5s
# 1000:	total: 12.3s	remaining: 18.4s
# 1100:	total: 13.8s	remaining: 17.5s
# 1200:	total: 15.1s	remaining: 16.4s
# 1300:	total: 16.3s	remaining: 15s
# 1400:	total: 17.4s	remaining: 13.7s
# 1500:	total: 18.7s	remaining: 12.4s
# 1600:	total: 19.9s	remaining: 11.2s
# 1700:	total: 21.1s	remaining: 9.92s
# 1800:	total: 22.3s	remaining: 8.67s
# 1900:	total: 23.6s	remaining: 7.42s
# 2000:	total: 24.9s	remaining: 6.2s
# 2100:	total: 26.2s	remaining: 4.97s
# 2200:	total: 27.4s	remaining: 3.72s
# 2300:	total: 28.6s	remaining: 2.47s
# 2400:	total: 29.8s	remaining: 1.23s
# 2499:	total: 31s	remaining: 0us
# 0:	total: 17.7ms	remaining: 44.2s
# 100:	total: 1.14s	remaining: 27s
# 200:	total: 2.32s	remaining: 26.5s
# 300:	total: 3.49s	remaining: 25.5s
# 400:	total: 4.68s	remaining: 24.5s
# 500:	total: 5.78s	remaining: 23.1s
# 600:	total: 6.9s	remaining: 21.8s
# 700:	total: 7.99s	remaining: 20.5s
# 800:	total: 9.06s	remaining: 19.2s
# 900:	total: 10.1s	remaining: 18s
# 1000:	total: 11.2s	remaining: 16.8s
# 1100:	total: 12.3s	remaining: 15.7s
# 1200:	total: 13.5s	remaining: 14.6s
# 1300:	total: 14.7s	remaining: 13.5s
# 1400:	total: 15.9s	remaining: 12.4s
# 1500:	total: 17s	remaining: 11.3s
# 1600:	total: 18.2s	remaining: 10.2s
# 1700:	total: 19.3s	remaining: 9.08s
# 1800:	total: 20.5s	remaining: 7.96s
# 1900:	total: 21.8s	remaining: 6.86s
# 2000:	total: 22.9s	remaining: 5.71s
# 2100:	total: 24.2s	remaining: 4.6s
# 2200:	total: 25.4s	remaining: 3.45s
# 2300:	total: 26.6s	remaining: 2.3s
# 2400:	total: 27.9s	remaining: 1.15s
# 2499:	total: 29.1s	remaining: 0us
# 0:	total: 24.5ms	remaining: 1m 1s
# 100:	total: 1.23s	remaining: 29.3s
# 200:	total: 2.49s	remaining: 28.4s
# 300:	total: 3.77s	remaining: 27.5s
# 400:	total: 5.02s	remaining: 26.3s
# 500:	total: 6.22s	remaining: 24.8s
# 600:	total: 7.44s	remaining: 23.5s
# 700:	total: 8.67s	remaining: 22.2s
# 800:	total: 9.88s	remaining: 21s
# 900:	total: 11.1s	remaining: 19.7s
# 1000:	total: 12.2s	remaining: 18.3s
# 1100:	total: 13.4s	remaining: 17.1s
# 1200:	total: 14.6s	remaining: 15.8s
# 1300:	total: 15.7s	remaining: 14.5s
# 1400:	total: 16.8s	remaining: 13.2s
# 1500:	total: 17.9s	remaining: 11.9s
# 1600:	total: 19s	remaining: 10.7s
# 1700:	total: 20.1s	remaining: 9.43s
# 1800:	total: 21.3s	remaining: 8.26s
# 1900:	total: 22.5s	remaining: 7.09s
# 2000:	total: 23.7s	remaining: 5.9s
# 2100:	total: 24.8s	remaining: 4.71s
# 2200:	total: 25.9s	remaining: 3.52s
# 2300:	total: 27s	remaining: 2.34s
# 2400:	total: 28.3s	remaining: 1.16s
# 2499:	total: 29.4s	remaining: 0us
# 0:	total: 16.4ms	remaining: 40.9s
# 100:	total: 1.13s	remaining: 26.7s
# 200:	total: 2.27s	remaining: 25.9s
# 300:	total: 3.43s	remaining: 25.1s
# 400:	total: 4.62s	remaining: 24.2s
# 500:	total: 5.81s	remaining: 23.2s
# 600:	total: 7.02s	remaining: 22.2s
# 700:	total: 8.19s	remaining: 21s
# 800:	total: 9.29s	remaining: 19.7s
# 900:	total: 10.4s	remaining: 18.5s
# 1000:	total: 11.5s	remaining: 17.3s
# 1100:	total: 12.7s	remaining: 16.1s
# 1200:	total: 13.8s	remaining: 14.9s
# 1300:	total: 15s	remaining: 13.8s
# 1400:	total: 16.2s	remaining: 12.7s
# 1500:	total: 17.4s	remaining: 11.6s
# 1600:	total: 18.5s	remaining: 10.4s
# 1700:	total: 19.6s	remaining: 9.22s
# 1800:	total: 20.8s	remaining: 8.08s
# 1900:	total: 22s	remaining: 6.94s
# 2000:	total: 23.2s	remaining: 5.78s
# 2100:	total: 24.3s	remaining: 4.61s
# 2200:	total: 25.4s	remaining: 3.46s
# 2300:	total: 26.6s	remaining: 2.3s
# 2400:	total: 27.8s	remaining: 1.14s
# 2499:	total: 28.9s	remaining: 0us
# 0:	total: 14.3ms	remaining: 35.8s
# 100:	total: 1.22s	remaining: 29s
# 200:	total: 2.42s	remaining: 27.7s
# 300:	total: 3.64s	remaining: 26.6s
# 400:	total: 4.82s	remaining: 25.2s
# 500:	total: 5.98s	remaining: 23.9s
# 600:	total: 7.1s	remaining: 22.4s
# 700:	total: 8.24s	remaining: 21.1s
# 800:	total: 9.36s	remaining: 19.9s
# 900:	total: 10.5s	remaining: 18.6s
# 1000:	total: 11.7s	remaining: 17.5s
# 1100:	total: 12.8s	remaining: 16.2s
# 1200:	total: 13.9s	remaining: 15s
# 1300:	total: 15.1s	remaining: 13.9s
# 1400:	total: 16.4s	remaining: 12.9s
# 1500:	total: 17.6s	remaining: 11.7s
# 1600:	total: 18.7s	remaining: 10.5s
# 1700:	total: 19.9s	remaining: 9.34s
# 1800:	total: 21s	remaining: 8.17s
# 1900:	total: 22.2s	remaining: 6.99s
# 2000:	total: 23.4s	remaining: 5.83s
# 2100:	total: 24.6s	remaining: 4.68s
# 2200:	total: 25.9s	remaining: 3.52s
# 2300:	total: 27s	remaining: 2.33s
# 2400:	total: 28.1s	remaining: 1.16s
# 2499:	total: 29.3s	remaining: 0us
# 0:	total: 18.7ms	remaining: 46.7s
# 100:	total: 1.17s	remaining: 27.7s
# 200:	total: 2.3s	remaining: 26.3s
# 300:	total: 3.47s	remaining: 25.3s
# 400:	total: 4.61s	remaining: 24.1s
# 500:	total: 5.72s	remaining: 22.8s
# 600:	total: 6.83s	remaining: 21.6s
# 700:	total: 7.91s	remaining: 20.3s
# 800:	total: 9.02s	remaining: 19.1s
# 900:	total: 10.2s	remaining: 18s
# 1000:	total: 11.3s	remaining: 16.9s
# 1100:	total: 12.5s	remaining: 15.8s
# 1200:	total: 13.6s	remaining: 14.7s
# 1300:	total: 14.7s	remaining: 13.5s
# 1400:	total: 15.8s	remaining: 12.4s
# 1500:	total: 17s	remaining: 11.3s
# 1600:	total: 18.1s	remaining: 10.2s
# 1700:	total: 19.3s	remaining: 9.08s
# 1800:	total: 20.6s	remaining: 7.98s
# 1900:	total: 21.8s	remaining: 6.88s
# 2000:	total: 23s	remaining: 5.73s
# 2100:	total: 24.1s	remaining: 4.58s
# 2200:	total: 25.3s	remaining: 3.43s
# 2300:	total: 26.4s	remaining: 2.28s
# 2400:	total: 27.5s	remaining: 1.14s
# 2499:	total: 28.7s	remaining: 0us
# 0:	total: 14.8ms	remaining: 36.9s
# 100:	total: 1.25s	remaining: 29.8s
# 200:	total: 2.48s	remaining: 28.4s
# 300:	total: 3.72s	remaining: 27.2s
# 400:	total: 4.95s	remaining: 25.9s
# 500:	total: 6.21s	remaining: 24.8s
# 600:	total: 7.47s	remaining: 23.6s
# 700:	total: 8.66s	remaining: 22.2s
# 800:	total: 9.82s	remaining: 20.8s
# 900:	total: 11s	remaining: 19.5s
# 1000:	total: 12.2s	remaining: 18.2s
# 1100:	total: 13.3s	remaining: 17s
# 1200:	total: 14.5s	remaining: 15.7s
# 1300:	total: 15.6s	remaining: 14.4s
# 1400:	total: 16.7s	remaining: 13.1s
# 1500:	total: 17.8s	remaining: 11.9s
# 1600:	total: 19s	remaining: 10.6s
# 1700:	total: 20.1s	remaining: 9.43s
# 1800:	total: 21.3s	remaining: 8.25s
# 1900:	total: 22.5s	remaining: 7.08s
# 2000:	total: 23.6s	remaining: 5.89s
# 2100:	total: 24.8s	remaining: 4.71s
# 2200:	total: 26s	remaining: 3.53s
# 2300:	total: 27.1s	remaining: 2.34s
# 2400:	total: 28.2s	remaining: 1.16s
# 2499:	total: 29.3s	remaining: 0us
# 0:	total: 18.8ms	remaining: 46.9s
# 100:	total: 1.29s	remaining: 30.7s
# 200:	total: 2.48s	remaining: 28.4s
# 300:	total: 3.64s	remaining: 26.6s
# 400:	total: 4.75s	remaining: 24.8s
# 500:	total: 5.87s	remaining: 23.4s
# 600:	total: 7s	remaining: 22.1s
# 700:	total: 8.08s	remaining: 20.7s
# 800:	total: 9.21s	remaining: 19.5s
# 900:	total: 10.4s	remaining: 18.4s
# 1000:	total: 11.6s	remaining: 17.3s
# 1100:	total: 12.8s	remaining: 16.3s
# 1200:	total: 14s	remaining: 15.1s
# 1300:	total: 15.1s	remaining: 13.9s
# 1400:	total: 16.3s	remaining: 12.8s
# 1500:	total: 17.5s	remaining: 11.6s
# 1600:	total: 18.7s	remaining: 10.5s
# 1700:	total: 19.9s	remaining: 9.33s
# 1800:	total: 21.1s	remaining: 8.18s
# 1900:	total: 22.3s	remaining: 7.03s
# 2000:	total: 23.5s	remaining: 5.87s
# 2100:	total: 24.7s	remaining: 4.7s
# 2200:	total: 25.9s	remaining: 3.52s
# 2300:	total: 27.1s	remaining: 2.34s
# 2400:	total: 28.3s	remaining: 1.17s
# 2499:	total: 29.5s	remaining: 0us
# 0:	total: 16.5ms	remaining: 41.2s
# 100:	total: 1.25s	remaining: 29.8s
# 200:	total: 2.5s	remaining: 28.7s
# 300:	total: 3.75s	remaining: 27.4s
# 400:	total: 4.94s	remaining: 25.9s
# 500:	total: 6.15s	remaining: 24.5s
# 600:	total: 7.26s	remaining: 23s
# 700:	total: 8.37s	remaining: 21.5s
# 800:	total: 9.46s	remaining: 20.1s
# 900:	total: 10.6s	remaining: 18.8s
# 1000:	total: 11.7s	remaining: 17.5s
# 1100:	total: 12.8s	remaining: 16.3s
# 1200:	total: 13.9s	remaining: 15.1s
# 1300:	total: 15s	remaining: 13.8s
# 1400:	total: 16.1s	remaining: 12.7s
# 1500:	total: 17.2s	remaining: 11.5s
# 1600:	total: 18.3s	remaining: 10.3s
# 1700:	total: 19.4s	remaining: 9.12s
# 1800:	total: 20.6s	remaining: 7.98s
# 1900:	total: 21.7s	remaining: 6.85s
# 2000:	total: 22.8s	remaining: 5.69s
# 2100:	total: 23.9s	remaining: 4.53s
# 2200:	total: 25.1s	remaining: 3.41s
# 2300:	total: 26.3s	remaining: 2.27s
# 2400:	total: 27.4s	remaining: 1.13s
# 2499:	total: 28.5s	remaining: 0us
# 0:	total: 14.8ms	remaining: 37.1s
# 100:	total: 1.14s	remaining: 27.1s
# 200:	total: 2.45s	remaining: 28.1s
# 300:	total: 3.71s	remaining: 27.1s
# ...
# 400:	total: 7.43s	remaining: 38.9s
# 500:	total: 9.24s	remaining: 36.9s
# 600:	total: 11.1s	remaining: 35s
# 700:	total: 12.8s	remaining: 32.7s
# 800:	total: 14.5s	remaining: 30.8s
# 900:	total: 16.4s	remaining: 29.1s
# 1000:	total: 18.3s	remaining: 27.3s
# 1100:	total: 20.3s	remaining: 25.7s
# 1200:	total: 22.2s	remaining: 24s
# 1300:	total: 23.9s	remaining: 22s
# 1400:	total: 25.7s	remaining: 20.1s
# 1500:	total: 27.4s	remaining: 18.2s
# 1600:	total: 29.2s	remaining: 16.4s
# 1700:	total: 30.9s	remaining: 14.5s
# 1800:	total: 32.6s	remaining: 12.7s
# 1900:	total: 34.5s	remaining: 10.9s
# 2000:	total: 36.4s	remaining: 9.07s
# 2100:	total: 38.3s	remaining: 7.27s
# 2200:	total: 40.3s	remaining: 5.47s
# 2300:	total: 42.2s	remaining: 3.65s
# 2400:	total: 44.2s	remaining: 1.82s
# 2499:	total: 46.1s	remaining: 0us
# 0:	total: 37.7ms	remaining: 1m 34s
# 100:	total: 2.02s	remaining: 48s
# 200:	total: 3.96s	remaining: 45.3s
# 300:	total: 6.04s	remaining: 44.1s
# 400:	total: 7.92s	remaining: 41.5s
# 500:	total: 9.84s	remaining: 39.3s
# 600:	total: 11.7s	remaining: 37s
# 700:	total: 13.5s	remaining: 34.5s
# 800:	total: 15.4s	remaining: 32.7s
# 900:	total: 17.3s	remaining: 30.7s
# 1000:	total: 19.3s	remaining: 28.8s
# 1100:	total: 21.3s	remaining: 27.1s
# 1200:	total: 23.1s	remaining: 25s
# 1300:	total: 24.9s	remaining: 23s
# 1400:	total: 26.7s	remaining: 21s
# 1500:	total: 28.5s	remaining: 19s
# 1600:	total: 30.4s	remaining: 17s
# 1700:	total: 32.2s	remaining: 15.1s
# 1800:	total: 34.1s	remaining: 13.2s
# 1900:	total: 35.8s	remaining: 11.3s
# 2000:	total: 37.6s	remaining: 9.36s
# 2100:	total: 39.4s	remaining: 7.47s
# 2200:	total: 41.3s	remaining: 5.61s
# 2300:	total: 43.2s	remaining: 3.73s
# 2400:	total: 45.1s	remaining: 1.86s
# 2499:	total: 46.9s	remaining: 0us
# 0:	total: 25.8ms	remaining: 1m 4s
# 100:	total: 1.87s	remaining: 44.3s
# 200:	total: 3.71s	remaining: 42.4s
# 300:	total: 5.66s	remaining: 41.4s
# 400:	total: 7.8s	remaining: 40.8s
# 500:	total: 9.79s	remaining: 39.1s
# 600:	total: 11.7s	remaining: 37s
# 700:	total: 13.7s	remaining: 35.1s
# 800:	total: 15.6s	remaining: 33.2s
# 900:	total: 17.6s	remaining: 31.2s
# 1000:	total: 19.5s	remaining: 29.1s
# 1100:	total: 21.5s	remaining: 27.3s
# 1200:	total: 23.4s	remaining: 25.3s
# 1300:	total: 25.3s	remaining: 23.4s
# 1400:	total: 27.3s	remaining: 21.4s
# 1500:	total: 29s	remaining: 19.3s
# 1600:	total: 31s	remaining: 17.4s
# 1700:	total: 32.9s	remaining: 15.5s
# 1800:	total: 34.8s	remaining: 13.5s
# 1900:	total: 36.7s	remaining: 11.6s
# 2000:	total: 38.4s	remaining: 9.59s
# 2100:	total: 40.3s	remaining: 7.64s
# 2200:	total: 42.2s	remaining: 5.73s
# 2300:	total: 43.9s	remaining: 3.8s
# 2400:	total: 45.8s	remaining: 1.89s
# 2499:	total: 47.6s	remaining: 0us
# 0:	total: 33.7ms	remaining: 1m 24s
# 100:	total: 2.09s	remaining: 49.6s
# 200:	total: 3.95s	remaining: 45.2s
# 300:	total: 5.86s	remaining: 42.8s
# 400:	total: 7.58s	remaining: 39.7s
# 500:	total: 9.5s	remaining: 37.9s
# 600:	total: 11.5s	remaining: 36.4s
# 700:	total: 13.5s	remaining: 34.7s
# 800:	total: 15.6s	remaining: 33.2s
# 900:	total: 17.7s	remaining: 31.5s
# 1000:	total: 19.8s	remaining: 29.6s
# 1100:	total: 21.8s	remaining: 27.7s
# 1200:	total: 23.8s	remaining: 25.8s
# 1300:	total: 25.8s	remaining: 23.8s
# 1400:	total: 27.7s	remaining: 21.7s
# 1500:	total: 29.8s	remaining: 19.9s
# 1600:	total: 31.8s	remaining: 17.9s
# 1700:	total: 33.7s	remaining: 15.8s
# 1800:	total: 35.6s	remaining: 13.8s
# 1900:	total: 37.5s	remaining: 11.8s
# 2000:	total: 39.4s	remaining: 9.84s
# 2100:	total: 41.3s	remaining: 7.84s
# 2200:	total: 43.2s	remaining: 5.86s
# 2300:	total: 44.8s	remaining: 3.88s
# 2400:	total: 46.5s	remaining: 1.92s
# 2499:	total: 48.2s	remaining: 0us
# |  4        |  0.9237   |  0.5429   |  6.096    |  0.6877   |
# 0:	total: 65.6ms	remaining: 2m 43s
# 100:	total: 5.81s	remaining: 2m 18s
# 200:	total: 11.5s	remaining: 2m 11s
# 300:	total: 17s	remaining: 2m 3s
# 400:	total: 21.9s	remaining: 1m 54s
# 500:	total: 26.8s	remaining: 1m 47s
# 600:	total: 31.9s	remaining: 1m 40s
# 700:	total: 36.9s	remaining: 1m 34s
# 800:	total: 41.8s	remaining: 1m 28s
# 900:	total: 46.8s	remaining: 1m 23s
# 1000:	total: 51.7s	remaining: 1m 17s
# 1100:	total: 56.6s	remaining: 1m 11s
# 1200:	total: 1m 1s	remaining: 1m 6s
# 1300:	total: 1m 6s	remaining: 1m 1s
# 1400:	total: 1m 11s	remaining: 56.2s
# 1500:	total: 1m 16s	remaining: 51.1s
# 1600:	total: 1m 21s	remaining: 46s
# 1700:	total: 1m 27s	remaining: 40.9s
# 1800:	total: 1m 32s	remaining: 35.9s
# 1900:	total: 1m 37s	remaining: 30.7s
# 2000:	total: 1m 42s	remaining: 25.7s
# 2100:	total: 1m 48s	remaining: 20.5s
# 2200:	total: 1m 53s	remaining: 15.4s
# 2300:	total: 1m 58s	remaining: 10.2s
# 2400:	total: 2m 3s	remaining: 5.11s
# 2499:	total: 2m 9s	remaining: 0us
# 0:	total: 56.1ms	remaining: 2m 20s
# 100:	total: 5.86s	remaining: 2m 19s
# 200:	total: 12.2s	remaining: 2m 19s
# 300:	total: 18s	remaining: 2m 11s
# 400:	total: 23.9s	remaining: 2m 4s
# 500:	total: 29.4s	remaining: 1m 57s
# 600:	total: 35.2s	remaining: 1m 51s
# 700:	total: 40.8s	remaining: 1m 44s
# 800:	total: 46.4s	remaining: 1m 38s
# 900:	total: 51.7s	remaining: 1m 31s
# 1000:	total: 57.4s	remaining: 1m 25s
# 1100:	total: 1m 3s	remaining: 1m 20s
# 1200:	total: 1m 9s	remaining: 1m 14s
# 1300:	total: 1m 14s	remaining: 1m 9s
# 1400:	total: 1m 20s	remaining: 1m 3s
# 1500:	total: 1m 26s	remaining: 57.3s
# 1600:	total: 1m 31s	remaining: 51.5s
# 1700:	total: 1m 37s	remaining: 45.6s
# 1800:	total: 1m 42s	remaining: 39.8s
# 1900:	total: 1m 47s	remaining: 34s
# 2000:	total: 1m 53s	remaining: 28.3s
# 2100:	total: 1m 59s	remaining: 22.6s
# 2200:	total: 2m 4s	remaining: 16.9s
# 2300:	total: 2m 9s	remaining: 11.2s
# 2400:	total: 2m 15s	remaining: 5.58s
# 2499:	total: 2m 21s	remaining: 0us
# 0:	total: 66.1ms	remaining: 2m 45s
# 100:	total: 5.15s	remaining: 2m 2s
# 200:	total: 10.7s	remaining: 2m 2s
# 300:	total: 16.5s	remaining: 2m
# 400:	total: 22.6s	remaining: 1m 58s
# 500:	total: 28.1s	remaining: 1m 52s
# 600:	total: 33.2s	remaining: 1m 44s
# 700:	total: 38.2s	remaining: 1m 38s
# 800:	total: 43.5s	remaining: 1m 32s
# 900:	total: 48.5s	remaining: 1m 25s
# 1000:	total: 53.5s	remaining: 1m 20s
# 1100:	total: 58.6s	remaining: 1m 14s
# 1200:	total: 1m 3s	remaining: 1m 9s
# 1300:	total: 1m 9s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.6s
# 1500:	total: 1m 19s	remaining: 53.2s
# 1600:	total: 1m 25s	remaining: 47.7s
# 1700:	total: 1m 30s	remaining: 42.4s
# 1800:	total: 1m 35s	remaining: 37.1s
# 1900:	total: 1m 40s	remaining: 31.8s
# 2000:	total: 1m 46s	remaining: 26.5s
# 2100:	total: 1m 51s	remaining: 21.2s
# 2200:	total: 1m 56s	remaining: 15.9s
# 2300:	total: 2m 2s	remaining: 10.6s
# 2400:	total: 2m 7s	remaining: 5.24s
# 2499:	total: 2m 12s	remaining: 0us
# 0:	total: 62.2ms	remaining: 2m 35s
# 100:	total: 5.81s	remaining: 2m 18s
# 200:	total: 11.4s	remaining: 2m 10s
# 300:	total: 16.5s	remaining: 2m
# 400:	total: 21.6s	remaining: 1m 52s
# 500:	total: 26.7s	remaining: 1m 46s
# 600:	total: 31.7s	remaining: 1m 40s
# 700:	total: 36.8s	remaining: 1m 34s
# 800:	total: 41.8s	remaining: 1m 28s
# 900:	total: 47s	remaining: 1m 23s
# 1000:	total: 52.4s	remaining: 1m 18s
# 1100:	total: 57.8s	remaining: 1m 13s
# 1200:	total: 1m 3s	remaining: 1m 8s
# 1300:	total: 1m 8s	remaining: 1m 3s
# 1400:	total: 1m 13s	remaining: 57.9s
# 1500:	total: 1m 18s	remaining: 52.5s
# 1600:	total: 1m 23s	remaining: 47.1s
# 1700:	total: 1m 29s	remaining: 41.8s
# 1800:	total: 1m 34s	remaining: 36.7s
# 1900:	total: 1m 40s	remaining: 31.6s
# 2000:	total: 1m 46s	remaining: 26.5s
# 2100:	total: 1m 51s	remaining: 21.2s
# 2200:	total: 1m 56s	remaining: 15.9s
# 2300:	total: 2m 1s	remaining: 10.5s
# 2400:	total: 2m 7s	remaining: 5.24s
# 2499:	total: 2m 12s	remaining: 0us
# 0:	total: 66.9ms	remaining: 2m 47s
# 100:	total: 5.15s	remaining: 2m 2s
# 200:	total: 10.7s	remaining: 2m 2s
# 300:	total: 16.7s	remaining: 2m 1s
# 400:	total: 22.1s	remaining: 1m 55s
# 500:	total: 27.7s	remaining: 1m 50s
# 600:	total: 33.3s	remaining: 1m 45s
# 700:	total: 38.8s	remaining: 1m 39s
# 800:	total: 44.1s	remaining: 1m 33s
# 900:	total: 49.5s	remaining: 1m 27s
# 1000:	total: 55.1s	remaining: 1m 22s
# 1100:	total: 1m	remaining: 1m 16s
# 1200:	total: 1m 6s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 5s
# 1400:	total: 1m 17s	remaining: 1m
# 1500:	total: 1m 22s	remaining: 55s
# 1600:	total: 1m 28s	remaining: 49.4s
# 1700:	total: 1m 33s	remaining: 43.9s
# 1800:	total: 1m 38s	remaining: 38.3s
# 1900:	total: 1m 44s	remaining: 32.8s
# 2000:	total: 1m 49s	remaining: 27.4s
# 2100:	total: 1m 55s	remaining: 22s
# 2200:	total: 2m 1s	remaining: 16.5s
# 2300:	total: 2m 7s	remaining: 11s
# 2400:	total: 2m 13s	remaining: 5.49s
# 2499:	total: 2m 18s	remaining: 0us
# 0:	total: 84.2ms	remaining: 3m 30s
# 100:	total: 5.55s	remaining: 2m 11s
# 200:	total: 10.9s	remaining: 2m 5s
# 300:	total: 16.6s	remaining: 2m 1s
# 400:	total: 22.1s	remaining: 1m 55s
# 500:	total: 27.8s	remaining: 1m 51s
# 600:	total: 33.5s	remaining: 1m 45s
# 700:	total: 39.2s	remaining: 1m 40s
# 800:	total: 44.5s	remaining: 1m 34s
# 900:	total: 49.8s	remaining: 1m 28s
# 1000:	total: 55.4s	remaining: 1m 23s
# 1100:	total: 1m 1s	remaining: 1m 17s
# 1200:	total: 1m 7s	remaining: 1m 12s
# 1300:	total: 1m 13s	remaining: 1m 7s
# 1400:	total: 1m 19s	remaining: 1m 2s
# 1500:	total: 1m 25s	remaining: 56.9s
# 1600:	total: 1m 31s	remaining: 51.3s
# 1700:	total: 1m 37s	remaining: 45.9s
# 1800:	total: 1m 43s	remaining: 40.4s
# 1900:	total: 1m 49s	remaining: 34.5s
# 2000:	total: 1m 55s	remaining: 28.7s
# 2100:	total: 2m 1s	remaining: 23s
# 2200:	total: 2m 8s	remaining: 17.4s
# 2300:	total: 2m 15s	remaining: 11.7s
# 2400:	total: 2m 21s	remaining: 5.84s
# 2499:	total: 2m 28s	remaining: 0us
# 0:	total: 64.3ms	remaining: 2m 40s
# 100:	total: 5.81s	remaining: 2m 17s
# 200:	total: 11.2s	remaining: 2m 7s
# 300:	total: 16.8s	remaining: 2m 3s
# 400:	total: 22.8s	remaining: 1m 59s
# 500:	total: 28.8s	remaining: 1m 55s
# 600:	total: 35s	remaining: 1m 50s
# 700:	total: 41.7s	remaining: 1m 46s
# 800:	total: 48s	remaining: 1m 41s
# 900:	total: 54.2s	remaining: 1m 36s
# 1000:	total: 1m	remaining: 1m 30s
# 1100:	total: 1m 5s	remaining: 1m 23s
# 1200:	total: 1m 11s	remaining: 1m 16s
# 1300:	total: 1m 16s	remaining: 1m 10s
# 1400:	total: 1m 21s	remaining: 1m 4s
# 1500:	total: 1m 27s	remaining: 58.3s
# 1600:	total: 1m 33s	remaining: 52.3s
# 1700:	total: 1m 38s	remaining: 46.4s
# 1800:	total: 1m 44s	remaining: 40.5s
# 1900:	total: 1m 49s	remaining: 34.6s
# 2000:	total: 1m 55s	remaining: 28.8s
# 2100:	total: 2m 1s	remaining: 23s
# 2200:	total: 2m 7s	remaining: 17.3s
# 2300:	total: 2m 12s	remaining: 11.5s
# 2400:	total: 2m 18s	remaining: 5.71s
# 2499:	total: 2m 24s	remaining: 0us
# 0:	total: 90.5ms	remaining: 3m 46s
# 100:	total: 5.86s	remaining: 2m 19s
# 200:	total: 11.3s	remaining: 2m 9s
# 300:	total: 16.8s	remaining: 2m 2s
# 400:	total: 22.5s	remaining: 1m 57s
# 500:	total: 27.9s	remaining: 1m 51s
# 600:	total: 33.7s	remaining: 1m 46s
# 700:	total: 39.6s	remaining: 1m 41s
# 800:	total: 45.3s	remaining: 1m 35s
# 900:	total: 51s	remaining: 1m 30s
# 1000:	total: 56.2s	remaining: 1m 24s
# 1100:	total: 1m 1s	remaining: 1m 17s
# 1200:	total: 1m 6s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 5s
# 1400:	total: 1m 16s	remaining: 1m
# 1500:	total: 1m 21s	remaining: 54.4s
# 1600:	total: 1m 27s	remaining: 49.1s
# 1700:	total: 1m 33s	remaining: 43.8s
# 1800:	total: 1m 38s	remaining: 38.3s
# 1900:	total: 1m 44s	remaining: 33s
# 2000:	total: 1m 50s	remaining: 27.5s
# 2100:	total: 1m 56s	remaining: 22.1s
# 2200:	total: 2m 2s	remaining: 16.7s
# 2300:	total: 2m 7s	remaining: 11.1s
# 2400:	total: 2m 13s	remaining: 5.49s
# 2499:	total: 2m 19s	remaining: 0us
# 0:	total: 69.8ms	remaining: 2m 54s
# 100:	total: 6.19s	remaining: 2m 27s
# 200:	total: 11.9s	remaining: 2m 16s
# 300:	total: 17.2s	remaining: 2m 5s
# 400:	total: 22.9s	remaining: 2m
# 500:	total: 28.5s	remaining: 1m 53s
# 600:	total: 34.3s	remaining: 1m 48s
# 700:	total: 39.9s	remaining: 1m 42s
# 800:	total: 45.1s	remaining: 1m 35s
# 900:	total: 50.2s	remaining: 1m 29s
# 1000:	total: 55.4s	remaining: 1m 22s
# 1100:	total: 1m	remaining: 1m 17s
# 1200:	total: 1m 6s	remaining: 1m 11s
# 1300:	total: 1m 11s	remaining: 1m 5s
# 1400:	total: 1m 16s	remaining: 59.9s
# 1500:	total: 1m 21s	remaining: 54.2s
# 1600:	total: 1m 26s	remaining: 48.6s
# 1700:	total: 1m 31s	remaining: 43s
# 1800:	total: 1m 36s	remaining: 37.5s
# 1900:	total: 1m 41s	remaining: 32.1s
# 2000:	total: 1m 46s	remaining: 26.6s
# 2100:	total: 1m 51s	remaining: 21.2s
# 2200:	total: 1m 56s	remaining: 15.9s
# 2300:	total: 2m 2s	remaining: 10.6s
# 2400:	total: 2m 7s	remaining: 5.26s
# 2499:	total: 2m 12s	remaining: 0us
# 0:	total: 60.7ms	remaining: 2m 31s
# 100:	total: 5.11s	remaining: 2m 1s
# 200:	total: 10.7s	remaining: 2m 2s
# 300:	total: 16.3s	remaining: 1m 58s
# 400:	total: 21.4s	remaining: 1m 52s
# 500:	total: 26.8s	remaining: 1m 47s
# 600:	total: 32.6s	remaining: 1m 43s
# 700:	total: 37.9s	remaining: 1m 37s
# 800:	total: 43s	remaining: 1m 31s
# 900:	total: 47.8s	remaining: 1m 24s
# 1000:	total: 53s	remaining: 1m 19s
# 1100:	total: 58.1s	remaining: 1m 13s
# 1200:	total: 1m 3s	remaining: 1m 8s
# 1300:	total: 1m 8s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.4s
# 1500:	total: 1m 20s	remaining: 53.5s
# 1600:	total: 1m 26s	remaining: 48.6s
# 1700:	total: 1m 31s	remaining: 43.2s
# 1800:	total: 1m 37s	remaining: 37.7s
# 1900:	total: 1m 42s	remaining: 32.4s
# 2000:	total: 1m 48s	remaining: 27.1s
# 2100:	total: 1m 54s	remaining: 21.7s
# 2200:	total: 2m	remaining: 16.3s
# 2300:	total: 2m 5s	remaining: 10.9s
# 2400:	total: 2m 11s	remaining: 5.42s
# 2499:	total: 2m 16s	remaining: 0us
# 0:	total: 88.7ms	remaining: 3m 41s
# 100:	total: 5.28s	remaining: 2m 5s
# 200:	total: 10.8s	remaining: 2m 3s
# 300:	total: 16.4s	remaining: 2m
# 400:	total: 21.8s	remaining: 1m 54s
# 500:	total: 27.1s	remaining: 1m 48s
# 600:	total: 32.3s	remaining: 1m 42s
# 700:	total: 37.5s	remaining: 1m 36s
# 800:	total: 42.7s	remaining: 1m 30s
# 900:	total: 47.9s	remaining: 1m 25s
# 1000:	total: 53.2s	remaining: 1m 19s
# 1100:	total: 58.5s	remaining: 1m 14s
# 1200:	total: 1m 3s	remaining: 1m 8s
# 1300:	total: 1m 8s	remaining: 1m 3s
# 1400:	total: 1m 14s	remaining: 58.4s
# 1500:	total: 1m 20s	remaining: 53.3s
# 1600:	total: 1m 26s	remaining: 48.3s
# 1700:	total: 1m 31s	remaining: 43s
# 1800:	total: 1m 37s	remaining: 37.8s
# 1900:	total: 1m 42s	remaining: 32.4s
# 2000:	total: 1m 48s	remaining: 27.1s
# 2100:	total: 1m 53s	remaining: 21.6s
# 2200:	total: 1m 59s	remaining: 16.2s
# 2300:	total: 2m 4s	remaining: 10.8s
# 2400:	total: 2m 10s	remaining: 5.37s
# 2499:	total: 2m 15s	remaining: 0us
# 0:	total: 60.5ms	remaining: 2m 31s
# 100:	total: 5.36s	remaining: 2m 7s
# 200:	total: 10.7s	remaining: 2m 2s
# 300:	total: 16.3s	remaining: 1m 59s
# 400:	total: 21.8s	remaining: 1m 54s
# 500:	total: 27.5s	remaining: 1m 49s
# 600:	total: 33.2s	remaining: 1m 44s
# 700:	total: 39.1s	remaining: 1m 40s
# 800:	total: 44.7s	remaining: 1m 34s
# 900:	total: 50.4s	remaining: 1m 29s
# 1000:	total: 56s	remaining: 1m 23s
# 1100:	total: 1m 1s	remaining: 1m 18s
# 1200:	total: 1m 7s	remaining: 1m 12s
# 1300:	total: 1m 13s	remaining: 1m 7s
# 1400:	total: 1m 18s	remaining: 1m 1s
# 1500:	total: 1m 24s	remaining: 56.1s
# 1600:	total: 1m 29s	remaining: 50.5s
# 1700:	total: 1m 35s	remaining: 44.9s
# 1800:	total: 1m 41s	remaining: 39.4s
# 1900:	total: 1m 46s	remaining: 33.6s
# 2000:	total: 1m 52s	remaining: 28s
# 2100:	total: 1m 58s	remaining: 22.4s
# 2200:	total: 2m 5s	remaining: 17s
# 2300:	total: 2m 15s	remaining: 11.7s
# 2400:	total: 2m 21s	remaining: 5.85s
# 2499:	total: 2m 26s	remaining: 0us
# 0:	total: 70ms	remaining: 2m 54s
# 100:	total: 5.2s	remaining: 2m 3s
# 200:	total: 10.8s	remaining: 2m 3s
# 300:	total: 16.3s	remaining: 1m 58s
# 400:	total: 21.9s	remaining: 1m 54s
# 500:	total: 27.5s	remaining: 1m 49s
# 600:	total: 32.4s	remaining: 1m 42s
# 700:	total: 37.7s	remaining: 1m 36s
# 800:	total: 42.8s	remaining: 1m 30s
# 900:	total: 48.4s	remaining: 1m 25s
# 1000:	total: 53.7s	remaining: 1m 20s
# 1100:	total: 59s	remaining: 1m 14s
# 1200:	total: 1m 4s	remaining: 1m 9s
# 1300:	total: 1m 9s	remaining: 1m 4s
# 1400:	total: 1m 14s	remaining: 58.8s
# 1500:	total: 1m 20s	remaining: 53.4s
# 1600:	total: 1m 25s	remaining: 48.1s
# 1700:	total: 1m 30s	remaining: 42.7s
# 1800:	total: 1m 36s	remaining: 37.3s
# 1900:	total: 1m 41s	remaining: 32s
# 2000:	total: 1m 47s	remaining: 26.7s
# 2100:	total: 1m 52s	remaining: 21.4s
# 2200:	total: 1m 58s	remaining: 16.1s
# 2300:	total: 2m 3s	remaining: 10.7s
# 2400:	total: 2m 8s	remaining: 5.3s
# 2499:	total: 2m 13s	remaining: 0us
# 0:	total: 60.4ms	remaining: 2m 30s
# 100:	total: 5.58s	remaining: 2m 12s
# 200:	total: 11.2s	remaining: 2m 8s
# 300:	total: 16.9s	remaining: 2m 3s
# 400:	total: 21.9s	remaining: 1m 54s
# 500:	total: 27.2s	remaining: 1m 48s

# %%
#categorical_features_indices = np.where(X_train.dtypes != np.float)[0]
cat1 = CatBoostClassifier(loss_function="Logloss",eval_metric="AUC",
                          iterations=2500,learning_rate=0.01,depth=8,verbose=100,bagging_temperature = 0.42,
                          early_stopping_rounds=500)
cat1.fit(X_train,pd.DataFrame(y_train))

y_test_pre = cat1.predict(X_test)
y_test_true = np.array(y_test)
print ("the catboost model auc : %.4g" % metrics.roc_auc_score(y_test_true,y_test_pre))
# Out:
# 0:	total: 63.8ms	remaining: 2m 39s
# 100:	total: 5.34s	remaining: 2m 6s
# 200:	total: 10.6s	remaining: 2m 1s
# 300:	total: 15.6s	remaining: 1m 53s
# 400:	total: 20.5s	remaining: 1m 47s
# 500:	total: 25.5s	remaining: 1m 41s
# 600:	total: 30.4s	remaining: 1m 36s
# 700:	total: 35.4s	remaining: 1m 30s
# 800:	total: 40.3s	remaining: 1m 25s
# 900:	total: 45.2s	remaining: 1m 20s
# 1000:	total: 50.2s	remaining: 1m 15s
# 1100:	total: 55.3s	remaining: 1m 10s
# 1200:	total: 1m	remaining: 1m 5s
# 1300:	total: 1m 5s	remaining: 1m
# 1400:	total: 1m 10s	remaining: 55s
# 1500:	total: 1m 15s	remaining: 50s
# 1600:	total: 1m 20s	remaining: 45s
# 1700:	total: 1m 25s	remaining: 40s
# 1800:	total: 1m 29s	remaining: 34.9s
# 1900:	total: 1m 34s	remaining: 29.9s
# 2000:	total: 1m 39s	remaining: 24.9s
# 2100:	total: 1m 44s	remaining: 19.9s
# 2200:	total: 1m 49s	remaining: 14.9s
# 2300:	total: 1m 54s	remaining: 9.92s
# 2400:	total: 1m 59s	remaining: 4.94s
# 2499:	total: 2m 4s	remaining: 0us
# the catboost model auc : 0.8623

# %%
#具体的模型得分报告
print(classification_report(y_test_true,y_test_pre))
print("auc值为:",roc_auc_score(y_test_true,y_test_pre))

#ROC曲线绘制
fpr1,tpr1,threshold1 = roc_curve(y_test_true,y_test_pre)
plt.plot(fpr1, tpr1, color='r') 
plt.plot([0, 1], [0, 1], color='blue',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('CatBoostClassifier ROC Curve')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3364
#          1.0       1.00      0.72      0.84        69
#
#     accuracy                           0.99      3433
#    macro avg       1.00      0.86      0.92      3433
# weighted avg       0.99      0.99      0.99      3433
#
# auc值为: 0.8623188405797102
# Text(0.5, 1.0, 'CatBoostClassifier ROC Curve')

# %%
#特征重要性排名
cat_predictors = [i  for i in ramdonForest_end_Data.drop(columns = 'FLAG').columns]
cat_feat_imp = pd.Series(cat1.feature_importances_,cat_predictors).sort_values(ascending=False)
cat_feat_imp[0:20].plot(kind = 'bar',title='Feature Importance')
plt.ylabel('Feature Importance Score')
plt.show()
print(cat_feat_imp)
# Out:
# ASSETS_IMPAIR_LOSS     3.126828
# DILUTED_EPS            2.571754
# NOPERATE_EXP           2.501154
# BASIC_EPS              2.176551
# ADVANCE_RECEIPTS       1.992892
#                          ...
# OTH_COMPR_INCOME       0.464318
# BIZ_TAX_SURCHG         0.417010
# T_LIAB                 0.394510
# C_PAID_DIV_PROF_INT    0.345849
# T_CL                   0.288373
# Length: 98, dtype: float64

# %%
print(cat_feat_imp[0:20])
# Out:
# ASSETS_IMPAIR_LOSS     3.126828
# DILUTED_EPS            2.571754
# NOPERATE_EXP           2.501154
# BASIC_EPS              2.176551
# ADVANCE_RECEIPTS       1.992892
# OTH_CA                 1.918777
# OTH_PAYABLE            1.890064
# INVEST_INCOME          1.841392
# C_PAID_OTH_FINAN_A     1.838302
# DISP_FIX_ASSETS_OTH    1.801449
# FOREX_EFFECTS          1.790290
# OR_TC                  1.780632
# C_INF_FR_INVEST_A      1.738514
# MINORITY_INT           1.669192
# NOTES_PAYABLE          1.664507
# RETAINED_EARNINGS      1.604778
# REFUND_OF_TAX          1.479321
# PAID_IN_CAPITAL        1.449349
# LT_AMOR_EXP            1.422186
# OTH_NCA                1.366682
# dtype: float64
